# %%
import wandb
import sleap_roots_training

from pathlib import Path

# %%
# Constants for W&B initialization
ENTITY_NAME = "eberrigan-salk-institute-for-biological-studies"
PROJECT_NAME = "sleap-roots"
REGISTRY = "sleap-roots-labels"
JOB_TYPE = "build_dataset"
EXPERIMENT_NAME = "wheat_5-14DAG_seminal_6nodes_labels_2025-05-29"

# Constants for dataset creation
ARTIFACT_NAME = "wheat_5-14DAG_seminal_6nodes_labels"
DESCRIPTION = "5-14 DAG wheat labels for seminal root with 6 nodes"
TAGS = ["wheat", "5-14DAG", "seminal", "6nodes", "wheat5-14DAG"]
COLLECTION_NAME = "wheat_5-14DAG_seminal_6nodes_labels"
DATASET_PATH = "D:/SLEAP/20250529_seminal_root_generalist/wheat/labels_sr_5-14DAG.v004.slp"

# %%
print(wandb.run)
# Out:
# None

# %%
sleap_roots_training.reset_config()
# Out:
# Configuration updated successfully at e:\repositories\sleap-roots-training\sleap_roots_training\config.yaml.
# Configuration has been reset to default values.

# %%
sleap_roots_training.update_config(entity_name=ENTITY_NAME, project_name=PROJECT_NAME, registry=REGISTRY, job_type=JOB_TYPE, experiment_name=EXPERIMENT_NAME, collection_name=COLLECTION_NAME)
# Out:
# Configuration updated successfully at e:\repositories\sleap-roots-training\sleap_roots_training\config.yaml.
# CONFIG updated to {'project_name': 'sleap-roots', 'entity_name': 'eberrigan-salk-institute-for-biological-studies', 'experiment_name': 'wheat_5-14DAG_seminal_6nodes_labels_2025-05-29', 'registry': 'sleap-roots-labels', 'collection_name': 'wheat_5-14DAG_seminal_6nodes_labels', 'job_type': 'build_dataset'}.

# %%
sleap_roots_training.make_dataset_artifact(artifact_name=ARTIFACT_NAME, dataset_path=DATASET_PATH, link_to_registry=True, description=DESCRIPTION, tags=TAGS)
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: eberrigan (eberrigan-salk-institute-for-biological-studies). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.6
# Run data is saved locally in <code>e:\repositories\sleap-roots-training\wandb\run-20250529_152109-jz0lepft</code>
# Syncing run <strong><a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/jz0lepft' target="_blank">wheat_5-14DAG_seminal_6nodes_labels_2025-05-29</a></strong> to <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a>
#  View run at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/jz0lepft' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/jz0lepft</a>
# INFO:root:Dataset artifact created: wheat_5-14DAG_seminal_6nodes_labels from D:/SLEAP/20250529_seminal_root_generalist/wheat/labels_sr_5-14DAG.v004.slp.
# INFO:root:Linking wheat_5-14DAG_seminal_6nodes_labels to registry eberrigan-salk-institute-for-biological-studies-org/wandb-registry-sleap-roots-labels/wheat_5-14DAG_seminal_6nodes_labels.
# VBox(children=(Label(value='5.623 MB of 5.623 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
#  View run <strong style="color:#cdcd00">wheat_5-14DAG_seminal_6nodes_labels_2025-05-29</strong> at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/jz0lepft' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/jz0lepft</a><br/> View project at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a><br/>Synced 6 W&B file(s), 0 media file(s), 4 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250529_152109-jz0lepft\logs</code>
# INFO:root:W&B run finished successfully.
# <Artifact QXJ0aWZhY3Q6MTc3MjY3NDUwOA==>
