# %%
import wandb
import sleap_roots_training

from pathlib import Path

from sleap_roots_training.train import main

# %%
# Constants for W&B initialization
ENTITY_NAME = "eberrigan-salk-institute-for-biological-studies"
PROJECT_NAME = "sleap-roots"
REGISTRY = "sleap-roots-models"
JOB_TYPE = "sweep"
EXPERIMENT_NAME = "20250529_wheat_seminal_sweep"

# Constants for artifact creation
DESCRIPTION = "wheat 5-14 DAG seminal roots with 6 nodes with varying input scaling"
TAGS = ["wheat5-14DAG", "seminal", "6nodes", "wheat", "input_scaling"]
MODEL_TAGS = ["wheat5-14DAG", "seminal", "6nodes", "wheat"]
COLLECTION_NAME = EXPERIMENT_NAME
CSV_PATH = "D:/SLEAP/20250529_seminal_root_generalist/wheat/train_test_splits.csv"

# %%
print(wandb.run)
# Out:
# None

# %%
sleap_roots_training.reset_config()
# Out:
# Configuration updated successfully at e:\repositories\sleap-roots-training\sleap_roots_training\config.yaml.
# Configuration has been reset to default values.

# %%
sleap_roots_training.update_config(entity_name=ENTITY_NAME, project_name=PROJECT_NAME, registry=REGISTRY, job_type=JOB_TYPE, experiment_name=EXPERIMENT_NAME, collection_name=COLLECTION_NAME)
# Out:
# Configuration updated successfully at e:\repositories\sleap-roots-training\sleap_roots_training\config.yaml.
# CONFIG updated to {'project_name': 'sleap-roots', 'entity_name': 'eberrigan-salk-institute-for-biological-studies', 'experiment_name': '20250529_wheat_seminal_sweep', 'registry': 'sleap-roots-models', 'collection_name': '20250529_wheat_seminal_sweep', 'job_type': 'sweep'}.

# %%
# Define the sweep configuration
sweep_config = {
    "method": "grid",
    "parameters": {
        "data.preprocessing.input_scaling": {"values": [0.5, 0.75, 1.0]}
    }
}

# %%
main(csv_path=CSV_PATH, tags=TAGS, model_tags=MODEL_TAGS, use_sweep=True, sweep_config=sweep_config)
# Out:
# INFO:root:Starting main function with CSV: D:/SLEAP/20250529_seminal_root_generalist/wheat/train_test_splits.csv
# INFO:root:Detected 3 train-test splits.
# INFO:root:Processing train-test split version: 0
# INFO:root:Creating W&B sweep for version 0...
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# Create sweep with ID: 872vxc35
# Sweep URL: https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/sweeps/872vxc35
# INFO:root:Sweep created for version 0 with ID: 872vxc35
# INFO:root:Running W&B grid sweep with 3 experiments for version 0...
# INFO:wandb.agents.pyagent:Starting sweep agent: entity=None, project=None, count=3
# wandb: Agent Starting Run: sxyykxsq with config:
# wandb: 	data.preprocessing.input_scaling: 0.5
# INFO:root:Starting training for version 0...
# INFO:root:Directory path for version 0: D:\SLEAP\20250529_seminal_root_generalist\wheat\train_test_split.v000
# wandb: Currently logged in as: eberrigan (eberrigan-salk-institute-for-biological-studies). Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# Tracking run with wandb version 0.18.6
# Run data is saved locally in <code>e:\repositories\sleap-roots-training\wandb\run-20250529_155024-sxyykxsq</code>
# Syncing run <strong><a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/sxyykxsq' target="_blank">20250529_wheat_seminal_sweep_training_v000</a></strong> to <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/sweeps/872vxc35' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/sweeps/872vxc35</a>
#  View project at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a>
#  View sweep at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/sweeps/872vxc35' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/sweeps/872vxc35</a>
#  View run at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/sxyykxsq' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/sxyykxsq</a>
# INFO:root:Updating configuration with W&B parameters.
# INFO:root:Original Parameters: {
#     "data": {
#         "labels": {
#             "training_labels": "D:\\SLEAP\\20250529_seminal_root_generalist\\wheat\\train_test_split.v000\\train.pkg.slp",
#             "validation_labels": "D:\\SLEAP\\20250529_seminal_root_generalist\\wheat\\train_test_split.v000\\val.pkg.slp",
#             "validation_fraction": 0.1,
#             "test_labels": "D:\\SLEAP\\20250529_seminal_root_generalist\\wheat\\train_test_split.v000\\test.pkg.slp",
#             "split_by_inds": false,
#             "training_inds": null,
#             "validation_inds": null,
#             "test_inds": null,
#             "search_path_hints": [],
#             "skeletons": []
#         },
#         "preprocessing": {
#             "ensure_rgb": false,
#             "ensure_grayscale": false,
#             "imagenet_mode": null,
#             "input_scaling": 1.0,
#             "pad_to_stride": null,
#             "resize_and_pad_to_target": true,
#             "target_height": null,
#             "target_width": null
#         },
#         "instance_cropping": {
#             "center_on_part": null,
#             "crop_size": null,
#             "crop_size_detection_padding": 16
#         }
#     },
#     "model": {
#         "backbone": {
#             "leap": null,
#             "unet": {
#                 "stem_stride": null,
#                 "max_stride": 64,
#                 "output_stride": 2,
#                 "filters": 24,
#                 "filters_rate": 1.5,
#                 "middle_block": true,
#                 "up_interpolate": true,
#                 "stacks": 1
#             },
#             "hourglass": null,
#             "resnet": null,
#             "pretrained_encoder": null
#         },
#         "heads": {
#             "single_instance": null,
#             "centroid": null,
#             "centered_instance": null,
#             "multi_instance": {
#                 "confmaps": {
#                     "part_names": null,
#                     "sigma": 2.5,
#                     "output_stride": 2,
#                     "loss_weight": 1.0,
#                     "offset_refinement": false
#                 },
#                 "pafs": {
#                     "edges": null,
#                     "sigma": 75.0,
#                     "output_stride": 8,
#                     "loss_weight": 1.0
#                 }
#             }
#         }
#     },
#     "optimization": {
#         "preload_data": true,
#         "augmentation_config": {
#             "rotate": true,
#             "rotation_min_angle": -5.0,
#             "rotation_max_angle": 5.0,
#             "translate": false,
#             "translate_min": -5,
#             "translate_max": 5,
#             "scale": true,
#             "scale_min": 0.5,
#             "scale_max": 1.2,
#             "uniform_noise": false,
#             "uniform_noise_min_val": 0.0,
#             "uniform_noise_max_val": 10.0,
#             "gaussian_noise": false,
#             "gaussian_noise_mean": 5.0,
#             "gaussian_noise_stddev": 1.0,
#             "contrast": true,
#             "contrast_min_gamma": 0.5,
#             "contrast_max_gamma": 2.0,
#             "brightness": false,
#             "brightness_min_val": 0.0,
#             "brightness_max_val": 10.0,
#             "random_crop": false,
#             "random_crop_height": 256,
#             "random_crop_width": 256,
#             "random_flip": false,
#             "flip_horizontal": true
#         },
#         "online_shuffling": true,
#         "shuffle_buffer_size": 128,
#         "prefetch": true,
#         "batch_size": 4,
#         "batches_per_epoch": null,
#         "min_batches_per_epoch": 200,
#         "val_batches_per_epoch": null,
#         "min_val_batches_per_epoch": 10,
#         "epochs": 200,
#         "optimizer": "adam",
#         "initial_learning_rate": 0.0001,
#         "learning_rate_schedule": {
#             "reduce_on_plateau": true,
#             "reduction_factor": 0.5,
#             "plateau_min_delta": 1e-06,
#             "plateau_patience": 5,
#             "plateau_cooldown": 3,
#             "min_learning_rate": 1e-08
#         },
#         "hard_keypoint_mining": {
#             "online_mining": false,
#             "hard_to_easy_ratio": 2.0,
#             "min_hard_keypoints": 2,
#             "max_hard_keypoints": null,
#             "loss_scale": 5.0
#         },
#         "early_stopping": {
#             "stop_training_on_plateau": true,
#             "plateau_min_delta": 1e-06,
#             "plateau_patience": 10
#         }
#     },
#     "outputs": {
#         "save_outputs": true,
#         "run_name": null,
#         "run_name_prefix": "",
#         "run_name_suffix": "",
#         "runs_folder": "D:\\SLEAP\\20250529_seminal_root_generalist\\wheat\\train_test_split.v000\\models",
#         "tags": [
#             ""
#         ],
#         "save_visualizations": false,
#         "delete_viz_images": true,
#         "zip_outputs": false,
#         "log_to_csv": true,
#         "checkpointing": {
#             "initial_model": false,
#             "best_model": true,
#             "every_epoch": false,
#             "latest_model": false,
#             "final_model": false
#         },
#         "tensorboard": {
#             "write_logs": false,
#             "loss_frequency": "epoch",
#             "architecture_graph": false,
#             "profile_graph": false,
#             "visualizations": true
#         },
#         "zmq": {
#             "subscribe_to_controller": false,
#             "controller_address": "tcp://127.0.0.1:9000",
#             "controller_polling_timeout": 10,
#             "publish_updates": false,
#             "publish_address": "tcp://127.0.0.1:9001"
#         }
#     },
#     "name": "",
#     "description": "",
#     "sleap_version": "",
#     "filename": "",
#     "data.preprocessing.input_scaling": 0.5,
#     "version": 0,
#     "config_path": "D:/SLEAP/20250529_seminal_root_generalist/wheat/train_test_split.v000/initial_config_modified_v000.json"
# }
# INFO:root:Updated parameter: data -> {'labels': {'training_labels': 'D:\\SLEAP\\20250529_seminal_root_generalist\\wheat\\train_test_split.v000\\train.pkg.slp', 'validation_labels': 'D:\\SLEAP\\20250529_seminal_root_generalist\\wheat\\train_test_split.v000\\val.pkg.slp', 'validation_fraction': 0.1, 'test_labels': 'D:\\SLEAP\\20250529_seminal_root_generalist\\wheat\\train_test_split.v000\\test.pkg.slp', 'split_by_inds': False, 'training_inds': None, 'validation_inds': None, 'test_inds': None, 'search_path_hints': [], 'skeletons': []}, 'preprocessing': {'ensure_rgb': False, 'ensure_grayscale': False, 'imagenet_mode': None, 'input_scaling': 1.0, 'pad_to_stride': None, 'resize_and_pad_to_target': True, 'target_height': None, 'target_width': None}, 'instance_cropping': {'center_on_part': None, 'crop_size': None, 'crop_size_detection_padding': 16}}
# INFO:root:Updated parameter: model -> {'backbone': {'leap': None, 'unet': {'stem_stride': None, 'max_stride': 64, 'output_stride': 2, 'filters': 24, 'filters_rate': 1.5, 'middle_block': True, 'up_interpolate': True, 'stacks': 1}, 'hourglass': None, 'resnet': None, 'pretrained_encoder': None}, 'heads': {'single_instance': None, 'centroid': None, 'centered_instance': None, 'multi_instance': {'confmaps': {'part_names': None, 'sigma': 2.5, 'output_stride': 2, 'loss_weight': 1.0, 'offset_refinement': False}, 'pafs': {'edges': None, 'sigma': 75.0, 'output_stride': 8, 'loss_weight': 1.0}}}}
# INFO:root:Updated parameter: optimization -> {'preload_data': True, 'augmentation_config': {'rotate': True, 'rotation_min_angle': -5.0, 'rotation_max_angle': 5.0, 'translate': False, 'translate_min': -5, 'translate_max': 5, 'scale': True, 'scale_min': 0.5, 'scale_max': 1.2, 'uniform_noise': False, 'uniform_noise_min_val': 0.0, 'uniform_noise_max_val': 10.0, 'gaussian_noise': False, 'gaussian_noise_mean': 5.0, 'gaussian_noise_stddev': 1.0, 'contrast': True, 'contrast_min_gamma': 0.5, 'contrast_max_gamma': 2.0, 'brightness': False, 'brightness_min_val': 0.0, 'brightness_max_val': 10.0, 'random_crop': False, 'random_crop_height': 256, 'random_crop_width': 256, 'random_flip': False, 'flip_horizontal': True}, 'online_shuffling': True, 'shuffle_buffer_size': 128, 'prefetch': True, 'batch_size': 4, 'batches_per_epoch': None, 'min_batches_per_epoch': 200, 'val_batches_per_epoch': None, 'min_val_batches_per_epoch': 10, 'epochs': 200, 'optimizer': 'adam', 'initial_learning_rate': 0.0001, 'learning_rate_schedule': {'reduce_on_plateau': True, 'reduction_factor': 0.5, 'plateau_min_delta': 1e-06, 'plateau_patience': 5, 'plateau_cooldown': 3, 'min_learning_rate': 1e-08}, 'hard_keypoint_mining': {'online_mining': False, 'hard_to_easy_ratio': 2.0, 'min_hard_keypoints': 2, 'max_hard_keypoints': None, 'loss_scale': 5.0}, 'early_stopping': {'stop_training_on_plateau': True, 'plateau_min_delta': 1e-06, 'plateau_patience': 10}}
# INFO:root:Updated parameter: outputs -> {'save_outputs': True, 'run_name': None, 'run_name_prefix': '', 'run_name_suffix': '', 'runs_folder': 'D:\\SLEAP\\20250529_seminal_root_generalist\\wheat\\train_test_split.v000\\models', 'tags': [''], 'save_visualizations': False, 'delete_viz_images': True, 'zip_outputs': False, 'log_to_csv': True, 'checkpointing': {'initial_model': False, 'best_model': True, 'every_epoch': False, 'latest_model': False, 'final_model': False}, 'tensorboard': {'write_logs': False, 'loss_frequency': 'epoch', 'architecture_graph': False, 'profile_graph': False, 'visualizations': True}, 'zmq': {'subscribe_to_controller': False, 'controller_address': 'tcp://127.0.0.1:9000', 'controller_polling_timeout': 10, 'publish_updates': False, 'publish_address': 'tcp://127.0.0.1:9001'}}
# INFO:root:Updated parameter: name ->
# INFO:root:Updated parameter: description ->
# INFO:root:Updated parameter: sleap_version ->
# INFO:root:Updated parameter: filename ->
# INFO:root:Updated parameter: data.preprocessing.input_scaling -> 0.5
# INFO:root:Updated parameter: version -> 0
# INFO:root:Updated parameter: config_path -> D:/SLEAP/20250529_seminal_root_generalist/wheat/train_test_split.v000/initial_config_modified_v000.json
# INFO:root:Final updated configuration:
# {
#     "data": {
#         "labels": {
#             "training_labels": "D:\\SLEAP\\20250529_seminal_root_generalist\\wheat\\train_test_split.v000\\train.pkg.slp",
#             "validation_labels": "D:\\SLEAP\\20250529_seminal_root_generalist\\wheat\\train_test_split.v000\\val.pkg.slp",
#             "validation_fraction": 0.1,
#             "test_labels": "D:\\SLEAP\\20250529_seminal_root_generalist\\wheat\\train_test_split.v000\\test.pkg.slp",
#             "split_by_inds": false,
#             "training_inds": null,
#             "validation_inds": null,
#             "test_inds": null,
#             "search_path_hints": [],
#             "skeletons": []
#         },
#         "preprocessing": {
#             "ensure_rgb": false,
#             "ensure_grayscale": false,
#             "imagenet_mode": null,
#             "input_scaling": 0.5,
#             "pad_to_stride": null,
#             "resize_and_pad_to_target": true,
#             "target_height": null,
#             "target_width": null
#         },
#         "instance_cropping": {
#             "center_on_part": null,
#             "crop_size": null,
#             "crop_size_detection_padding": 16
#         }
#     },
#     "model": {
#         "backbone": {
#             "leap": null,
#             "unet": {
#                 "stem_stride": null,
#                 "max_stride": 64,
#                 "output_stride": 2,
#                 "filters": 24,
#                 "filters_rate": 1.5,
#                 "middle_block": true,
#                 "up_interpolate": true,
#                 "stacks": 1
#             },
#             "hourglass": null,
#             "resnet": null,
#             "pretrained_encoder": null
#         },
#         "heads": {
#             "single_instance": null,
#             "centroid": null,
#             "centered_instance": null,
#             "multi_instance": {
#                 "confmaps": {
#                     "part_names": null,
#                     "sigma": 2.5,
#                     "output_stride": 2,
#                     "loss_weight": 1.0,
#                     "offset_refinement": false
#                 },
#                 "pafs": {
#                     "edges": null,
#                     "sigma": 75.0,
#                     "output_stride": 8,
#                     "loss_weight": 1.0
#                 }
#             }
#         }
#     },
#     "optimization": {
#         "preload_data": true,
#         "augmentation_config": {
#             "rotate": true,
#             "rotation_min_angle": -5.0,
#             "rotation_max_angle": 5.0,
#             "translate": false,
#             "translate_min": -5,
#             "translate_max": 5,
#             "scale": true,
#             "scale_min": 0.5,
#             "scale_max": 1.2,
#             "uniform_noise": false,
#             "uniform_noise_min_val": 0.0,
#             "uniform_noise_max_val": 10.0,
#             "gaussian_noise": false,
#             "gaussian_noise_mean": 5.0,
#             "gaussian_noise_stddev": 1.0,
#             "contrast": true,
#             "contrast_min_gamma": 0.5,
#             "contrast_max_gamma": 2.0,
#             "brightness": false,
#             "brightness_min_val": 0.0,
#             "brightness_max_val": 10.0,
#             "random_crop": false,
#             "random_crop_height": 256,
#             "random_crop_width": 256,
#             "random_flip": false,
#             "flip_horizontal": true
#         },
#         "online_shuffling": true,
#         "shuffle_buffer_size": 128,
#         "prefetch": true,
#         "batch_size": 4,
#         "batches_per_epoch": null,
#         "min_batches_per_epoch": 200,
#         "val_batches_per_epoch": null,
#         "min_val_batches_per_epoch": 10,
#         "epochs": 200,
#         "optimizer": "adam",
#         "initial_learning_rate": 0.0001,
#         "learning_rate_schedule": {
#             "reduce_on_plateau": true,
#             "reduction_factor": 0.5,
#             "plateau_min_delta": 1e-06,
#             "plateau_patience": 5,
#             "plateau_cooldown": 3,
#             "min_learning_rate": 1e-08
#         },
#         "hard_keypoint_mining": {
#             "online_mining": false,
#             "hard_to_easy_ratio": 2.0,
#             "min_hard_keypoints": 2,
#             "max_hard_keypoints": null,
#             "loss_scale": 5.0
#         },
#         "early_stopping": {
#             "stop_training_on_plateau": true,
#             "plateau_min_delta": 1e-06,
#             "plateau_patience": 10
#         }
#     },
#     "outputs": {
#         "save_outputs": true,
#         "run_name": null,
#         "run_name_prefix": "",
#         "run_name_suffix": "",
#         "runs_folder": "D:\\SLEAP\\20250529_seminal_root_generalist\\wheat\\train_test_split.v000\\models",
#         "tags": [
#             ""
#         ],
#         "save_visualizations": false,
#         "delete_viz_images": true,
#         "zip_outputs": false,
#         "log_to_csv": true,
#         "checkpointing": {
#             "initial_model": false,
#             "best_model": true,
#             "every_epoch": false,
#             "latest_model": false,
#             "final_model": false
#         },
#         "tensorboard": {
#             "write_logs": false,
#             "loss_frequency": "epoch",
#             "architecture_graph": false,
#             "profile_graph": false,
#             "visualizations": true
#         },
#         "zmq": {
#             "subscribe_to_controller": false,
#             "controller_address": "tcp://127.0.0.1:9000",
#             "controller_polling_timeout": 10,
#             "publish_updates": false,
#             "publish_address": "tcp://127.0.0.1:9001"
#         }
#     },
#     "name": "",
#     "description": "",
#     "sleap_version": "",
#     "filename": "",
#     "version": 0,
#     "config_path": "D:/SLEAP/20250529_seminal_root_generalist/wheat/train_test_split.v000/initial_config_modified_v000.json"
# }
# INFO:root:Saved updated configuration to: D:\SLEAP\20250529_seminal_root_generalist\wheat\train_test_split.v000\modified_config_v000_20250529_155025.json
# INFO:root:Training with updated config for version 0.
# INFO:root:Executing training command: sleap-train D:/SLEAP/20250529_seminal_root_generalist/wheat/train_test_split.v000/modified_config_v000_20250529_155025.json
# Executing: sleap-train D:/SLEAP/20250529_seminal_root_generalist/wheat/train_test_split.v000/modified_config_v000_20250529_155025.json
# INFO:sleap.nn.training:Versions:
# SLEAP: 1.3.4
# TensorFlow: 2.7.0
# Numpy: 1.21.6
# Python: 3.7.12
# OS: Windows-10-10.0.26100-SP0
# INFO:sleap.nn.training:Training labels file: None
# INFO:sleap.nn.training:Training profile: D:/SLEAP/20250529_seminal_root_generalist/wheat/train_test_split.v000/modified_config_v000_20250529_155025.json
# INFO:sleap.nn.training:
# INFO:sleap.nn.training:Arguments:
# INFO:sleap.nn.training:{
#     "training_job_path": "D:/SLEAP/20250529_seminal_root_generalist/wheat/train_test_split.v000/modified_config_v000_20250529_155025.json",
#     "labels_path": null,
#     "video_paths": [
#         ""
#     ],
#     "val_labels": null,
#     "test_labels": null,
#     "base_checkpoint": null,
#     "tensorboard": false,
#     "save_viz": false,
#     "zmq": false,
#     "run_name": "",
#     "prefix": "",
#     "suffix": "",
#     "cpu": false,
#     "first_gpu": false,
#     "last_gpu": false,
#     "gpu": "auto"
# }
# INFO:sleap.nn.training:
# INFO:sleap.nn.training:Training job:
# INFO:sleap.nn.training:{
#     "data": {
#         "labels": {
#             "training_labels": "D:\\SLEAP\\20250529_seminal_root_generalist\\wheat\\train_test_split.v000\\train.pkg.slp",
#             "validation_labels": "D:\\SLEAP\\20250529_seminal_root_generalist\\wheat\\train_test_split.v000\\val.pkg.slp",
#             "validation_fraction": 0.1,
#             "test_labels": "D:\\SLEAP\\20250529_seminal_root_generalist\\wheat\\train_test_split.v000\\test.pkg.slp",
#             "split_by_inds": false,
#             "training_inds": null,
#             "validation_inds": null,
#             "test_inds": null,
#             "search_path_hints": [],
#             "skeletons": []
#         },
#         "preprocessing": {
#             "ensure_rgb": false,
#             "ensure_grayscale": false,
#             "imagenet_mode": null,
#             "input_scaling": 0.5,
#             "pad_to_stride": null,
#             "resize_and_pad_to_target": true,
#             "target_height": null,
#             "target_width": null
#         },
#         "instance_cropping": {
#             "center_on_part": null,
#             "crop_size": null,
#             "crop_size_detection_padding": 16
#         }
#     },
#     "model": {
#         "backbone": {
#             "leap": null,
#             "unet": {
#                 "stem_stride": null,
#                 "max_stride": 64,
#                 "output_stride": 2,
#                 "filters": 24,
#                 "filters_rate": 1.5,
#                 "middle_block": true,
#                 "up_interpolate": true,
#                 "stacks": 1
#             },
#             "hourglass": null,
#             "resnet": null,
#             "pretrained_encoder": null
#         },
#         "heads": {
#             "single_instance": null,
#             "centroid": null,
#             "centered_instance": null,
#             "multi_instance": {
#                 "confmaps": {
#                     "part_names": null,
#                     "sigma": 2.5,
#                     "output_stride": 2,
#                     "loss_weight": 1.0,
#                     "offset_refinement": false
#                 },
#                 "pafs": {
#                     "edges": null,
#                     "sigma": 75.0,
#                     "output_stride": 8,
#                     "loss_weight": 1.0
#                 }
#             },
#             "multi_class_bottomup": null,
#             "multi_class_topdown": null
#         },
#         "base_checkpoint": null
#     },
#     "optimization": {
#         "preload_data": true,
#         "augmentation_config": {
#             "rotate": true,
#             "rotation_min_angle": -5.0,
#             "rotation_max_angle": 5.0,
#             "translate": false,
#             "translate_min": -5,
#             "translate_max": 5,
#             "scale": true,
#             "scale_min": 0.5,
#             "scale_max": 1.2,
#             "uniform_noise": false,
#             "uniform_noise_min_val": 0.0,
#             "uniform_noise_max_val": 10.0,
#             "gaussian_noise": false,
#             "gaussian_noise_mean": 5.0,
#             "gaussian_noise_stddev": 1.0,
#             "contrast": true,
#             "contrast_min_gamma": 0.5,
#             "contrast_max_gamma": 2.0,
#             "brightness": false,
#             "brightness_min_val": 0.0,
#             "brightness_max_val": 10.0,
#             "random_crop": false,
#             "random_crop_height": 256,
#             "random_crop_width": 256,
#             "random_flip": false,
#             "flip_horizontal": true
#         },
#         "online_shuffling": true,
#         "shuffle_buffer_size": 128,
#         "prefetch": true,
#         "batch_size": 4,
#         "batches_per_epoch": null,
#         "min_batches_per_epoch": 200,
#         "val_batches_per_epoch": null,
#         "min_val_batches_per_epoch": 10,
#         "epochs": 200,
#         "optimizer": "adam",
#         "initial_learning_rate": 0.0001,
#         "learning_rate_schedule": {
#             "reduce_on_plateau": true,
#             "reduction_factor": 0.5,
#             "plateau_min_delta": 1e-06,
#             "plateau_patience": 5,
#             "plateau_cooldown": 3,
#             "min_learning_rate": 1e-08
#         },
#         "hard_keypoint_mining": {
#             "online_mining": false,
#             "hard_to_easy_ratio": 2.0,
#             "min_hard_keypoints": 2,
#             "max_hard_keypoints": null,
#             "loss_scale": 5.0
#         },
#         "early_stopping": {
#             "stop_training_on_plateau": true,
#             "plateau_min_delta": 1e-06,
#             "plateau_patience": 10
#         }
#     },
#     "outputs": {
#         "save_outputs": true,
#         "run_name": null,
#         "run_name_prefix": "",
#         "run_name_suffix": "",
#         "runs_folder": "D:\\SLEAP\\20250529_seminal_root_generalist\\wheat\\train_test_split.v000\\models",
#         "tags": [
#             ""
#         ],
#         "save_visualizations": false,
#         "delete_viz_images": true,
#         "zip_outputs": false,
#         "log_to_csv": true,
#         "checkpointing": {
#             "initial_model": false,
#             "best_model": true,
#             "every_epoch": false,
#             "latest_model": false,
#             "final_model": false
#         },
#         "tensorboard": {
#             "write_logs": false,
#             "loss_frequency": "epoch",
#             "architecture_graph": false,
#             "profile_graph": false,
#             "visualizations": true
#         },
#         "zmq": {
#             "subscribe_to_controller": false,
#             "controller_address": "tcp://127.0.0.1:9000",
#             "controller_polling_timeout": 10,
#             "publish_updates": false,
#             "publish_address": "tcp://127.0.0.1:9001"
#         }
#     },
#     "name": "",
#     "description": "",
#     "sleap_version": "",
#     "filename": "D:/SLEAP/20250529_seminal_root_generalist/wheat/train_test_split.v000/modified_config_v000_20250529_155025.json"
# }
# INFO:sleap.nn.training:
# INFO:sleap.nn.training:Auto-selected GPU 0 with 23006 MiB of free memory.
# INFO:sleap.nn.training:Using GPU 0 for acceleration.
# INFO:sleap.nn.training:Disabled GPU memory pre-allocation.
# INFO:sleap.nn.training:System:
# GPUs: 1/1 available
#   Device: /physical_device:GPU:0
#          Available: True
#         Initalized: False
#      Memory growth: True
# INFO:sleap.nn.training:
# INFO:sleap.nn.training:Initializing trainer...
# INFO:sleap.nn.training:Loading training labels from: D:\SLEAP\20250529_seminal_root_generalist\wheat\train_test_split.v000\train.pkg.slp
# INFO:sleap.nn.training:Loading validation labels from: D:\SLEAP\20250529_seminal_root_generalist\wheat\train_test_split.v000\val.pkg.slp
# INFO:sleap.nn.training:Loading test labels from: D:\SLEAP\20250529_seminal_root_generalist\wheat\train_test_split.v000\test.pkg.slp
# INFO:sleap.nn.training:Setting up for training...
# INFO:sleap.nn.training:Setting up pipeline builders...
# INFO:sleap.nn.training:Setting up model...
# INFO:sleap.nn.training:Building test pipeline...
# INFO:sleap.nn.training:Loaded test example. [1.932s]
# INFO:sleap.nn.training:  Input shape: (576, 1024, 1)
# INFO:sleap.nn.training:Created Keras model.
# INFO:sleap.nn.training:  Backbone: UNet(stacks=1, filters=24, filters_rate=1.5, kernel_size=3, stem_kernel_size=7, convs_per_block=2, stem_blocks=0, down_blocks=6, middle_block=True, up_blocks=5, up_interpolate=True, block_contraction=False)
# INFO:sleap.nn.training:  Max stride: 64
# INFO:sleap.nn.training:  Parameters: 3,848,881
# INFO:sleap.nn.training:  Heads:
# INFO:sleap.nn.training:    [0] = MultiInstanceConfmapsHead(part_names=['r1', 'r2', 'r3', 'r4', 'r5', 'r6'], sigma=2.5, output_stride=2, loss_weight=1.0)
# INFO:sleap.nn.training:    [1] = PartAffinityFieldsHead(edges=[('r1', 'r2'), ('r2', 'r3'), ('r3', 'r4'), ('r4', 'r5'), ('r5', 'r6')], sigma=75.0, output_stride=8, loss_weight=1.0)
# INFO:sleap.nn.training:  Outputs:
# INFO:sleap.nn.training:    [0] = KerasTensor(type_spec=TensorSpec(shape=(None, 288, 512, 6), dtype=tf.float32, name=None), name='MultiInstanceConfmapsHead/BiasAdd:0', description="created by layer 'MultiInstanceConfmapsHead'")
# INFO:sleap.nn.training:    [1] = KerasTensor(type_spec=TensorSpec(shape=(None, 72, 128, 10), dtype=tf.float32, name=None), name='PartAffinityFieldsHead/BiasAdd:0', description="created by layer 'PartAffinityFieldsHead'")
# INFO:sleap.nn.training:Training from scratch
# INFO:sleap.nn.training:Setting up data pipelines...
# INFO:sleap.nn.training:Training set: n = 143
# INFO:sleap.nn.training:Validation set: n = 31
# INFO:sleap.nn.training:Setting up optimization...
# INFO:sleap.nn.training:  Learning rate schedule: LearningRateScheduleConfig(reduce_on_plateau=True, reduction_factor=0.5, plateau_min_delta=1e-06, plateau_patience=5, plateau_cooldown=3, min_learning_rate=1e-08)
# INFO:sleap.nn.training:  Early stopping: EarlyStoppingConfig(stop_training_on_plateau=True, plateau_min_delta=1e-06, plateau_patience=10)
# INFO:sleap.nn.training:Setting up outputs...
# INFO:sleap.nn.training:Created run path: D:\SLEAP\20250529_seminal_root_generalist\wheat\train_test_split.v000\models\250529_155034.multi_instance.n=174
# INFO:sleap.nn.training:Setting up visualization...
# INFO:sleap.nn.training:Finished trainer set up. [4.8s]
# INFO:sleap.nn.training:Creating tf.data.Datasets for training data generation...
# INFO:sleap.nn.training:Finished creating training datasets. [5.7s]
# INFO:sleap.nn.training:Starting training loop...
# Epoch 1/200
# 200/200 - 43s - loss: 0.0041 - MultiInstanceConfmapsHead_loss: 5.2700e-04 - PartAffinityFieldsHead_loss: 0.0036 - val_loss: 0.0027 - val_MultiInstanceConfmapsHead_loss: 4.6359e-04 - val_PartAffinityFieldsHead_loss: 0.0023 - lr: 1.0000e-04 - 43s/epoch - 214ms/step
# Epoch 2/200
# 200/200 - 36s - loss: 0.0026 - MultiInstanceConfmapsHead_loss: 4.4804e-04 - PartAffinityFieldsHead_loss: 0.0022 - val_loss: 0.0021 - val_MultiInstanceConfmapsHead_loss: 4.1675e-04 - val_PartAffinityFieldsHead_loss: 0.0017 - lr: 1.0000e-04 - 36s/epoch - 180ms/step
# Epoch 3/200
# 200/200 - 36s - loss: 0.0022 - MultiInstanceConfmapsHead_loss: 4.0628e-04 - PartAffinityFieldsHead_loss: 0.0018 - val_loss: 0.0020 - val_MultiInstanceConfmapsHead_loss: 3.9769e-04 - val_PartAffinityFieldsHead_loss: 0.0016 - lr: 1.0000e-04 - 36s/epoch - 181ms/step
# Epoch 4/200
# 200/200 - 35s - loss: 0.0020 - MultiInstanceConfmapsHead_loss: 3.7776e-04 - PartAffinityFieldsHead_loss: 0.0016 - val_loss: 0.0016 - val_MultiInstanceConfmapsHead_loss: 3.3253e-04 - val_PartAffinityFieldsHead_loss: 0.0013 - lr: 1.0000e-04 - 35s/epoch - 176ms/step
# Epoch 5/200
# 200/200 - 36s - loss: 0.0018 - MultiInstanceConfmapsHead_loss: 3.5393e-04 - PartAffinityFieldsHead_loss: 0.0015 - val_loss: 0.0016 - val_MultiInstanceConfmapsHead_loss: 3.3604e-04 - val_PartAffinityFieldsHead_loss: 0.0012 - lr: 1.0000e-04 - 36s/epoch - 180ms/step
# Epoch 6/200
# 200/200 - 35s - loss: 0.0017 - MultiInstanceConfmapsHead_loss: 3.3844e-04 - PartAffinityFieldsHead_loss: 0.0014 - val_loss: 0.0016 - val_MultiInstanceConfmapsHead_loss: 3.2893e-04 - val_PartAffinityFieldsHead_loss: 0.0013 - lr: 1.0000e-04 - 35s/epoch - 174ms/step
# Epoch 7/200
# 200/200 - 36s - loss: 0.0016 - MultiInstanceConfmapsHead_loss: 3.2304e-04 - PartAffinityFieldsHead_loss: 0.0013 - val_loss: 0.0015 - val_MultiInstanceConfmapsHead_loss: 3.0463e-04 - val_PartAffinityFieldsHead_loss: 0.0012 - lr: 1.0000e-04 - 36s/epoch - 178ms/step
# Epoch 8/200
# 200/200 - 34s - loss: 0.0015 - MultiInstanceConfmapsHead_loss: 3.1247e-04 - PartAffinityFieldsHead_loss: 0.0012 - val_loss: 0.0016 - val_MultiInstanceConfmapsHead_loss: 3.3119e-04 - val_PartAffinityFieldsHead_loss: 0.0013 - lr: 1.0000e-04 - 34s/epoch - 172ms/step
# Epoch 9/200
# 200/200 - 35s - loss: 0.0014 - MultiInstanceConfmapsHead_loss: 2.9518e-04 - PartAffinityFieldsHead_loss: 0.0011 - val_loss: 0.0015 - val_MultiInstanceConfmapsHead_loss: 3.0301e-04 - val_PartAffinityFieldsHead_loss: 0.0012 - lr: 1.0000e-04 - 35s/epoch - 176ms/step
# Epoch 10/200
# 200/200 - 36s - loss: 0.0014 - MultiInstanceConfmapsHead_loss: 2.8982e-04 - PartAffinityFieldsHead_loss: 0.0011 - val_loss: 0.0013 - val_MultiInstanceConfmapsHead_loss: 2.8021e-04 - val_PartAffinityFieldsHead_loss: 0.0010 - lr: 1.0000e-04 - 36s/epoch - 179ms/step
# Epoch 11/200
# 200/200 - 34s - loss: 0.0013 - MultiInstanceConfmapsHead_loss: 2.7746e-04 - PartAffinityFieldsHead_loss: 0.0010 - val_loss: 0.0014 - val_MultiInstanceConfmapsHead_loss: 2.9733e-04 - val_PartAffinityFieldsHead_loss: 0.0011 - lr: 1.0000e-04 - 34s/epoch - 171ms/step
# Epoch 12/200
# 200/200 - 36s - loss: 0.0012 - MultiInstanceConfmapsHead_loss: 2.6622e-04 - PartAffinityFieldsHead_loss: 9.5476e-04 - val_loss: 0.0013 - val_MultiInstanceConfmapsHead_loss: 2.7648e-04 - val_PartAffinityFieldsHead_loss: 0.0010 - lr: 1.0000e-04 - 36s/epoch - 178ms/step
# Epoch 13/200
# 200/200 - 34s - loss: 0.0012 - MultiInstanceConfmapsHead_loss: 2.6175e-04 - PartAffinityFieldsHead_loss: 9.4468e-04 - val_loss: 0.0013 - val_MultiInstanceConfmapsHead_loss: 2.8530e-04 - val_PartAffinityFieldsHead_loss: 0.0010 - lr: 1.0000e-04 - 34s/epoch - 172ms/step
# Epoch 14/200
# 200/200 - 36s - loss: 0.0011 - MultiInstanceConfmapsHead_loss: 2.5343e-04 - PartAffinityFieldsHead_loss: 8.8633e-04 - val_loss: 0.0012 - val_MultiInstanceConfmapsHead_loss: 2.7173e-04 - val_PartAffinityFieldsHead_loss: 9.3608e-04 - lr: 1.0000e-04 - 36s/epoch - 178ms/step
# Epoch 15/200
# 200/200 - 35s - loss: 0.0011 - MultiInstanceConfmapsHead_loss: 2.4472e-04 - PartAffinityFieldsHead_loss: 8.4561e-04 - val_loss: 0.0012 - val_MultiInstanceConfmapsHead_loss: 2.6561e-04 - val_PartAffinityFieldsHead_loss: 8.9003e-04 - lr: 1.0000e-04 - 35s/epoch - 176ms/step
# Epoch 16/200
# 200/200 - 34s - loss: 9.9690e-04 - MultiInstanceConfmapsHead_loss: 2.2932e-04 - PartAffinityFieldsHead_loss: 7.6758e-04 - val_loss: 0.0012 - val_MultiInstanceConfmapsHead_loss: 2.6562e-04 - val_PartAffinityFieldsHead_loss: 9.1613e-04 - lr: 1.0000e-04 - 34s/epoch - 171ms/step
# Epoch 17/200
# 200/200 - 36s - loss: 9.4647e-04 - MultiInstanceConfmapsHead_loss: 2.1854e-04 - PartAffinityFieldsHead_loss: 7.2793e-04 - val_loss: 0.0011 - val_MultiInstanceConfmapsHead_loss: 2.4477e-04 - val_PartAffinityFieldsHead_loss: 8.7859e-04 - lr: 1.0000e-04 - 36s/epoch - 178ms/step
# Epoch 18/200
# 200/200 - 34s - loss: 9.5060e-04 - MultiInstanceConfmapsHead_loss: 2.1849e-04 - PartAffinityFieldsHead_loss: 7.3211e-04 - val_loss: 0.0011 - val_MultiInstanceConfmapsHead_loss: 2.5983e-04 - val_PartAffinityFieldsHead_loss: 8.7854e-04 - lr: 1.0000e-04 - 34s/epoch - 172ms/step
# Epoch 19/200
# 200/200 - 35s - loss: 8.9342e-04 - MultiInstanceConfmapsHead_loss: 2.0977e-04 - PartAffinityFieldsHead_loss: 6.8365e-04 - val_loss: 0.0013 - val_MultiInstanceConfmapsHead_loss: 2.7862e-04 - val_PartAffinityFieldsHead_loss: 9.8379e-04 - lr: 1.0000e-04 - 35s/epoch - 175ms/step
# Epoch 20/200
# 200/200 - 35s - loss: 8.5176e-04 - MultiInstanceConfmapsHead_loss: 2.0064e-04 - PartAffinityFieldsHead_loss: 6.5111e-04 - val_loss: 0.0012 - val_MultiInstanceConfmapsHead_loss: 2.7044e-04 - val_PartAffinityFieldsHead_loss: 8.8187e-04 - lr: 1.0000e-04 - 35s/epoch - 176ms/step
# Epoch 21/200
# 200/200 - 35s - loss: 8.2789e-04 - MultiInstanceConfmapsHead_loss: 1.9617e-04 - PartAffinityFieldsHead_loss: 6.3172e-04 - val_loss: 0.0012 - val_MultiInstanceConfmapsHead_loss: 2.6811e-04 - val_PartAffinityFieldsHead_loss: 9.2596e-04 - lr: 1.0000e-04 - 35s/epoch - 175ms/step
# Epoch 22/200
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 200/200 - 35s - loss: 8.1120e-04 - MultiInstanceConfmapsHead_loss: 1.9404e-04 - PartAffinityFieldsHead_loss: 6.1716e-04 - val_loss: 0.0013 - val_MultiInstanceConfmapsHead_loss: 2.8201e-04 - val_PartAffinityFieldsHead_loss: 9.7716e-04 - lr: 1.0000e-04 - 35s/epoch - 175ms/step
# Epoch 23/200
# 200/200 - 35s - loss: 6.9396e-04 - MultiInstanceConfmapsHead_loss: 1.6722e-04 - PartAffinityFieldsHead_loss: 5.2674e-04 - val_loss: 0.0012 - val_MultiInstanceConfmapsHead_loss: 2.7987e-04 - val_PartAffinityFieldsHead_loss: 9.2312e-04 - lr: 5.0000e-05 - 35s/epoch - 174ms/step
# Epoch 24/200
# 200/200 - 35s - loss: 6.6789e-04 - MultiInstanceConfmapsHead_loss: 1.6101e-04 - PartAffinityFieldsHead_loss: 5.0688e-04 - val_loss: 0.0012 - val_MultiInstanceConfmapsHead_loss: 2.7305e-04 - val_PartAffinityFieldsHead_loss: 9.3873e-04 - lr: 5.0000e-05 - 35s/epoch - 174ms/step
# Epoch 25/200
# 200/200 - 35s - loss: 6.6845e-04 - MultiInstanceConfmapsHead_loss: 1.6063e-04 - PartAffinityFieldsHead_loss: 5.0781e-04 - val_loss: 0.0013 - val_MultiInstanceConfmapsHead_loss: 2.8730e-04 - val_PartAffinityFieldsHead_loss: 9.8017e-04 - lr: 5.0000e-05 - 35s/epoch - 175ms/step
# Epoch 26/200
# 200/200 - 35s - loss: 6.4725e-04 - MultiInstanceConfmapsHead_loss: 1.5625e-04 - PartAffinityFieldsHead_loss: 4.9100e-04 - val_loss: 0.0012 - val_MultiInstanceConfmapsHead_loss: 2.8535e-04 - val_PartAffinityFieldsHead_loss: 9.5018e-04 - lr: 5.0000e-05 - 35s/epoch - 175ms/step
# Epoch 27/200
# 200/200 - 35s - loss: 6.1924e-04 - MultiInstanceConfmapsHead_loss: 1.4891e-04 - PartAffinityFieldsHead_loss: 4.7033e-04 - val_loss: 0.0012 - val_MultiInstanceConfmapsHead_loss: 2.8994e-04 - val_PartAffinityFieldsHead_loss: 9.2982e-04 - lr: 5.0000e-05 - 35s/epoch - 175ms/step
# Epoch 00027: early stopping
# INFO:sleap.nn.training:Finished training loop. [15.9 min]
# INFO:sleap.nn.training:Saving evaluation metrics to model folder...
# Predicting... -------------------------------------- 100% ETA: 0:00:00 18.5 FPS
# INFO:sleap.nn.evals:Saved predictions: D:\SLEAP\20250529_seminal_root_generalist\wheat\train_test_split.v000\models\250529_155034.multi_instance.n=174\labels_pr.train.slp
# INFO:sleap.nn.evals:Saved metrics: D:\SLEAP\20250529_seminal_root_generalist\wheat\train_test_split.v000\models\250529_155034.multi_instance.n=174\metrics.train.npz
# INFO:sleap.nn.evals:OKS mAP: 0.290287
# Predicting... -------------------------------------- 100% ETA: 0:00:00 10.9 FPS
# INFO:sleap.nn.evals:Saved predictions: D:\SLEAP\20250529_seminal_root_generalist\wheat\train_test_split.v000\models\250529_155034.multi_instance.n=174\labels_pr.val.slp
# INFO:sleap.nn.evals:Saved metrics: D:\SLEAP\20250529_seminal_root_generalist\wheat\train_test_split.v000\models\250529_155034.multi_instance.n=174\metrics.val.npz
# INFO:sleap.nn.evals:OKS mAP: 0.091083
# WARNING:tensorflow:5 out of the last 45 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002360AD31B88> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Predicting... --------------------------------------- 100% ETA: 0:00:00 7.8 FPS
# INFO:sleap.nn.evals:Saved predictions: D:\SLEAP\20250529_seminal_root_generalist\wheat\train_test_split.v000\models\250529_155034.multi_instance.n=174\labels_pr.test.slp
# INFO:sleap.nn.evals:Saved metrics: D:\SLEAP\20250529_seminal_root_generalist\wheat\train_test_split.v000\models\250529_155034.multi_instance.n=174\metrics.test.npz
# INFO:sleap.nn.evals:OKS mAP: 0.080055
#
# INFO:root:Latest run directory: D:\SLEAP\20250529_seminal_root_generalist\wheat\train_test_split.v000\models\250529_155034.multi_instance.n=174
# wandb: Adding directory to artifact (D:\SLEAP\20250529_seminal_root_generalist\wheat\train_test_split.v000\models\250529_155034.multi_instance.n=174)...
# W&B run configuration updated with training configuration.
# Done. 0.2s
# Model path: D:/SLEAP/20250529_seminal_root_generalist/wheat/train_test_split.v000/models/250529_155034.multi_instance.n=174
# Metrics loaded from model directory: D:/SLEAP/20250529_seminal_root_generalist/wheat/train_test_split.v000/models/250529_155034.multi_instance.n=174
# Model artifact '20250529_wheat_seminal_sweep_v000' logged to W&B with evaluations.
# VBox(children=(Label(value='3.089 MB of 60.693 MB uploaded\r'), FloatProgress(value=0.05089942026867667, max=1…
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>dist_avg</td><td>2.09943</td></tr><tr><td>dist_p50</td><td>0.67862</td></tr><tr><td>dist_p90</td><td>5.53234</td></tr><tr><td>dist_p95</td><td>9.02905</td></tr><tr><td>dist_p99</td><td>17.52898</td></tr><tr><td>dist_std</td><td>3.47094</td></tr><tr><td>model_name</td><td>250529_155034.multi_...</td></tr><tr><td>model_path</td><td>D:/SLEAP/20250529_se...</td></tr><tr><td>oks_map</td><td>0.08005</td></tr><tr><td>oks_mar</td><td>0.18279</td></tr><tr><td>vis_prec</td><td>1</td></tr><tr><td>vis_recall</td><td>0.88385</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">20250529_wheat_seminal_sweep_training_v000</strong> at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/sxyykxsq' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/sxyykxsq</a><br/> View project at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a><br/>Synced 4 W&B file(s), 0 media file(s), 24 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250529_155024-sxyykxsq\logs</code>
# INFO:root:W&B run for version 0 finished.
# INFO:root:Completed training for version 0.
# wandb: Agent Starting Run: emc3plww with config:
# wandb: 	data.preprocessing.input_scaling: 0.75
# INFO:root:Starting training for version 0...
# INFO:root:Directory path for version 0: D:\SLEAP\20250529_seminal_root_generalist\wheat\train_test_split.v000
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# Tracking run with wandb version 0.18.6
# Run data is saved locally in <code>e:\repositories\sleap-roots-training\wandb\run-20250529_160722-emc3plww</code>
# Syncing run <strong><a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/emc3plww' target="_blank">20250529_wheat_seminal_sweep_training_v000</a></strong> to <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/sweeps/872vxc35' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/sweeps/872vxc35</a>
#  View project at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a>
#  View sweep at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/sweeps/872vxc35' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/sweeps/872vxc35</a>
#  View run at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/emc3plww' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/emc3plww</a>
# INFO:root:Updating configuration with W&B parameters.
# INFO:root:Original Parameters: {
#     "data": {
#         "labels": {
#             "training_labels": "D:\\SLEAP\\20250529_seminal_root_generalist\\wheat\\train_test_split.v000\\train.pkg.slp",
#             "validation_labels": "D:\\SLEAP\\20250529_seminal_root_generalist\\wheat\\train_test_split.v000\\val.pkg.slp",
#             "validation_fraction": 0.1,
#             "test_labels": "D:\\SLEAP\\20250529_seminal_root_generalist\\wheat\\train_test_split.v000\\test.pkg.slp",
#             "split_by_inds": false,
#             "training_inds": null,
#             "validation_inds": null,
#             "test_inds": null,
#             "search_path_hints": [],
#             "skeletons": []
#         },
#         "preprocessing": {
#             "ensure_rgb": false,
#             "ensure_grayscale": false,
#             "imagenet_mode": null,
#             "input_scaling": 1.0,
#             "pad_to_stride": null,
#             "resize_and_pad_to_target": true,
#             "target_height": null,
#             "target_width": null
#         },
#         "instance_cropping": {
#             "center_on_part": null,
#             "crop_size": null,
#             "crop_size_detection_padding": 16
#         }
#     },
#     "model": {
#         "backbone": {
#             "leap": null,
#             "unet": {
#                 "stem_stride": null,
#                 "max_stride": 64,
#                 "output_stride": 2,
#                 "filters": 24,
#                 "filters_rate": 1.5,
#                 "middle_block": true,
#                 "up_interpolate": true,
#                 "stacks": 1
#             },
#             "hourglass": null,
#             "resnet": null,
#             "pretrained_encoder": null
#         },
#         "heads": {
#             "single_instance": null,
#             "centroid": null,
#             "centered_instance": null,
#             "multi_instance": {
#                 "confmaps": {
#                     "part_names": null,
#                     "sigma": 2.5,
#                     "output_stride": 2,
#                     "loss_weight": 1.0,
#                     "offset_refinement": false
#                 },
#                 "pafs": {
#                     "edges": null,
#                     "sigma": 75.0,
#                     "output_stride": 8,
#                     "loss_weight": 1.0
#                 }
#             }
#         }
#     },
#     "optimization": {
#         "preload_data": true,
#         "augmentation_config": {
#             "rotate": true,
#             "rotation_min_angle": -5.0,
#             "rotation_max_angle": 5.0,
#             "translate": false,
#             "translate_min": -5,
#             "translate_max": 5,
#             "scale": true,
#             "scale_min": 0.5,
#             "scale_max": 1.2,
#             "uniform_noise": false,
#             "uniform_noise_min_val": 0.0,
#             "uniform_noise_max_val": 10.0,
#             "gaussian_noise": false,
#             "gaussian_noise_mean": 5.0,
#             "gaussian_noise_stddev": 1.0,
#             "contrast": true,
#             "contrast_min_gamma": 0.5,
#             "contrast_max_gamma": 2.0,
#             "brightness": false,
#             "brightness_min_val": 0.0,
#             "brightness_max_val": 10.0,
#             "random_crop": false,
#             "random_crop_height": 256,
#             "random_crop_width": 256,
#             "random_flip": false,
#             "flip_horizontal": true
#         },
#         "online_shuffling": true,
#         "shuffle_buffer_size": 128,
#         "prefetch": true,
#         "batch_size": 4,
#         "batches_per_epoch": null,
#         "min_batches_per_epoch": 200,
#         "val_batches_per_epoch": null,
#         "min_val_batches_per_epoch": 10,
#         "epochs": 200,
#         "optimizer": "adam",
#         "initial_learning_rate": 0.0001,
#         "learning_rate_schedule": {
#             "reduce_on_plateau": true,
#             "reduction_factor": 0.5,
#             "plateau_min_delta": 1e-06,
#             "plateau_patience": 5,
#             "plateau_cooldown": 3,
#             "min_learning_rate": 1e-08
#         },
#         "hard_keypoint_mining": {
#             "online_mining": false,
#             "hard_to_easy_ratio": 2.0,
#             "min_hard_keypoints": 2,
#             "max_hard_keypoints": null,
#             "loss_scale": 5.0
#         },
#         "early_stopping": {
#             "stop_training_on_plateau": true,
#             "plateau_min_delta": 1e-06,
#             "plateau_patience": 10
#         }
#     },
#     "outputs": {
#         "save_outputs": true,
#         "run_name": null,
#         "run_name_prefix": "",
#         "run_name_suffix": "",
# ...
# INFO:sleap.nn.training:  Outputs:
# INFO:sleap.nn.training:    [0] = KerasTensor(type_spec=TensorSpec(shape=(None, 544, 1024, 6), dtype=tf.float32, name=None), name='MultiInstanceConfmapsHead/BiasAdd:0', description="created by layer 'MultiInstanceConfmapsHead'")
# INFO:sleap.nn.training:    [1] = KerasTensor(type_spec=TensorSpec(shape=(None, 136, 256, 10), dtype=tf.float32, name=None), name='PartAffinityFieldsHead/BiasAdd:0', description="created by layer 'PartAffinityFieldsHead'")
# INFO:sleap.nn.training:Training from scratch
# INFO:sleap.nn.training:Setting up data pipelines...
# INFO:sleap.nn.training:Training set: n = 143
# INFO:sleap.nn.training:Validation set: n = 31
# INFO:sleap.nn.training:Setting up optimization...
# INFO:sleap.nn.training:  Learning rate schedule: LearningRateScheduleConfig(reduce_on_plateau=True, reduction_factor=0.5, plateau_min_delta=1e-06, plateau_patience=5, plateau_cooldown=3, min_learning_rate=1e-08)
# INFO:sleap.nn.training:  Early stopping: EarlyStoppingConfig(stop_training_on_plateau=True, plateau_min_delta=1e-06, plateau_patience=10)
# INFO:sleap.nn.training:Setting up outputs...
# INFO:sleap.nn.training:Created run path: D:\SLEAP\20250529_seminal_root_generalist\wheat\train_test_split.v002\models\250529_202658.multi_instance.n=174
# INFO:sleap.nn.training:Setting up visualization...
# INFO:sleap.nn.training:Finished trainer set up. [4.7s]
# INFO:sleap.nn.training:Creating tf.data.Datasets for training data generation...
# INFO:sleap.nn.training:Finished creating training datasets. [5.7s]
# INFO:sleap.nn.training:Starting training loop...
# Epoch 1/200
# 200/200 - 108s - loss: 0.0018 - MultiInstanceConfmapsHead_loss: 1.4880e-04 - PartAffinityFieldsHead_loss: 0.0016 - val_loss: 0.0016 - val_MultiInstanceConfmapsHead_loss: 1.4245e-04 - val_PartAffinityFieldsHead_loss: 0.0015 - lr: 1.0000e-04 - 108s/epoch - 542ms/step
# Epoch 2/200
# 200/200 - 102s - loss: 0.0014 - MultiInstanceConfmapsHead_loss: 1.3868e-04 - PartAffinityFieldsHead_loss: 0.0012 - val_loss: 0.0013 - val_MultiInstanceConfmapsHead_loss: 1.3511e-04 - val_PartAffinityFieldsHead_loss: 0.0012 - lr: 1.0000e-04 - 102s/epoch - 511ms/step
# Epoch 3/200
# 200/200 - 103s - loss: 0.0012 - MultiInstanceConfmapsHead_loss: 1.3258e-04 - PartAffinityFieldsHead_loss: 0.0011 - val_loss: 9.9278e-04 - val_MultiInstanceConfmapsHead_loss: 1.2414e-04 - val_PartAffinityFieldsHead_loss: 8.6864e-04 - lr: 1.0000e-04 - 103s/epoch - 513ms/step
# Epoch 4/200
# 200/200 - 98s - loss: 0.0011 - MultiInstanceConfmapsHead_loss: 1.2579e-04 - PartAffinityFieldsHead_loss: 9.6735e-04 - val_loss: 0.0010 - val_MultiInstanceConfmapsHead_loss: 1.2460e-04 - val_PartAffinityFieldsHead_loss: 9.0421e-04 - lr: 1.0000e-04 - 98s/epoch - 489ms/step
# Epoch 5/200
# 200/200 - 100s - loss: 9.9620e-04 - MultiInstanceConfmapsHead_loss: 1.2054e-04 - PartAffinityFieldsHead_loss: 8.7565e-04 - val_loss: 0.0010 - val_MultiInstanceConfmapsHead_loss: 1.2113e-04 - val_PartAffinityFieldsHead_loss: 8.9540e-04 - lr: 1.0000e-04 - 100s/epoch - 501ms/step
# Epoch 6/200
# 200/200 - 101s - loss: 9.5128e-04 - MultiInstanceConfmapsHead_loss: 1.1581e-04 - PartAffinityFieldsHead_loss: 8.3546e-04 - val_loss: 8.4559e-04 - val_MultiInstanceConfmapsHead_loss: 1.1131e-04 - val_PartAffinityFieldsHead_loss: 7.3428e-04 - lr: 1.0000e-04 - 101s/epoch - 505ms/step
# Epoch 7/200
# 200/200 - 100s - loss: 8.8193e-04 - MultiInstanceConfmapsHead_loss: 1.1212e-04 - PartAffinityFieldsHead_loss: 7.6981e-04 - val_loss: 0.0011 - val_MultiInstanceConfmapsHead_loss: 1.1732e-04 - val_PartAffinityFieldsHead_loss: 9.5046e-04 - lr: 1.0000e-04 - 100s/epoch - 498ms/step
# Epoch 8/200
# 200/200 - 100s - loss: 8.5662e-04 - MultiInstanceConfmapsHead_loss: 1.0929e-04 - PartAffinityFieldsHead_loss: 7.4733e-04 - val_loss: 8.8635e-04 - val_MultiInstanceConfmapsHead_loss: 1.0821e-04 - val_PartAffinityFieldsHead_loss: 7.7814e-04 - lr: 1.0000e-04 - 100s/epoch - 499ms/step
# Epoch 9/200
# 200/200 - 102s - loss: 8.1158e-04 - MultiInstanceConfmapsHead_loss: 1.0579e-04 - PartAffinityFieldsHead_loss: 7.0579e-04 - val_loss: 7.8026e-04 - val_MultiInstanceConfmapsHead_loss: 1.0525e-04 - val_PartAffinityFieldsHead_loss: 6.7501e-04 - lr: 1.0000e-04 - 102s/epoch - 508ms/step
# Epoch 10/200
# 200/200 - 99s - loss: 7.7829e-04 - MultiInstanceConfmapsHead_loss: 1.0353e-04 - PartAffinityFieldsHead_loss: 6.7475e-04 - val_loss: 9.5385e-04 - val_MultiInstanceConfmapsHead_loss: 1.1210e-04 - val_PartAffinityFieldsHead_loss: 8.4175e-04 - lr: 1.0000e-04 - 99s/epoch - 496ms/step
# Epoch 11/200
# 200/200 - 99s - loss: 7.5055e-04 - MultiInstanceConfmapsHead_loss: 1.0203e-04 - PartAffinityFieldsHead_loss: 6.4853e-04 - val_loss: 9.2503e-04 - val_MultiInstanceConfmapsHead_loss: 1.0771e-04 - val_PartAffinityFieldsHead_loss: 8.1732e-04 - lr: 1.0000e-04 - 99s/epoch - 497ms/step
# Epoch 12/200
# 200/200 - 100s - loss: 7.2500e-04 - MultiInstanceConfmapsHead_loss: 9.9516e-05 - PartAffinityFieldsHead_loss: 6.2549e-04 - val_loss: 8.6995e-04 - val_MultiInstanceConfmapsHead_loss: 1.0634e-04 - val_PartAffinityFieldsHead_loss: 7.6361e-04 - lr: 1.0000e-04 - 100s/epoch - 501ms/step
# Epoch 13/200
# 200/200 - 100s - loss: 6.7357e-04 - MultiInstanceConfmapsHead_loss: 9.7213e-05 - PartAffinityFieldsHead_loss: 5.7636e-04 - val_loss: 8.2674e-04 - val_MultiInstanceConfmapsHead_loss: 1.0398e-04 - val_PartAffinityFieldsHead_loss: 7.2276e-04 - lr: 1.0000e-04 - 100s/epoch - 501ms/step
# Epoch 14/200
# 200/200 - 101s - loss: 6.7571e-04 - MultiInstanceConfmapsHead_loss: 9.5116e-05 - PartAffinityFieldsHead_loss: 5.8059e-04 - val_loss: 7.0982e-04 - val_MultiInstanceConfmapsHead_loss: 1.0117e-04 - val_PartAffinityFieldsHead_loss: 6.0865e-04 - lr: 1.0000e-04 - 101s/epoch - 505ms/step
# Epoch 15/200
# 200/200 - 99s - loss: 6.2490e-04 - MultiInstanceConfmapsHead_loss: 9.2777e-05 - PartAffinityFieldsHead_loss: 5.3212e-04 - val_loss: 8.8231e-04 - val_MultiInstanceConfmapsHead_loss: 1.0643e-04 - val_PartAffinityFieldsHead_loss: 7.7588e-04 - lr: 1.0000e-04 - 99s/epoch - 494ms/step
# Epoch 16/200
# 200/200 - 100s - loss: 6.0476e-04 - MultiInstanceConfmapsHead_loss: 9.1291e-05 - PartAffinityFieldsHead_loss: 5.1346e-04 - val_loss: 8.2804e-04 - val_MultiInstanceConfmapsHead_loss: 1.0528e-04 - val_PartAffinityFieldsHead_loss: 7.2276e-04 - lr: 1.0000e-04 - 100s/epoch - 499ms/step
# Epoch 17/200
# 200/200 - 100s - loss: 5.8545e-04 - MultiInstanceConfmapsHead_loss: 8.9055e-05 - PartAffinityFieldsHead_loss: 4.9640e-04 - val_loss: 7.5618e-04 - val_MultiInstanceConfmapsHead_loss: 9.7602e-05 - val_PartAffinityFieldsHead_loss: 6.5858e-04 - lr: 1.0000e-04 - 100s/epoch - 498ms/step
# Epoch 18/200
# 200/200 - 100s - loss: 5.5893e-04 - MultiInstanceConfmapsHead_loss: 8.7045e-05 - PartAffinityFieldsHead_loss: 4.7188e-04 - val_loss: 6.9811e-04 - val_MultiInstanceConfmapsHead_loss: 9.8314e-05 - val_PartAffinityFieldsHead_loss: 5.9980e-04 - lr: 1.0000e-04 - 100s/epoch - 502ms/step
# Epoch 19/200
# 200/200 - 99s - loss: 5.2961e-04 - MultiInstanceConfmapsHead_loss: 8.5565e-05 - PartAffinityFieldsHead_loss: 4.4405e-04 - val_loss: 8.1951e-04 - val_MultiInstanceConfmapsHead_loss: 1.0436e-04 - val_PartAffinityFieldsHead_loss: 7.1514e-04 - lr: 1.0000e-04 - 99s/epoch - 495ms/step
# Epoch 20/200
# 200/200 - 100s - loss: 5.2296e-04 - MultiInstanceConfmapsHead_loss: 8.4750e-05 - PartAffinityFieldsHead_loss: 4.3821e-04 - val_loss: 7.7318e-04 - val_MultiInstanceConfmapsHead_loss: 9.9759e-05 - val_PartAffinityFieldsHead_loss: 6.7343e-04 - lr: 1.0000e-04 - 100s/epoch - 499ms/step
# Epoch 21/200
# 200/200 - 99s - loss: 5.0299e-04 - MultiInstanceConfmapsHead_loss: 8.1791e-05 - PartAffinityFieldsHead_loss: 4.2120e-04 - val_loss: 7.4820e-04 - val_MultiInstanceConfmapsHead_loss: 1.0351e-04 - val_PartAffinityFieldsHead_loss: 6.4469e-04 - lr: 1.0000e-04 - 99s/epoch - 497ms/step
# Epoch 22/200
# 200/200 - 101s - loss: 4.7957e-04 - MultiInstanceConfmapsHead_loss: 8.0740e-05 - PartAffinityFieldsHead_loss: 3.9883e-04 - val_loss: 6.3864e-04 - val_MultiInstanceConfmapsHead_loss: 9.5860e-05 - val_PartAffinityFieldsHead_loss: 5.4278e-04 - lr: 1.0000e-04 - 101s/epoch - 507ms/step
# Epoch 23/200
# 200/200 - 98s - loss: 4.4295e-04 - MultiInstanceConfmapsHead_loss: 7.6885e-05 - PartAffinityFieldsHead_loss: 3.6607e-04 - val_loss: 6.9384e-04 - val_MultiInstanceConfmapsHead_loss: 1.0002e-04 - val_PartAffinityFieldsHead_loss: 5.9382e-04 - lr: 1.0000e-04 - 98s/epoch - 490ms/step
# Epoch 24/200
# 200/200 - 100s - loss: 4.4854e-04 - MultiInstanceConfmapsHead_loss: 7.6805e-05 - PartAffinityFieldsHead_loss: 3.7174e-04 - val_loss: 7.8727e-04 - val_MultiInstanceConfmapsHead_loss: 1.0003e-04 - val_PartAffinityFieldsHead_loss: 6.8724e-04 - lr: 1.0000e-04 - 100s/epoch - 499ms/step
# Epoch 25/200
# 200/200 - 100s - loss: 4.2098e-04 - MultiInstanceConfmapsHead_loss: 7.4129e-05 - PartAffinityFieldsHead_loss: 3.4685e-04 - val_loss: 7.9898e-04 - val_MultiInstanceConfmapsHead_loss: 1.0314e-04 - val_PartAffinityFieldsHead_loss: 6.9584e-04 - lr: 1.0000e-04 - 100s/epoch - 499ms/step
# Epoch 26/200
# 200/200 - 100s - loss: 4.0515e-04 - MultiInstanceConfmapsHead_loss: 7.2562e-05 - PartAffinityFieldsHead_loss: 3.3258e-04 - val_loss: 7.4454e-04 - val_MultiInstanceConfmapsHead_loss: 9.9366e-05 - val_PartAffinityFieldsHead_loss: 6.4518e-04 - lr: 1.0000e-04 - 100s/epoch - 501ms/step
# Epoch 27/200
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 200/200 - 100s - loss: 3.9244e-04 - MultiInstanceConfmapsHead_loss: 7.1670e-05 - PartAffinityFieldsHead_loss: 3.2077e-04 - val_loss: 8.4433e-04 - val_MultiInstanceConfmapsHead_loss: 1.0788e-04 - val_PartAffinityFieldsHead_loss: 7.3645e-04 - lr: 1.0000e-04 - 100s/epoch - 502ms/step
# Epoch 28/200
# 200/200 - 100s - loss: 3.4223e-04 - MultiInstanceConfmapsHead_loss: 6.5192e-05 - PartAffinityFieldsHead_loss: 2.7704e-04 - val_loss: 7.4116e-04 - val_MultiInstanceConfmapsHead_loss: 1.0079e-04 - val_PartAffinityFieldsHead_loss: 6.4038e-04 - lr: 5.0000e-05 - 100s/epoch - 498ms/step
# Epoch 29/200
# 200/200 - 100s - loss: 3.2850e-04 - MultiInstanceConfmapsHead_loss: 6.1989e-05 - PartAffinityFieldsHead_loss: 2.6651e-04 - val_loss: 6.6793e-04 - val_MultiInstanceConfmapsHead_loss: 9.8953e-05 - val_PartAffinityFieldsHead_loss: 5.6898e-04 - lr: 5.0000e-05 - 100s/epoch - 499ms/step
# Epoch 30/200
# 200/200 - 100s - loss: 3.1411e-04 - MultiInstanceConfmapsHead_loss: 6.0278e-05 - PartAffinityFieldsHead_loss: 2.5383e-04 - val_loss: 8.2146e-04 - val_MultiInstanceConfmapsHead_loss: 1.0769e-04 - val_PartAffinityFieldsHead_loss: 7.1377e-04 - lr: 5.0000e-05 - 100s/epoch - 499ms/step
# Epoch 31/200
# 200/200 - 101s - loss: 3.0608e-04 - MultiInstanceConfmapsHead_loss: 5.9035e-05 - PartAffinityFieldsHead_loss: 2.4705e-04 - val_loss: 8.4443e-04 - val_MultiInstanceConfmapsHead_loss: 1.1003e-04 - val_PartAffinityFieldsHead_loss: 7.3440e-04 - lr: 5.0000e-05 - 101s/epoch - 505ms/step
# Epoch 32/200
# 200/200 - 98s - loss: 2.9382e-04 - MultiInstanceConfmapsHead_loss: 5.7650e-05 - PartAffinityFieldsHead_loss: 2.3617e-04 - val_loss: 8.0051e-04 - val_MultiInstanceConfmapsHead_loss: 1.0777e-04 - val_PartAffinityFieldsHead_loss: 6.9274e-04 - lr: 5.0000e-05 - 98s/epoch - 492ms/step
# Epoch 00032: early stopping
# INFO:sleap.nn.training:Finished training loop. [53.5 min]
# INFO:sleap.nn.training:Saving evaluation metrics to model folder...
# Predicting... --------------------------------------- 100% ETA: 0:00:00 6.3 FPS
# INFO:sleap.nn.evals:Saved predictions: D:\SLEAP\20250529_seminal_root_generalist\wheat\train_test_split.v002\models\250529_202658.multi_instance.n=174\labels_pr.train.slp
# INFO:sleap.nn.evals:Saved metrics: D:\SLEAP\20250529_seminal_root_generalist\wheat\train_test_split.v002\models\250529_202658.multi_instance.n=174\metrics.train.npz
# INFO:sleap.nn.evals:OKS mAP: 0.545077
# Predicting... -------------------------------------- 100% ETA: 0:00:00 10.3 FPS
# INFO:sleap.nn.evals:Saved predictions: D:\SLEAP\20250529_seminal_root_generalist\wheat\train_test_split.v002\models\250529_202658.multi_instance.n=174\labels_pr.val.slp
# INFO:sleap.nn.evals:Saved metrics: D:\SLEAP\20250529_seminal_root_generalist\wheat\train_test_split.v002\models\250529_202658.multi_instance.n=174\metrics.val.npz
# INFO:sleap.nn.evals:OKS mAP: 0.101042
# WARNING:tensorflow:5 out of the last 45 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001DC16720048> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Predicting... --------------------------------------- 100% ETA: 0:00:00 5.6 FPS
# INFO:sleap.nn.evals:Saved predictions: D:\SLEAP\20250529_seminal_root_generalist\wheat\train_test_split.v002\models\250529_202658.multi_instance.n=174\labels_pr.test.slp
# INFO:sleap.nn.evals:Saved metrics: D:\SLEAP\20250529_seminal_root_generalist\wheat\train_test_split.v002\models\250529_202658.multi_instance.n=174\metrics.test.npz
# INFO:sleap.nn.evals:OKS mAP: 0.078967
#
# INFO:root:Latest run directory: D:\SLEAP\20250529_seminal_root_generalist\wheat\train_test_split.v002\models\250529_202658.multi_instance.n=174
# wandb: Adding directory to artifact (D:\SLEAP\20250529_seminal_root_generalist\wheat\train_test_split.v002\models\250529_202658.multi_instance.n=174)...
# W&B run configuration updated with training configuration.
# Done. 0.2s
# Model path: D:/SLEAP/20250529_seminal_root_generalist/wheat/train_test_split.v002/models/250529_202658.multi_instance.n=174
# Metrics loaded from model directory: D:/SLEAP/20250529_seminal_root_generalist/wheat/train_test_split.v002/models/250529_202658.multi_instance.n=174
# Model artifact '20250529_wheat_seminal_sweep_v002' logged to W&B with evaluations.
# VBox(children=(Label(value='2.651 MB of 60.677 MB uploaded\r'), FloatProgress(value=0.043688831321758194, max=…
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>dist_avg</td><td>1.66961</td></tr><tr><td>dist_p50</td><td>0.70438</td></tr><tr><td>dist_p90</td><td>3.94026</td></tr><tr><td>dist_p95</td><td>5.83074</td></tr><tr><td>dist_p99</td><td>15.35653</td></tr><tr><td>dist_std</td><td>2.78036</td></tr><tr><td>model_name</td><td>250529_202658.multi_...</td></tr><tr><td>model_path</td><td>D:/SLEAP/20250529_se...</td></tr><tr><td>oks_map</td><td>0.07897</td></tr><tr><td>oks_mar</td><td>0.15317</td></tr><tr><td>vis_prec</td><td>0.99699</td></tr><tr><td>vis_recall</td><td>0.89474</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">20250529_wheat_seminal_sweep_training_v002</strong> at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/con8micx' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/con8micx</a><br/> View project at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a><br/>Synced 6 W&B file(s), 0 media file(s), 19 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250529_202647-con8micx\logs</code>
# INFO:root:W&B run for version 2 finished.
# INFO:root:Completed training for version 2.
# INFO:root:Finished sweep for version 2.
# INFO:root:All versions processed successfully.
