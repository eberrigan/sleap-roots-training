# %%
import wandb
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sleap
import numpy as np
import datetime

from matplotlib.patches import ConnectionPatch
from pathlib import Path

# %%
import sleap_roots_training

from sleap_roots_training.evaluate import main, predictions_viz_from_sleap_files, fetch_sweep_metrics, get_sweep_ids_for_group_from_runs

# %%
# Constants for W&B initialization
ENTITY_NAME = "eberrigan-salk-institute-for-biological-studies"
PROJECT_NAME = "sleap-roots"
REGISTRY = "sleap-roots-models"
JOB_TYPE = "sweep"
EXPERIMENT_NAME = "20250530_younger_rice_seminal_sweep_input_scaling"

# Constants for artifact creation
DESCRIPTION = "rice 3DAG crown roots with 6 nodes with varying input scaling"
TAGS = ["rice", "3DAG", "crown", "6nodes", "rice3DAG", "input_scaling"]
MODEL_TAGS = ["rice3DAG", "crown", "6nodes", "rice"]
COLLECTION_NAME = EXPERIMENT_NAME
CSV_PATH = "D:/SLEAP/20250530_seminal_root_generalist/younger_rice/train_test_splits.csv"
ARTIFACT_NAME = "younger_rice_seminal_6nodes_input_scaling_sweep_n6"

# %%
# Model and group configuration
# https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/groups/20250530_younger_rice_seminal_sweep_input_scaling?nw=nwusereberrigan
MODEL_GROUP = "20250530_younger_rice_seminal_sweep_input_scaling" # This is the group name for the sweep
VERSIONS = ["000", "001", "002"] # Each model artifact has the name "{MODEL_GROUP}_v{VERSION}"

# %%
TARGET_METRICS = ["dist_p50", "dist_p90", "dist_p95", "dist_p99", "dist_avg", "dist_std", "vis_prec", "vis_recall", "oks_map", "oks_mar"]

# %%
sleap_roots_training.reset_config()
# Out:
# Configuration updated successfully at e:\repositories\sleap-roots-training\sleap_roots_training\config.yaml.
# Configuration has been reset to default values.

# %%
sleap_roots_training.update_config(entity_name=ENTITY_NAME, project_name=PROJECT_NAME, registry=REGISTRY, experiment_name=EXPERIMENT_NAME)
# Out:
# Configuration updated successfully at e:\repositories\sleap-roots-training\sleap_roots_training\config.yaml.
# CONFIG updated to {'project_name': 'sleap-roots', 'entity_name': 'eberrigan-salk-institute-for-biological-studies', 'experiment_name': '20250530_younger_rice_seminal_sweep_input_scaling', 'registry': 'sleap-roots-models', 'collection_name': None, 'job_type': None}.

# %%
# Make directory for experiment
Path(EXPERIMENT_NAME).mkdir(exist_ok=True, parents=True)

# %%
datetime_str = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

# %%
sweep_ids = get_sweep_ids_for_group_from_runs(group_name=MODEL_GROUP)
# Out:
# INFO:root:Found 18 runs in group '20250530_younger_rice_seminal_sweep_input_scaling'.
# INFO:root:Found 6 unique sweep IDs for group '20250530_younger_rice_seminal_sweep_input_scaling': ['a193y2u3', 'ke5c8g0s', 'maf7zhat', 'pbfbjsq9', 'qhmfs9ha', 'zfd4ujej']

# %%
sweep_df = fetch_sweep_metrics(
    sweep_ids=sweep_ids,
    target_metrics=TARGET_METRICS,
    include_config=True,
)

# %%
sweep_df
# Out:
#       run_id                                               name  \
# 0   qrtkohbf  20250530_younger_rice_seminal_sweep_input_scal...
# 1   81o13x0x  20250530_younger_rice_seminal_sweep_input_scal...
# 2   h6tad35d  20250530_younger_rice_seminal_sweep_input_scal...
# 3   mdo3ajgs  20250530_younger_rice_seminal_sweep_input_scal...
# 4   hjymtw5h  20250530_younger_rice_seminal_sweep_input_scal...
# 5   oi7z7yq3  20250530_younger_rice_seminal_sweep_input_scal...
# 6   cu9g3nje  20250530_younger_rice_seminal_sweep_input_scal...
# 7   j5scf554  20250530_younger_rice_seminal_sweep_input_scal...
# 8   h54t5qh6  20250530_younger_rice_seminal_sweep_input_scal...
# 9   9p0e1ipo  20250530_younger_rice_seminal_sweep_input_scal...
# 10  wa4hlh3j  20250530_younger_rice_seminal_sweep_input_scal...
# 11  totswez0  20250530_younger_rice_seminal_sweep_input_scal...
# 12  sdnxtk11  20250530_younger_rice_seminal_sweep_input_scal...
# 13  3fxgc33a  20250530_younger_rice_seminal_sweep_input_scal...
# 14  ahms7gg5  20250530_younger_rice_seminal_sweep_input_scal...
# 15  sferajd3  20250530_younger_rice_seminal_sweep_input_scal...
# 16  ld6r5wrt  20250530_younger_rice_seminal_sweep_input_scal...
# 17  nqtmsunz  20250530_younger_rice_seminal_sweep_input_scal...
#
#                                                 group  sweep_id  dist_p50  \
# 0   20250530_younger_rice_seminal_sweep_input_scaling  a193y2u3  0.286794
# 1   20250530_younger_rice_seminal_sweep_input_scaling  a193y2u3  0.301394
# 2   20250530_younger_rice_seminal_sweep_input_scaling  a193y2u3  0.320337
# 3   20250530_younger_rice_seminal_sweep_input_scaling  ke5c8g0s  0.319400
# 4   20250530_younger_rice_seminal_sweep_input_scaling  ke5c8g0s  0.309257
# 5   20250530_younger_rice_seminal_sweep_input_scaling  ke5c8g0s  0.308387
# 6   20250530_younger_rice_seminal_sweep_input_scaling  maf7zhat  0.291379
# 7   20250530_younger_rice_seminal_sweep_input_scaling  maf7zhat  0.300427
# 8   20250530_younger_rice_seminal_sweep_input_scaling  maf7zhat  0.279013
# 9   20250530_younger_rice_seminal_sweep_input_scaling  pbfbjsq9  0.289792
# 10  20250530_younger_rice_seminal_sweep_input_scaling  pbfbjsq9  0.285962
# 11  20250530_younger_rice_seminal_sweep_input_scaling  pbfbjsq9  0.300754
# 12  20250530_younger_rice_seminal_sweep_input_scaling  qhmfs9ha  0.320640
# 13  20250530_younger_rice_seminal_sweep_input_scaling  qhmfs9ha  0.319432
# 14  20250530_younger_rice_seminal_sweep_input_scaling  qhmfs9ha  0.332072
# 15  20250530_younger_rice_seminal_sweep_input_scaling  zfd4ujej  0.303794
# 16  20250530_younger_rice_seminal_sweep_input_scaling  zfd4ujej  0.308566
# 17  20250530_younger_rice_seminal_sweep_input_scaling  zfd4ujej  0.308077
#
#     dist_p90  dist_p95   dist_p99  dist_avg  dist_std  ...  config/name  \
# 0   1.752561  2.802334  10.701627  0.863954  2.408870  ...
# 1   1.783864  3.106004  15.400946  0.951913  2.724440  ...
# 2   2.000613  3.739581  18.313780  1.069889  3.029175  ...
# 3   1.856650  3.412274  21.592263  1.117053  3.446124  ...
# 4   1.514791  2.860783  21.783899  1.068597  3.485570  ...
# 5   1.514678  2.895000  14.112521  0.964810  3.007482  ...
# 6   1.430505  2.209452   6.369415  0.723378  2.002563  ...
# 7   1.737482  3.056709  16.440534  1.004317  3.091313  ...
# 8   1.874522  4.827789  22.071200  1.198309  3.723943  ...
# 9   1.779367  3.308230  24.015624  1.254448  4.055879  ...
# 10  1.414610  2.365154  14.280285  0.883345  2.671889  ...
# 11  2.219702  6.327577  26.422083  1.472999  4.400879  ...
# 12  1.484317  2.244557  18.087807  0.933873  3.177132  ...
# 13  1.503953  2.401962  23.887111  1.066593  3.670190  ...
# 14  1.825229  3.827686  25.550758  1.261469  3.975282  ...
# 15  1.371865  2.229005   7.195291  0.723123  2.098262  ...
# 16  1.494653  2.483430  11.457096  0.883219  2.750089  ...
# 17  1.731325  3.678025  24.524552  1.184375  3.831838  ...
#
#                                          config/model  \
# 0   {'heads': {'centroid': None, 'multi_instance':...
# 1   {'heads': {'centroid': None, 'multi_instance':...
# 2   {'heads': {'centroid': None, 'multi_instance':...
# 3   {'heads': {'centroid': None, 'multi_instance':...
# 4   {'heads': {'centroid': None, 'multi_instance':...
# 5   {'heads': {'centroid': None, 'multi_instance':...
# 6   {'heads': {'centroid': None, 'multi_instance':...
# 7   {'heads': {'centroid': None, 'multi_instance':...
# 8   {'heads': {'centroid': None, 'multi_instance':...
# 9   {'heads': {'centroid': None, 'multi_instance':...
# 10  {'heads': {'centroid': None, 'multi_instance':...
# 11  {'heads': {'centroid': None, 'multi_instance':...
# 12  {'heads': {'centroid': None, 'multi_instance':...
# 13  {'heads': {'centroid': None, 'multi_instance':...
# 14  {'heads': {'centroid': None, 'multi_instance':...
# 15  {'heads': {'centroid': None, 'multi_instance':...
# 16  {'heads': {'centroid': None, 'multi_instance':...
# 17  {'heads': {'centroid': None, 'multi_instance':...
#
#                                        config/outputs  config/version  \
# 0   {'zmq': {'publish_address': 'tcp://127.0.0.1:9...               1
# 1   {'zmq': {'publish_address': 'tcp://127.0.0.1:9...               1
# 2   {'zmq': {'publish_address': 'tcp://127.0.0.1:9...               1
# 3   {'zmq': {'publish_address': 'tcp://127.0.0.1:9...               0
# 4   {'zmq': {'publish_address': 'tcp://127.0.0.1:9...               0
# 5   {'zmq': {'publish_address': 'tcp://127.0.0.1:9...               0
# 6   {'zmq': {'publish_address': 'tcp://127.0.0.1:9...               5
# 7   {'zmq': {'publish_address': 'tcp://127.0.0.1:9...               5
# 8   {'zmq': {'publish_address': 'tcp://127.0.0.1:9...               5
# 9   {'zmq': {'publish_address': 'tcp://127.0.0.1:9...               4
# 10  {'zmq': {'publish_address': 'tcp://127.0.0.1:9...               4
# 11  {'zmq': {'publish_address': 'tcp://127.0.0.1:9...               4
# 12  {'zmq': {'publish_address': 'tcp://127.0.0.1:9...               3
# 13  {'zmq': {'publish_address': 'tcp://127.0.0.1:9...               3
# 14  {'zmq': {'publish_address': 'tcp://127.0.0.1:9...               3
# 15  {'zmq': {'publish_address': 'tcp://127.0.0.1:9...               2
# 16  {'zmq': {'publish_address': 'tcp://127.0.0.1:9...               2
# 17  {'zmq': {'publish_address': 'tcp://127.0.0.1:9...               2
#
#                                       config/filename  \
# 0   D:\SLEAP\20250530_seminal_root_generalist\youn...
# 1   D:\SLEAP\20250530_seminal_root_generalist\youn...
# 2   D:\SLEAP\20250530_seminal_root_generalist\youn...
# 3   D:\SLEAP\20250530_seminal_root_generalist\youn...
# 4   D:\SLEAP\20250530_seminal_root_generalist\youn...
# 5   D:\SLEAP\20250530_seminal_root_generalist\youn...
# 6   D:\SLEAP\20250530_seminal_root_generalist\youn...
# 7   D:\SLEAP\20250530_seminal_root_generalist\youn...
# 8   D:\SLEAP\20250530_seminal_root_generalist\youn...
# 9   D:\SLEAP\20250530_seminal_root_generalist\youn...
# 10  D:\SLEAP\20250530_seminal_root_generalist\youn...
# 11  D:\SLEAP\20250530_seminal_root_generalist\youn...
# 12  D:\SLEAP\20250530_seminal_root_generalist\youn...
# 13  D:\SLEAP\20250530_seminal_root_generalist\youn...
# 14  D:\SLEAP\20250530_seminal_root_generalist\youn...
# 15  D:\SLEAP\20250530_seminal_root_generalist\youn...
# 16  D:\SLEAP\20250530_seminal_root_generalist\youn...
# 17  D:\SLEAP\20250530_seminal_root_generalist\youn...
#
#                                    config/config_path config/description  \
# 0   D:/SLEAP/20250530_seminal_root_generalist/youn...
# 1   D:/SLEAP/20250530_seminal_root_generalist/youn...
# 2   D:/SLEAP/20250530_seminal_root_generalist/youn...
# 3   D:/SLEAP/20250530_seminal_root_generalist/youn...
# 4   D:/SLEAP/20250530_seminal_root_generalist/youn...
# 5   D:/SLEAP/20250530_seminal_root_generalist/youn...
# 6   D:/SLEAP/20250530_seminal_root_generalist/youn...
# 7   D:/SLEAP/20250530_seminal_root_generalist/youn...
# 8   D:/SLEAP/20250530_seminal_root_generalist/youn...
# 9   D:/SLEAP/20250530_seminal_root_generalist/youn...
# 10  D:/SLEAP/20250530_seminal_root_generalist/youn...
# 11  D:/SLEAP/20250530_seminal_root_generalist/youn...
# 12  D:/SLEAP/20250530_seminal_root_generalist/youn...
# 13  D:/SLEAP/20250530_seminal_root_generalist/youn...
# 14  D:/SLEAP/20250530_seminal_root_generalist/youn...
# 15  D:/SLEAP/20250530_seminal_root_generalist/youn...
# 16  D:/SLEAP/20250530_seminal_root_generalist/youn...
# 17  D:/SLEAP/20250530_seminal_root_generalist/youn...
#
#                                   config/optimization  config/sleap_version  \
# 0   {'epochs': 200, 'prefetch': True, 'optimizer':...                 1.3.4
# 1   {'epochs': 200, 'prefetch': True, 'optimizer':...                 1.3.4
# 2   {'epochs': 200, 'prefetch': True, 'optimizer':...                 1.3.4
# 3   {'epochs': 200, 'prefetch': True, 'optimizer':...                 1.3.4
# 4   {'epochs': 200, 'prefetch': True, 'optimizer':...                 1.3.4
# 5   {'epochs': 200, 'prefetch': True, 'optimizer':...                 1.3.4
# 6   {'epochs': 200, 'prefetch': True, 'optimizer':...                 1.3.4
# 7   {'epochs': 200, 'prefetch': True, 'optimizer':...                 1.3.4
# 8   {'epochs': 200, 'prefetch': True, 'optimizer':...                 1.3.4
# 9   {'epochs': 200, 'prefetch': True, 'optimizer':...                 1.3.4
# 10  {'epochs': 200, 'prefetch': True, 'optimizer':...                 1.3.4
# 11  {'epochs': 200, 'prefetch': True, 'optimizer':...                 1.3.4
# 12  {'epochs': 200, 'prefetch': True, 'optimizer':...                 1.3.4
# 13  {'epochs': 200, 'prefetch': True, 'optimizer':...                 1.3.4
# 14  {'epochs': 200, 'prefetch': True, 'optimizer':...                 1.3.4
# 15  {'epochs': 200, 'prefetch': True, 'optimizer':...                 1.3.4
# 16  {'epochs': 200, 'prefetch': True, 'optimizer':...                 1.3.4
# 17  {'epochs': 200, 'prefetch': True, 'optimizer':...                 1.3.4
#
#    config/data.preprocessing.input_scaling
# 0                                     1.00
# 1                                     0.75
# 2                                     0.50
# 3                                     1.00
# 4                                     0.75
# 5                                     0.50
# 6                                     1.00
# 7                                     0.75
# 8                                     0.50
# 9                                     1.00
# 10                                    0.75
# 11                                    0.50
# 12                                    1.00
# 13                                    0.75
# 14                                    0.50
# 15                                    1.00
# 16                                    0.75
# 17                                    0.50
#
# [18 rows x 25 columns]

# %%
sweep_csv_path = Path(EXPERIMENT_NAME) / f"sweep_metrics_{datetime_str}.csv"
sweep_df.to_csv(sweep_csv_path, index=False)
print(f"Sweep metrics saved to {sweep_csv_path}")
# Out:
# Sweep metrics saved to 20250530_younger_rice_seminal_sweep_input_scaling\sweep_metrics_2025-06-03_09-44-06.csv

# %%
# ========== SETTINGS ==========
font_settings = {
    "font.family": "sans-serif",
    "font.sans-serif": ["Arial", "DejaVu Sans"],
    "font.size": 18,
    "axes.titlesize": 24,
    "axes.labelsize": 20,
    "xtick.labelsize": 16,
    "ytick.labelsize": 16,
    "legend.fontsize": 16,
    "figure.titlesize": 26
}


plt.rcParams.update(font_settings)
sns.set_theme(style="whitegrid", font_scale=1.5)

# ========== LOAD LABEL COUNTS ==========
label_csv_path = CSV_PATH
df_labels = pd.read_csv(label_csv_path)

# Sum train + val + test labels per crop using version 0 since all versions have the same ratios of train/val/test
df_labels_v0 = df_labels[df_labels["version"] == 0]
total_labeled_per_crop = df_labels_v0["labeled_frames"].sum()

data = sweep_df.copy()

# ========== PLOTTING ==========
plt.figure(figsize=(14, 10))

# Barplot (median dist_avg)
ax = sns.barplot(
    data=sweep_df, x="config/data.preprocessing.input_scaling", y="dist_avg",
    estimator=np.median, errorbar="sd",
    palette="magma", edgecolor="black", linewidth=2
)

# Overlay raw points
sns.stripplot(
    data=sweep_df, x="config/data.preprocessing.input_scaling", y="dist_avg",
    color="black", size=6, alpha=0.7, jitter=True
)

# Title and axis labels
plt.title("Younger Rice Seminal Root Error for Varying Input Scaling", pad=20)
plt.xlabel("Input Scaling", labelpad=10)
plt.ylabel("Average Error (mm)", labelpad=10)

# Readability adjustments
# plt.xticks(rotation=45, ha="right")
sns.despine()
plt.grid(axis="y", linestyle="--", alpha=0.6)


# Save
plot_file_path = Path(EXPERIMENT_NAME) / f"{datetime_str}_input_scaling_sweep_eval.png"
plt.savefig(plot_file_path, dpi=600, bbox_inches="tight", transparent=True)
plt.show()
print(f"Plot saved to {plot_file_path}")
# Out:
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# Plot saved to 20250530_younger_rice_seminal_sweep_input_scaling\2025-06-03_09-44-06_input_scaling_sweep_eval.png

# %%
# ========== SETTINGS ==========
font_settings = {
    "font.family": "sans-serif",
    "font.sans-serif": ["Arial", "DejaVu Sans"],
    "font.size": 18,
    "axes.titlesize": 24,
    "axes.labelsize": 20,
    "xtick.labelsize": 16,
    "ytick.labelsize": 16,
    "legend.fontsize": 16,
    "figure.titlesize": 26
}


plt.rcParams.update(font_settings)
sns.set_theme(style="whitegrid", font_scale=1.5)

# ========== LOAD LABEL COUNTS ==========
label_csv_path = CSV_PATH
df_labels = pd.read_csv(label_csv_path)

# Sum train + val + test labels per crop using version 0 since all versions have the same ratios of train/val/test
df_labels_v0 = df_labels[df_labels["version"] == 0]
total_labeled_per_crop = df_labels_v0["labeled_frames"].sum()

data = sweep_df.copy()

data["input_scale"] = data["config/data.preprocessing.input_scaling"]
# ========== PLOTTING ==========
plt.figure(figsize=(14, 10))

sns.pointplot(
    data=data,
    x="input_scale",
    y="dist_avg",
    hue="config/version",
    palette="Set2",
    markers="o",
    linestyles="-",
    errorbar=None
)

# sns.stripplot(
#     data=data,
#     x="input_scale",
#     y="dist_avg",
#     color="black",
#     size=10,
#     alpha=0.6,
#     jitter=False,
# )

plt.title("Younger Rice Seminal Root Error by Input Scaling and Version", pad=20)
plt.xlabel("Input Scaling", labelpad=10)
plt.ylabel("Average Error (mm)", labelpad=10)

sns.despine()
plt.grid(axis="y", linestyle="--", alpha=0.6)
plt.legend(title="Train/Test Version")

plot_file_path = Path(EXPERIMENT_NAME) / f"{datetime_str}_input_scaling_sweep_eval_version.png"
plt.savefig(plot_file_path, dpi=600, bbox_inches="tight", transparent=True)
plt.show()
print(f"Plot saved to {plot_file_path}")
# Out:
# Plot saved to 20250530_younger_rice_seminal_sweep_input_scaling\2025-06-03_09-44-06_input_scaling_sweep_eval_version.png

# %%
from scipy.stats import friedmanchisquare

# Pivot data: rows = version, columns = input_scaling
pivot = sweep_df.pivot_table(
    index="config/version",
    columns="config/data.preprocessing.input_scaling",
    values="dist_avg"
)

# Apply Friedman test
stat, p = friedmanchisquare(*[pivot[col] for col in pivot.columns])

print(f"Friedman test statistic: {stat:.3f}, p-value: {p:.4f}")
if p < 0.05:
    print("Significant difference detected between input scalings.")
else:
    print("No significant difference between input scalings.")

# from itertools import combinations
# from scipy.stats import wilcoxon

# scaling_pairs = combinations(pivot.columns, 2)

# for a, b in scaling_pairs:
#     stat, p = wilcoxon(pivot[a], pivot[b])
#     print(f"{a} vs {b}: p = {p:.4f}")
# Out:
# Friedman test statistic: 4.333, p-value: 0.1146
# No significant difference between input scalings.

# %%
# selected_version = "000"
# model_name = f"{MODEL_GROUP}_v{selected_version}"
# frame_index = 6

# # Paths and settings
# prediction_files = []
# test_group_names = []

# for group in GROUPS:
#     test_set = f"{group}_v{selected_version}"
#     run_dir = Path(EXPERIMENT_NAME) / f"{model_name}_on_{test_set}_{datetime_str}"
#     prediction_path = run_dir / f"{model_name}_on_{test_set}_test_predictions.slp"

#     if prediction_path.exists():
#         prediction_files.append(prediction_path.as_posix())
#         # Clean group name (remove suffix)
#         test_group_names.append(group.split("_")[-1])
#     else:
#         print(f"Missing prediction file: {prediction_path}")

# # Call the grid visualization function
# predictions_viz_from_sleap_files(
#     prediction_files_grid=[prediction_files],  # wrap in another list: 1 row
#     test_group_names=test_group_names, # column label
#     model_names=[model_name],  # row label
#     output_path=Path(EXPERIMENT_NAME) / f"{datetime_str}_predictions_grid_frame{frame_index}.png",
#     frame_idx=frame_index,
#     figsize_scale=5,
#     dpi=300,
#     transparent=False,
#     font_settings=font_settings,
#     colormap="magma",
#     spacing={
#         "left": 0.00,
#         "right": 1.00,
#         "top": 1.00,
#         "bottom": 0.00,
#         "wspace": 0.0,
#         "hspace": 0.0,
#         }
# )

# %%
# === Initialize the W&B run ===
add_files_run = wandb.init(
    project=PROJECT_NAME,
    entity=ENTITY_NAME,
    job_type="add_files_to_artifact"
)

# === Use existing artifact and download its contents ===
# metrics_artifact = add_files_run.use_artifact(f"{ARTIFACT_NAME}:latest", type="metrics")
# artifact_dir = Path(metrics_artifact.download())
# print(f"Artifact downloaded to: {artifact_dir}")

# === Create a new artifact ===
new_metrics_artifact = wandb.Artifact(name=ARTIFACT_NAME, type="metrics")

# === Add generalizable model plots ===
new_metrics_artifact.add_file((Path(EXPERIMENT_NAME) / f"{datetime_str}_input_scaling_sweep_eval.png").as_posix())
new_metrics_artifact.add_file((Path(EXPERIMENT_NAME) / f"{datetime_str}_input_scaling_sweep_eval_version.png").as_posix())

# === Add associated CSVs ===
new_metrics_artifact.add_file((Path(label_csv_path)).as_posix())
new_metrics_artifact.add_file((Path(sweep_csv_path)).as_posix())

# === Add existing artifact contents ===
# for file_path in artifact_dir.iterdir():
#     new_metrics_artifact.add_file(file_path)

# === Log and finish ===
add_files_run.log_artifact(new_metrics_artifact)
add_files_run.finish()
# Out:
# Tracking run with wandb version 0.18.6
# Run data is saved locally in <code>e:\repositories\sleap-roots-training\wandb\run-20250603_094412-3gvgso69</code>
# Syncing run <strong><a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/3gvgso69' target="_blank">lunar-monkey-488</a></strong> to <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a>
#  View run at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/3gvgso69' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/3gvgso69</a>
#  View run <strong style="color:#cdcd00">lunar-monkey-488</strong> at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/3gvgso69' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/3gvgso69</a><br/> View project at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a><br/>Synced 6 W&B file(s), 0 media file(s), 6 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250603_094412-3gvgso69\logs</code>
