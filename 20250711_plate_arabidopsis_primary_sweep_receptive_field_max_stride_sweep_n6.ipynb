# %%
import wandb
import sleap_roots_training

from pathlib import Path

from sleap_roots_training.train import main

# %%
# Constants for W&B initialization
ENTITY_NAME = "eberrigan-salk-institute-for-biological-studies"
PROJECT_NAME = "sleap-roots"
REGISTRY = "sleap-roots-models"
JOB_TYPE = "sweep"
EXPERIMENT_NAME = "20250711_plate_arabidopsis_primary_sweep_receptive_field"

# Constants for artifact creation
DESCRIPTION = "2-7 DAG arabidopsis primary root in plates with 8 nodes varying max stride [8, 16, 32, 64, 128] sweep"
TAGS = ["plate", "arabidopsis", "2-7DAG", "primary", "8nodes", "arabidopsis2-7DAG", "2025-07-11", "max_stride_sweep"]
MODEL_TAGS = ["plate", "arabidopsis", "2-7DAG", "primary", "8nodes", "arabidopsis2-7DAG", "2025-07-11", "max_stride_sweep"]
COLLECTION_NAME = EXPERIMENT_NAME
CSV_PATH = "//multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/20250711_plate_arabidopsis_primary_sweep_receptive_field/train_test_splits.csv"

# %%
    # "model": {
    #     "backbone": {
    #         "leap": null,
    #         "unet": {
    #             "stem_stride": null,
    #             "max_stride": 16,

# Define the sweep configuration
sweep_config = {
    "method": "grid",
    "parameters": {
        "model.backbone.unet.max_stride": {"values": [8, 16, 32, 64, 128]},
    }
}

# %%
print(wandb.run)
# Out:
# None

# %%
sleap_roots_training.reset_config()
# Out:
# Configuration updated successfully at c:\repos\sleap-roots-training\sleap_roots_training\config.yaml.
# Configuration has been reset to default values.

# %%
sleap_roots_training.update_config(entity_name=ENTITY_NAME, project_name=PROJECT_NAME, registry=REGISTRY, job_type=JOB_TYPE, experiment_name=EXPERIMENT_NAME, collection_name=COLLECTION_NAME)
# Out:
# Configuration updated successfully at c:\repos\sleap-roots-training\sleap_roots_training\config.yaml.
# CONFIG updated to {'project_name': 'sleap-roots', 'entity_name': 'eberrigan-salk-institute-for-biological-studies', 'experiment_name': '20250711_plate_arabidopsis_primary_sweep_receptive_field', 'registry': 'sleap-roots-models', 'collection_name': '20250711_plate_arabidopsis_primary_sweep_receptive_field', 'job_type': 'sweep'}.

# %%
main(csv_path=CSV_PATH, tags=TAGS, model_tags=MODEL_TAGS, use_sweep=True, sweep_config=sweep_config)
# Out:
# INFO:root:Starting main function with CSV: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/20250711_plate_arabidopsis_primary_sweep_receptive_field/train_test_splits.csv
# INFO:root:Detected 6 train-test splits.
# INFO:root:Processing train-test split version: 0
# INFO:root:Creating W&B sweep for version 0...
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# Create sweep with ID: 45bjarr8
# Sweep URL: https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/sweeps/45bjarr8
# INFO:root:Sweep created for version 0 with ID: 45bjarr8
# INFO:root:Running W&B grid sweep with 5 experiments for version 0...
# INFO:wandb.agents.pyagent:Starting sweep agent: entity=None, project=None, count=5
# wandb: Agent Starting Run: a1ef1tls with config:
# wandb: 	model.backbone.unet.max_stride: 8
# INFO:root:Starting training for version 0...
# INFO:root:Directory path for version 0: \\multilab-na.ad.salk.edu\hpi_dev\users\eberrigan\SLEAP\20250711_plate_arabidopsis_primary_sweep_receptive_field\train_test_split.v000
# wandb: Currently logged in as: eberrigan (eberrigan-salk-institute-for-biological-studies). Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>c:\repos\sleap-roots-training\wandb\run-20250714_130211-a1ef1tls</code>
# Syncing run <strong><a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/a1ef1tls' target="_blank">20250711_plate_arabidopsis_primary_sweep_receptive_field_training_v000</a></strong> to <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/sweeps/45bjarr8' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/sweeps/45bjarr8</a>
#  View project at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a>
#  View sweep at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/sweeps/45bjarr8' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/sweeps/45bjarr8</a>
#  View run at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/a1ef1tls' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/a1ef1tls</a>
# INFO:root:Updating configuration with W&B parameters.
# INFO:root:Original Parameters: {
#     "data": {
#         "labels": {
#             "training_labels": "\\\\multilab-na.ad.salk.edu\\hpi_dev\\users\\eberrigan\\SLEAP\\20250711_plate_arabidopsis_primary_sweep_receptive_field\\train_test_split.v000\\train.pkg.slp",
#             "validation_labels": "\\\\multilab-na.ad.salk.edu\\hpi_dev\\users\\eberrigan\\SLEAP\\20250711_plate_arabidopsis_primary_sweep_receptive_field\\train_test_split.v000\\val.pkg.slp",
#             "validation_fraction": 0.1,
#             "test_labels": "\\\\multilab-na.ad.salk.edu\\hpi_dev\\users\\eberrigan\\SLEAP\\20250711_plate_arabidopsis_primary_sweep_receptive_field\\train_test_split.v000\\test.pkg.slp",
#             "split_by_inds": false,
#             "training_inds": null,
#             "validation_inds": null,
#             "test_inds": null,
#             "search_path_hints": [],
#             "skeletons": []
#         },
#         "preprocessing": {
#             "ensure_rgb": false,
#             "ensure_grayscale": false,
#             "imagenet_mode": null,
#             "input_scaling": 1.0,
#             "pad_to_stride": null,
#             "resize_and_pad_to_target": true,
#             "target_height": null,
#             "target_width": null
#         },
#         "instance_cropping": {
#             "center_on_part": null,
#             "crop_size": null,
#             "crop_size_detection_padding": 16
#         }
#     },
#     "model": {
#         "backbone": {
#             "leap": null,
#             "unet": {
#                 "stem_stride": null,
#                 "max_stride": 16,
#                 "output_stride": 2,
#                 "filters": 24,
#                 "filters_rate": 1.5,
#                 "middle_block": true,
#                 "up_interpolate": true,
#                 "stacks": 1
#             },
#             "hourglass": null,
#             "resnet": null,
#             "pretrained_encoder": null
#         },
#         "heads": {
#             "single_instance": null,
#             "centroid": null,
#             "centered_instance": null,
#             "multi_instance": {
#                 "confmaps": {
#                     "part_names": null,
#                     "sigma": 2.5,
#                     "output_stride": 2,
#                     "loss_weight": 1.0,
#                     "offset_refinement": false
#                 },
#                 "pafs": {
#                     "edges": null,
#                     "sigma": 75.0,
#                     "output_stride": 8,
#                     "loss_weight": 1.0
#                 }
#             }
#         }
#     },
#     "optimization": {
#         "preload_data": true,
#         "augmentation_config": {
#             "rotate": false,
#             "rotation_min_angle": -5.0,
#             "rotation_max_angle": 5.0,
#             "translate": false,
#             "translate_min": -5,
#             "translate_max": 5,
#             "scale": false,
#             "scale_min": 0.5,
#             "scale_max": 1.2,
#             "uniform_noise": false,
#             "uniform_noise_min_val": 0.0,
#             "uniform_noise_max_val": 10.0,
#             "gaussian_noise": false,
#             "gaussian_noise_mean": 5.0,
#             "gaussian_noise_stddev": 1.0,
#             "contrast": false,
#             "contrast_min_gamma": 0.5,
#             "contrast_max_gamma": 2.0,
#             "brightness": false,
#             "brightness_min_val": 0.0,
#             "brightness_max_val": 10.0,
#             "random_crop": false,
#             "random_crop_height": 256,
#             "random_crop_width": 256,
#             "random_flip": false,
#             "flip_horizontal": true
#         },
#         "online_shuffling": true,
#         "shuffle_buffer_size": 128,
#         "prefetch": true,
#         "batch_size": 4,
#         "batches_per_epoch": null,
#         "min_batches_per_epoch": 200,
#         "val_batches_per_epoch": null,
#         "min_val_batches_per_epoch": 10,
#         "epochs": 200,
#         "optimizer": "adam",
#         "initial_learning_rate": 0.0001,
#         "learning_rate_schedule": {
#             "reduce_on_plateau": true,
#             "reduction_factor": 0.5,
#             "plateau_min_delta": 1e-06,
#             "plateau_patience": 5,
#             "plateau_cooldown": 3,
#             "min_learning_rate": 1e-08
#         },
#         "hard_keypoint_mining": {
#             "online_mining": false,
#             "hard_to_easy_ratio": 2.0,
#             "min_hard_keypoints": 2,
#             "max_hard_keypoints": null,
#             "loss_scale": 5.0
#         },
#         "early_stopping": {
#             "stop_training_on_plateau": true,
#             "plateau_min_delta": 1e-06,
#             "plateau_patience": 10
#         }
#     },
#     "outputs": {
#         "save_outputs": true,
#         "run_name": null,
#         "run_name_prefix": "",
#         "run_name_suffix": "",
#         "runs_folder": "\\\\multilab-na.ad.salk.edu\\hpi_dev\\users\\eberrigan\\SLEAP\\20250711_plate_arabidopsis_primary_sweep_receptive_field\\train_test_split.v000\\models",
#         "tags": [
#             ""
#         ],
#         "save_visualizations": false,
#         "delete_viz_images": true,
#         "zip_outputs": false,
#         "log_to_csv": true,
#         "checkpointing": {
#             "initial_model": false,
#             "best_model": true,
#             "every_epoch": false,
#             "latest_model": false,
#             "final_model": false
#         },
#         "tensorboard": {
#             "write_logs": false,
#             "loss_frequency": "epoch",
#             "architecture_graph": false,
#             "profile_graph": false,
#             "visualizations": true
#         },
#         "zmq": {
#             "subscribe_to_controller": false,
#             "controller_address": "tcp://127.0.0.1:9000",
#             "controller_polling_timeout": 10,
#             "publish_updates": false,
#             "publish_address": "tcp://127.0.0.1:9001"
#         }
#     },
#     "name": "",
#     "description": "",
#     "sleap_version": "",
#     "filename": "",
#     "model.backbone.unet.max_stride": 8,
#     "version": 0,
#     "config_path": "//multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/20250711_plate_arabidopsis_primary_sweep_receptive_field/train_test_split.v000/initial_config_modified_v000.json"
# }
# INFO:root:Updated parameter: data -> {'labels': {'training_labels': '\\\\multilab-na.ad.salk.edu\\hpi_dev\\users\\eberrigan\\SLEAP\\20250711_plate_arabidopsis_primary_sweep_receptive_field\\train_test_split.v000\\train.pkg.slp', 'validation_labels': '\\\\multilab-na.ad.salk.edu\\hpi_dev\\users\\eberrigan\\SLEAP\\20250711_plate_arabidopsis_primary_sweep_receptive_field\\train_test_split.v000\\val.pkg.slp', 'validation_fraction': 0.1, 'test_labels': '\\\\multilab-na.ad.salk.edu\\hpi_dev\\users\\eberrigan\\SLEAP\\20250711_plate_arabidopsis_primary_sweep_receptive_field\\train_test_split.v000\\test.pkg.slp', 'split_by_inds': False, 'training_inds': None, 'validation_inds': None, 'test_inds': None, 'search_path_hints': [], 'skeletons': []}, 'preprocessing': {'ensure_rgb': False, 'ensure_grayscale': False, 'imagenet_mode': None, 'input_scaling': 1.0, 'pad_to_stride': None, 'resize_and_pad_to_target': True, 'target_height': None, 'target_width': None}, 'instance_cropping': {'center_on_part': None, 'crop_size': None, 'crop_size_detection_padding': 16}}
# INFO:root:Updated parameter: model -> {'backbone': {'leap': None, 'unet': {'stem_stride': None, 'max_stride': 16, 'output_stride': 2, 'filters': 24, 'filters_rate': 1.5, 'middle_block': True, 'up_interpolate': True, 'stacks': 1}, 'hourglass': None, 'resnet': None, 'pretrained_encoder': None}, 'heads': {'single_instance': None, 'centroid': None, 'centered_instance': None, 'multi_instance': {'confmaps': {'part_names': None, 'sigma': 2.5, 'output_stride': 2, 'loss_weight': 1.0, 'offset_refinement': False}, 'pafs': {'edges': None, 'sigma': 75.0, 'output_stride': 8, 'loss_weight': 1.0}}}}
# INFO:root:Updated parameter: optimization -> {'preload_data': True, 'augmentation_config': {'rotate': False, 'rotation_min_angle': -5.0, 'rotation_max_angle': 5.0, 'translate': False, 'translate_min': -5, 'translate_max': 5, 'scale': False, 'scale_min': 0.5, 'scale_max': 1.2, 'uniform_noise': False, 'uniform_noise_min_val': 0.0, 'uniform_noise_max_val': 10.0, 'gaussian_noise': False, 'gaussian_noise_mean': 5.0, 'gaussian_noise_stddev': 1.0, 'contrast': False, 'contrast_min_gamma': 0.5, 'contrast_max_gamma': 2.0, 'brightness': False, 'brightness_min_val': 0.0, 'brightness_max_val': 10.0, 'random_crop': False, 'random_crop_height': 256, 'random_crop_width': 256, 'random_flip': False, 'flip_horizontal': True}, 'online_shuffling': True, 'shuffle_buffer_size': 128, 'prefetch': True, 'batch_size': 4, 'batches_per_epoch': None, 'min_batches_per_epoch': 200, 'val_batches_per_epoch': None, 'min_val_batches_per_epoch': 10, 'epochs': 200, 'optimizer': 'adam', 'initial_learning_rate': 0.0001, 'learning_rate_schedule': {'reduce_on_plateau': True, 'reduction_factor': 0.5, 'plateau_min_delta': 1e-06, 'plateau_patience': 5, 'plateau_cooldown': 3, 'min_learning_rate': 1e-08}, 'hard_keypoint_mining': {'online_mining': False, 'hard_to_easy_ratio': 2.0, 'min_hard_keypoints': 2, 'max_hard_keypoints': None, 'loss_scale': 5.0}, 'early_stopping': {'stop_training_on_plateau': True, 'plateau_min_delta': 1e-06, 'plateau_patience': 10}}
# INFO:root:Updated parameter: outputs -> {'save_outputs': True, 'run_name': None, 'run_name_prefix': '', 'run_name_suffix': '', 'runs_folder': '\\\\multilab-na.ad.salk.edu\\hpi_dev\\users\\eberrigan\\SLEAP\\20250711_plate_arabidopsis_primary_sweep_receptive_field\\train_test_split.v000\\models', 'tags': [''], 'save_visualizations': False, 'delete_viz_images': True, 'zip_outputs': False, 'log_to_csv': True, 'checkpointing': {'initial_model': False, 'best_model': True, 'every_epoch': False, 'latest_model': False, 'final_model': False}, 'tensorboard': {'write_logs': False, 'loss_frequency': 'epoch', 'architecture_graph': False, 'profile_graph': False, 'visualizations': True}, 'zmq': {'subscribe_to_controller': False, 'controller_address': 'tcp://127.0.0.1:9000', 'controller_polling_timeout': 10, 'publish_updates': False, 'publish_address': 'tcp://127.0.0.1:9001'}}
# INFO:root:Updated parameter: name ->
# INFO:root:Updated parameter: description ->
# INFO:root:Updated parameter: sleap_version ->
# INFO:root:Updated parameter: filename ->
# INFO:root:Updated parameter: model.backbone.unet.max_stride -> 8
# INFO:root:Updated parameter: version -> 0
# INFO:root:Updated parameter: config_path -> //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/20250711_plate_arabidopsis_primary_sweep_receptive_field/train_test_split.v000/initial_config_modified_v000.json
# INFO:root:Final updated configuration:
# {
#     "data": {
#         "labels": {
#             "training_labels": "\\\\multilab-na.ad.salk.edu\\hpi_dev\\users\\eberrigan\\SLEAP\\20250711_plate_arabidopsis_primary_sweep_receptive_field\\train_test_split.v000\\train.pkg.slp",
#             "validation_labels": "\\\\multilab-na.ad.salk.edu\\hpi_dev\\users\\eberrigan\\SLEAP\\20250711_plate_arabidopsis_primary_sweep_receptive_field\\train_test_split.v000\\val.pkg.slp",
#             "validation_fraction": 0.1,
#             "test_labels": "\\\\multilab-na.ad.salk.edu\\hpi_dev\\users\\eberrigan\\SLEAP\\20250711_plate_arabidopsis_primary_sweep_receptive_field\\train_test_split.v000\\test.pkg.slp",
#             "split_by_inds": false,
#             "training_inds": null,
#             "validation_inds": null,
#             "test_inds": null,
#             "search_path_hints": [],
#             "skeletons": []
#         },
#         "preprocessing": {
#             "ensure_rgb": false,
#             "ensure_grayscale": false,
#             "imagenet_mode": null,
#             "input_scaling": 1.0,
#             "pad_to_stride": null,
#             "resize_and_pad_to_target": true,
#             "target_height": null,
#             "target_width": null
#         },
#         "instance_cropping": {
#             "center_on_part": null,
#             "crop_size": null,
#             "crop_size_detection_padding": 16
#         }
#     },
#     "model": {
#         "backbone": {
#             "leap": null,
#             "unet": {
#                 "stem_stride": null,
#                 "max_stride": 8,
#                 "output_stride": 2,
#                 "filters": 24,
#                 "filters_rate": 1.5,
#                 "middle_block": true,
#                 "up_interpolate": true,
#                 "stacks": 1
#             },
#             "hourglass": null,
#             "resnet": null,
#             "pretrained_encoder": null
#         },
#         "heads": {
#             "single_instance": null,
#             "centroid": null,
#             "centered_instance": null,
#             "multi_instance": {
#                 "confmaps": {
#                     "part_names": null,
#                     "sigma": 2.5,
#                     "output_stride": 2,
#                     "loss_weight": 1.0,
#                     "offset_refinement": false
#                 },
#                 "pafs": {
#                     "edges": null,
#                     "sigma": 75.0,
#                     "output_stride": 8,
#                     "loss_weight": 1.0
#                 }
#             }
#         }
#     },
#     "optimization": {
#         "preload_data": true,
#         "augmentation_config": {
#             "rotate": false,
#             "rotation_min_angle": -5.0,
#             "rotation_max_angle": 5.0,
#             "translate": false,
#             "translate_min": -5,
#             "translate_max": 5,
#             "scale": false,
#             "scale_min": 0.5,
#             "scale_max": 1.2,
#             "uniform_noise": false,
#             "uniform_noise_min_val": 0.0,
#             "uniform_noise_max_val": 10.0,
#             "gaussian_noise": false,
#             "gaussian_noise_mean": 5.0,
#             "gaussian_noise_stddev": 1.0,
#             "contrast": false,
#             "contrast_min_gamma": 0.5,
#             "contrast_max_gamma": 2.0,
#             "brightness": false,
#             "brightness_min_val": 0.0,
#             "brightness_max_val": 10.0,
#             "random_crop": false,
#             "random_crop_height": 256,
#             "random_crop_width": 256,
#             "random_flip": false,
#             "flip_horizontal": true
#         },
#         "online_shuffling": true,
#         "shuffle_buffer_size": 128,
#         "prefetch": true,
#         "batch_size": 4,
#         "batches_per_epoch": null,
#         "min_batches_per_epoch": 200,
#         "val_batches_per_epoch": null,
#         "min_val_batches_per_epoch": 10,
#         "epochs": 200,
#         "optimizer": "adam",
#         "initial_learning_rate": 0.0001,
#         "learning_rate_schedule": {
#             "reduce_on_plateau": true,
#             "reduction_factor": 0.5,
#             "plateau_min_delta": 1e-06,
#             "plateau_patience": 5,
#             "plateau_cooldown": 3,
#             "min_learning_rate": 1e-08
#         },
#         "hard_keypoint_mining": {
#             "online_mining": false,
#             "hard_to_easy_ratio": 2.0,
#             "min_hard_keypoints": 2,
#             "max_hard_keypoints": null,
#             "loss_scale": 5.0
#         },
#         "early_stopping": {
#             "stop_training_on_plateau": true,
#             "plateau_min_delta": 1e-06,
#             "plateau_patience": 10
#         }
#     },
#     "outputs": {
#         "save_outputs": true,
#         "run_name": null,
#         "run_name_prefix": "",
#         "run_name_suffix": "",
#         "runs_folder": "\\\\multilab-na.ad.salk.edu\\hpi_dev\\users\\eberrigan\\SLEAP\\20250711_plate_arabidopsis_primary_sweep_receptive_field\\train_test_split.v000\\models",
#         "tags": [
#             ""
#         ],
#         "save_visualizations": false,
#         "delete_viz_images": true,
#         "zip_outputs": false,
#         "log_to_csv": true,
#         "checkpointing": {
#             "initial_model": false,
#             "best_model": true,
#             "every_epoch": false,
#             "latest_model": false,
#             "final_model": false
#         },
#         "tensorboard": {
#             "write_logs": false,
#             "loss_frequency": "epoch",
#             "architecture_graph": false,
#             "profile_graph": false,
#             "visualizations": true
#         },
#         "zmq": {
#             "subscribe_to_controller": false,
#             "controller_address": "tcp://127.0.0.1:9000",
#             "controller_polling_timeout": 10,
#             "publish_updates": false,
#             "publish_address": "tcp://127.0.0.1:9001"
#         }
#     },
#     "name": "",
#     "description": "",
#     "sleap_version": "",
#     "filename": "",
#     "version": 0,
#     "config_path": "//multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/20250711_plate_arabidopsis_primary_sweep_receptive_field/train_test_split.v000/initial_config_modified_v000.json"
# }
# INFO:root:Saved updated configuration to: \\multilab-na.ad.salk.edu\hpi_dev\users\eberrigan\SLEAP\20250711_plate_arabidopsis_primary_sweep_receptive_field\train_test_split.v000\modified_config_v000_20250714_130212.json
# INFO:root:Training with updated config for version 0.
# INFO:root:Executing training command: sleap-train //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/20250711_plate_arabidopsis_primary_sweep_receptive_field/train_test_split.v000/modified_config_v000_20250714_130212.json
# Executing: sleap-train //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/20250711_plate_arabidopsis_primary_sweep_receptive_field/train_test_split.v000/modified_config_v000_20250714_130212.json
# INFO:sleap.nn.training:Versions:
# SLEAP: 1.4.1a2
# TensorFlow: 2.7.0
# Numpy: 1.21.6
# Python: 3.7.12
# OS: Windows-10-10.0.26100-SP0
# INFO:sleap.nn.training:Training labels file: None
# INFO:sleap.nn.training:Training profile: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/20250711_plate_arabidopsis_primary_sweep_receptive_field/train_test_split.v000/modified_config_v000_20250714_130212.json
# INFO:sleap.nn.training:
# INFO:sleap.nn.training:Arguments:
# INFO:sleap.nn.training:{
#     "training_job_path": "//multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/20250711_plate_arabidopsis_primary_sweep_receptive_field/train_test_split.v000/modified_config_v000_20250714_130212.json",
#     "labels_path": null,
#     "video_paths": [
#         ""
#     ],
#     "val_labels": null,
#     "test_labels": null,
#     "base_checkpoint": null,
#     "tensorboard": false,
#     "save_viz": false,
#     "zmq": false,
#     "publish_port": 9001,
#     "controller_port": 9000,
#     "run_name": "",
#     "prefix": "",
#     "suffix": "",
#     "cpu": false,
#     "first_gpu": false,
#     "last_gpu": false,
#     "gpu": "auto"
# }
# INFO:sleap.nn.training:
# INFO:sleap.nn.training:Training job:
# INFO:sleap.nn.training:{
#     "data": {
#         "labels": {
#             "training_labels": "\\\\multilab-na.ad.salk.edu\\hpi_dev\\users\\eberrigan\\SLEAP\\20250711_plate_arabidopsis_primary_sweep_receptive_field\\train_test_split.v000\\train.pkg.slp",
#             "validation_labels": "\\\\multilab-na.ad.salk.edu\\hpi_dev\\users\\eberrigan\\SLEAP\\20250711_plate_arabidopsis_primary_sweep_receptive_field\\train_test_split.v000\\val.pkg.slp",
#             "validation_fraction": 0.1,
#             "test_labels": "\\\\multilab-na.ad.salk.edu\\hpi_dev\\users\\eberrigan\\SLEAP\\20250711_plate_arabidopsis_primary_sweep_receptive_field\\train_test_split.v000\\test.pkg.slp",
#             "split_by_inds": false,
#             "training_inds": null,
#             "validation_inds": null,
#             "test_inds": null,
#             "search_path_hints": [],
#             "skeletons": []
#         },
#         "preprocessing": {
#             "ensure_rgb": false,
#             "ensure_grayscale": false,
#             "imagenet_mode": null,
#             "input_scaling": 1.0,
#             "pad_to_stride": null,
#             "resize_and_pad_to_target": true,
#             "target_height": null,
#             "target_width": null
#         },
#         "instance_cropping": {
#             "center_on_part": null,
#             "crop_size": null,
#             "crop_size_detection_padding": 16
#         }
#     },
#     "model": {
#         "backbone": {
#             "leap": null,
#             "unet": {
#                 "stem_stride": null,
#                 "max_stride": 8,
#                 "output_stride": 2,
#                 "filters": 24,
#                 "filters_rate": 1.5,
#                 "middle_block": true,
#                 "up_interpolate": true,
#                 "stacks": 1
#             },
#             "hourglass": null,
#             "resnet": null,
#             "pretrained_encoder": null
#         },
#         "heads": {
#             "single_instance": null,
#             "centroid": null,
#             "centered_instance": null,
#             "multi_instance": {
#                 "confmaps": {
#                     "part_names": null,
#                     "sigma": 2.5,
#                     "output_stride": 2,
#                     "loss_weight": 1.0,
#                     "offset_refinement": false
#                 },
#                 "pafs": {
#                     "edges": null,
#                     "sigma": 75.0,
#                     "output_stride": 8,
#                     "loss_weight": 1.0
#                 }
#             },
#             "multi_class_bottomup": null,
#             "multi_class_topdown": null
#         },
#         "base_checkpoint": null
#     },
#     "optimization": {
#         "preload_data": true,
#         "augmentation_config": {
#             "rotate": false,
#             "rotation_min_angle": -5.0,
#             "rotation_max_angle": 5.0,
#             "translate": false,
#             "translate_min": -5,
#             "translate_max": 5,
#             "scale": false,
#             "scale_min": 0.5,
#             "scale_max": 1.2,
#             "uniform_noise": false,
#             "uniform_noise_min_val": 0.0,
#             "uniform_noise_max_val": 10.0,
#             "gaussian_noise": false,
#             "gaussian_noise_mean": 5.0,
#             "gaussian_noise_stddev": 1.0,
#             "contrast": false,
#             "contrast_min_gamma": 0.5,
#             "contrast_max_gamma": 2.0,
#             "brightness": false,
#             "brightness_min_val": 0.0,
#             "brightness_max_val": 10.0,
#             "random_crop": false,
#             "random_crop_height": 256,
#             "random_crop_width": 256,
#             "random_flip": false,
#             "flip_horizontal": true
#         },
#         "online_shuffling": true,
#         "shuffle_buffer_size": 128,
#         "prefetch": true,
#         "batch_size": 4,
#         "batches_per_epoch": null,
#         "min_batches_per_epoch": 200,
#         "val_batches_per_epoch": null,
#         "min_val_batches_per_epoch": 10,
#         "epochs": 200,
#         "optimizer": "adam",
#         "initial_learning_rate": 0.0001,
#         "learning_rate_schedule": {
#             "reduce_on_plateau": true,
#             "reduction_factor": 0.5,
#             "plateau_min_delta": 1e-06,
#             "plateau_patience": 5,
#             "plateau_cooldown": 3,
#             "min_learning_rate": 1e-08
#         },
#         "hard_keypoint_mining": {
#             "online_mining": false,
#             "hard_to_easy_ratio": 2.0,
#             "min_hard_keypoints": 2,
#             "max_hard_keypoints": null,
#             "loss_scale": 5.0
#         },
#         "early_stopping": {
#             "stop_training_on_plateau": true,
#             "plateau_min_delta": 1e-06,
#             "plateau_patience": 10
#         }
#     },
#     "outputs": {
#         "save_outputs": true,
#         "run_name": null,
#         "run_name_prefix": "",
#         "run_name_suffix": "",
#         "runs_folder": "\\\\multilab-na.ad.salk.edu\\hpi_dev\\users\\eberrigan\\SLEAP\\20250711_plate_arabidopsis_primary_sweep_receptive_field\\train_test_split.v000\\models",
#         "tags": [
#             ""
#         ],
#         "save_visualizations": false,
#         "delete_viz_images": true,
#         "zip_outputs": false,
#         "log_to_csv": true,
#         "checkpointing": {
#             "initial_model": false,
#             "best_model": true,
#             "every_epoch": false,
#             "latest_model": false,
#             "final_model": false
#         },
#         "tensorboard": {
#             "write_logs": false,
#             "loss_frequency": "epoch",
#             "architecture_graph": false,
#             "profile_graph": false,
#             "visualizations": true
#         },
#         "zmq": {
#             "subscribe_to_controller": false,
#             "controller_address": "tcp://127.0.0.1:9000",
#             "controller_polling_timeout": 10,
#             "publish_updates": false,
#             "publish_address": "tcp://127.0.0.1:9001"
#         }
#     },
#     "name": "",
#     "description": "",
#     "sleap_version": "",
#     "filename": "//multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/20250711_plate_arabidopsis_primary_sweep_receptive_field/train_test_split.v000/modified_config_v000_20250714_130212.json"
# }
# INFO:sleap.nn.training:
# INFO:sleap.nn.training:Auto-selected GPU 0 with 22664 MiB of free memory.
# INFO:sleap.nn.training:Using GPU 0 for acceleration.
# INFO:sleap.nn.training:Disabled GPU memory pre-allocation.
# INFO:sleap.nn.training:System:
# GPUs: 1/1 available
#   Device: /physical_device:GPU:0
#          Available: True
#        Initialized: False
#      Memory growth: True
# INFO:sleap.nn.training:
# INFO:sleap.nn.training:Initializing trainer...
# INFO:sleap.nn.training:Loading training labels from: \\multilab-na.ad.salk.edu\hpi_dev\users\eberrigan\SLEAP\20250711_plate_arabidopsis_primary_sweep_receptive_field\train_test_split.v000\train.pkg.slp
# INFO:sleap.nn.training:Loading validation labels from: \\multilab-na.ad.salk.edu\hpi_dev\users\eberrigan\SLEAP\20250711_plate_arabidopsis_primary_sweep_receptive_field\train_test_split.v000\val.pkg.slp
# INFO:sleap.nn.training:Loading test labels from: \\multilab-na.ad.salk.edu\hpi_dev\users\eberrigan\SLEAP\20250711_plate_arabidopsis_primary_sweep_receptive_field\train_test_split.v000\test.pkg.slp
# INFO:sleap.nn.training:Setting up for training...
# INFO:sleap.nn.training:Setting up pipeline builders...
# INFO:sleap.nn.training:Setting up model...
# INFO:sleap.nn.training:Building test pipeline...
# INFO:sleap.nn.training:Loaded test example. [12.683s]
# INFO:sleap.nn.training:  Input shape: (1504, 1616, 1)
# INFO:sleap.nn.training:Created Keras model.
# INFO:sleap.nn.training:  Backbone: UNet(stacks=1, filters=24, filters_rate=1.5, kernel_size=3, stem_kernel_size=7, convs_per_block=2, stem_blocks=0, down_blocks=3, middle_block=True, up_blocks=2, up_interpolate=True, block_contraction=False)
# INFO:sleap.nn.training:  Max stride: 8
# INFO:sleap.nn.training:  Parameters: 301,687
# INFO:sleap.nn.training:  Heads:
# INFO:sleap.nn.training:    [0] = MultiInstanceConfmapsHead(part_names=['r1', 'r2', 'r3', 'r4', 'r5', 'r6', 'r7', 'r8'], sigma=2.5, output_stride=2, loss_weight=1.0)
# INFO:sleap.nn.training:    [1] = PartAffinityFieldsHead(edges=[('r1', 'r2'), ('r2', 'r3'), ('r3', 'r4'), ('r4', 'r5'), ('r5', 'r6'), ('r6', 'r7'), ('r7', 'r8')], sigma=75.0, output_stride=8, loss_weight=1.0)
# INFO:sleap.nn.training:  Outputs:
# INFO:sleap.nn.training:    [0] = KerasTensor(type_spec=TensorSpec(shape=(None, 752, 808, 8), dtype=tf.float32, name=None), name='MultiInstanceConfmapsHead/BiasAdd:0', description="created by layer 'MultiInstanceConfmapsHead'")
# INFO:sleap.nn.training:    [1] = KerasTensor(type_spec=TensorSpec(shape=(None, 188, 202, 14), dtype=tf.float32, name=None), name='PartAffinityFieldsHead/BiasAdd:0', description="created by layer 'PartAffinityFieldsHead'")
# INFO:sleap.nn.training:Training from scratch
# INFO:sleap.nn.training:Setting up data pipelines...
# INFO:sleap.nn.training:Training set: n = 424
# INFO:sleap.nn.training:Validation set: n = 91
# INFO:sleap.nn.training:Setting up optimization...
# INFO:sleap.nn.training:  Learning rate schedule: LearningRateScheduleConfig(reduce_on_plateau=True, reduction_factor=0.5, plateau_min_delta=1e-06, plateau_patience=5, plateau_cooldown=3, min_learning_rate=1e-08)
# INFO:sleap.nn.training:  Early stopping: EarlyStoppingConfig(stop_training_on_plateau=True, plateau_min_delta=1e-06, plateau_patience=10)
# INFO:sleap.nn.training:Setting up outputs...
# INFO:sleap.nn.training:Created run path: \\multilab-na.ad.salk.edu\hpi_dev\users\eberrigan\SLEAP\20250711_plate_arabidopsis_primary_sweep_receptive_field\train_test_split.v000\models\250714_130235.multi_instance.n=515
# INFO:sleap.nn.training:Setting up visualization...
# INFO:sleap.nn.training:Finished trainer set up. [20.5s]
# INFO:sleap.nn.training:Creating tf.data.Datasets for training data generation...
# INFO:sleap.nn.training:Finished creating training datasets. [23.5s]
# INFO:sleap.nn.training:Starting training loop...
# Epoch 1/200
# 200/200 - 133s - loss: 0.0019 - MultiInstanceConfmapsHead_loss: 1.6065e-04 - PartAffinityFieldsHead_loss: 0.0017 - val_loss: 0.0018 - val_MultiInstanceConfmapsHead_loss: 1.5917e-04 - val_PartAffinityFieldsHead_loss: 0.0017 - lr: 1.0000e-04 - 133s/epoch - 664ms/step
# Epoch 2/200
# 200/200 - 112s - loss: 0.0018 - MultiInstanceConfmapsHead_loss: 1.5774e-04 - PartAffinityFieldsHead_loss: 0.0016 - val_loss: 0.0017 - val_MultiInstanceConfmapsHead_loss: 1.5507e-04 - val_PartAffinityFieldsHead_loss: 0.0016 - lr: 1.0000e-04 - 112s/epoch - 558ms/step
# Epoch 3/200
# 200/200 - 111s - loss: 0.0017 - MultiInstanceConfmapsHead_loss: 1.5219e-04 - PartAffinityFieldsHead_loss: 0.0015 - val_loss: 0.0017 - val_MultiInstanceConfmapsHead_loss: 1.4902e-04 - val_PartAffinityFieldsHead_loss: 0.0015 - lr: 1.0000e-04 - 111s/epoch - 557ms/step
# Epoch 4/200
# 200/200 - 109s - loss: 0.0016 - MultiInstanceConfmapsHead_loss: 1.4799e-04 - PartAffinityFieldsHead_loss: 0.0015 - val_loss: 0.0017 - val_MultiInstanceConfmapsHead_loss: 1.4730e-04 - val_PartAffinityFieldsHead_loss: 0.0015 - lr: 1.0000e-04 - 109s/epoch - 544ms/step
# Epoch 5/200
# 200/200 - 106s - loss: 0.0016 - MultiInstanceConfmapsHead_loss: 1.4609e-04 - PartAffinityFieldsHead_loss: 0.0015 - val_loss: 0.0016 - val_MultiInstanceConfmapsHead_loss: 1.4525e-04 - val_PartAffinityFieldsHead_loss: 0.0015 - lr: 1.0000e-04 - 106s/epoch - 530ms/step
# Epoch 6/200
# 200/200 - 106s - loss: 0.0016 - MultiInstanceConfmapsHead_loss: 1.4449e-04 - PartAffinityFieldsHead_loss: 0.0014 - val_loss: 0.0016 - val_MultiInstanceConfmapsHead_loss: 1.4416e-04 - val_PartAffinityFieldsHead_loss: 0.0015 - lr: 1.0000e-04 - 106s/epoch - 530ms/step
# Epoch 7/200
# 200/200 - 107s - loss: 0.0016 - MultiInstanceConfmapsHead_loss: 1.4334e-04 - PartAffinityFieldsHead_loss: 0.0014 - val_loss: 0.0016 - val_MultiInstanceConfmapsHead_loss: 1.4468e-04 - val_PartAffinityFieldsHead_loss: 0.0014 - lr: 1.0000e-04 - 107s/epoch - 537ms/step
# Epoch 8/200
# 200/200 - 105s - loss: 0.0016 - MultiInstanceConfmapsHead_loss: 1.4251e-04 - PartAffinityFieldsHead_loss: 0.0014 - val_loss: 0.0016 - val_MultiInstanceConfmapsHead_loss: 1.4191e-04 - val_PartAffinityFieldsHead_loss: 0.0014 - lr: 1.0000e-04 - 105s/epoch - 523ms/step
# Epoch 9/200
# 200/200 - 105s - loss: 0.0015 - MultiInstanceConfmapsHead_loss: 1.4154e-04 - PartAffinityFieldsHead_loss: 0.0014 - val_loss: 0.0015 - val_MultiInstanceConfmapsHead_loss: 1.4008e-04 - val_PartAffinityFieldsHead_loss: 0.0014 - lr: 1.0000e-04 - 105s/epoch - 525ms/step
# Epoch 10/200
# 200/200 - 108s - loss: 0.0015 - MultiInstanceConfmapsHead_loss: 1.4068e-04 - PartAffinityFieldsHead_loss: 0.0014 - val_loss: 0.0016 - val_MultiInstanceConfmapsHead_loss: 1.4096e-04 - val_PartAffinityFieldsHead_loss: 0.0014 - lr: 1.0000e-04 - 108s/epoch - 538ms/step
# Epoch 11/200
# 200/200 - 112s - loss: 0.0015 - MultiInstanceConfmapsHead_loss: 1.4020e-04 - PartAffinityFieldsHead_loss: 0.0014 - val_loss: 0.0015 - val_MultiInstanceConfmapsHead_loss: 1.3912e-04 - val_PartAffinityFieldsHead_loss: 0.0014 - lr: 1.0000e-04 - 112s/epoch - 559ms/step
# Epoch 12/200
# 200/200 - 109s - loss: 0.0015 - MultiInstanceConfmapsHead_loss: 1.3970e-04 - PartAffinityFieldsHead_loss: 0.0014 - val_loss: 0.0015 - val_MultiInstanceConfmapsHead_loss: 1.3889e-04 - val_PartAffinityFieldsHead_loss: 0.0014 - lr: 1.0000e-04 - 109s/epoch - 544ms/step
# Epoch 13/200
# 200/200 - 107s - loss: 0.0015 - MultiInstanceConfmapsHead_loss: 1.3858e-04 - PartAffinityFieldsHead_loss: 0.0014 - val_loss: 0.0015 - val_MultiInstanceConfmapsHead_loss: 1.3824e-04 - val_PartAffinityFieldsHead_loss: 0.0014 - lr: 1.0000e-04 - 107s/epoch - 533ms/step
# Epoch 14/200
# 200/200 - 111s - loss: 0.0015 - MultiInstanceConfmapsHead_loss: 1.3842e-04 - PartAffinityFieldsHead_loss: 0.0014 - val_loss: 0.0015 - val_MultiInstanceConfmapsHead_loss: 1.3833e-04 - val_PartAffinityFieldsHead_loss: 0.0014 - lr: 1.0000e-04 - 111s/epoch - 553ms/step
# Epoch 15/200
# 200/200 - 109s - loss: 0.0015 - MultiInstanceConfmapsHead_loss: 1.3784e-04 - PartAffinityFieldsHead_loss: 0.0013 - val_loss: 0.0015 - val_MultiInstanceConfmapsHead_loss: 1.3745e-04 - val_PartAffinityFieldsHead_loss: 0.0013 - lr: 1.0000e-04 - 109s/epoch - 543ms/step
# Epoch 16/200
# 200/200 - 106s - loss: 0.0015 - MultiInstanceConfmapsHead_loss: 1.3727e-04 - PartAffinityFieldsHead_loss: 0.0013 - val_loss: 0.0015 - val_MultiInstanceConfmapsHead_loss: 1.3706e-04 - val_PartAffinityFieldsHead_loss: 0.0013 - lr: 1.0000e-04 - 106s/epoch - 532ms/step
# Epoch 17/200
# 200/200 - 108s - loss: 0.0015 - MultiInstanceConfmapsHead_loss: 1.3691e-04 - PartAffinityFieldsHead_loss: 0.0013 - val_loss: 0.0015 - val_MultiInstanceConfmapsHead_loss: 1.3661e-04 - val_PartAffinityFieldsHead_loss: 0.0013 - lr: 1.0000e-04 - 108s/epoch - 542ms/step
# Epoch 18/200
# 200/200 - 104s - loss: 0.0015 - MultiInstanceConfmapsHead_loss: 1.3645e-04 - PartAffinityFieldsHead_loss: 0.0013 - val_loss: 0.0014 - val_MultiInstanceConfmapsHead_loss: 1.3638e-04 - val_PartAffinityFieldsHead_loss: 0.0013 - lr: 1.0000e-04 - 104s/epoch - 522ms/step
# Epoch 19/200
# 200/200 - 107s - loss: 0.0014 - MultiInstanceConfmapsHead_loss: 1.3649e-04 - PartAffinityFieldsHead_loss: 0.0013 - val_loss: 0.0015 - val_MultiInstanceConfmapsHead_loss: 1.3644e-04 - val_PartAffinityFieldsHead_loss: 0.0013 - lr: 1.0000e-04 - 107s/epoch - 533ms/step
# Epoch 20/200
# 200/200 - 106s - loss: 0.0014 - MultiInstanceConfmapsHead_loss: 1.3613e-04 - PartAffinityFieldsHead_loss: 0.0013 - val_loss: 0.0015 - val_MultiInstanceConfmapsHead_loss: 1.3861e-04 - val_PartAffinityFieldsHead_loss: 0.0013 - lr: 1.0000e-04 - 106s/epoch - 531ms/step
# Epoch 21/200
# 200/200 - 109s - loss: 0.0014 - MultiInstanceConfmapsHead_loss: 1.3549e-04 - PartAffinityFieldsHead_loss: 0.0013 - val_loss: 0.0015 - val_MultiInstanceConfmapsHead_loss: 1.3643e-04 - val_PartAffinityFieldsHead_loss: 0.0013 - lr: 1.0000e-04 - 109s/epoch - 543ms/step
# Epoch 22/200
# 200/200 - 112s - loss: 0.0014 - MultiInstanceConfmapsHead_loss: 1.3550e-04 - PartAffinityFieldsHead_loss: 0.0013 - val_loss: 0.0014 - val_MultiInstanceConfmapsHead_loss: 1.3489e-04 - val_PartAffinityFieldsHead_loss: 0.0013 - lr: 1.0000e-04 - 112s/epoch - 560ms/step
# Epoch 23/200
# 200/200 - 109s - loss: 0.0014 - MultiInstanceConfmapsHead_loss: 1.3479e-04 - PartAffinityFieldsHead_loss: 0.0013 - val_loss: 0.0014 - val_MultiInstanceConfmapsHead_loss: 1.3437e-04 - val_PartAffinityFieldsHead_loss: 0.0013 - lr: 1.0000e-04 - 109s/epoch - 543ms/step
# Epoch 24/200
# 200/200 - 109s - loss: 0.0014 - MultiInstanceConfmapsHead_loss: 1.3455e-04 - PartAffinityFieldsHead_loss: 0.0013 - val_loss: 0.0014 - val_MultiInstanceConfmapsHead_loss: 1.3490e-04 - val_PartAffinityFieldsHead_loss: 0.0013 - lr: 1.0000e-04 - 109s/epoch - 543ms/step
# Epoch 25/200
# 200/200 - 109s - loss: 0.0014 - MultiInstanceConfmapsHead_loss: 1.3414e-04 - PartAffinityFieldsHead_loss: 0.0013 - val_loss: 0.0015 - val_MultiInstanceConfmapsHead_loss: 1.3359e-04 - val_PartAffinityFieldsHead_loss: 0.0013 - lr: 1.0000e-04 - 109s/epoch - 543ms/step
# Epoch 26/200
# 200/200 - 108s - loss: 0.0014 - MultiInstanceConfmapsHead_loss: 1.3409e-04 - PartAffinityFieldsHead_loss: 0.0013 - val_loss: 0.0014 - val_MultiInstanceConfmapsHead_loss: 1.3325e-04 - val_PartAffinityFieldsHead_loss: 0.0013 - lr: 1.0000e-04 - 108s/epoch - 538ms/step
# Epoch 27/200
# 200/200 - 105s - loss: 0.0014 - MultiInstanceConfmapsHead_loss: 1.3376e-04 - PartAffinityFieldsHead_loss: 0.0013 - val_loss: 0.0014 - val_MultiInstanceConfmapsHead_loss: 1.3336e-04 - val_PartAffinityFieldsHead_loss: 0.0013 - lr: 1.0000e-04 - 105s/epoch - 525ms/step
# Epoch 28/200
# 200/200 - 110s - loss: 0.0014 - MultiInstanceConfmapsHead_loss: 1.3310e-04 - PartAffinityFieldsHead_loss: 0.0013 - val_loss: 0.0014 - val_MultiInstanceConfmapsHead_loss: 1.3307e-04 - val_PartAffinityFieldsHead_loss: 0.0013 - lr: 1.0000e-04 - 110s/epoch - 548ms/step
# Epoch 29/200
# 200/200 - 104s - loss: 0.0014 - MultiInstanceConfmapsHead_loss: 1.3318e-04 - PartAffinityFieldsHead_loss: 0.0013 - val_loss: 0.0014 - val_MultiInstanceConfmapsHead_loss: 1.3396e-04 - val_PartAffinityFieldsHead_loss: 0.0013 - lr: 1.0000e-04 - 104s/epoch - 520ms/step
# Epoch 30/200
# 200/200 - 104s - loss: 0.0014 - MultiInstanceConfmapsHead_loss: 1.3303e-04 - PartAffinityFieldsHead_loss: 0.0013 - val_loss: 0.0014 - val_MultiInstanceConfmapsHead_loss: 1.3365e-04 - val_PartAffinityFieldsHead_loss: 0.0013 - lr: 1.0000e-04 - 104s/epoch - 521ms/step
# Epoch 31/200
# 200/200 - 107s - loss: 0.0014 - MultiInstanceConfmapsHead_loss: 1.3282e-04 - PartAffinityFieldsHead_loss: 0.0013 - val_loss: 0.0014 - val_MultiInstanceConfmapsHead_loss: 1.3219e-04 - val_PartAffinityFieldsHead_loss: 0.0013 - lr: 1.0000e-04 - 107s/epoch - 533ms/step
# Epoch 32/200
# 200/200 - 107s - loss: 0.0014 - MultiInstanceConfmapsHead_loss: 1.3214e-04 - PartAffinityFieldsHead_loss: 0.0013 - val_loss: 0.0014 - val_MultiInstanceConfmapsHead_loss: 1.3314e-04 - val_PartAffinityFieldsHead_loss: 0.0013 - lr: 1.0000e-04 - 107s/epoch - 534ms/step
# Epoch 33/200
# 200/200 - 107s - loss: 0.0014 - MultiInstanceConfmapsHead_loss: 1.3213e-04 - PartAffinityFieldsHead_loss: 0.0013 - val_loss: 0.0014 - val_MultiInstanceConfmapsHead_loss: 1.3215e-04 - val_PartAffinityFieldsHead_loss: 0.0013 - lr: 1.0000e-04 - 107s/epoch - 536ms/step
# Epoch 34/200
# 200/200 - 107s - loss: 0.0014 - MultiInstanceConfmapsHead_loss: 1.3193e-04 - PartAffinityFieldsHead_loss: 0.0013 - val_loss: 0.0014 - val_MultiInstanceConfmapsHead_loss: 1.3220e-04 - val_PartAffinityFieldsHead_loss: 0.0013 - lr: 1.0000e-04 - 107s/epoch - 534ms/step
# Epoch 35/200
# 200/200 - 110s - loss: 0.0014 - MultiInstanceConfmapsHead_loss: 1.3173e-04 - PartAffinityFieldsHead_loss: 0.0013 - val_loss: 0.0014 - val_MultiInstanceConfmapsHead_loss: 1.3137e-04 - val_PartAffinityFieldsHead_loss: 0.0013 - lr: 1.0000e-04 - 110s/epoch - 548ms/step
# Epoch 36/200
# 200/200 - 104s - loss: 0.0014 - MultiInstanceConfmapsHead_loss: 1.3166e-04 - PartAffinityFieldsHead_loss: 0.0012 - val_loss: 0.0014 - val_MultiInstanceConfmapsHead_loss: 1.3202e-04 - val_PartAffinityFieldsHead_loss: 0.0013 - lr: 1.0000e-04 - 104s/epoch - 518ms/step
# Epoch 37/200
# 200/200 - 107s - loss: 0.0014 - MultiInstanceConfmapsHead_loss: 1.3112e-04 - PartAffinityFieldsHead_loss: 0.0012 - val_loss: 0.0014 - val_MultiInstanceConfmapsHead_loss: 1.3119e-04 - val_PartAffinityFieldsHead_loss: 0.0013 - lr: 1.0000e-04 - 107s/epoch - 537ms/step
# Epoch 38/200
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 200/200 - 107s - loss: 0.0014 - MultiInstanceConfmapsHead_loss: 1.3096e-04 - PartAffinityFieldsHead_loss: 0.0012 - val_loss: 0.0014 - val_MultiInstanceConfmapsHead_loss: 1.3143e-04 - val_PartAffinityFieldsHead_loss: 0.0013 - lr: 1.0000e-04 - 107s/epoch - 533ms/step
# Epoch 39/200
# 200/200 - 107s - loss: 0.0014 - MultiInstanceConfmapsHead_loss: 1.3010e-04 - PartAffinityFieldsHead_loss: 0.0012 - val_loss: 0.0014 - val_MultiInstanceConfmapsHead_loss: 1.3024e-04 - val_PartAffinityFieldsHead_loss: 0.0012 - lr: 5.0000e-05 - 107s/epoch - 533ms/step
# Epoch 40/200
# 200/200 - 107s - loss: 0.0014 - MultiInstanceConfmapsHead_loss: 1.3005e-04 - PartAffinityFieldsHead_loss: 0.0012 - val_loss: 0.0014 - val_MultiInstanceConfmapsHead_loss: 1.3122e-04 - val_PartAffinityFieldsHead_loss: 0.0012 - lr: 5.0000e-05 - 107s/epoch - 537ms/step
# Epoch 41/200
# 200/200 - 108s - loss: 0.0014 - MultiInstanceConfmapsHead_loss: 1.2987e-04 - PartAffinityFieldsHead_loss: 0.0012 - val_loss: 0.0014 - val_MultiInstanceConfmapsHead_loss: 1.3047e-04 - val_PartAffinityFieldsHead_loss: 0.0012 - lr: 5.0000e-05 - 108s/epoch - 538ms/step
# Epoch 42/200
# 200/200 - 107s - loss: 0.0014 - MultiInstanceConfmapsHead_loss: 1.2963e-04 - PartAffinityFieldsHead_loss: 0.0012 - val_loss: 0.0014 - val_MultiInstanceConfmapsHead_loss: 1.3050e-04 - val_PartAffinityFieldsHead_loss: 0.0012 - lr: 5.0000e-05 - 107s/epoch - 537ms/step
# Epoch 43/200
# 200/200 - 108s - loss: 0.0014 - MultiInstanceConfmapsHead_loss: 1.2977e-04 - PartAffinityFieldsHead_loss: 0.0012 - val_loss: 0.0014 - val_MultiInstanceConfmapsHead_loss: 1.3048e-04 - val_PartAffinityFieldsHead_loss: 0.0012 - lr: 5.0000e-05 - 108s/epoch - 540ms/step
# Epoch 44/200
# 200/200 - 111s - loss: 0.0013 - MultiInstanceConfmapsHead_loss: 1.2937e-04 - PartAffinityFieldsHead_loss: 0.0012 - val_loss: 0.0014 - val_MultiInstanceConfmapsHead_loss: 1.3017e-04 - val_PartAffinityFieldsHead_loss: 0.0012 - lr: 5.0000e-05 - 111s/epoch - 554ms/step
# Epoch 45/200
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 200/200 - 105s - loss: 0.0014 - MultiInstanceConfmapsHead_loss: 1.2953e-04 - PartAffinityFieldsHead_loss: 0.0012 - val_loss: 0.0014 - val_MultiInstanceConfmapsHead_loss: 1.3063e-04 - val_PartAffinityFieldsHead_loss: 0.0013 - lr: 5.0000e-05 - 105s/epoch - 527ms/step
# Epoch 46/200
# 200/200 - 108s - loss: 0.0013 - MultiInstanceConfmapsHead_loss: 1.2907e-04 - PartAffinityFieldsHead_loss: 0.0012 - val_loss: 0.0014 - val_MultiInstanceConfmapsHead_loss: 1.2986e-04 - val_PartAffinityFieldsHead_loss: 0.0012 - lr: 2.5000e-05 - 108s/epoch - 539ms/step
# Epoch 47/200
# 200/200 - 109s - loss: 0.0014 - MultiInstanceConfmapsHead_loss: 1.2897e-04 - PartAffinityFieldsHead_loss: 0.0012 - val_loss: 0.0014 - val_MultiInstanceConfmapsHead_loss: 1.2983e-04 - val_PartAffinityFieldsHead_loss: 0.0012 - lr: 2.5000e-05 - 109s/epoch - 544ms/step
# Epoch 48/200
# 200/200 - 108s - loss: 0.0013 - MultiInstanceConfmapsHead_loss: 1.2884e-04 - PartAffinityFieldsHead_loss: 0.0012 - val_loss: 0.0014 - val_MultiInstanceConfmapsHead_loss: 1.2998e-04 - val_PartAffinityFieldsHead_loss: 0.0013 - lr: 2.5000e-05 - 108s/epoch - 538ms/step
# Epoch 49/200
# 200/200 - 108s - loss: 0.0013 - MultiInstanceConfmapsHead_loss: 1.2880e-04 - PartAffinityFieldsHead_loss: 0.0012 - val_loss: 0.0013 - val_MultiInstanceConfmapsHead_loss: 1.2977e-04 - val_PartAffinityFieldsHead_loss: 0.0012 - lr: 2.5000e-05 - 108s/epoch - 541ms/step
# Epoch 50/200
# 200/200 - 107s - loss: 0.0013 - MultiInstanceConfmapsHead_loss: 1.2875e-04 - PartAffinityFieldsHead_loss: 0.0012 - val_loss: 0.0013 - val_MultiInstanceConfmapsHead_loss: 1.2965e-04 - val_PartAffinityFieldsHead_loss: 0.0012 - lr: 2.5000e-05 - 107s/epoch - 536ms/step
# Epoch 51/200
# 200/200 - 106s - loss: 0.0013 - MultiInstanceConfmapsHead_loss: 1.2857e-04 - PartAffinityFieldsHead_loss: 0.0012 - val_loss: 0.0014 - val_MultiInstanceConfmapsHead_loss: 1.2969e-04 - val_PartAffinityFieldsHead_loss: 0.0012 - lr: 2.5000e-05 - 106s/epoch - 532ms/step
# Epoch 52/200
# 200/200 - 112s - loss: 0.0014 - MultiInstanceConfmapsHead_loss: 1.2854e-04 - PartAffinityFieldsHead_loss: 0.0012 - val_loss: 0.0013 - val_MultiInstanceConfmapsHead_loss: 1.2966e-04 - val_PartAffinityFieldsHead_loss: 0.0012 - lr: 2.5000e-05 - 112s/epoch - 561ms/step
# Epoch 53/200
# 200/200 - 107s - loss: 0.0013 - MultiInstanceConfmapsHead_loss: 1.2861e-04 - PartAffinityFieldsHead_loss: 0.0012 - val_loss: 0.0014 - val_MultiInstanceConfmapsHead_loss: 1.2943e-04 - val_PartAffinityFieldsHead_loss: 0.0012 - lr: 2.5000e-05 - 107s/epoch - 536ms/step
# Epoch 54/200
# 200/200 - 108s - loss: 0.0013 - MultiInstanceConfmapsHead_loss: 1.2855e-04 - PartAffinityFieldsHead_loss: 0.0012 - val_loss: 0.0013 - val_MultiInstanceConfmapsHead_loss: 1.2961e-04 - val_PartAffinityFieldsHead_loss: 0.0012 - lr: 2.5000e-05 - 108s/epoch - 539ms/step
# Epoch 55/200
# 200/200 - 109s - loss: 0.0013 - MultiInstanceConfmapsHead_loss: 1.2834e-04 - PartAffinityFieldsHead_loss: 0.0012 - val_loss: 0.0013 - val_MultiInstanceConfmapsHead_loss: 1.2951e-04 - val_PartAffinityFieldsHead_loss: 0.0012 - lr: 2.5000e-05 - 109s/epoch - 543ms/step
# Epoch 56/200
# 200/200 - 107s - loss: 0.0013 - MultiInstanceConfmapsHead_loss: 1.2830e-04 - PartAffinityFieldsHead_loss: 0.0012 - val_loss: 0.0014 - val_MultiInstanceConfmapsHead_loss: 1.2939e-04 - val_PartAffinityFieldsHead_loss: 0.0012 - lr: 2.5000e-05 - 107s/epoch - 534ms/step
# Epoch 57/200
#
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 200/200 - 106s - loss: 0.0013 - MultiInstanceConfmapsHead_loss: 1.2846e-04 - PartAffinityFieldsHead_loss: 0.0012 - val_loss: 0.0014 - val_MultiInstanceConfmapsHead_loss: 1.2955e-04 - val_PartAffinityFieldsHead_loss: 0.0012 - lr: 2.5000e-05 - 106s/epoch - 529ms/step
# Epoch 58/200
# 200/200 - 108s - loss: 0.0013 - MultiInstanceConfmapsHead_loss: 1.2787e-04 - PartAffinityFieldsHead_loss: 0.0012 - val_loss: 0.0014 - val_MultiInstanceConfmapsHead_loss: 1.2923e-04 - val_PartAffinityFieldsHead_loss: 0.0012 - lr: 1.2500e-05 - 108s/epoch - 540ms/step
# Epoch 59/200
# 200/200 - 107s - loss: 0.0013 - MultiInstanceConfmapsHead_loss: 1.2818e-04 - PartAffinityFieldsHead_loss: 0.0012 - val_loss: 0.0014 - val_MultiInstanceConfmapsHead_loss: 1.2946e-04 - val_PartAffinityFieldsHead_loss: 0.0012 - lr: 1.2500e-05 - 107s/epoch - 533ms/step
# Epoch 60/200
# ...
#             "crop_size_detection_padding": 16
#         }
#     },
#     "model": {
#         "backbone": {
#             "leap": null,
#             "unet": {
#                 "stem_stride": null,
#                 "max_stride": 16,
#                 "output_stride": 2,
#                 "filters": 24,
#                 "filters_rate": 1.5,
#                 "middle_block": true,
#                 "up_interpolate": true,
#                 "stacks": 1
#             },
#             "hourglass": null,
#             "resnet": null,
#             "pretrained_encoder": null
#         },
#         "heads": {
#             "single_instance": null,
#             "centroid": null,
#             "centered_instance": null,
#             "multi_instance": {
#                 "confmaps": {
#                     "part_names": null,
#                     "sigma": 2.5,
#                     "output_stride": 2,
#                     "loss_weight": 1.0,
#                     "offset_refinement": false
#                 },
#                 "pafs": {
#                     "edges": null,
#                     "sigma": 75.0,
#                     "output_stride": 8,
#                     "loss_weight": 1.0
#                 }
#             }
#         }
#     },
#     "optimization": {
#         "preload_data": true,
#         "augmentation_config": {
#             "rotate": false,
#             "rotation_min_angle": -5.0,
#             "rotation_max_angle": 5.0,
#             "translate": false,
#             "translate_min": -5,
#             "translate_max": 5,
#             "scale": false,
#             "scale_min": 0.5,
#             "scale_max": 1.2,
#             "uniform_noise": false,
#             "uniform_noise_min_val": 0.0,
#             "uniform_noise_max_val": 10.0,
#             "gaussian_noise": false,
#             "gaussian_noise_mean": 5.0,
#             "gaussian_noise_stddev": 1.0,
#             "contrast": false,
#             "contrast_min_gamma": 0.5,
#             "contrast_max_gamma": 2.0,
#             "brightness": false,
#             "brightness_min_val": 0.0,
#             "brightness_max_val": 10.0,
#             "random_crop": false,
#             "random_crop_height": 256,
#             "random_crop_width": 256,
#             "random_flip": false,
#             "flip_horizontal": true
#         },
#         "online_shuffling": true,
#         "shuffle_buffer_size": 128,
#         "prefetch": true,
#         "batch_size": 4,
#         "batches_per_epoch": null,
#         "min_batches_per_epoch": 200,
#         "val_batches_per_epoch": null,
#         "min_val_batches_per_epoch": 10,
#         "epochs": 200,
#         "optimizer": "adam",
#         "initial_learning_rate": 0.0001,
#         "learning_rate_schedule": {
#             "reduce_on_plateau": true,
#             "reduction_factor": 0.5,
#             "plateau_min_delta": 1e-06,
#             "plateau_patience": 5,
#             "plateau_cooldown": 3,
#             "min_learning_rate": 1e-08
#         },
#         "hard_keypoint_mining": {
#             "online_mining": false,
#             "hard_to_easy_ratio": 2.0,
#             "min_hard_keypoints": 2,
#             "max_hard_keypoints": null,
#             "loss_scale": 5.0
#         },
#         "early_stopping": {
#             "stop_training_on_plateau": true,
#             "plateau_min_delta": 1e-06,
#             "plateau_patience": 10
#         }
#     },
#     "outputs": {
#         "save_outputs": true,
#         "run_name": null,
#         "run_name_prefix": "",
#         "run_name_suffix": "",
#         "runs_folder": "\\\\multilab-na.ad.salk.edu\\hpi_dev\\users\\eberrigan\\SLEAP\\20250711_plate_arabidopsis_primary_sweep_receptive_field\\train_test_split.v004\\models",
#         "tags": [
#             ""
#         ],
#         "save_visualizations": false,
#         "delete_viz_images": true,
#         "zip_outputs": false,
#         "log_to_csv": true,
#         "checkpointing": {
#             "initial_model": false,
#             "best_model": true,
#             "every_epoch": false,
#             "latest_model": false,
#             "final_model": false
#         },
#         "tensorboard": {
#             "write_logs": false,
#             "loss_frequency": "epoch",
#             "architecture_graph": false,
#             "profile_graph": false,
#             "visualizations": true
#         },
#         "zmq": {
#             "subscribe_to_controller": false,
#             "controller_address": "tcp://127.0.0.1:9000",
#             "controller_polling_timeout": 10,
#             "publish_updates": false,
#             "publish_address": "tcp://127.0.0.1:9001"
#         }
#     },
#     "name": "",
#     "description": "",
#     "sleap_version": "",
#     "filename": "",
#     "model.backbone.unet.max_stride": 128,
#     "version": 4,
#     "config_path": "//multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/20250711_plate_arabidopsis_primary_sweep_receptive_field/train_test_split.v004/initial_config_modified_v004.json"
# }
# INFO:root:Updated parameter: data -> {'labels': {'training_labels': '\\\\multilab-na.ad.salk.edu\\hpi_dev\\users\\eberrigan\\SLEAP\\20250711_plate_arabidopsis_primary_sweep_receptive_field\\train_test_split.v004\\train.pkg.slp', 'validation_labels': '\\\\multilab-na.ad.salk.edu\\hpi_dev\\users\\eberrigan\\SLEAP\\20250711_plate_arabidopsis_primary_sweep_receptive_field\\train_test_split.v004\\val.pkg.slp', 'validation_fraction': 0.1, 'test_labels': '\\\\multilab-na.ad.salk.edu\\hpi_dev\\users\\eberrigan\\SLEAP\\20250711_plate_arabidopsis_primary_sweep_receptive_field\\train_test_split.v004\\test.pkg.slp', 'split_by_inds': False, 'training_inds': None, 'validation_inds': None, 'test_inds': None, 'search_path_hints': [], 'skeletons': []}, 'preprocessing': {'ensure_rgb': False, 'ensure_grayscale': False, 'imagenet_mode': None, 'input_scaling': 1.0, 'pad_to_stride': None, 'resize_and_pad_to_target': True, 'target_height': None, 'target_width': None}, 'instance_cropping': {'center_on_part': None, 'crop_size': None, 'crop_size_detection_padding': 16}}
# INFO:root:Updated parameter: model -> {'backbone': {'leap': None, 'unet': {'stem_stride': None, 'max_stride': 16, 'output_stride': 2, 'filters': 24, 'filters_rate': 1.5, 'middle_block': True, 'up_interpolate': True, 'stacks': 1}, 'hourglass': None, 'resnet': None, 'pretrained_encoder': None}, 'heads': {'single_instance': None, 'centroid': None, 'centered_instance': None, 'multi_instance': {'confmaps': {'part_names': None, 'sigma': 2.5, 'output_stride': 2, 'loss_weight': 1.0, 'offset_refinement': False}, 'pafs': {'edges': None, 'sigma': 75.0, 'output_stride': 8, 'loss_weight': 1.0}}}}
# INFO:root:Updated parameter: optimization -> {'preload_data': True, 'augmentation_config': {'rotate': False, 'rotation_min_angle': -5.0, 'rotation_max_angle': 5.0, 'translate': False, 'translate_min': -5, 'translate_max': 5, 'scale': False, 'scale_min': 0.5, 'scale_max': 1.2, 'uniform_noise': False, 'uniform_noise_min_val': 0.0, 'uniform_noise_max_val': 10.0, 'gaussian_noise': False, 'gaussian_noise_mean': 5.0, 'gaussian_noise_stddev': 1.0, 'contrast': False, 'contrast_min_gamma': 0.5, 'contrast_max_gamma': 2.0, 'brightness': False, 'brightness_min_val': 0.0, 'brightness_max_val': 10.0, 'random_crop': False, 'random_crop_height': 256, 'random_crop_width': 256, 'random_flip': False, 'flip_horizontal': True}, 'online_shuffling': True, 'shuffle_buffer_size': 128, 'prefetch': True, 'batch_size': 4, 'batches_per_epoch': None, 'min_batches_per_epoch': 200, 'val_batches_per_epoch': None, 'min_val_batches_per_epoch': 10, 'epochs': 200, 'optimizer': 'adam', 'initial_learning_rate': 0.0001, 'learning_rate_schedule': {'reduce_on_plateau': True, 'reduction_factor': 0.5, 'plateau_min_delta': 1e-06, 'plateau_patience': 5, 'plateau_cooldown': 3, 'min_learning_rate': 1e-08}, 'hard_keypoint_mining': {'online_mining': False, 'hard_to_easy_ratio': 2.0, 'min_hard_keypoints': 2, 'max_hard_keypoints': None, 'loss_scale': 5.0}, 'early_stopping': {'stop_training_on_plateau': True, 'plateau_min_delta': 1e-06, 'plateau_patience': 10}}
# INFO:root:Updated parameter: outputs -> {'save_outputs': True, 'run_name': None, 'run_name_prefix': '', 'run_name_suffix': '', 'runs_folder': '\\\\multilab-na.ad.salk.edu\\hpi_dev\\users\\eberrigan\\SLEAP\\20250711_plate_arabidopsis_primary_sweep_receptive_field\\train_test_split.v004\\models', 'tags': [''], 'save_visualizations': False, 'delete_viz_images': True, 'zip_outputs': False, 'log_to_csv': True, 'checkpointing': {'initial_model': False, 'best_model': True, 'every_epoch': False, 'latest_model': False, 'final_model': False}, 'tensorboard': {'write_logs': False, 'loss_frequency': 'epoch', 'architecture_graph': False, 'profile_graph': False, 'visualizations': True}, 'zmq': {'subscribe_to_controller': False, 'controller_address': 'tcp://127.0.0.1:9000', 'controller_polling_timeout': 10, 'publish_updates': False, 'publish_address': 'tcp://127.0.0.1:9001'}}
# INFO:root:Updated parameter: name ->
# INFO:root:Updated parameter: description ->
# INFO:root:Updated parameter: sleap_version ->
# INFO:root:Updated parameter: filename ->
# INFO:root:Updated parameter: model.backbone.unet.max_stride -> 128
# INFO:root:Updated parameter: version -> 4
# INFO:root:Updated parameter: config_path -> //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/20250711_plate_arabidopsis_primary_sweep_receptive_field/train_test_split.v004/initial_config_modified_v004.json
# INFO:root:Final updated configuration:
# {
#     "data": {
#         "labels": {
#             "training_labels": "\\\\multilab-na.ad.salk.edu\\hpi_dev\\users\\eberrigan\\SLEAP\\20250711_plate_arabidopsis_primary_sweep_receptive_field\\train_test_split.v004\\train.pkg.slp",
#             "validation_labels": "\\\\multilab-na.ad.salk.edu\\hpi_dev\\users\\eberrigan\\SLEAP\\20250711_plate_arabidopsis_primary_sweep_receptive_field\\train_test_split.v004\\val.pkg.slp",
#             "validation_fraction": 0.1,
#             "test_labels": "\\\\multilab-na.ad.salk.edu\\hpi_dev\\users\\eberrigan\\SLEAP\\20250711_plate_arabidopsis_primary_sweep_receptive_field\\train_test_split.v004\\test.pkg.slp",
#             "split_by_inds": false,
#             "training_inds": null,
#             "validation_inds": null,
#             "test_inds": null,
#             "search_path_hints": [],
#             "skeletons": []
#         },
#         "preprocessing": {
#             "ensure_rgb": false,
#             "ensure_grayscale": false,
#             "imagenet_mode": null,
#             "input_scaling": 1.0,
#             "pad_to_stride": null,
#             "resize_and_pad_to_target": true,
#             "target_height": null,
#             "target_width": null
#         },
#         "instance_cropping": {
#             "center_on_part": null,
#             "crop_size": null,
#             "crop_size_detection_padding": 16
#         }
#     },
#     "model": {
#         "backbone": {
#             "leap": null,
#             "unet": {
#                 "stem_stride": null,
#                 "max_stride": 128,
#                 "output_stride": 2,
#                 "filters": 24,
#                 "filters_rate": 1.5,
#                 "middle_block": true,
#                 "up_interpolate": true,
#                 "stacks": 1
#             },
#             "hourglass": null,
#             "resnet": null,
#             "pretrained_encoder": null
#         },
#         "heads": {
#             "single_instance": null,
#             "centroid": null,
#             "centered_instance": null,
#             "multi_instance": {
#                 "confmaps": {
#                     "part_names": null,
#                     "sigma": 2.5,
#                     "output_stride": 2,
#                     "loss_weight": 1.0,
#                     "offset_refinement": false
#                 },
#                 "pafs": {
#                     "edges": null,
#                     "sigma": 75.0,
#                     "output_stride": 8,
#                     "loss_weight": 1.0
#                 }
#             }
#         }
#     },
#     "optimization": {
#         "preload_data": true,
#         "augmentation_config": {
#             "rotate": false,
#             "rotation_min_angle": -5.0,
#             "rotation_max_angle": 5.0,
#             "translate": false,
#             "translate_min": -5,
#             "translate_max": 5,
#             "scale": false,
#             "scale_min": 0.5,
#             "scale_max": 1.2,
#             "uniform_noise": false,
#             "uniform_noise_min_val": 0.0,
#             "uniform_noise_max_val": 10.0,
#             "gaussian_noise": false,
#             "gaussian_noise_mean": 5.0,
#             "gaussian_noise_stddev": 1.0,
#             "contrast": false,
#             "contrast_min_gamma": 0.5,
#             "contrast_max_gamma": 2.0,
#             "brightness": false,
#             "brightness_min_val": 0.0,
#             "brightness_max_val": 10.0,
#             "random_crop": false,
#             "random_crop_height": 256,
#             "random_crop_width": 256,
#             "random_flip": false,
#             "flip_horizontal": true
#         },
#         "online_shuffling": true,
#         "shuffle_buffer_size": 128,
#         "prefetch": true,
#         "batch_size": 4,
#         "batches_per_epoch": null,
#         "min_batches_per_epoch": 200,
#         "val_batches_per_epoch": null,
#         "min_val_batches_per_epoch": 10,
#         "epochs": 200,
#         "optimizer": "adam",
#         "initial_learning_rate": 0.0001,
#         "learning_rate_schedule": {
#             "reduce_on_plateau": true,
#             "reduction_factor": 0.5,
#             "plateau_min_delta": 1e-06,
#             "plateau_patience": 5,
#             "plateau_cooldown": 3,
#             "min_learning_rate": 1e-08
#         },
#         "hard_keypoint_mining": {
#             "online_mining": false,
#             "hard_to_easy_ratio": 2.0,
#             "min_hard_keypoints": 2,
#             "max_hard_keypoints": null,
#             "loss_scale": 5.0
#         },
#         "early_stopping": {
#             "stop_training_on_plateau": true,
#             "plateau_min_delta": 1e-06,
#             "plateau_patience": 10
#         }
#     },
#     "outputs": {
#         "save_outputs": true,
#         "run_name": null,
#         "run_name_prefix": "",
#         "run_name_suffix": "",
#         "runs_folder": "\\\\multilab-na.ad.salk.edu\\hpi_dev\\users\\eberrigan\\SLEAP\\20250711_plate_arabidopsis_primary_sweep_receptive_field\\train_test_split.v004\\models",
#         "tags": [
#             ""
#         ],
#         "save_visualizations": false,
#         "delete_viz_images": true,
#         "zip_outputs": false,
#         "log_to_csv": true,
#         "checkpointing": {
#             "initial_model": false,
#             "best_model": true,
#             "every_epoch": false,
#             "latest_model": false,
#             "final_model": false
#         },
#         "tensorboard": {
#             "write_logs": false,
#             "loss_frequency": "epoch",
#             "architecture_graph": false,
#             "profile_graph": false,
#             "visualizations": true
#         },
#         "zmq": {
#             "subscribe_to_controller": false,
#             "controller_address": "tcp://127.0.0.1:9000",
#             "controller_polling_timeout": 10,
#             "publish_updates": false,
#             "publish_address": "tcp://127.0.0.1:9001"
#         }
#     },
#     "name": "",
#     "description": "",
#     "sleap_version": "",
#     "filename": "",
#     "version": 4,
#     "config_path": "//multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/20250711_plate_arabidopsis_primary_sweep_receptive_field/train_test_split.v004/initial_config_modified_v004.json"
# }
# INFO:root:Saved updated configuration to: \\multilab-na.ad.salk.edu\hpi_dev\users\eberrigan\SLEAP\20250711_plate_arabidopsis_primary_sweep_receptive_field\train_test_split.v004\modified_config_v004_20250715_183335.json
# INFO:root:Training with updated config for version 4.
# INFO:root:Executing training command: sleap-train //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/20250711_plate_arabidopsis_primary_sweep_receptive_field/train_test_split.v004/modified_config_v004_20250715_183335.json
# Executing: sleap-train //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/20250711_plate_arabidopsis_primary_sweep_receptive_field/train_test_split.v004/modified_config_v004_20250715_183335.json
