# %%
import wandb
import sleap_roots_training

from pathlib import Path

from sleap_roots_training.train import main

# %%
# Constants for W&B initialization
ENTITY_NAME = "eberrigan-salk-institute-for-biological-studies"
PROJECT_NAME = "sleap-roots"
REGISTRY = "sleap-roots-models"
JOB_TYPE = "sweep"
EXPERIMENT_NAME = "20250625_cyl_arabidopsis_primary_receptive_field"

# Constants for artifact creation
DESCRIPTION = "7-11 DAG arabidopsis primary root in cylinders with 6 nodes varying max stride"
TAGS = ["cyl", "arabidopsis", "7-11DAG", "primary", "6nodes", "arabidopsis7-11DAG", "2025-06-25", "max_stride_sweep"]
MODEL_TAGS = ["cyl", "arabidopsis", "7-11DAG", "primary", "6nodes", "arabidopsis7-11DAG", "2025-06-25", "max_stride_sweep"]
COLLECTION_NAME = EXPERIMENT_NAME
CSV_PATH = "//multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/20250625_cyl_arabidopsis_primary_receptive_field/train_test_splits.csv"

# %%
    # "model": {
    #     "backbone": {
    #         "leap": null,
    #         "unet": {
    #             "stem_stride": null,
    #             "max_stride": 16,

# Define the sweep configuration
sweep_config = {
    "method": "grid",
    "parameters": {
        "model.backbone.unet.max_stride": {"values": [16, 32, 64]},
    }
}

# %%
print(wandb.run)
# Out:
# None

# %%
sleap_roots_training.reset_config()
# Out:
# Configuration updated successfully at c:\repos\sleap-roots-training\sleap_roots_training\config.yaml.
# Configuration has been reset to default values.

# %%
sleap_roots_training.update_config(entity_name=ENTITY_NAME, project_name=PROJECT_NAME, registry=REGISTRY, job_type=JOB_TYPE, experiment_name=EXPERIMENT_NAME, collection_name=COLLECTION_NAME)
# Out:
# Configuration updated successfully at c:\repos\sleap-roots-training\sleap_roots_training\config.yaml.
# CONFIG updated to {'project_name': 'sleap-roots', 'entity_name': 'eberrigan-salk-institute-for-biological-studies', 'experiment_name': '20250625_cyl_arabidopsis_primary_receptive_field', 'registry': 'sleap-roots-models', 'collection_name': '20250625_cyl_arabidopsis_primary_receptive_field', 'job_type': 'sweep'}.

# %%
main(csv_path=CSV_PATH, tags=TAGS, model_tags=MODEL_TAGS, use_sweep=True, sweep_config=sweep_config)
# Out:
# INFO:root:Starting main function with CSV: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/20250625_cyl_arabidopsis_primary_receptive_field/train_test_splits.csv
# INFO:root:Detected 6 train-test splits.
# INFO:root:Processing train-test split version: 0
# INFO:root:Creating W&B sweep for version 0...
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# Create sweep with ID: m5dk874f
# Sweep URL: https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/sweeps/m5dk874f
# INFO:root:Sweep created for version 0 with ID: m5dk874f
# INFO:root:Running W&B grid sweep with 3 experiments for version 0...
# INFO:wandb.agents.pyagent:Starting sweep agent: entity=None, project=None, count=3
# wandb: Agent Starting Run: nxe8xgsd with config:
# wandb: 	model.backbone.unet.max_stride: 16
# INFO:root:Starting training for version 0...
# INFO:root:Directory path for version 0: \\multilab-na.ad.salk.edu\hpi_dev\users\eberrigan\SLEAP\20250625_cyl_arabidopsis_primary_receptive_field\train_test_split.v000
# wandb: Currently logged in as: eberrigan (eberrigan-salk-institute-for-biological-studies). Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>c:\repos\sleap-roots-training\wandb\run-20250625_122314-nxe8xgsd</code>
# Syncing run <strong><a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/nxe8xgsd' target="_blank">20250625_cyl_arabidopsis_primary_receptive_field_training_v000</a></strong> to <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/sweeps/m5dk874f' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/sweeps/m5dk874f</a>
#  View project at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a>
#  View sweep at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/sweeps/m5dk874f' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/sweeps/m5dk874f</a>
#  View run at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/nxe8xgsd' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/nxe8xgsd</a>
# INFO:root:Updating configuration with W&B parameters.
# INFO:root:Original Parameters: {
#     "data": {
#         "labels": {
#             "training_labels": "\\\\multilab-na.ad.salk.edu\\hpi_dev\\users\\eberrigan\\SLEAP\\20250625_cyl_arabidopsis_primary_receptive_field\\train_test_split.v000\\train.pkg.slp",
#             "validation_labels": "\\\\multilab-na.ad.salk.edu\\hpi_dev\\users\\eberrigan\\SLEAP\\20250625_cyl_arabidopsis_primary_receptive_field\\train_test_split.v000\\val.pkg.slp",
#             "validation_fraction": 0.1,
#             "test_labels": "\\\\multilab-na.ad.salk.edu\\hpi_dev\\users\\eberrigan\\SLEAP\\20250625_cyl_arabidopsis_primary_receptive_field\\train_test_split.v000\\test.pkg.slp",
#             "split_by_inds": false,
#             "training_inds": null,
#             "validation_inds": null,
#             "test_inds": null,
#             "search_path_hints": [],
#             "skeletons": []
#         },
#         "preprocessing": {
#             "ensure_rgb": false,
#             "ensure_grayscale": false,
#             "imagenet_mode": null,
#             "input_scaling": 1.0,
#             "pad_to_stride": null,
#             "resize_and_pad_to_target": true,
#             "target_height": null,
#             "target_width": null
#         },
#         "instance_cropping": {
#             "center_on_part": null,
#             "crop_size": null,
#             "crop_size_detection_padding": 16
#         }
#     },
#     "model": {
#         "backbone": {
#             "leap": null,
#             "unet": {
#                 "stem_stride": null,
#                 "max_stride": 16,
#                 "output_stride": 2,
#                 "filters": 24,
#                 "filters_rate": 1.5,
#                 "middle_block": true,
#                 "up_interpolate": true,
#                 "stacks": 1
#             },
#             "hourglass": null,
#             "resnet": null,
#             "pretrained_encoder": null
#         },
#         "heads": {
#             "single_instance": null,
#             "centroid": null,
#             "centered_instance": null,
#             "multi_instance": {
#                 "confmaps": {
#                     "part_names": null,
#                     "sigma": 2.5,
#                     "output_stride": 2,
#                     "loss_weight": 1.0,
#                     "offset_refinement": false
#                 },
#                 "pafs": {
#                     "edges": null,
#                     "sigma": 75.0,
#                     "output_stride": 8,
#                     "loss_weight": 1.0
#                 }
#             }
#         }
#     },
#     "optimization": {
#         "preload_data": true,
#         "augmentation_config": {
#             "rotate": false,
#             "rotation_min_angle": -5.0,
#             "rotation_max_angle": 5.0,
#             "translate": false,
#             "translate_min": -5,
#             "translate_max": 5,
#             "scale": false,
#             "scale_min": 0.5,
#             "scale_max": 1.2,
#             "uniform_noise": false,
#             "uniform_noise_min_val": 0.0,
#             "uniform_noise_max_val": 10.0,
#             "gaussian_noise": false,
#             "gaussian_noise_mean": 5.0,
#             "gaussian_noise_stddev": 1.0,
#             "contrast": false,
#             "contrast_min_gamma": 0.5,
#             "contrast_max_gamma": 2.0,
#             "brightness": false,
#             "brightness_min_val": 0.0,
#             "brightness_max_val": 10.0,
#             "random_crop": false,
#             "random_crop_height": 256,
#             "random_crop_width": 256,
#             "random_flip": false,
#             "flip_horizontal": true
#         },
#         "online_shuffling": true,
#         "shuffle_buffer_size": 128,
#         "prefetch": true,
#         "batch_size": 4,
#         "batches_per_epoch": null,
#         "min_batches_per_epoch": 200,
#         "val_batches_per_epoch": null,
#         "min_val_batches_per_epoch": 10,
#         "epochs": 200,
#         "optimizer": "adam",
#         "initial_learning_rate": 0.0001,
#         "learning_rate_schedule": {
#             "reduce_on_plateau": true,
#             "reduction_factor": 0.5,
#             "plateau_min_delta": 1e-06,
#             "plateau_patience": 5,
#             "plateau_cooldown": 3,
#             "min_learning_rate": 1e-08
#         },
#         "hard_keypoint_mining": {
#             "online_mining": false,
#             "hard_to_easy_ratio": 2.0,
#             "min_hard_keypoints": 2,
#             "max_hard_keypoints": null,
#             "loss_scale": 5.0
#         },
#         "early_stopping": {
#             "stop_training_on_plateau": true,
#             "plateau_min_delta": 1e-06,
#             "plateau_patience": 10
#         }
#     },
#     "outputs": {
#         "save_outputs": true,
#         "run_name": null,
#         "run_name_prefix": "",
#         "run_name_suffix": "",
#         "runs_folder": "\\\\multilab-na.ad.salk.edu\\hpi_dev\\users\\eberrigan\\SLEAP\\20250625_cyl_arabidopsis_primary_receptive_field\\train_test_split.v000\\models",
#         "tags": [
#             ""
#         ],
#         "save_visualizations": false,
#         "delete_viz_images": true,
#         "zip_outputs": false,
#         "log_to_csv": true,
#         "checkpointing": {
#             "initial_model": false,
#             "best_model": true,
#             "every_epoch": false,
#             "latest_model": false,
#             "final_model": false
#         },
#         "tensorboard": {
#             "write_logs": false,
#             "loss_frequency": "epoch",
#             "architecture_graph": false,
#             "profile_graph": false,
#             "visualizations": true
#         },
#         "zmq": {
#             "subscribe_to_controller": false,
#             "controller_address": "tcp://127.0.0.1:9000",
#             "controller_polling_timeout": 10,
#             "publish_updates": false,
#             "publish_address": "tcp://127.0.0.1:9001"
#         }
#     },
#     "name": "",
#     "description": "",
#     "sleap_version": "",
#     "filename": "",
#     "model.backbone.unet.max_stride": 16,
#     "version": 0,
#     "config_path": "//multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/20250625_cyl_arabidopsis_primary_receptive_field/train_test_split.v000/initial_config_modified_v000.json"
# }
# INFO:root:Updated parameter: data -> {'labels': {'training_labels': '\\\\multilab-na.ad.salk.edu\\hpi_dev\\users\\eberrigan\\SLEAP\\20250625_cyl_arabidopsis_primary_receptive_field\\train_test_split.v000\\train.pkg.slp', 'validation_labels': '\\\\multilab-na.ad.salk.edu\\hpi_dev\\users\\eberrigan\\SLEAP\\20250625_cyl_arabidopsis_primary_receptive_field\\train_test_split.v000\\val.pkg.slp', 'validation_fraction': 0.1, 'test_labels': '\\\\multilab-na.ad.salk.edu\\hpi_dev\\users\\eberrigan\\SLEAP\\20250625_cyl_arabidopsis_primary_receptive_field\\train_test_split.v000\\test.pkg.slp', 'split_by_inds': False, 'training_inds': None, 'validation_inds': None, 'test_inds': None, 'search_path_hints': [], 'skeletons': []}, 'preprocessing': {'ensure_rgb': False, 'ensure_grayscale': False, 'imagenet_mode': None, 'input_scaling': 1.0, 'pad_to_stride': None, 'resize_and_pad_to_target': True, 'target_height': None, 'target_width': None}, 'instance_cropping': {'center_on_part': None, 'crop_size': None, 'crop_size_detection_padding': 16}}
# INFO:root:Updated parameter: model -> {'backbone': {'leap': None, 'unet': {'stem_stride': None, 'max_stride': 16, 'output_stride': 2, 'filters': 24, 'filters_rate': 1.5, 'middle_block': True, 'up_interpolate': True, 'stacks': 1}, 'hourglass': None, 'resnet': None, 'pretrained_encoder': None}, 'heads': {'single_instance': None, 'centroid': None, 'centered_instance': None, 'multi_instance': {'confmaps': {'part_names': None, 'sigma': 2.5, 'output_stride': 2, 'loss_weight': 1.0, 'offset_refinement': False}, 'pafs': {'edges': None, 'sigma': 75.0, 'output_stride': 8, 'loss_weight': 1.0}}}}
# INFO:root:Updated parameter: optimization -> {'preload_data': True, 'augmentation_config': {'rotate': False, 'rotation_min_angle': -5.0, 'rotation_max_angle': 5.0, 'translate': False, 'translate_min': -5, 'translate_max': 5, 'scale': False, 'scale_min': 0.5, 'scale_max': 1.2, 'uniform_noise': False, 'uniform_noise_min_val': 0.0, 'uniform_noise_max_val': 10.0, 'gaussian_noise': False, 'gaussian_noise_mean': 5.0, 'gaussian_noise_stddev': 1.0, 'contrast': False, 'contrast_min_gamma': 0.5, 'contrast_max_gamma': 2.0, 'brightness': False, 'brightness_min_val': 0.0, 'brightness_max_val': 10.0, 'random_crop': False, 'random_crop_height': 256, 'random_crop_width': 256, 'random_flip': False, 'flip_horizontal': True}, 'online_shuffling': True, 'shuffle_buffer_size': 128, 'prefetch': True, 'batch_size': 4, 'batches_per_epoch': None, 'min_batches_per_epoch': 200, 'val_batches_per_epoch': None, 'min_val_batches_per_epoch': 10, 'epochs': 200, 'optimizer': 'adam', 'initial_learning_rate': 0.0001, 'learning_rate_schedule': {'reduce_on_plateau': True, 'reduction_factor': 0.5, 'plateau_min_delta': 1e-06, 'plateau_patience': 5, 'plateau_cooldown': 3, 'min_learning_rate': 1e-08}, 'hard_keypoint_mining': {'online_mining': False, 'hard_to_easy_ratio': 2.0, 'min_hard_keypoints': 2, 'max_hard_keypoints': None, 'loss_scale': 5.0}, 'early_stopping': {'stop_training_on_plateau': True, 'plateau_min_delta': 1e-06, 'plateau_patience': 10}}
# INFO:root:Updated parameter: outputs -> {'save_outputs': True, 'run_name': None, 'run_name_prefix': '', 'run_name_suffix': '', 'runs_folder': '\\\\multilab-na.ad.salk.edu\\hpi_dev\\users\\eberrigan\\SLEAP\\20250625_cyl_arabidopsis_primary_receptive_field\\train_test_split.v000\\models', 'tags': [''], 'save_visualizations': False, 'delete_viz_images': True, 'zip_outputs': False, 'log_to_csv': True, 'checkpointing': {'initial_model': False, 'best_model': True, 'every_epoch': False, 'latest_model': False, 'final_model': False}, 'tensorboard': {'write_logs': False, 'loss_frequency': 'epoch', 'architecture_graph': False, 'profile_graph': False, 'visualizations': True}, 'zmq': {'subscribe_to_controller': False, 'controller_address': 'tcp://127.0.0.1:9000', 'controller_polling_timeout': 10, 'publish_updates': False, 'publish_address': 'tcp://127.0.0.1:9001'}}
# INFO:root:Updated parameter: name ->
# INFO:root:Updated parameter: description ->
# INFO:root:Updated parameter: sleap_version ->
# INFO:root:Updated parameter: filename ->
# INFO:root:Updated parameter: model.backbone.unet.max_stride -> 16
# INFO:root:Updated parameter: version -> 0
# INFO:root:Updated parameter: config_path -> //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/20250625_cyl_arabidopsis_primary_receptive_field/train_test_split.v000/initial_config_modified_v000.json
# INFO:root:Final updated configuration:
# {
#     "data": {
#         "labels": {
#             "training_labels": "\\\\multilab-na.ad.salk.edu\\hpi_dev\\users\\eberrigan\\SLEAP\\20250625_cyl_arabidopsis_primary_receptive_field\\train_test_split.v000\\train.pkg.slp",
#             "validation_labels": "\\\\multilab-na.ad.salk.edu\\hpi_dev\\users\\eberrigan\\SLEAP\\20250625_cyl_arabidopsis_primary_receptive_field\\train_test_split.v000\\val.pkg.slp",
#             "validation_fraction": 0.1,
#             "test_labels": "\\\\multilab-na.ad.salk.edu\\hpi_dev\\users\\eberrigan\\SLEAP\\20250625_cyl_arabidopsis_primary_receptive_field\\train_test_split.v000\\test.pkg.slp",
#             "split_by_inds": false,
#             "training_inds": null,
#             "validation_inds": null,
#             "test_inds": null,
#             "search_path_hints": [],
#             "skeletons": []
#         },
#         "preprocessing": {
#             "ensure_rgb": false,
#             "ensure_grayscale": false,
#             "imagenet_mode": null,
#             "input_scaling": 1.0,
#             "pad_to_stride": null,
#             "resize_and_pad_to_target": true,
#             "target_height": null,
#             "target_width": null
#         },
#         "instance_cropping": {
#             "center_on_part": null,
#             "crop_size": null,
#             "crop_size_detection_padding": 16
#         }
#     },
#     "model": {
#         "backbone": {
#             "leap": null,
#             "unet": {
#                 "stem_stride": null,
#                 "max_stride": 16,
#                 "output_stride": 2,
#                 "filters": 24,
#                 "filters_rate": 1.5,
#                 "middle_block": true,
#                 "up_interpolate": true,
#                 "stacks": 1
#             },
#             "hourglass": null,
#             "resnet": null,
#             "pretrained_encoder": null
#         },
#         "heads": {
#             "single_instance": null,
#             "centroid": null,
#             "centered_instance": null,
#             "multi_instance": {
#                 "confmaps": {
#                     "part_names": null,
#                     "sigma": 2.5,
#                     "output_stride": 2,
#                     "loss_weight": 1.0,
#                     "offset_refinement": false
#                 },
#                 "pafs": {
#                     "edges": null,
#                     "sigma": 75.0,
#                     "output_stride": 8,
#                     "loss_weight": 1.0
#                 }
#             }
#         }
#     },
#     "optimization": {
#         "preload_data": true,
#         "augmentation_config": {
#             "rotate": false,
#             "rotation_min_angle": -5.0,
#             "rotation_max_angle": 5.0,
#             "translate": false,
#             "translate_min": -5,
#             "translate_max": 5,
#             "scale": false,
#             "scale_min": 0.5,
#             "scale_max": 1.2,
#             "uniform_noise": false,
#             "uniform_noise_min_val": 0.0,
#             "uniform_noise_max_val": 10.0,
#             "gaussian_noise": false,
#             "gaussian_noise_mean": 5.0,
#             "gaussian_noise_stddev": 1.0,
#             "contrast": false,
#             "contrast_min_gamma": 0.5,
#             "contrast_max_gamma": 2.0,
#             "brightness": false,
#             "brightness_min_val": 0.0,
#             "brightness_max_val": 10.0,
#             "random_crop": false,
#             "random_crop_height": 256,
#             "random_crop_width": 256,
#             "random_flip": false,
#             "flip_horizontal": true
#         },
#         "online_shuffling": true,
#         "shuffle_buffer_size": 128,
#         "prefetch": true,
#         "batch_size": 4,
#         "batches_per_epoch": null,
#         "min_batches_per_epoch": 200,
#         "val_batches_per_epoch": null,
#         "min_val_batches_per_epoch": 10,
#         "epochs": 200,
#         "optimizer": "adam",
#         "initial_learning_rate": 0.0001,
#         "learning_rate_schedule": {
#             "reduce_on_plateau": true,
#             "reduction_factor": 0.5,
#             "plateau_min_delta": 1e-06,
#             "plateau_patience": 5,
#             "plateau_cooldown": 3,
#             "min_learning_rate": 1e-08
#         },
#         "hard_keypoint_mining": {
#             "online_mining": false,
#             "hard_to_easy_ratio": 2.0,
#             "min_hard_keypoints": 2,
#             "max_hard_keypoints": null,
#             "loss_scale": 5.0
#         },
#         "early_stopping": {
#             "stop_training_on_plateau": true,
#             "plateau_min_delta": 1e-06,
#             "plateau_patience": 10
#         }
#     },
#     "outputs": {
#         "save_outputs": true,
#         "run_name": null,
#         "run_name_prefix": "",
#         "run_name_suffix": "",
#         "runs_folder": "\\\\multilab-na.ad.salk.edu\\hpi_dev\\users\\eberrigan\\SLEAP\\20250625_cyl_arabidopsis_primary_receptive_field\\train_test_split.v000\\models",
#         "tags": [
#             ""
#         ],
#         "save_visualizations": false,
#         "delete_viz_images": true,
#         "zip_outputs": false,
#         "log_to_csv": true,
#         "checkpointing": {
#             "initial_model": false,
#             "best_model": true,
#             "every_epoch": false,
#             "latest_model": false,
#             "final_model": false
#         },
#         "tensorboard": {
#             "write_logs": false,
#             "loss_frequency": "epoch",
#             "architecture_graph": false,
#             "profile_graph": false,
#             "visualizations": true
#         },
#         "zmq": {
#             "subscribe_to_controller": false,
#             "controller_address": "tcp://127.0.0.1:9000",
#             "controller_polling_timeout": 10,
#             "publish_updates": false,
#             "publish_address": "tcp://127.0.0.1:9001"
#         }
#     },
#     "name": "",
#     "description": "",
#     "sleap_version": "",
#     "filename": "",
#     "version": 0,
#     "config_path": "//multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/20250625_cyl_arabidopsis_primary_receptive_field/train_test_split.v000/initial_config_modified_v000.json"
# }
# INFO:root:Saved updated configuration to: \\multilab-na.ad.salk.edu\hpi_dev\users\eberrigan\SLEAP\20250625_cyl_arabidopsis_primary_receptive_field\train_test_split.v000\modified_config_v000_20250625_122315.json
# INFO:root:Training with updated config for version 0.
# INFO:root:Executing training command: sleap-train //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/20250625_cyl_arabidopsis_primary_receptive_field/train_test_split.v000/modified_config_v000_20250625_122315.json
# Executing: sleap-train //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/20250625_cyl_arabidopsis_primary_receptive_field/train_test_split.v000/modified_config_v000_20250625_122315.json
# INFO:sleap.nn.training:Versions:
# SLEAP: 1.4.1a2
# TensorFlow: 2.7.0
# Numpy: 1.21.6
# Python: 3.7.12
# OS: Windows-10-10.0.26100-SP0
# INFO:sleap.nn.training:Training labels file: None
# INFO:sleap.nn.training:Training profile: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/20250625_cyl_arabidopsis_primary_receptive_field/train_test_split.v000/modified_config_v000_20250625_122315.json
# INFO:sleap.nn.training:
# INFO:sleap.nn.training:Arguments:
# INFO:sleap.nn.training:{
#     "training_job_path": "//multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/20250625_cyl_arabidopsis_primary_receptive_field/train_test_split.v000/modified_config_v000_20250625_122315.json",
#     "labels_path": null,
#     "video_paths": [
#         ""
#     ],
#     "val_labels": null,
#     "test_labels": null,
#     "base_checkpoint": null,
#     "tensorboard": false,
#     "save_viz": false,
#     "zmq": false,
#     "publish_port": 9001,
#     "controller_port": 9000,
#     "run_name": "",
#     "prefix": "",
#     "suffix": "",
#     "cpu": false,
#     "first_gpu": false,
#     "last_gpu": false,
#     "gpu": "auto"
# }
# INFO:sleap.nn.training:
# INFO:sleap.nn.training:Training job:
# INFO:sleap.nn.training:{
#     "data": {
#         "labels": {
#             "training_labels": "\\\\multilab-na.ad.salk.edu\\hpi_dev\\users\\eberrigan\\SLEAP\\20250625_cyl_arabidopsis_primary_receptive_field\\train_test_split.v000\\train.pkg.slp",
#             "validation_labels": "\\\\multilab-na.ad.salk.edu\\hpi_dev\\users\\eberrigan\\SLEAP\\20250625_cyl_arabidopsis_primary_receptive_field\\train_test_split.v000\\val.pkg.slp",
#             "validation_fraction": 0.1,
#             "test_labels": "\\\\multilab-na.ad.salk.edu\\hpi_dev\\users\\eberrigan\\SLEAP\\20250625_cyl_arabidopsis_primary_receptive_field\\train_test_split.v000\\test.pkg.slp",
#             "split_by_inds": false,
#             "training_inds": null,
#             "validation_inds": null,
#             "test_inds": null,
#             "search_path_hints": [],
#             "skeletons": []
#         },
#         "preprocessing": {
#             "ensure_rgb": false,
#             "ensure_grayscale": false,
#             "imagenet_mode": null,
#             "input_scaling": 1.0,
#             "pad_to_stride": null,
#             "resize_and_pad_to_target": true,
#             "target_height": null,
#             "target_width": null
#         },
#         "instance_cropping": {
#             "center_on_part": null,
#             "crop_size": null,
#             "crop_size_detection_padding": 16
#         }
#     },
#     "model": {
#         "backbone": {
#             "leap": null,
#             "unet": {
#                 "stem_stride": null,
#                 "max_stride": 16,
#                 "output_stride": 2,
#                 "filters": 24,
#                 "filters_rate": 1.5,
#                 "middle_block": true,
#                 "up_interpolate": true,
#                 "stacks": 1
#             },
#             "hourglass": null,
#             "resnet": null,
#             "pretrained_encoder": null
#         },
#         "heads": {
#             "single_instance": null,
#             "centroid": null,
#             "centered_instance": null,
#             "multi_instance": {
#                 "confmaps": {
#                     "part_names": null,
#                     "sigma": 2.5,
#                     "output_stride": 2,
#                     "loss_weight": 1.0,
#                     "offset_refinement": false
#                 },
#                 "pafs": {
#                     "edges": null,
#                     "sigma": 75.0,
#                     "output_stride": 8,
#                     "loss_weight": 1.0
#                 }
#             },
#             "multi_class_bottomup": null,
#             "multi_class_topdown": null
#         },
#         "base_checkpoint": null
#     },
#     "optimization": {
#         "preload_data": true,
#         "augmentation_config": {
#             "rotate": false,
#             "rotation_min_angle": -5.0,
#             "rotation_max_angle": 5.0,
#             "translate": false,
#             "translate_min": -5,
#             "translate_max": 5,
#             "scale": false,
#             "scale_min": 0.5,
#             "scale_max": 1.2,
#             "uniform_noise": false,
#             "uniform_noise_min_val": 0.0,
#             "uniform_noise_max_val": 10.0,
#             "gaussian_noise": false,
#             "gaussian_noise_mean": 5.0,
#             "gaussian_noise_stddev": 1.0,
#             "contrast": false,
#             "contrast_min_gamma": 0.5,
#             "contrast_max_gamma": 2.0,
#             "brightness": false,
#             "brightness_min_val": 0.0,
#             "brightness_max_val": 10.0,
#             "random_crop": false,
#             "random_crop_height": 256,
#             "random_crop_width": 256,
#             "random_flip": false,
#             "flip_horizontal": true
#         },
#         "online_shuffling": true,
#         "shuffle_buffer_size": 128,
#         "prefetch": true,
#         "batch_size": 4,
#         "batches_per_epoch": null,
#         "min_batches_per_epoch": 200,
#         "val_batches_per_epoch": null,
#         "min_val_batches_per_epoch": 10,
#         "epochs": 200,
#         "optimizer": "adam",
#         "initial_learning_rate": 0.0001,
#         "learning_rate_schedule": {
#             "reduce_on_plateau": true,
#             "reduction_factor": 0.5,
#             "plateau_min_delta": 1e-06,
#             "plateau_patience": 5,
#             "plateau_cooldown": 3,
#             "min_learning_rate": 1e-08
#         },
#         "hard_keypoint_mining": {
#             "online_mining": false,
#             "hard_to_easy_ratio": 2.0,
#             "min_hard_keypoints": 2,
#             "max_hard_keypoints": null,
#             "loss_scale": 5.0
#         },
#         "early_stopping": {
#             "stop_training_on_plateau": true,
#             "plateau_min_delta": 1e-06,
#             "plateau_patience": 10
#         }
#     },
#     "outputs": {
#         "save_outputs": true,
#         "run_name": null,
#         "run_name_prefix": "",
#         "run_name_suffix": "",
#         "runs_folder": "\\\\multilab-na.ad.salk.edu\\hpi_dev\\users\\eberrigan\\SLEAP\\20250625_cyl_arabidopsis_primary_receptive_field\\train_test_split.v000\\models",
#         "tags": [
#             ""
#         ],
#         "save_visualizations": false,
#         "delete_viz_images": true,
#         "zip_outputs": false,
#         "log_to_csv": true,
#         "checkpointing": {
#             "initial_model": false,
#             "best_model": true,
#             "every_epoch": false,
#             "latest_model": false,
#             "final_model": false
#         },
#         "tensorboard": {
#             "write_logs": false,
#             "loss_frequency": "epoch",
#             "architecture_graph": false,
#             "profile_graph": false,
#             "visualizations": true
#         },
#         "zmq": {
#             "subscribe_to_controller": false,
#             "controller_address": "tcp://127.0.0.1:9000",
#             "controller_polling_timeout": 10,
#             "publish_updates": false,
#             "publish_address": "tcp://127.0.0.1:9001"
#         }
#     },
#     "name": "",
#     "description": "",
#     "sleap_version": "",
#     "filename": "//multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/20250625_cyl_arabidopsis_primary_receptive_field/train_test_split.v000/modified_config_v000_20250625_122315.json"
# }
# INFO:sleap.nn.training:
# INFO:sleap.nn.training:Auto-selected GPU 0 with 22408 MiB of free memory.
# INFO:sleap.nn.training:Using GPU 0 for acceleration.
# INFO:sleap.nn.training:Disabled GPU memory pre-allocation.
# INFO:sleap.nn.training:System:
# GPUs: 1/1 available
#   Device: /physical_device:GPU:0
#          Available: True
#        Initialized: False
#      Memory growth: True
# INFO:sleap.nn.training:
# INFO:sleap.nn.training:Initializing trainer...
# INFO:sleap.nn.training:Loading training labels from: \\multilab-na.ad.salk.edu\hpi_dev\users\eberrigan\SLEAP\20250625_cyl_arabidopsis_primary_receptive_field\train_test_split.v000\train.pkg.slp
# INFO:sleap.nn.training:Loading validation labels from: \\multilab-na.ad.salk.edu\hpi_dev\users\eberrigan\SLEAP\20250625_cyl_arabidopsis_primary_receptive_field\train_test_split.v000\val.pkg.slp
# INFO:sleap.nn.training:Loading test labels from: \\multilab-na.ad.salk.edu\hpi_dev\users\eberrigan\SLEAP\20250625_cyl_arabidopsis_primary_receptive_field\train_test_split.v000\test.pkg.slp
# INFO:sleap.nn.training:Setting up for training...
# INFO:sleap.nn.training:Setting up pipeline builders...
# INFO:sleap.nn.training:Setting up model...
# INFO:sleap.nn.training:Building test pipeline...
# INFO:sleap.nn.training:Loaded test example. [5.586s]
# INFO:sleap.nn.training:  Input shape: (1088, 2048, 1)
# INFO:sleap.nn.training:Created Keras model.
# INFO:sleap.nn.training:  Backbone: UNet(stacks=1, filters=24, filters_rate=1.5, kernel_size=3, stem_kernel_size=7, convs_per_block=2, stem_blocks=0, down_blocks=4, middle_block=True, up_blocks=3, up_interpolate=True, block_contraction=False)
# INFO:sleap.nn.training:  Max stride: 16
# INFO:sleap.nn.training:  Parameters: 727,974
# INFO:sleap.nn.training:  Heads:
# INFO:sleap.nn.training:    [0] = MultiInstanceConfmapsHead(part_names=['r1', 'r2', 'r3', 'r4', 'r5', 'r6'], sigma=2.5, output_stride=2, loss_weight=1.0)
# INFO:sleap.nn.training:    [1] = PartAffinityFieldsHead(edges=[('r1', 'r2'), ('r2', 'r3'), ('r3', 'r4'), ('r4', 'r5'), ('r5', 'r6')], sigma=75.0, output_stride=8, loss_weight=1.0)
# INFO:sleap.nn.training:  Outputs:
# INFO:sleap.nn.training:    [0] = KerasTensor(type_spec=TensorSpec(shape=(None, 544, 1024, 6), dtype=tf.float32, name=None), name='MultiInstanceConfmapsHead/BiasAdd:0', description="created by layer 'MultiInstanceConfmapsHead'")
# INFO:sleap.nn.training:    [1] = KerasTensor(type_spec=TensorSpec(shape=(None, 136, 256, 10), dtype=tf.float32, name=None), name='PartAffinityFieldsHead/BiasAdd:0', description="created by layer 'PartAffinityFieldsHead'")
# INFO:sleap.nn.training:Training from scratch
# INFO:sleap.nn.training:Setting up data pipelines...
# INFO:sleap.nn.training:Training set: n = 99
# INFO:sleap.nn.training:Validation set: n = 21
# INFO:sleap.nn.training:Setting up optimization...
# INFO:sleap.nn.training:  Learning rate schedule: LearningRateScheduleConfig(reduce_on_plateau=True, reduction_factor=0.5, plateau_min_delta=1e-06, plateau_patience=5, plateau_cooldown=3, min_learning_rate=1e-08)
# INFO:sleap.nn.training:  Early stopping: EarlyStoppingConfig(stop_training_on_plateau=True, plateau_min_delta=1e-06, plateau_patience=10)
# INFO:sleap.nn.training:Setting up outputs...
# INFO:sleap.nn.training:Created run path: \\multilab-na.ad.salk.edu\hpi_dev\users\eberrigan\SLEAP\20250625_cyl_arabidopsis_primary_receptive_field\train_test_split.v000\models\250625_122328.multi_instance.n=120
# INFO:sleap.nn.training:Setting up visualization...
# INFO:sleap.nn.training:Finished trainer set up. [10.2s]
# INFO:sleap.nn.training:Creating tf.data.Datasets for training data generation...
# INFO:sleap.nn.training:Finished creating training datasets. [8.6s]
# INFO:sleap.nn.training:Starting training loop...
# Epoch 1/200
# 200/200 - 104s - loss: 6.7185e-04 - MultiInstanceConfmapsHead_loss: 7.6498e-05 - PartAffinityFieldsHead_loss: 5.9535e-04 - val_loss: 7.4165e-04 - val_MultiInstanceConfmapsHead_loss: 7.4292e-05 - val_PartAffinityFieldsHead_loss: 6.6736e-04 - lr: 1.0000e-04 - 104s/epoch - 522ms/step
# Epoch 2/200
# 200/200 - 85s - loss: 6.5943e-04 - MultiInstanceConfmapsHead_loss: 7.2789e-05 - PartAffinityFieldsHead_loss: 5.8664e-04 - val_loss: 7.2568e-04 - val_MultiInstanceConfmapsHead_loss: 7.3202e-05 - val_PartAffinityFieldsHead_loss: 6.5248e-04 - lr: 1.0000e-04 - 85s/epoch - 424ms/step
# Epoch 3/200
# 200/200 - 85s - loss: 6.6563e-04 - MultiInstanceConfmapsHead_loss: 7.2950e-05 - PartAffinityFieldsHead_loss: 5.9268e-04 - val_loss: 6.9242e-04 - val_MultiInstanceConfmapsHead_loss: 7.1323e-05 - val_PartAffinityFieldsHead_loss: 6.2110e-04 - lr: 1.0000e-04 - 85s/epoch - 427ms/step
# Epoch 4/200
# 200/200 - 82s - loss: 6.1680e-04 - MultiInstanceConfmapsHead_loss: 7.1837e-05 - PartAffinityFieldsHead_loss: 5.4496e-04 - val_loss: 6.4332e-04 - val_MultiInstanceConfmapsHead_loss: 7.1917e-05 - val_PartAffinityFieldsHead_loss: 5.7140e-04 - lr: 1.0000e-04 - 82s/epoch - 412ms/step
# Epoch 5/200
# 200/200 - 83s - loss: 5.6812e-04 - MultiInstanceConfmapsHead_loss: 7.1125e-05 - PartAffinityFieldsHead_loss: 4.9700e-04 - val_loss: 6.2644e-04 - val_MultiInstanceConfmapsHead_loss: 7.1471e-05 - val_PartAffinityFieldsHead_loss: 5.5497e-04 - lr: 1.0000e-04 - 83s/epoch - 417ms/step
# Epoch 6/200
# 200/200 - 81s - loss: 5.4263e-04 - MultiInstanceConfmapsHead_loss: 6.8805e-05 - PartAffinityFieldsHead_loss: 4.7382e-04 - val_loss: 6.3800e-04 - val_MultiInstanceConfmapsHead_loss: 7.0583e-05 - val_PartAffinityFieldsHead_loss: 5.6742e-04 - lr: 1.0000e-04 - 81s/epoch - 403ms/step
# Epoch 7/200
# 200/200 - 82s - loss: 5.2366e-04 - MultiInstanceConfmapsHead_loss: 6.7094e-05 - PartAffinityFieldsHead_loss: 4.5657e-04 - val_loss: 6.1426e-04 - val_MultiInstanceConfmapsHead_loss: 6.8897e-05 - val_PartAffinityFieldsHead_loss: 5.4536e-04 - lr: 1.0000e-04 - 82s/epoch - 408ms/step
# Epoch 8/200
# 200/200 - 82s - loss: 5.1646e-04 - MultiInstanceConfmapsHead_loss: 6.6308e-05 - PartAffinityFieldsHead_loss: 4.5015e-04 - val_loss: 5.7717e-04 - val_MultiInstanceConfmapsHead_loss: 6.6022e-05 - val_PartAffinityFieldsHead_loss: 5.1115e-04 - lr: 1.0000e-04 - 82s/epoch - 410ms/step
# Epoch 9/200
# 200/200 - 80s - loss: 4.9533e-04 - MultiInstanceConfmapsHead_loss: 6.4504e-05 - PartAffinityFieldsHead_loss: 4.3083e-04 - val_loss: 6.0450e-04 - val_MultiInstanceConfmapsHead_loss: 6.7083e-05 - val_PartAffinityFieldsHead_loss: 5.3742e-04 - lr: 1.0000e-04 - 80s/epoch - 399ms/step
# Epoch 10/200
# 200/200 - 83s - loss: 4.8746e-04 - MultiInstanceConfmapsHead_loss: 6.3228e-05 - PartAffinityFieldsHead_loss: 4.2423e-04 - val_loss: 5.8479e-04 - val_MultiInstanceConfmapsHead_loss: 6.6157e-05 - val_PartAffinityFieldsHead_loss: 5.1864e-04 - lr: 1.0000e-04 - 83s/epoch - 413ms/step
# Epoch 11/200
# 200/200 - 82s - loss: 4.7678e-04 - MultiInstanceConfmapsHead_loss: 6.2001e-05 - PartAffinityFieldsHead_loss: 4.1478e-04 - val_loss: 5.7687e-04 - val_MultiInstanceConfmapsHead_loss: 6.3995e-05 - val_PartAffinityFieldsHead_loss: 5.1288e-04 - lr: 1.0000e-04 - 82s/epoch - 412ms/step
# Epoch 12/200
# 200/200 - 83s - loss: 4.6301e-04 - MultiInstanceConfmapsHead_loss: 6.0861e-05 - PartAffinityFieldsHead_loss: 4.0215e-04 - val_loss: 5.7297e-04 - val_MultiInstanceConfmapsHead_loss: 6.2836e-05 - val_PartAffinityFieldsHead_loss: 5.1013e-04 - lr: 1.0000e-04 - 83s/epoch - 413ms/step
# Epoch 13/200
# 200/200 - 80s - loss: 4.5228e-04 - MultiInstanceConfmapsHead_loss: 5.9857e-05 - PartAffinityFieldsHead_loss: 3.9243e-04 - val_loss: 5.3723e-04 - val_MultiInstanceConfmapsHead_loss: 6.1163e-05 - val_PartAffinityFieldsHead_loss: 4.7607e-04 - lr: 1.0000e-04 - 80s/epoch - 398ms/step
# Epoch 14/200
# 200/200 - 81s - loss: 4.4551e-04 - MultiInstanceConfmapsHead_loss: 5.8941e-05 - PartAffinityFieldsHead_loss: 3.8656e-04 - val_loss: 5.4364e-04 - val_MultiInstanceConfmapsHead_loss: 6.1885e-05 - val_PartAffinityFieldsHead_loss: 4.8176e-04 - lr: 1.0000e-04 - 81s/epoch - 403ms/step
# Epoch 15/200
# 200/200 - 84s - loss: 4.2484e-04 - MultiInstanceConfmapsHead_loss: 5.6976e-05 - PartAffinityFieldsHead_loss: 3.6786e-04 - val_loss: 5.3323e-04 - val_MultiInstanceConfmapsHead_loss: 5.9315e-05 - val_PartAffinityFieldsHead_loss: 4.7391e-04 - lr: 1.0000e-04 - 84s/epoch - 419ms/step
# Epoch 16/200
# 200/200 - 79s - loss: 4.1354e-04 - MultiInstanceConfmapsHead_loss: 5.5566e-05 - PartAffinityFieldsHead_loss: 3.5798e-04 - val_loss: 5.6416e-04 - val_MultiInstanceConfmapsHead_loss: 6.2057e-05 - val_PartAffinityFieldsHead_loss: 5.0211e-04 - lr: 1.0000e-04 - 79s/epoch - 395ms/step
# Epoch 17/200
# 200/200 - 79s - loss: 4.0628e-04 - MultiInstanceConfmapsHead_loss: 5.4913e-05 - PartAffinityFieldsHead_loss: 3.5137e-04 - val_loss: 5.5229e-04 - val_MultiInstanceConfmapsHead_loss: 6.0265e-05 - val_PartAffinityFieldsHead_loss: 4.9203e-04 - lr: 1.0000e-04 - 79s/epoch - 397ms/step
# Epoch 18/200
# 200/200 - 78s - loss: 3.9474e-04 - MultiInstanceConfmapsHead_loss: 5.3513e-05 - PartAffinityFieldsHead_loss: 3.4123e-04 - val_loss: 5.4971e-04 - val_MultiInstanceConfmapsHead_loss: 6.1248e-05 - val_PartAffinityFieldsHead_loss: 4.8846e-04 - lr: 1.0000e-04 - 78s/epoch - 392ms/step
# Epoch 19/200
# 200/200 - 82s - loss: 3.8605e-04 - MultiInstanceConfmapsHead_loss: 5.2214e-05 - PartAffinityFieldsHead_loss: 3.3383e-04 - val_loss: 5.2071e-04 - val_MultiInstanceConfmapsHead_loss: 5.9127e-05 - val_PartAffinityFieldsHead_loss: 4.6158e-04 - lr: 1.0000e-04 - 82s/epoch - 408ms/step
# Epoch 20/200
# 200/200 - 79s - loss: 3.7565e-04 - MultiInstanceConfmapsHead_loss: 5.1096e-05 - PartAffinityFieldsHead_loss: 3.2455e-04 - val_loss: 5.1476e-04 - val_MultiInstanceConfmapsHead_loss: 5.9600e-05 - val_PartAffinityFieldsHead_loss: 4.5516e-04 - lr: 1.0000e-04 - 79s/epoch - 395ms/step
# Epoch 21/200
# 200/200 - 82s - loss: 3.5301e-04 - MultiInstanceConfmapsHead_loss: 4.8810e-05 - PartAffinityFieldsHead_loss: 3.0420e-04 - val_loss: 5.5767e-04 - val_MultiInstanceConfmapsHead_loss: 6.0553e-05 - val_PartAffinityFieldsHead_loss: 4.9712e-04 - lr: 1.0000e-04 - 82s/epoch - 408ms/step
# Epoch 22/200
# 200/200 - 80s - loss: 3.4877e-04 - MultiInstanceConfmapsHead_loss: 4.7668e-05 - PartAffinityFieldsHead_loss: 3.0111e-04 - val_loss: 5.5518e-04 - val_MultiInstanceConfmapsHead_loss: 6.0659e-05 - val_PartAffinityFieldsHead_loss: 4.9452e-04 - lr: 1.0000e-04 - 80s/epoch - 400ms/step
# Epoch 23/200
# 200/200 - 79s - loss: 3.4176e-04 - MultiInstanceConfmapsHead_loss: 4.6451e-05 - PartAffinityFieldsHead_loss: 2.9531e-04 - val_loss: 5.3418e-04 - val_MultiInstanceConfmapsHead_loss: 6.1302e-05 - val_PartAffinityFieldsHead_loss: 4.7288e-04 - lr: 1.0000e-04 - 79s/epoch - 395ms/step
# Epoch 24/200
# 200/200 - 82s - loss: 3.2008e-04 - MultiInstanceConfmapsHead_loss: 4.4306e-05 - PartAffinityFieldsHead_loss: 2.7578e-04 - val_loss: 4.8918e-04 - val_MultiInstanceConfmapsHead_loss: 5.8827e-05 - val_PartAffinityFieldsHead_loss: 4.3036e-04 - lr: 1.0000e-04 - 82s/epoch - 408ms/step
# Epoch 25/200
# 200/200 - 79s - loss: 3.0828e-04 - MultiInstanceConfmapsHead_loss: 4.2722e-05 - PartAffinityFieldsHead_loss: 2.6556e-04 - val_loss: 5.3128e-04 - val_MultiInstanceConfmapsHead_loss: 6.0399e-05 - val_PartAffinityFieldsHead_loss: 4.7088e-04 - lr: 1.0000e-04 - 79s/epoch - 394ms/step
# Epoch 26/200
# 200/200 - 79s - loss: 2.8921e-04 - MultiInstanceConfmapsHead_loss: 3.9954e-05 - PartAffinityFieldsHead_loss: 2.4926e-04 - val_loss: 5.3436e-04 - val_MultiInstanceConfmapsHead_loss: 6.0261e-05 - val_PartAffinityFieldsHead_loss: 4.7410e-04 - lr: 1.0000e-04 - 79s/epoch - 395ms/step
# Epoch 27/200
# 200/200 - 80s - loss: 2.7978e-04 - MultiInstanceConfmapsHead_loss: 3.8496e-05 - PartAffinityFieldsHead_loss: 2.4128e-04 - val_loss: 5.2928e-04 - val_MultiInstanceConfmapsHead_loss: 5.9671e-05 - val_PartAffinityFieldsHead_loss: 4.6961e-04 - lr: 1.0000e-04 - 80s/epoch - 400ms/step
# Epoch 28/200
# 200/200 - 80s - loss: 2.6477e-04 - MultiInstanceConfmapsHead_loss: 3.6501e-05 - PartAffinityFieldsHead_loss: 2.2826e-04 - val_loss: 5.2494e-04 - val_MultiInstanceConfmapsHead_loss: 6.0113e-05 - val_PartAffinityFieldsHead_loss: 4.6483e-04 - lr: 1.0000e-04 - 80s/epoch - 401ms/step
# Epoch 29/200
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 200/200 - 80s - loss: 2.5137e-04 - MultiInstanceConfmapsHead_loss: 3.4553e-05 - PartAffinityFieldsHead_loss: 2.1682e-04 - val_loss: 5.4372e-04 - val_MultiInstanceConfmapsHead_loss: 6.1181e-05 - val_PartAffinityFieldsHead_loss: 4.8254e-04 - lr: 1.0000e-04 - 80s/epoch - 399ms/step
# Epoch 30/200
# 200/200 - 80s - loss: 2.2431e-04 - MultiInstanceConfmapsHead_loss: 3.0045e-05 - PartAffinityFieldsHead_loss: 1.9427e-04 - val_loss: 5.2348e-04 - val_MultiInstanceConfmapsHead_loss: 6.1110e-05 - val_PartAffinityFieldsHead_loss: 4.6237e-04 - lr: 5.0000e-05 - 80s/epoch - 400ms/step
# Epoch 31/200
# 200/200 - 80s - loss: 2.1014e-04 - MultiInstanceConfmapsHead_loss: 2.8184e-05 - PartAffinityFieldsHead_loss: 1.8196e-04 - val_loss: 5.4388e-04 - val_MultiInstanceConfmapsHead_loss: 6.0682e-05 - val_PartAffinityFieldsHead_loss: 4.8319e-04 - lr: 5.0000e-05 - 80s/epoch - 400ms/step
# Epoch 32/200
# 200/200 - 78s - loss: 2.0515e-04 - MultiInstanceConfmapsHead_loss: 2.7122e-05 - PartAffinityFieldsHead_loss: 1.7803e-04 - val_loss: 5.6621e-04 - val_MultiInstanceConfmapsHead_loss: 6.3818e-05 - val_PartAffinityFieldsHead_loss: 5.0239e-04 - lr: 5.0000e-05 - 78s/epoch - 390ms/step
# Epoch 33/200
# 200/200 - 81s - loss: 1.9823e-04 - MultiInstanceConfmapsHead_loss: 2.6018e-05 - PartAffinityFieldsHead_loss: 1.7221e-04 - val_loss: 5.4765e-04 - val_MultiInstanceConfmapsHead_loss: 6.2963e-05 - val_PartAffinityFieldsHead_loss: 4.8469e-04 - lr: 5.0000e-05 - 81s/epoch - 403ms/step
# Epoch 34/200
# 200/200 - 80s - loss: 1.9444e-04 - MultiInstanceConfmapsHead_loss: 2.5346e-05 - PartAffinityFieldsHead_loss: 1.6909e-04 - val_loss: 5.5584e-04 - val_MultiInstanceConfmapsHead_loss: 6.2790e-05 - val_PartAffinityFieldsHead_loss: 4.9305e-04 - lr: 5.0000e-05 - 80s/epoch - 398ms/step
# Epoch 00034: early stopping
# INFO:sleap.nn.training:Finished training loop. [46.2 min]
# INFO:sleap.nn.training:Saving evaluation metrics to model folder...
# Predicting... ---------------------------------------- 100% ETA: 0:00:00 ?
# INFO:sleap.nn.evals:Saved predictions: \\multilab-na.ad.salk.edu\hpi_dev\users\eberrigan\SLEAP\20250625_cyl_arabidopsis_primary_receptive_field\train_test_split.v000\models\250625_122328.multi_instance.n=120\labels_pr.train.slp
# INFO:sleap.nn.evals:Saved metrics: \\multilab-na.ad.salk.edu\hpi_dev\users\eberrigan\SLEAP\20250625_cyl_arabidopsis_primary_receptive_field\train_test_split.v000\models\250625_122328.multi_instance.n=120\metrics.train.npz
# INFO:sleap.nn.evals:OKS mAP: 0.291193
# Predicting... --------------------------------------- 100% ETA: 0:00:00 2.6 FPS
# INFO:sleap.nn.evals:Saved predictions: \\multilab-na.ad.salk.edu\hpi_dev\users\eberrigan\SLEAP\20250625_cyl_arabidopsis_primary_receptive_field\train_test_split.v000\models\250625_122328.multi_instance.n=120\labels_pr.val.slp
# INFO:sleap.nn.evals:Saved metrics: \\multilab-na.ad.salk.edu\hpi_dev\users\eberrigan\SLEAP\20250625_cyl_arabidopsis_primary_receptive_field\train_test_split.v000\models\250625_122328.multi_instance.n=120\metrics.val.npz
# INFO:sleap.nn.evals:OKS mAP: 0.011089
# WARNING:tensorflow:5 out of the last 32 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001F5A5890948> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Predicting... --------------------------------------- 100% ETA: 0:00:00 4.2 FPS
# INFO:sleap.nn.evals:Saved predictions: \\multilab-na.ad.salk.edu\hpi_dev\users\eberrigan\SLEAP\20250625_cyl_arabidopsis_primary_receptive_field\train_test_split.v000\models\250625_122328.multi_instance.n=120\labels_pr.test.slp
# INFO:sleap.nn.evals:Saved metrics: \\multilab-na.ad.salk.edu\hpi_dev\users\eberrigan\SLEAP\20250625_cyl_arabidopsis_primary_receptive_field\train_test_split.v000\models\250625_122328.multi_instance.n=120\metrics.test.npz
# INFO:sleap.nn.evals:OKS mAP: 0.008581
#
# INFO:root:Latest run directory: \\multilab-na.ad.salk.edu\hpi_dev\users\eberrigan\SLEAP\20250625_cyl_arabidopsis_primary_receptive_field\train_test_split.v000\models\250625_122328.multi_instance.n=120
# wandb: Adding directory to artifact (\\multilab-na.ad.salk.edu\hpi_dev\users\eberrigan\SLEAP\20250625_cyl_arabidopsis_primary_receptive_field\train_test_split.v000\models\250625_122328.multi_instance.n=120)...
# W&B run configuration updated with training configuration.
# Done. 0.2s
# Model path: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/20250625_cyl_arabidopsis_primary_receptive_field/train_test_split.v000/models/250625_122328.multi_instance.n=120
# Metrics loaded from model directory: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/20250625_cyl_arabidopsis_primary_receptive_field/train_test_split.v000/models/250625_122328.multi_instance.n=120
# Model artifact '20250625_cyl_arabidopsis_primary_receptive_field_v000' logged to W&B with evaluations.
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>dist_avg</td><td>1.71042</td></tr><tr><td>dist_p50</td><td>0.58585</td></tr><tr><td>dist_p90</td><td>4.53712</td></tr><tr><td>dist_p95</td><td>8.42168</td></tr><tr><td>dist_p99</td><td>11.29879</td></tr><tr><td>dist_std</td><td>2.54674</td></tr><tr><td>model_name</td><td>250625_122328.multi_...</td></tr><tr><td>model_path</td><td>//multilab-na.ad.sal...</td></tr><tr><td>oks_map</td><td>0.00858</td></tr><tr><td>oks_mar</td><td>0.01364</td></tr><tr><td>vis_prec</td><td>1</td></tr><tr><td>vis_recall</td><td>0.63095</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">20250625_cyl_arabidopsis_primary_receptive_field_training_v000</strong> at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/nxe8xgsd' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/nxe8xgsd</a><br/> View project at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a><br/>Synced 5 W&B file(s), 0 media file(s), 23 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250625_122314-nxe8xgsd\logs</code>
# INFO:root:W&B run for version 0 finished.
# INFO:root:Completed training for version 0.
# wandb: Agent Starting Run: qilbptpp with config:
# wandb: 	model.backbone.unet.max_stride: 32
# INFO:root:Starting training for version 0...
# INFO:root:Directory path for version 0: \\multilab-na.ad.salk.edu\hpi_dev\users\eberrigan\SLEAP\20250625_cyl_arabidopsis_primary_receptive_field\train_test_split.v000
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>c:\repos\sleap-roots-training\wandb\run-20250625_131046-qilbptpp</code>
# Syncing run <strong><a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/qilbptpp' target="_blank">20250625_cyl_arabidopsis_primary_receptive_field_training_v000</a></strong> to <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/sweeps/m5dk874f' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/sweeps/m5dk874f</a>
#  View project at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a>
#  View sweep at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/sweeps/m5dk874f' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/sweeps/m5dk874f</a>
# ...
#             "profile_graph": false,
#             "visualizations": true
#         },
#         "zmq": {
#             "subscribe_to_controller": false,
#             "controller_address": "tcp://127.0.0.1:9000",
#             "controller_polling_timeout": 10,
#             "publish_updates": false,
#             "publish_address": "tcp://127.0.0.1:9001"
#         }
#     },
#     "name": "",
#     "description": "",
#     "sleap_version": "",
#     "filename": "//multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/20250625_cyl_arabidopsis_primary_receptive_field/train_test_split.v005/modified_config_v005_20250625_214352.json"
# }
# INFO:sleap.nn.training:
# INFO:sleap.nn.training:Auto-selected GPU 0 with 22394 MiB of free memory.
# INFO:sleap.nn.training:Using GPU 0 for acceleration.
# INFO:sleap.nn.training:Disabled GPU memory pre-allocation.
# INFO:sleap.nn.training:System:
# GPUs: 1/1 available
#   Device: /physical_device:GPU:0
#          Available: True
#        Initialized: False
#      Memory growth: True
# INFO:sleap.nn.training:
# INFO:sleap.nn.training:Initializing trainer...
# INFO:sleap.nn.training:Loading training labels from: \\multilab-na.ad.salk.edu\hpi_dev\users\eberrigan\SLEAP\20250625_cyl_arabidopsis_primary_receptive_field\train_test_split.v005\train.pkg.slp
# INFO:sleap.nn.training:Loading validation labels from: \\multilab-na.ad.salk.edu\hpi_dev\users\eberrigan\SLEAP\20250625_cyl_arabidopsis_primary_receptive_field\train_test_split.v005\val.pkg.slp
# INFO:sleap.nn.training:Loading test labels from: \\multilab-na.ad.salk.edu\hpi_dev\users\eberrigan\SLEAP\20250625_cyl_arabidopsis_primary_receptive_field\train_test_split.v005\test.pkg.slp
# INFO:sleap.nn.training:Setting up for training...
# INFO:sleap.nn.training:Setting up pipeline builders...
# INFO:sleap.nn.training:Setting up model...
# INFO:sleap.nn.training:Building test pipeline...
# INFO:sleap.nn.training:Loaded test example. [5.323s]
# INFO:sleap.nn.training:  Input shape: (1088, 2048, 1)
# INFO:sleap.nn.training:Created Keras model.
# INFO:sleap.nn.training:  Backbone: UNet(stacks=1, filters=24, filters_rate=1.5, kernel_size=3, stem_kernel_size=7, convs_per_block=2, stem_blocks=0, down_blocks=6, middle_block=True, up_blocks=5, up_interpolate=True, block_contraction=False)
# INFO:sleap.nn.training:  Max stride: 64
# INFO:sleap.nn.training:  Parameters: 3,848,881
# INFO:sleap.nn.training:  Heads:
# INFO:sleap.nn.training:    [0] = MultiInstanceConfmapsHead(part_names=['r1', 'r2', 'r3', 'r4', 'r5', 'r6'], sigma=2.5, output_stride=2, loss_weight=1.0)
# INFO:sleap.nn.training:    [1] = PartAffinityFieldsHead(edges=[('r1', 'r2'), ('r2', 'r3'), ('r3', 'r4'), ('r4', 'r5'), ('r5', 'r6')], sigma=75.0, output_stride=8, loss_weight=1.0)
# INFO:sleap.nn.training:  Outputs:
# INFO:sleap.nn.training:    [0] = KerasTensor(type_spec=TensorSpec(shape=(None, 544, 1024, 6), dtype=tf.float32, name=None), name='MultiInstanceConfmapsHead/BiasAdd:0', description="created by layer 'MultiInstanceConfmapsHead'")
# INFO:sleap.nn.training:    [1] = KerasTensor(type_spec=TensorSpec(shape=(None, 136, 256, 10), dtype=tf.float32, name=None), name='PartAffinityFieldsHead/BiasAdd:0', description="created by layer 'PartAffinityFieldsHead'")
# INFO:sleap.nn.training:Training from scratch
# INFO:sleap.nn.training:Setting up data pipelines...
# INFO:sleap.nn.training:Training set: n = 99
# INFO:sleap.nn.training:Validation set: n = 21
# INFO:sleap.nn.training:Setting up optimization...
# INFO:sleap.nn.training:  Learning rate schedule: LearningRateScheduleConfig(reduce_on_plateau=True, reduction_factor=0.5, plateau_min_delta=1e-06, plateau_patience=5, plateau_cooldown=3, min_learning_rate=1e-08)
# INFO:sleap.nn.training:  Early stopping: EarlyStoppingConfig(stop_training_on_plateau=True, plateau_min_delta=1e-06, plateau_patience=10)
# INFO:sleap.nn.training:Setting up outputs...
# INFO:sleap.nn.training:Created run path: \\multilab-na.ad.salk.edu\hpi_dev\users\eberrigan\SLEAP\20250625_cyl_arabidopsis_primary_receptive_field\train_test_split.v005\models\250625_214406.multi_instance.n=120
# INFO:sleap.nn.training:Setting up visualization...
# INFO:sleap.nn.training:Finished trainer set up. [10.1s]
# INFO:sleap.nn.training:Creating tf.data.Datasets for training data generation...
# INFO:sleap.nn.training:Finished creating training datasets. [8.9s]
# INFO:sleap.nn.training:Starting training loop...
# Epoch 1/200
# 200/200 - 98s - loss: 6.7005e-04 - MultiInstanceConfmapsHead_loss: 7.4859e-05 - PartAffinityFieldsHead_loss: 5.9519e-04 - val_loss: 6.7128e-04 - val_MultiInstanceConfmapsHead_loss: 7.2332e-05 - val_PartAffinityFieldsHead_loss: 5.9895e-04 - lr: 1.0000e-04 - 98s/epoch - 490ms/step
# Epoch 2/200
# 200/200 - 79s - loss: 6.7386e-04 - MultiInstanceConfmapsHead_loss: 7.1055e-05 - PartAffinityFieldsHead_loss: 6.0281e-04 - val_loss: 6.7088e-04 - val_MultiInstanceConfmapsHead_loss: 7.3044e-05 - val_PartAffinityFieldsHead_loss: 5.9784e-04 - lr: 1.0000e-04 - 79s/epoch - 394ms/step
# Epoch 3/200
# 200/200 - 79s - loss: 5.9660e-04 - MultiInstanceConfmapsHead_loss: 6.9478e-05 - PartAffinityFieldsHead_loss: 5.2713e-04 - val_loss: 5.6685e-04 - val_MultiInstanceConfmapsHead_loss: 7.0062e-05 - val_PartAffinityFieldsHead_loss: 4.9678e-04 - lr: 1.0000e-04 - 79s/epoch - 397ms/step
# Epoch 4/200
# 200/200 - 77s - loss: 5.1849e-04 - MultiInstanceConfmapsHead_loss: 6.7661e-05 - PartAffinityFieldsHead_loss: 4.5083e-04 - val_loss: 5.5935e-04 - val_MultiInstanceConfmapsHead_loss: 7.1921e-05 - val_PartAffinityFieldsHead_loss: 4.8743e-04 - lr: 1.0000e-04 - 77s/epoch - 387ms/step
# Epoch 5/200
# 200/200 - 78s - loss: 4.6264e-04 - MultiInstanceConfmapsHead_loss: 6.5490e-05 - PartAffinityFieldsHead_loss: 3.9714e-04 - val_loss: 4.9136e-04 - val_MultiInstanceConfmapsHead_loss: 6.6719e-05 - val_PartAffinityFieldsHead_loss: 4.2464e-04 - lr: 1.0000e-04 - 78s/epoch - 392ms/step
# Epoch 6/200
# 200/200 - 78s - loss: 4.1469e-04 - MultiInstanceConfmapsHead_loss: 6.2580e-05 - PartAffinityFieldsHead_loss: 3.5211e-04 - val_loss: 4.6759e-04 - val_MultiInstanceConfmapsHead_loss: 6.3929e-05 - val_PartAffinityFieldsHead_loss: 4.0366e-04 - lr: 1.0000e-04 - 78s/epoch - 389ms/step
# Epoch 7/200
# 200/200 - 78s - loss: 3.6853e-04 - MultiInstanceConfmapsHead_loss: 5.9254e-05 - PartAffinityFieldsHead_loss: 3.0927e-04 - val_loss: 4.3868e-04 - val_MultiInstanceConfmapsHead_loss: 6.1774e-05 - val_PartAffinityFieldsHead_loss: 3.7690e-04 - lr: 1.0000e-04 - 78s/epoch - 388ms/step
# Epoch 8/200
# 200/200 - 76s - loss: 3.1025e-04 - MultiInstanceConfmapsHead_loss: 5.4558e-05 - PartAffinityFieldsHead_loss: 2.5569e-04 - val_loss: 4.5288e-04 - val_MultiInstanceConfmapsHead_loss: 6.0850e-05 - val_PartAffinityFieldsHead_loss: 3.9203e-04 - lr: 1.0000e-04 - 76s/epoch - 378ms/step
# Epoch 9/200
# 200/200 - 78s - loss: 2.6904e-04 - MultiInstanceConfmapsHead_loss: 5.0168e-05 - PartAffinityFieldsHead_loss: 2.1887e-04 - val_loss: 4.6203e-04 - val_MultiInstanceConfmapsHead_loss: 6.2568e-05 - val_PartAffinityFieldsHead_loss: 3.9947e-04 - lr: 1.0000e-04 - 78s/epoch - 388ms/step
# Epoch 10/200
# 200/200 - 78s - loss: 2.1071e-04 - MultiInstanceConfmapsHead_loss: 4.3189e-05 - PartAffinityFieldsHead_loss: 1.6752e-04 - val_loss: 5.0541e-04 - val_MultiInstanceConfmapsHead_loss: 6.8791e-05 - val_PartAffinityFieldsHead_loss: 4.3662e-04 - lr: 1.0000e-04 - 78s/epoch - 389ms/step
# Epoch 11/200
# 200/200 - 78s - loss: 1.9258e-04 - MultiInstanceConfmapsHead_loss: 4.0608e-05 - PartAffinityFieldsHead_loss: 1.5197e-04 - val_loss: 4.2914e-04 - val_MultiInstanceConfmapsHead_loss: 6.3694e-05 - val_PartAffinityFieldsHead_loss: 3.6545e-04 - lr: 1.0000e-04 - 78s/epoch - 390ms/step
# Epoch 12/200
# 200/200 - 77s - loss: 1.5556e-04 - MultiInstanceConfmapsHead_loss: 3.5014e-05 - PartAffinityFieldsHead_loss: 1.2055e-04 - val_loss: 4.9449e-04 - val_MultiInstanceConfmapsHead_loss: 7.1470e-05 - val_PartAffinityFieldsHead_loss: 4.2302e-04 - lr: 1.0000e-04 - 77s/epoch - 383ms/step
# Epoch 13/200
# 200/200 - 77s - loss: 1.3698e-04 - MultiInstanceConfmapsHead_loss: 3.0508e-05 - PartAffinityFieldsHead_loss: 1.0647e-04 - val_loss: 4.8552e-04 - val_MultiInstanceConfmapsHead_loss: 6.9318e-05 - val_PartAffinityFieldsHead_loss: 4.1621e-04 - lr: 1.0000e-04 - 77s/epoch - 386ms/step
# Epoch 14/200
# 200/200 - 75s - loss: 1.1353e-04 - MultiInstanceConfmapsHead_loss: 2.6561e-05 - PartAffinityFieldsHead_loss: 8.6970e-05 - val_loss: 4.9437e-04 - val_MultiInstanceConfmapsHead_loss: 7.0717e-05 - val_PartAffinityFieldsHead_loss: 4.2365e-04 - lr: 1.0000e-04 - 75s/epoch - 377ms/step
# Epoch 15/200
# 200/200 - 77s - loss: 9.9753e-05 - MultiInstanceConfmapsHead_loss: 2.3923e-05 - PartAffinityFieldsHead_loss: 7.5830e-05 - val_loss: 4.8547e-04 - val_MultiInstanceConfmapsHead_loss: 6.7578e-05 - val_PartAffinityFieldsHead_loss: 4.1789e-04 - lr: 1.0000e-04 - 77s/epoch - 383ms/step
# Epoch 16/200
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 200/200 - 78s - loss: 9.5646e-05 - MultiInstanceConfmapsHead_loss: 2.2892e-05 - PartAffinityFieldsHead_loss: 7.2754e-05 - val_loss: 5.0632e-04 - val_MultiInstanceConfmapsHead_loss: 7.6472e-05 - val_PartAffinityFieldsHead_loss: 4.2985e-04 - lr: 1.0000e-04 - 78s/epoch - 390ms/step
# Epoch 17/200
# 200/200 - 76s - loss: 6.1503e-05 - MultiInstanceConfmapsHead_loss: 1.2192e-05 - PartAffinityFieldsHead_loss: 4.9311e-05 - val_loss: 5.0225e-04 - val_MultiInstanceConfmapsHead_loss: 7.7542e-05 - val_PartAffinityFieldsHead_loss: 4.2471e-04 - lr: 5.0000e-05 - 76s/epoch - 378ms/step
# Epoch 18/200
# 200/200 - 77s - loss: 5.1409e-05 - MultiInstanceConfmapsHead_loss: 8.9795e-06 - PartAffinityFieldsHead_loss: 4.2429e-05 - val_loss: 4.7855e-04 - val_MultiInstanceConfmapsHead_loss: 7.8161e-05 - val_PartAffinityFieldsHead_loss: 4.0039e-04 - lr: 5.0000e-05 - 77s/epoch - 385ms/step
# Epoch 19/200
# 200/200 - 77s - loss: 4.7239e-05 - MultiInstanceConfmapsHead_loss: 7.9699e-06 - PartAffinityFieldsHead_loss: 3.9269e-05 - val_loss: 4.9802e-04 - val_MultiInstanceConfmapsHead_loss: 7.9560e-05 - val_PartAffinityFieldsHead_loss: 4.1846e-04 - lr: 5.0000e-05 - 77s/epoch - 386ms/step
# Epoch 20/200
# 200/200 - 77s - loss: 4.4919e-05 - MultiInstanceConfmapsHead_loss: 7.4972e-06 - PartAffinityFieldsHead_loss: 3.7422e-05 - val_loss: 5.0617e-04 - val_MultiInstanceConfmapsHead_loss: 8.1370e-05 - val_PartAffinityFieldsHead_loss: 4.2480e-04 - lr: 5.0000e-05 - 77s/epoch - 384ms/step
# Epoch 21/200
# 200/200 - 77s - loss: 4.1571e-05 - MultiInstanceConfmapsHead_loss: 6.7730e-06 - PartAffinityFieldsHead_loss: 3.4798e-05 - val_loss: 5.0627e-04 - val_MultiInstanceConfmapsHead_loss: 7.9887e-05 - val_PartAffinityFieldsHead_loss: 4.2638e-04 - lr: 5.0000e-05 - 77s/epoch - 383ms/step
# Epoch 00021: early stopping
# INFO:sleap.nn.training:Finished training loop. [27.4 min]
# INFO:sleap.nn.training:Saving evaluation metrics to model folder...
# Predicting... ---------------------------------------- 100% ETA: 0:00:00 ?
# INFO:sleap.nn.evals:Saved predictions: \\multilab-na.ad.salk.edu\hpi_dev\users\eberrigan\SLEAP\20250625_cyl_arabidopsis_primary_receptive_field\train_test_split.v005\models\250625_214406.multi_instance.n=120\labels_pr.train.slp
# INFO:sleap.nn.evals:Saved metrics: \\multilab-na.ad.salk.edu\hpi_dev\users\eberrigan\SLEAP\20250625_cyl_arabidopsis_primary_receptive_field\train_test_split.v005\models\250625_214406.multi_instance.n=120\metrics.train.npz
# INFO:sleap.nn.evals:OKS mAP: 0.797753
# Predicting... --------------------------------------- 100% ETA: 0:00:00 2.6 FPS
# INFO:sleap.nn.evals:Saved predictions: \\multilab-na.ad.salk.edu\hpi_dev\users\eberrigan\SLEAP\20250625_cyl_arabidopsis_primary_receptive_field\train_test_split.v005\models\250625_214406.multi_instance.n=120\labels_pr.val.slp
# INFO:sleap.nn.evals:Saved metrics: \\multilab-na.ad.salk.edu\hpi_dev\users\eberrigan\SLEAP\20250625_cyl_arabidopsis_primary_receptive_field\train_test_split.v005\models\250625_214406.multi_instance.n=120\metrics.val.npz
# INFO:sleap.nn.evals:OKS mAP: 0.020026
# WARNING:tensorflow:5 out of the last 32 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000027BAB5FBEE8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Predicting... --------------------------------------- 100% ETA: 0:00:00 4.4 FPS
# INFO:sleap.nn.evals:Saved predictions: \\multilab-na.ad.salk.edu\hpi_dev\users\eberrigan\SLEAP\20250625_cyl_arabidopsis_primary_receptive_field\train_test_split.v005\models\250625_214406.multi_instance.n=120\labels_pr.test.slp
# INFO:sleap.nn.evals:Saved metrics: \\multilab-na.ad.salk.edu\hpi_dev\users\eberrigan\SLEAP\20250625_cyl_arabidopsis_primary_receptive_field\train_test_split.v005\models\250625_214406.multi_instance.n=120\metrics.test.npz
# INFO:sleap.nn.evals:OKS mAP: 0.000657
#
# INFO:root:Latest run directory: \\multilab-na.ad.salk.edu\hpi_dev\users\eberrigan\SLEAP\20250625_cyl_arabidopsis_primary_receptive_field\train_test_split.v005\models\250625_214406.multi_instance.n=120
# wandb: Adding directory to artifact (\\multilab-na.ad.salk.edu\hpi_dev\users\eberrigan\SLEAP\20250625_cyl_arabidopsis_primary_receptive_field\train_test_split.v005\models\250625_214406.multi_instance.n=120)...
# W&B run configuration updated with training configuration.
# Done. 1.2s
# Model path: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/20250625_cyl_arabidopsis_primary_receptive_field/train_test_split.v005/models/250625_214406.multi_instance.n=120
# Metrics loaded from model directory: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/20250625_cyl_arabidopsis_primary_receptive_field/train_test_split.v005/models/250625_214406.multi_instance.n=120
# Model artifact '20250625_cyl_arabidopsis_primary_receptive_field_v005' logged to W&B with evaluations.
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>dist_avg</td><td>1.30371</td></tr><tr><td>dist_p50</td><td>0.7408</td></tr><tr><td>dist_p90</td><td>3.00968</td></tr><tr><td>dist_p95</td><td>5.81487</td></tr><tr><td>dist_p99</td><td>8.93165</td></tr><tr><td>dist_std</td><td>1.76836</td></tr><tr><td>model_name</td><td>250625_214406.multi_...</td></tr><tr><td>model_path</td><td>//multilab-na.ad.sal...</td></tr><tr><td>oks_map</td><td>0.00066</td></tr><tr><td>oks_mar</td><td>0.00426</td></tr><tr><td>vis_prec</td><td>1</td></tr><tr><td>vis_recall</td><td>0.87319</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">20250625_cyl_arabidopsis_primary_receptive_field_training_v005</strong> at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/g70pd752' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/g70pd752</a><br/> View project at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a><br/>Synced 7 W&B file(s), 0 media file(s), 16 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250625_214351-g70pd752\logs</code>
# INFO:root:W&B run for version 5 finished.
# INFO:root:Completed training for version 5.
# INFO:root:Finished sweep for version 5.
# INFO:root:All versions processed successfully.
