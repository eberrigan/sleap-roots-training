# %%
import wandb
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sleap
import numpy as np
import datetime
import matplotlib.pyplot as plt
import numpy as np

from matplotlib.patches import ConnectionPatch
from pathlib import Path
from itertools import combinations
from scipy.stats import wilcoxon
from scipy.stats import friedmanchisquare

# %%
import sleap_roots_training

from sleap_roots_training.evaluate import (main, 
                                           predictions_viz_from_sleap_files, 
                                           fetch_sweep_metrics, 
                                           get_sweep_ids_for_group_from_runs, 
                                           visualize_predictions_from_artifacts,
)

# %%
# Constants for W&B initialization
ENTITY_NAME = "eberrigan-salk-institute-for-biological-studies"
PROJECT_NAME = "sleap-roots"
REGISTRY = "sleap-roots-models"
JOB_TYPE = "evaluation"
EXPERIMENT_NAME = "20250711_plate_arabidopsis_primary_sweep_receptive_field"

# Constants for artifact creation
DESCRIPTION = "2-7 DAG arabidopsis primary root in plates with 8 nodes varying max stride [8, 16, 32, 64, 128] sweep"
TAGS = ["plate", "arabidopsis", "2-7DAG", "primary", "8nodes", "arabidopsis2-7DAG", "2025-07-11", "max_stride_sweep"]
COLLECTION_NAME = EXPERIMENT_NAME
CSV_PATH = "//multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/20250711_plate_arabidopsis_primary_sweep_receptive_field/train_test_splits.csv"
ARTIFACT_NAME = "plate_arabidopsis_primary_receptive_field_max_stride_sweep_evaluation"

# Model and group configuration
# https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/groups
MODEL_GROUP = "20250711_plate_arabidopsis_primary_sweep_receptive_field" # This is the group name for the sweep
TARGET_METRICS = ["dist_p50", "dist_p90", "dist_p95", "dist_p99", "dist_avg", "dist_std", "vis_prec", "vis_recall", "oks_map", "oks_mar"]

# %%
sleap_roots_training.reset_config()
# Out:
# Configuration updated successfully at c:\repos\sleap-roots-training\sleap_roots_training\config.yaml.
# Configuration has been reset to default values.

# %%
sleap_roots_training.update_config(entity_name=ENTITY_NAME, project_name=PROJECT_NAME, registry=REGISTRY, experiment_name=EXPERIMENT_NAME)
# Out:
# Configuration updated successfully at c:\repos\sleap-roots-training\sleap_roots_training\config.yaml.
# CONFIG updated to {'project_name': 'sleap-roots', 'entity_name': 'eberrigan-salk-institute-for-biological-studies', 'experiment_name': '20250711_plate_arabidopsis_primary_sweep_receptive_field', 'registry': 'sleap-roots-models', 'collection_name': None, 'job_type': None}.

# %%
# Make directory for experiment
Path(EXPERIMENT_NAME).mkdir(exist_ok=True, parents=True)

# %%
datetime_str = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

# %%
# sweep_ids = get_sweep_ids_for_group_from_runs(group_name=MODEL_GROUP)
sweep_ids = get_sweep_ids_for_group_from_runs(
    group_name=MODEL_GROUP,
    earliest_time="2025-07-11T01:30:27Z"
)
# Out:
# INFO:root:Found 25 runs in group '20250711_plate_arabidopsis_primary_sweep_receptive_field' with filters: {'group': '20250711_plate_arabidopsis_primary_sweep_receptive_field', 'createdAt': {'$gte': '2025-07-11T01:30:27Z'}}
# INFO:root:Found 5 unique sweep IDs: ['0s9xjxd8', '45bjarr8', 'acpmpg1x', 'pv2nixwm', 'ytc0bglj']

# %%
sweep_df = fetch_sweep_metrics(
    sweep_ids=sweep_ids,
    target_metrics=TARGET_METRICS,
    include_config=True,
)

# %%
sweep_df
# Out:
#       run_id                                               name  \
# 0   t58nb19p  20250711_plate_arabidopsis_primary_sweep_recep...
# 1   wmlgyl1r  20250711_plate_arabidopsis_primary_sweep_recep...
# 2   so719v6l  20250711_plate_arabidopsis_primary_sweep_recep...
# 3   rpysuaq1  20250711_plate_arabidopsis_primary_sweep_recep...
# 4   eesv2e8m  20250711_plate_arabidopsis_primary_sweep_recep...
# 5   3tgy48kw  20250711_plate_arabidopsis_primary_sweep_recep...
# 6   b5an2u50  20250711_plate_arabidopsis_primary_sweep_recep...
# 7   e3dauw89  20250711_plate_arabidopsis_primary_sweep_recep...
# 8   v10k4vaa  20250711_plate_arabidopsis_primary_sweep_recep...
# 9   a1ef1tls  20250711_plate_arabidopsis_primary_sweep_recep...
# 10  zvpco77g  20250711_plate_arabidopsis_primary_sweep_recep...
# 11  gdh22nre  20250711_plate_arabidopsis_primary_sweep_recep...
# 12  0fklk33i  20250711_plate_arabidopsis_primary_sweep_recep...
# 13  mx5y15eu  20250711_plate_arabidopsis_primary_sweep_recep...
# 14  rxuqgrrt  20250711_plate_arabidopsis_primary_sweep_recep...
# 15  jdia8g2l  20250711_plate_arabidopsis_primary_sweep_recep...
# 16  gq2cucux  20250711_plate_arabidopsis_primary_sweep_recep...
# 17  unilhmmg  20250711_plate_arabidopsis_primary_sweep_recep...
# 18  lmeyruma  20250711_plate_arabidopsis_primary_sweep_recep...
# 19  boimv5g5  20250711_plate_arabidopsis_primary_sweep_recep...
# 20  jibjfxky  20250711_plate_arabidopsis_primary_sweep_recep...
# 21  wio9ud69  20250711_plate_arabidopsis_primary_sweep_recep...
# 22  5fu799n2  20250711_plate_arabidopsis_primary_sweep_recep...
# 23  uhifqi5s  20250711_plate_arabidopsis_primary_sweep_recep...
#
#                                                 group  sweep_id  dist_p50  \
# 0   20250711_plate_arabidopsis_primary_sweep_recep...  0s9xjxd8       NaN
# 1   20250711_plate_arabidopsis_primary_sweep_recep...  0s9xjxd8  0.864587
# 2   20250711_plate_arabidopsis_primary_sweep_recep...  0s9xjxd8  0.951781
# 3   20250711_plate_arabidopsis_primary_sweep_recep...  0s9xjxd8  0.814496
# 4   20250711_plate_arabidopsis_primary_sweep_recep...  0s9xjxd8  0.375201
# 5   20250711_plate_arabidopsis_primary_sweep_recep...  45bjarr8       NaN
# 6   20250711_plate_arabidopsis_primary_sweep_recep...  45bjarr8  0.816908
# 7   20250711_plate_arabidopsis_primary_sweep_recep...  45bjarr8  0.874802
# 8   20250711_plate_arabidopsis_primary_sweep_recep...  45bjarr8  0.745647
# 9   20250711_plate_arabidopsis_primary_sweep_recep...  45bjarr8  0.292784
# 10  20250711_plate_arabidopsis_primary_sweep_recep...  acpmpg1x       NaN
# 11  20250711_plate_arabidopsis_primary_sweep_recep...  acpmpg1x  0.802077
# 12  20250711_plate_arabidopsis_primary_sweep_recep...  acpmpg1x  0.908233
# 13  20250711_plate_arabidopsis_primary_sweep_recep...  acpmpg1x  0.503433
# 14  20250711_plate_arabidopsis_primary_sweep_recep...  acpmpg1x  0.300641
# 15  20250711_plate_arabidopsis_primary_sweep_recep...  pv2nixwm  0.734306
# 16  20250711_plate_arabidopsis_primary_sweep_recep...  pv2nixwm  0.703170
# 17  20250711_plate_arabidopsis_primary_sweep_recep...  pv2nixwm  0.624598
# 18  20250711_plate_arabidopsis_primary_sweep_recep...  pv2nixwm  0.548594
# 19  20250711_plate_arabidopsis_primary_sweep_recep...  ytc0bglj       NaN
# 20  20250711_plate_arabidopsis_primary_sweep_recep...  ytc0bglj  0.844424
# 21  20250711_plate_arabidopsis_primary_sweep_recep...  ytc0bglj  0.722326
# 22  20250711_plate_arabidopsis_primary_sweep_recep...  ytc0bglj  0.555514
# 23  20250711_plate_arabidopsis_primary_sweep_recep...  ytc0bglj  2.313887
#
#      dist_p90   dist_p95   dist_p99  dist_avg  dist_std  ...  config/name  \
# 0         NaN        NaN        NaN       NaN       NaN  ...
# 1    5.473388   8.895695  18.295114  2.236511  4.151039  ...
# 2    9.556026  15.568722  33.206777  3.445150  6.370838  ...
# 3   14.682596  17.047235  31.451176  3.953850  6.670361  ...
# 4    9.080185  12.389828  33.235375  3.008446  5.814524  ...
# 5         NaN        NaN        NaN       NaN       NaN  ...
# 6    5.292714   8.302414  22.388856  2.201196  4.250145  ...
# 7   12.547745  16.867045  33.645174  3.722486  7.015430  ...
# 8   14.852816  17.765598  38.920671  4.194159  7.510077  ...
# 9   10.816536  12.664214  15.474111  3.170837  4.356270  ...
# 10        NaN        NaN        NaN       NaN       NaN  ...
# 11   5.179290   7.414567  17.953928  2.059879  3.813168  ...
# 12   8.626215  16.310769  31.640253  3.262802  6.150493  ...
# 13  11.912886  16.834927  29.325473  3.123278  6.545848  ...
# 14   8.918761  15.641621  21.197113  2.704794  5.068919  ...
# 15   4.688201   6.936870  17.649281  2.007862  4.547304  ...
# 16   7.799458  14.775082  25.634166  2.772923  5.228409  ...
# 17  14.484681  16.756769  32.041756  3.714158  6.882484  ...
# 18   7.061731  11.003056  12.516612  2.478828  3.764995  ...
# 19        NaN        NaN        NaN       NaN       NaN  ...
# 20   5.186340   7.406516  16.273139  2.108346  3.703160  ...
# 21  13.707535  17.571001  32.616782  3.658752  7.032708  ...
# 22  12.676276  16.210894  27.175003  3.090743  5.944803  ...
# 23  11.822715  14.018614  15.193557  3.877266  4.680101  ...
#
#                                          config/model  \
# 0   {'heads': {'centroid': None, 'multi_instance':...
# 1   {'heads': {'centroid': None, 'multi_instance':...
# 2   {'heads': {'centroid': None, 'multi_instance':...
# 3   {'heads': {'centroid': None, 'multi_instance':...
# 4   {'heads': {'centroid': None, 'multi_instance':...
# 5   {'heads': {'centroid': None, 'multi_instance':...
# 6   {'heads': {'centroid': None, 'multi_instance':...
# 7   {'heads': {'centroid': None, 'multi_instance':...
# 8   {'heads': {'centroid': None, 'multi_instance':...
# 9   {'heads': {'centroid': None, 'multi_instance':...
# 10  {'heads': {'centroid': None, 'multi_instance':...
# 11  {'heads': {'centroid': None, 'multi_instance':...
# 12  {'heads': {'centroid': None, 'multi_instance':...
# 13  {'heads': {'centroid': None, 'multi_instance':...
# 14  {'heads': {'centroid': None, 'multi_instance':...
# 15  {'heads': {'centroid': None, 'multi_instance':...
# 16  {'heads': {'centroid': None, 'multi_instance':...
# 17  {'heads': {'centroid': None, 'multi_instance':...
# 18  {'heads': {'centroid': None, 'multi_instance':...
# 19  {'heads': {'centroid': None, 'multi_instance':...
# 20  {'heads': {'centroid': None, 'multi_instance':...
# 21  {'heads': {'centroid': None, 'multi_instance':...
# 22  {'heads': {'centroid': None, 'multi_instance':...
# 23  {'heads': {'centroid': None, 'multi_instance':...
#
#                                        config/outputs  config/version  \
# 0   {'zmq': {'publish_address': 'tcp://127.0.0.1:9...               2
# 1   {'zmq': {'publish_address': 'tcp://127.0.0.1:9...               2
# 2   {'zmq': {'publish_address': 'tcp://127.0.0.1:9...               2
# 3   {'zmq': {'publish_address': 'tcp://127.0.0.1:9...               2
# 4   {'zmq': {'publish_address': 'tcp://127.0.0.1:9...               2
# 5   {'zmq': {'publish_address': 'tcp://127.0.0.1:9...               0
# 6   {'zmq': {'publish_address': 'tcp://127.0.0.1:9...               0
# 7   {'zmq': {'publish_address': 'tcp://127.0.0.1:9...               0
# 8   {'zmq': {'publish_address': 'tcp://127.0.0.1:9...               0
# 9   {'zmq': {'publish_address': 'tcp://127.0.0.1:9...               0
# 10  {'zmq': {'publish_address': 'tcp://127.0.0.1:9...               1
# 11  {'zmq': {'publish_address': 'tcp://127.0.0.1:9...               1
# 12  {'zmq': {'publish_address': 'tcp://127.0.0.1:9...               1
# 13  {'zmq': {'publish_address': 'tcp://127.0.0.1:9...               1
# 14  {'zmq': {'publish_address': 'tcp://127.0.0.1:9...               1
# 15  {'zmq': {'publish_address': 'tcp://127.0.0.1:9...               4
# 16  {'zmq': {'publish_address': 'tcp://127.0.0.1:9...               4
# 17  {'zmq': {'publish_address': 'tcp://127.0.0.1:9...               4
# 18  {'zmq': {'publish_address': 'tcp://127.0.0.1:9...               4
# 19  {'zmq': {'publish_address': 'tcp://127.0.0.1:9...               3
# 20  {'zmq': {'publish_address': 'tcp://127.0.0.1:9...               3
# 21  {'zmq': {'publish_address': 'tcp://127.0.0.1:9...               3
# 22  {'zmq': {'publish_address': 'tcp://127.0.0.1:9...               3
# 23  {'zmq': {'publish_address': 'tcp://127.0.0.1:9...               3
#
#                                       config/filename  \
# 0   \\multilab-na.ad.salk.edu\hpi_dev\users\eberri...
# 1   \\multilab-na.ad.salk.edu\hpi_dev\users\eberri...
# 2   \\multilab-na.ad.salk.edu\hpi_dev\users\eberri...
# 3   \\multilab-na.ad.salk.edu\hpi_dev\users\eberri...
# 4   \\multilab-na.ad.salk.edu\hpi_dev\users\eberri...
# 5   \\multilab-na.ad.salk.edu\hpi_dev\users\eberri...
# 6   \\multilab-na.ad.salk.edu\hpi_dev\users\eberri...
# 7   \\multilab-na.ad.salk.edu\hpi_dev\users\eberri...
# 8   \\multilab-na.ad.salk.edu\hpi_dev\users\eberri...
# 9   \\multilab-na.ad.salk.edu\hpi_dev\users\eberri...
# 10  \\multilab-na.ad.salk.edu\hpi_dev\users\eberri...
# 11  \\multilab-na.ad.salk.edu\hpi_dev\users\eberri...
# 12  \\multilab-na.ad.salk.edu\hpi_dev\users\eberri...
# 13  \\multilab-na.ad.salk.edu\hpi_dev\users\eberri...
# 14  \\multilab-na.ad.salk.edu\hpi_dev\users\eberri...
# 15  \\multilab-na.ad.salk.edu\hpi_dev\users\eberri...
# 16  \\multilab-na.ad.salk.edu\hpi_dev\users\eberri...
# 17  \\multilab-na.ad.salk.edu\hpi_dev\users\eberri...
# 18  \\multilab-na.ad.salk.edu\hpi_dev\users\eberri...
# 19  \\multilab-na.ad.salk.edu\hpi_dev\users\eberri...
# 20  \\multilab-na.ad.salk.edu\hpi_dev\users\eberri...
# 21  \\multilab-na.ad.salk.edu\hpi_dev\users\eberri...
# 22  \\multilab-na.ad.salk.edu\hpi_dev\users\eberri...
# 23  \\multilab-na.ad.salk.edu\hpi_dev\users\eberri...
#
#                                    config/config_path config/description  \
# 0   //multilab-na.ad.salk.edu/hpi_dev/users/eberri...
# 1   //multilab-na.ad.salk.edu/hpi_dev/users/eberri...
# 2   //multilab-na.ad.salk.edu/hpi_dev/users/eberri...
# 3   //multilab-na.ad.salk.edu/hpi_dev/users/eberri...
# 4   //multilab-na.ad.salk.edu/hpi_dev/users/eberri...
# 5   //multilab-na.ad.salk.edu/hpi_dev/users/eberri...
# 6   //multilab-na.ad.salk.edu/hpi_dev/users/eberri...
# 7   //multilab-na.ad.salk.edu/hpi_dev/users/eberri...
# 8   //multilab-na.ad.salk.edu/hpi_dev/users/eberri...
# 9   //multilab-na.ad.salk.edu/hpi_dev/users/eberri...
# 10  //multilab-na.ad.salk.edu/hpi_dev/users/eberri...
# 11  //multilab-na.ad.salk.edu/hpi_dev/users/eberri...
# 12  //multilab-na.ad.salk.edu/hpi_dev/users/eberri...
# 13  //multilab-na.ad.salk.edu/hpi_dev/users/eberri...
# 14  //multilab-na.ad.salk.edu/hpi_dev/users/eberri...
# 15  //multilab-na.ad.salk.edu/hpi_dev/users/eberri...
# 16  //multilab-na.ad.salk.edu/hpi_dev/users/eberri...
# 17  //multilab-na.ad.salk.edu/hpi_dev/users/eberri...
# 18  //multilab-na.ad.salk.edu/hpi_dev/users/eberri...
# 19  //multilab-na.ad.salk.edu/hpi_dev/users/eberri...
# 20  //multilab-na.ad.salk.edu/hpi_dev/users/eberri...
# 21  //multilab-na.ad.salk.edu/hpi_dev/users/eberri...
# 22  //multilab-na.ad.salk.edu/hpi_dev/users/eberri...
# 23  //multilab-na.ad.salk.edu/hpi_dev/users/eberri...
#
#                                   config/optimization  config/sleap_version  \
# 0   {'epochs': 200, 'prefetch': True, 'optimizer':...               1.4.1a2
# 1   {'epochs': 200, 'prefetch': True, 'optimizer':...               1.4.1a2
# 2   {'epochs': 200, 'prefetch': True, 'optimizer':...               1.4.1a2
# 3   {'epochs': 200, 'prefetch': True, 'optimizer':...               1.4.1a2
# 4   {'epochs': 200, 'prefetch': True, 'optimizer':...               1.4.1a2
# 5   {'epochs': 200, 'prefetch': True, 'optimizer':...               1.4.1a2
# 6   {'epochs': 200, 'prefetch': True, 'optimizer':...               1.4.1a2
# 7   {'epochs': 200, 'prefetch': True, 'optimizer':...               1.4.1a2
# 8   {'epochs': 200, 'prefetch': True, 'optimizer':...               1.4.1a2
# 9   {'epochs': 200, 'prefetch': True, 'optimizer':...               1.4.1a2
# 10  {'epochs': 200, 'prefetch': True, 'optimizer':...               1.4.1a2
# 11  {'epochs': 200, 'prefetch': True, 'optimizer':...               1.4.1a2
# 12  {'epochs': 200, 'prefetch': True, 'optimizer':...               1.4.1a2
# 13  {'epochs': 200, 'prefetch': True, 'optimizer':...               1.4.1a2
# 14  {'epochs': 200, 'prefetch': True, 'optimizer':...               1.4.1a2
# 15  {'epochs': 200, 'prefetch': True, 'optimizer':...               1.4.1a2
# 16  {'epochs': 200, 'prefetch': True, 'optimizer':...               1.4.1a2
# 17  {'epochs': 200, 'prefetch': True, 'optimizer':...               1.4.1a2
# 18  {'epochs': 200, 'prefetch': True, 'optimizer':...               1.4.1a2
# 19  {'epochs': 200, 'prefetch': True, 'optimizer':...               1.4.1a2
# 20  {'epochs': 200, 'prefetch': True, 'optimizer':...               1.4.1a2
# 21  {'epochs': 200, 'prefetch': True, 'optimizer':...               1.4.1a2
# 22  {'epochs': 200, 'prefetch': True, 'optimizer':...               1.4.1a2
# 23  {'epochs': 200, 'prefetch': True, 'optimizer':...               1.4.1a2
#
#    config/model.backbone.unet.max_stride
# 0                                    128
# 1                                     64
# 2                                     32
# 3                                     16
# 4                                      8
# 5                                    128
# 6                                     64
# 7                                     32
# 8                                     16
# 9                                      8
# 10                                   128
# 11                                    64
# 12                                    32
# 13                                    16
# 14                                     8
# 15                                    64
# 16                                    32
# 17                                    16
# 18                                     8
# 19                                   128
# 20                                    64
# 21                                    32
# 22                                    16
# 23                                     8
#
# [24 rows x 25 columns]

# %%
sweep_csv_path = Path(EXPERIMENT_NAME) / f"sweep_metrics_{datetime_str}.csv"
sweep_df.to_csv(sweep_csv_path, index=False)
print(f"Sweep metrics saved to {sweep_csv_path}")
# Out:
# Sweep metrics saved to 20250711_plate_arabidopsis_primary_sweep_receptive_field\sweep_metrics_2025-07-15_19-08-03.csv

# %%
# ========== SETTINGS ==========
font_settings = {
    "font.family": "sans-serif",
    "font.sans-serif": ["Arial", "DejaVu Sans"],
    "font.size": 18,
    "axes.titlesize": 24,
    "axes.labelsize": 20,
    "xtick.labelsize": 16,
    "ytick.labelsize": 16,
    "legend.fontsize": 16,
    "figure.titlesize": 26
}


plt.rcParams.update(font_settings)
sns.set_theme(style="whitegrid", font_scale=1.5)

# ========== LOAD LABEL COUNTS ==========
label_csv_path = CSV_PATH
df_labels = pd.read_csv(label_csv_path)

# Sum train + val + test labels per crop using version 0 since all versions have the same ratios of train/val/test
df_labels_v0 = df_labels[df_labels["version"] == 0]
total_labeled_per_crop = df_labels_v0["labeled_frames"].sum()

data = sweep_df.copy()

# ========== PLOTTING ==========
plt.figure(figsize=(5, 10))

# Barplot (median dist_avg)
ax = sns.barplot(
    data=sweep_df, x="config/model.backbone.unet.max_stride", y="dist_avg",
    estimator=np.median, errorbar="sd",
    palette="magma", edgecolor="black", linewidth=2
)

# Overlay raw points
sns.stripplot(
    data=sweep_df, x="config/model.backbone.unet.max_stride", y="dist_avg",
    color="black", size=6, alpha=0.7, jitter=True
)

# Title and axis labels
plt.title("Arabidopsis Primary Root in Plate Error for Varying Max Stride", pad=20)
plt.xlabel("Max Stride", labelpad=10)
plt.ylabel("Average Error (mm)", labelpad=10)

# Readability adjustments
# plt.xticks(rotation=45, ha="right")
sns.despine()
plt.grid(axis="y", linestyle="--", alpha=0.6)


# Save
plot_file_path = Path(EXPERIMENT_NAME) / f"{datetime_str}_max_stride_sweep_eval.png"
plt.savefig(plot_file_path, dpi=600, bbox_inches="tight", transparent=True)
plt.show()
print(f"Plot saved to {plot_file_path}")
# Out:
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# Plot saved to 20250711_plate_arabidopsis_primary_sweep_receptive_field\2025-07-15_19-08-03_max_stride_sweep_eval.png

# %%
# ========== SETTINGS ==========
font_settings = {
    "font.family": "sans-serif",
    "font.sans-serif": ["Arial", "DejaVu Sans"],
    "font.size": 18,
    "axes.titlesize": 24,
    "axes.labelsize": 20,
    "xtick.labelsize": 16,
    "ytick.labelsize": 16,
    "legend.fontsize": 16,
    "figure.titlesize": 26
}


plt.rcParams.update(font_settings)
sns.set_theme(style="whitegrid", font_scale=1.5)

# ========== LOAD LABEL COUNTS ==========
label_csv_path = CSV_PATH
df_labels = pd.read_csv(label_csv_path)

# Sum train + val + test labels per crop using version 0 since all versions have the same ratios of train/val/test
df_labels_v0 = df_labels[df_labels["version"] == 0]
total_labeled_per_crop = df_labels_v0["labeled_frames"].sum()

data = sweep_df.copy()

data["input_scale"] = data["config/model.backbone.unet.max_stride"]
# ========== PLOTTING ==========
plt.figure(figsize=(14, 10))

sns.pointplot(
    data=data,
    x="input_scale",
    y="dist_avg",
    hue="config/version",
    palette="Set2",
    markers="o",
    linestyles="-",
    errorbar=None
)

# sns.stripplot(
#     data=data,
#     x="input_scale",
#     y="dist_avg",
#     color="black",
#     size=10,
#     alpha=0.6,
#     jitter=False,
# )

plt.title("Arabidopsis Primary Root in Plates Error for Varying Max Stride and Version", pad=20)
plt.xlabel("Max Stride", labelpad=10)
plt.ylabel("Average Error (mm)", labelpad=10)

sns.despine()
plt.grid(axis="y", linestyle="--", alpha=0.6)
plt.legend(title="Train/Test Version")

plot_file_path = Path(EXPERIMENT_NAME) / f"{datetime_str}_max_stride_sweep_eval_version.png"
plt.savefig(plot_file_path, dpi=600, bbox_inches="tight", transparent=True)
plt.show()
print(f"Plot saved to {plot_file_path}")
# Out:
# Plot saved to 20250711_plate_arabidopsis_primary_sweep_receptive_field\2025-07-15_19-08-03_max_stride_sweep_eval_version.png

# %%
# Pivot data: rows = version, columns = parameter
pivot = sweep_df.pivot_table(
    index="config/version",
    columns="config/model.backbone.unet.max_stride",
    values="dist_avg"
)

# Apply Friedman test
stat, p = friedmanchisquare(*[pivot[col] for col in pivot.columns])

print(f"Friedman test statistic: {stat:.3f}, p-value: {p:.4f}")
if p < 0.05:
    print("Significant difference detected between parameters.")
else:
    print("No significant difference between parameters.")

from itertools import combinations
from scipy.stats import wilcoxon

scaling_pairs = combinations(pivot.columns, 2)

for a, b in scaling_pairs:
    stat, p = wilcoxon(pivot[a], pivot[b])
    print(f"{a} vs {b}: p = {p:.4f}")
# Out:
# Friedman test statistic: 10.680, p-value: 0.0136
# Significant difference detected between parameters.
# 8 vs 16: p = 0.1875
# 8 vs 32: p = 0.1250
# 8 vs 64: p = 0.0625
# 16 vs 32: p = 0.6250
# 16 vs 64: p = 0.0625
# 32 vs 64: p = 0.0625

# %%
# Determine significant pairwise differences
significant_pairs = []
for a, b in combinations(pivot.columns, 2):
    stat, p = wilcoxon(pivot[a], pivot[b])
    if p < 0.05:
        significant_pairs.append((a, b, p))
        print(f"{a} vs {b}: p = {p:.4f}")

# ========== PLOTTING ==========
plt.figure(figsize=(14, 10))

ax = sns.pointplot(
    data=data,
    x="input_scale",
    y="dist_avg",
    hue="config/version",
    palette="Set2",
    markers="o",
    linestyles="-",
    errorbar=None
)

plt.title("Arabidopsis Primary Root in Plates Error for Varying Max Stride and Version", pad=20)
plt.xlabel("Max Stride", labelpad=10)
plt.ylabel("Average Error (mm)", labelpad=10)

sns.despine()
plt.grid(axis="y", linestyle="--", alpha=0.6)
plt.legend(title="Train/Test Version")

# Annotate significance
y_max = data["dist_avg"].max()
offset = 0.02 * y_max
line_height = 0.01 * y_max

# Get sorted unique x-axis values to map max_stride to positions
x_ticks = sorted(data["input_scale"].unique())
x_tick_to_index = {val: idx for idx, val in enumerate(x_ticks)}

for idx, (a, b, p_val) in enumerate(significant_pairs):
    x1 = x_tick_to_index[a]
    x2 = x_tick_to_index[b]
    y = y_max + offset + idx * (line_height * 4)

    # Draw line
    ax.plot([x1, x1, x2, x2], [y, y+line_height, y+line_height, y], lw=1.5, c='k')
    # Draw p-value or asterisk
    annotation = "*" if p_val < 0.05 else "n.s."
    ax.text((x1 + x2) / 2, y + line_height + offset / 5, annotation, ha='center', va='bottom', fontsize=16)

plot_file_path = Path(EXPERIMENT_NAME) / f"{datetime_str}_max_stride_sweep_eval_version_sig.png"
plt.savefig(plot_file_path, dpi=600, bbox_inches="tight", transparent=True)
plt.show()
print(f"Plot saved to {plot_file_path}")
# Out:
# Plot saved to 20250711_plate_arabidopsis_primary_sweep_receptive_field\2025-07-15_19-08-03_max_stride_sweep_eval_version_sig.png

# %%
# selected_version = "000"
# model_name = f"{MODEL_GROUP}_v{selected_version}"


# visualize_predictions_from_artifacts(model_artifact_name=model_name,
#                                      test_artifact_name=model_name,
#                                      output_dir=Path(EXPERIMENT_NAME) / f"{datetime_str}_{model_name}_test_predictions",
#                                      num_frames=5,
#                                      overwrite=False,
# )

# %%
# === Initialize the W&B run ===
add_files_run = wandb.init(
    project=PROJECT_NAME,
    entity=ENTITY_NAME,
    job_type="add_files_to_artifact"
)

# === Create a new artifact ===
new_metrics_artifact = wandb.Artifact(name=ARTIFACT_NAME, type="metrics")
new_metrics_artifact.description = (
    f"Summary plots and metrics from {len(sweep_ids)} sweeps for experiment '{EXPERIMENT_NAME}'."
)
new_metrics_artifact.metadata.update({
    "source_sweep_ids": sweep_ids,
    "experiment_name": EXPERIMENT_NAME,
    "metrics": TARGET_METRICS,
    "generated_at": datetime_str,
})

# === Add plots and CSVs ===
new_metrics_artifact.add_file((Path(EXPERIMENT_NAME) / f"{datetime_str}_max_stride_sweep_eval.png").as_posix())
new_metrics_artifact.add_file((Path(EXPERIMENT_NAME) / f"{datetime_str}_max_stride_sweep_eval_version.png").as_posix())
new_metrics_artifact.add_file((Path(EXPERIMENT_NAME) / f"{datetime_str}_max_stride_sweep_eval_version_sig.png").as_posix())
new_metrics_artifact.add_file(Path(label_csv_path).as_posix())
new_metrics_artifact.add_file(Path(sweep_csv_path).as_posix())

# === Add run references (optional) ===
api = wandb.Api()
for sweep_id in sweep_ids:
    sweep = api.sweep(f"{ENTITY_NAME}/{PROJECT_NAME}/{sweep_id}")
    for run in sweep.runs:
        if run.state != "finished":
            continue
        new_metrics_artifact.add_reference(run.url)

# === Log and finish ===
add_files_run.log_artifact(new_metrics_artifact)
add_files_run.finish()
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: eberrigan (eberrigan-salk-institute-for-biological-studies). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>c:\repos\sleap-roots-training\wandb\run-20250715_190810-nx6w1zxs</code>
# Syncing run <strong><a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/nx6w1zxs' target="_blank">sweet-serenity-588</a></strong> to <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a>
#  View run at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/nx6w1zxs' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/nx6w1zxs</a>
#  View run <strong style="color:#cdcd00">sweet-serenity-588</strong> at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/nx6w1zxs' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/nx6w1zxs</a><br/> View project at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a><br/>Synced 4 W&B file(s), 0 media file(s), 12 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250715_190810-nx6w1zxs\logs</code>

# %%
# # === Initialize the W&B run ===
# add_files_run = wandb.init(
#     project=PROJECT_NAME,
#     entity=ENTITY_NAME,
#     job_type="add_files_to_artifact"
# )

# # === Use existing artifact and download its contents ===
# # metrics_artifact = add_files_run.use_artifact(f"{ARTIFACT_NAME}:latest", type="metrics")
# # artifact_dir = Path(metrics_artifact.download())
# # print(f"Artifact downloaded to: {artifact_dir}")

# # === Create a new artifact ===
# new_metrics_artifact = wandb.Artifact(name=ARTIFACT_NAME, type="metrics")

# # === Add plots ===
# new_metrics_artifact.add_file((Path(EXPERIMENT_NAME) / f"{datetime_str}_max_stride_sweep_eval.png").as_posix())
# new_metrics_artifact.add_file((Path(EXPERIMENT_NAME) / f"{datetime_str}_max_stride_sweep_eval_version.png").as_posix())

# # === Add associated CSVs ===
# new_metrics_artifact.add_file((Path(label_csv_path)).as_posix())
# new_metrics_artifact.add_file((Path(sweep_csv_path)).as_posix())

# # === Add existing artifact contents ===
# # for file_path in artifact_dir.iterdir():
# #     new_metrics_artifact.add_file(file_path)

# # === Log and finish ===
# add_files_run.log_artifact(new_metrics_artifact)
# add_files_run.finish()
