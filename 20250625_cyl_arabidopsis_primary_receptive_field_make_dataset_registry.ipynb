# %%
import wandb
import sleap_roots_training

from pathlib import Path

# %%
# Constants for W&B initialization
ENTITY_NAME = "eberrigan-salk-institute-for-biological-studies"
PROJECT_NAME = "sleap-roots"
REGISTRY = "sleap-roots-labels"
JOB_TYPE = "build_dataset"
EXPERIMENT_NAME = "20250625_cyl_arabidopsis_primary_receptive_field"

# Constants for dataset creation
ARTIFACT_NAME = "cyl_arabidopsis_7-11DAG_primary_6nodes_labels"
DESCRIPTION = "7-11 DAG arabidopsis labels for primary root with 6 nodes"
TAGS = ["cyl", "arabidopsis", "7-11DAG", "primary", "6nodes", "arabidopsis7-11DAG", "2025-06-25"]
COLLECTION_NAME = "cyl_arabidopsis_7-11DAG_primary_6nodes_labels"
DATASET_PATH = "//multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/20250625_cyl_arabidopsis_primary_receptive_field/labels_ONLYarabidopsis_primary_6nodes.v001.slp"

# %%
print(wandb.run)
# Out:
# None

# %%
sleap_roots_training.reset_config()
# Out:
# Configuration updated successfully at c:\repos\sleap-roots-training\sleap_roots_training\config.yaml.
# Configuration has been reset to default values.

# %%
sleap_roots_training.update_config(entity_name=ENTITY_NAME, project_name=PROJECT_NAME, registry=REGISTRY, job_type=JOB_TYPE, experiment_name=EXPERIMENT_NAME, collection_name=COLLECTION_NAME)
# Out:
# Configuration updated successfully at c:\repos\sleap-roots-training\sleap_roots_training\config.yaml.
# CONFIG updated to {'project_name': 'sleap-roots', 'entity_name': 'eberrigan-salk-institute-for-biological-studies', 'experiment_name': '20250625_cyl_arabidopsis_primary_receptive_field', 'registry': 'sleap-roots-labels', 'collection_name': 'cyl_arabidopsis_7-11DAG_primary_6nodes_labels', 'job_type': 'build_dataset'}.

# %%
sleap_roots_training.make_dataset_artifact(artifact_name=ARTIFACT_NAME, dataset_path=DATASET_PATH, link_to_registry=True, description=DESCRIPTION, tags=TAGS)
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: eberrigan (eberrigan-salk-institute-for-biological-studies). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>c:\repos\sleap-roots-training\wandb\run-20250625_113406-xdcno79h</code>
# Syncing run <strong><a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/xdcno79h' target="_blank">20250625_cyl_arabidopsis_primary_receptive_field</a></strong> to <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a>
#  View run at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/xdcno79h' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/xdcno79h</a>
# INFO:root:Dataset artifact created: cyl_arabidopsis_7-11DAG_primary_6nodes_labels from //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/20250625_cyl_arabidopsis_primary_receptive_field/labels_ONLYarabidopsis_primary_6nodes.v001.slp.
# INFO:root:Linking cyl_arabidopsis_7-11DAG_primary_6nodes_labels to registry eberrigan-salk-institute-for-biological-studies-org/wandb-registry-sleap-roots-labels/cyl_arabidopsis_7-11DAG_primary_6nodes_labels.
#  View run <strong style="color:#cdcd00">20250625_cyl_arabidopsis_primary_receptive_field</strong> at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/xdcno79h' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/xdcno79h</a><br/> View project at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a><br/>Synced 5 W&B file(s), 0 media file(s), 8 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250625_113406-xdcno79h\logs</code>
# INFO:root:W&B run finished successfully.
# <Artifact QXJ0aWZhY3Q6MTgzNjcxNDQ5Mg==>
