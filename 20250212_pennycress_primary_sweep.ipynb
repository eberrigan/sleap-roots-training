# %%
import wandb
import sleap_roots_training

from pathlib import Path

from sleap_roots_training.train import main

# %%
# Constants for W&B initialization
ENTITY_NAME = "eberrigan-salk-institute-for-biological-studies"
PROJECT_NAME = "sleap-roots"
REGISTRY = "sleap-roots-models"
JOB_TYPE = "sweep"
EXPERIMENT_NAME = "canola-pennycress-arabidopsis-primary-2025-01-20-hp-sweep-test-2025-02-17"

# Constants for artifact creation
DESCRIPTION = "canola pennycress and arabidopsis labels of all ages for primary root with 6 nodes with varying input scaling"
TAGS = ["canola2-13DAG", "pennycress14DAG", "arabidopsis7-11DAG", "primary", "6nodes", "canola", "pennycress", "arabidopsis", "input_scaling"]
MODEL_TAGS = ["canola2-13DAG", "pennycress14DAG", "arabidopsis7-11DAG", "primary", "6nodes", "canola", "pennycress", "arabidopsis"]
COLLECTION_NAME = EXPERIMENT_NAME
CSV_PATH = "D:/SLEAP/20250102_generalizability_experiment/primary/canola_pennycress_arabidopsis/train_test_splits.csv"

# %%
print(wandb.run)
# Out:
# None

# %%
sleap_roots_training.reset_config()
# Out:
# Configuration updated successfully at e:\repositories\sleap-roots-training\sleap_roots_training\config.yaml.
# Configuration has been reset to default values.

# %%
sleap_roots_training.update_config(entity_name=ENTITY_NAME, project_name=PROJECT_NAME, registry=REGISTRY, job_type=JOB_TYPE, experiment_name=EXPERIMENT_NAME, collection_name=COLLECTION_NAME)
# Out:
# Configuration updated successfully at e:\repositories\sleap-roots-training\sleap_roots_training\config.yaml.
# CONFIG updated to {'project_name': 'sleap-roots', 'entity_name': 'eberrigan-salk-institute-for-biological-studies', 'experiment_name': 'canola-pennycress-arabidopsis-primary-2025-01-20-hp-sweep-test-2025-02-17', 'registry': 'sleap-roots-models', 'collection_name': 'canola-pennycress-arabidopsis-primary-2025-01-20-hp-sweep-test-2025-02-17', 'job_type': 'sweep'}.

# %%
# Define the sweep configuration
sweep_config = {
    "method": "grid",
    "parameters": {
        "data.preprocessing.input_scaling": {"values": [0.5, 0.75]}
    }
}

# %%
main(csv_path=CSV_PATH, tags=TAGS, model_tags=MODEL_TAGS, use_sweep=True, sweep_config=sweep_config)
# Out:
# INFO:root:Starting main function with CSV: D:/SLEAP/20250102_generalizability_experiment/primary/canola_pennycress_arabidopsis/train_test_splits.csv
# INFO:root:Detected 3 train-test splits.
# INFO:root:Processing train-test split version: 0
# INFO:root:Creating W&B sweep for version 0...
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# Create sweep with ID: 6y11lsxw
# Sweep URL: https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/sweeps/6y11lsxw
# INFO:root:Sweep created for version 0 with ID: 6y11lsxw
# INFO:root:Running W&B grid sweep with 2 experiments for version 0...
# INFO:wandb.agents.pyagent:Starting sweep agent: entity=None, project=None, count=2
# wandb: Agent Starting Run: 0abshtln with config:
# wandb: 	data.preprocessing.input_scaling: 0.5
# INFO:root:Starting training for version 0...
# ...
