# %%
import os
import pandas as pd
import sleap
import numpy as np
import random
import re
import matplotlib.pyplot as plt

from pathlib import Path

# %% [markdown]
# # Step 1
#
# This notebook processes labeled data to extract video age information and prepare datasets for model development. It outputs a CSV file summarizing video ages, a CSV detailing train-test splits, and a bar plot visualizing the age distribution.
#
# ### User-Defined Inputs
# - **Labels Path**: Path to the input labeled data (`user_labels`), which must be specified before running the notebook.
# - **Fractions for Data Splitting**:
#   - `fraction_train`: Proportion of data to be allocated to the training set.
#   - `val_test_fraction`: Proportion of the remaining data to be allocated to the test set.
#
# ### Key Functionalities
# 1. **Extracting Video Age Information**:
#    - Extracts the age (in days) from video filenames of labeled data.
#    - Saves the results to a CSV file (`video_ages.csv`).
#    - Generates a bar plot visualizing the age distribution.
#
# 2. **Splitting Data for Training**:
#    - Divides the labeled data into training, validation, and test sets using specified fractions.
#    - Repeats the split three times, saving datasets to directories (`train.pkg.slp`, `val.pkg.slp`, `test.pkg.slp`) with associated images.
#    - Records metadata for each split, including file path, version, labeled frames, and split type, in a CSV file (`train_test_splits_info.csv`).
#
# ### Outputs
# - A CSV file (`video_ages.csv`) with video filenames and corresponding age information.
# - A CSV file (`train_test_splits_info.csv`) summarizing train-test splits.
# - A bar plot visualizing the age distribution.

# %%
# labels path
labels_path = "//multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/20250711_plate_arabidopsis_primary_sweep_receptive_field/labels_plates_arabidopsis_primary_2-7DAP_8nodes.v006.slp"

# train, val and test fractions
fraction_train = 0.7 # fraction of total user labels to be used for training
val_test_fraction = 0.5 # 1-`fraction_train` allocated for validation and testing

# Number of train-test splits
num_splits = 6

# Directory output path
output_path = "//multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/20250711_plate_arabidopsis_primary_sweep_receptive_field"

# %%
# Arabidopsis plates age extraction function
# Example filename:
# //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-093501_049.tif'
# //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/IAA_Day3/Day3Processed/day4_20230320-084958_007.tif
def extract_age(filename):
    # Get file name without extension
    path = Path(filename)
    file_name = path.stem

    # Try to extract an integer at the beginning of the filename
    if file_name.split('_')[0].isdigit():
        age = int(file_name.split('_')[0])
        print(f"Extracted age: {age} from filename: {filename}")
        return age

    # If not a digit, try to find a number preceded by "day" (case-insensitive)
    match = re.search(r'[dD]ay\s*(\d+)', file_name)
    if match:
        age = int(match.group(1))
        print(f"Extracted age from regex: {age} from filename: {filename}")
        return age

    print(f"Could not extract age from filename: {filename}")
    return None

# %%
# Function to extract the age from the filename (for younger rice)
# D:/SLEAP/SLEAP_Rice/Hydroponic/5DAG_primary/h5_files/hg-1x-r8.h5S
# D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/F22HK4M.h5
# def extract_age(filename):
#     match = re.search(r'(\d+)DAG', filename)
#     match2 = re.search(r'(\d+)_do', filename)
#     if match:
#         print(f"Extracted age: {match.group(1)} from filename: {filename}")
#         return int(match.group(1))
#     elif match2:
#         print(f"Extracted age: {match2.group(1)} from filename: {filename}")
#         return int(match2.group(1))
#     else:
#         print(f"Age not found in filename: {filename}")
#         return 'NA'

# %%
# # Function to extract the age from the filename (for sorghum, wheat datasets)
# # Day14_2-7-2025FastScanner
# def extract_age(filename):
#     match = re.search(r'Day(\d+)_', filename)
#     if match:
#         print(f"Match found: {match.group(1)}")
#         return match.group(1)
#     else:
#         print(f"Match not found for {filename}")
#         return 'NA'

# %%
# Function to extract the age from the filename (for soybean dataset)
# h5_files_blue_6_do_1.17.22
# def extract_age(filename):
#     match = re.search(r'_(\d+)_do', filename)
#     if match:
#         print(f"Match found: {match.group(1)}")
#         return match.group(1)
#     else:
#         print(f"Match not found for {filename}")
#         return 'NA'

# %%
# Function to extract the age from the filename (for canola dataset)

# 'D:/SLEAP/SLEAP_Canola_Pennycress/primary_root/h5_files_for_PR_sleap_project/9_do/33PFABDMTW.h5'
# Z:/Experiments/Canola/CYL_Canola_Diversity_Screen/Downstream_Data_Extraction_and_Analysis/4-19-23_data_v000_not_qc_not_proofread/H5_w_SLEAP_predictions_preqc_preproofread/W22/2do/HMDQXXWRSQ.h5
# D:\SLEAP\SLEAP_Canola_Pennycress\primary_root\h5_files_for_PR_sleap_project\pennycress\14_do
# def extract_age(filename):
#     match = re.search(r'(\d+)_do', filename)
#     match2 = re.search(r'(\d+)do', filename)
#     if match:
#         print(f"Match found: {match.group(1)}")
#         # Check to see if it is pennycress
#         if 'pennycress' in filename:
#             return f"pennycress_{match.group(1)}"
#         return match.group(1)
#     elif match2:
#         print(f"Match found: {match2.group(1)}")
#         return match2.group(1)
#     else:
#         print(f"Match not found for {filename}")
#         return 'NA'

# %%
# Function to extract the age from the filename (for pennycress dataset)
# D:\SLEAP\SLEAP_Canola_Pennycress\primary_root\h5_files_for_PR_sleap_project\pennycress\14_do
# D:/SLEAP/SLEAP_Canola_Pennycress/lateral_3_nodes/h5_files_for_LR_sleap_project/pennycress_round2/7P2M34R81D.h5
# def extract_age(filename):
#     match = re.search(r'(\d+)_do', filename)
#     match2 = re.search('pennycress_round2', filename)
#     if match:
#         print(f"Match found: {match.group(1)}")
#         return match.group(1)
#     elif match2:
#         print(f"Match found: {match2.group(0)}")
#         return 14
#     else:
#         print(f"Match not found for {filename}")
#         return 'NA'

# %%
# Function to extract the age from the filename (for arabidopsis dataset)
# D:/SLEAP/SLEAP_arabidopsis/h5_files_7dap_041522/1027_E_R1.h5
# D:/SLEAP/SLEAP_arabidopsis/h5_files_reorganized/11_days/DMSO/1002_1.h5
# def extract_age(filename):
#     match = re.search(r'_(\d+)dap', filename)
#     match2 = re.search(r'(\d+)_days', filename)
#     if match:
#         print(f"Match found: {match.group(1)}")
#         return match.group(1)
#     elif match2:
#         print(f"Match found: {match2.group(1)}")
#         return match2.group(1)
#     else:
#         print(f"Match not found for {filename}")
#         return 'NA'

# %%
# arabidopsis, pennycress and canola
# def extract_age(filename):
#     match_pennycress = re.search(r'pennycress', filename)
#     match_arabodopsis = re.search(r'arabidopsis', filename)
#     # match_canola1 =  re.search(r'(\d+)_do', filename)
#     # match_canola2 = re.search(r'(\d+)do', filename)
#     if match_pennycress:
#         return 'pennycress'
#     elif match_arabodopsis:
#         print(f"Match found for {filename}")
#         return 'arabidopsis'
#     else:
#         print(f"Match not found for {filename}")
#         return 'NA'

# %%
base_labels = sleap.load_file(Path(labels_path).as_posix()) # load labels file
user_labels = base_labels.with_user_labels_only() # user instances only

# %%
# Make the output directory if it doesn't exist
Path(output_path).mkdir(parents=True, exist_ok=True)

# %%
# Print the first few items to check their structure
for label in user_labels[:5]:
    print(label)
# Out:
# LabeledFrame(video=SingleImageVideo('//multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-093501_049.tif'), frame_idx=0, instances=5)
# LabeledFrame(video=SingleImageVideo('//multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-093107_046.tif'), frame_idx=0, instances=5)
# LabeledFrame(video=SingleImageVideo('//multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-091611_011.tif'), frame_idx=0, instances=5)
# LabeledFrame(video=SingleImageVideo('//multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-092321_032.tif'), frame_idx=0, instances=5)
# LabeledFrame(video=SingleImageVideo('//multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-091436_006.tif'), frame_idx=0, instances=5)

# %%
print(f"There are {len(user_labels)} labels total.")

# Variables to keep count of matches and non-matches
match_count = 0
no_match_count = 0

# Create a DataFrame from the canola labels
data = []
for label in user_labels:
    age = extract_age(label.video.filename)
    if age != 'NA':
        match_count += 1
    else:
        no_match_count += 1
    data.append({'video_filename': label.video.filename, 'days_old': age})

df = pd.DataFrame(data)

# Save the DataFrame to a CSV file
csv_file = Path(output_path) / 'video_ages.csv'
df.to_csv(csv_file, index=False)

print(f"Details saved to {csv_file}")
print(f"Number of labeled frames with age found: {match_count}")
print(f"Number of labeled frames with age not found: {no_match_count}")
# Out:
# There are 606 labels total.
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-093501_049.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-093107_046.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-091611_011.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-092321_032.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-091436_006.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-092937_033.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-091611_012.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-091436_001.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-091436_003.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-092321_028.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-092937_034.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-091611_009.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-092937_037.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-092321_026.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-093501_050.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-092321_027.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-091436_008.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-091436_005.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-091611_010.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-092152_021.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-091436_007.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-092321_030.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-092152_019.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-092321_031.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-093107_047.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-092321_029.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-092937_040.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-092321_025.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-092152_018.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-092152_017.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-092937_038.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-093107_045.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-093107_048.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-092152_022.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-091611_016.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-091436_004.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-093107_044.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-092152_024.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-092937_039.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-093107_042.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-091611_015.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-093107_043.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-091611_014.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-092152_020.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-091436_002.tif
# Extracted age: 2 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day2/Day2Processed/2_20230308-085834_023.tif
# Extracted age: 2 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day2/Day2Processed/2_20230308-092749_101.tif
# Extracted age: 2 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day2/Day2Processed/2_20230308-092918_112.tif
# Extracted age: 3 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day3/Day3Processed/3_20230309-094504_022.tif
# Extracted age: 3 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day3/Day3Processed/3_20230309-094504_023.tif
# Extracted age: 3 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day3/Day3Processed/3_20230309-094633_027.tif
# Extracted age: 3 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day3/Day3Processed/3_20230309-094633_028.tif
# Extracted age: 3 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day3/Day3Processed/3_20230309-095447_047.tif
# Extracted age: 3 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day3/Day3Processed/3_20230309-095934_061.tif
# Extracted age: 3 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day3/Day3Processed/3_20230309-100824_082.tif
# Extracted age: 3 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day3/Day3Processed/3_20230309-100824_086.tif
# Extracted age: 3 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day3/Day3Processed/3_20230309-100953_094.tif
# Extracted age: 3 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day3/Day3Processed/3_20230309-101320_098.tif
# Extracted age: 3 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day3/Day3Processed/3_20230309-101320_101.tif
# Extracted age: 3 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day3/Day3Processed/3_20230309-101449_105.tif
# Extracted age: 3 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day3/Day3Processed/3_20230309-101449_107.tif
# Extracted age: 3 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day3/Day3Processed/3_20230309-102402_133.tif
# Extracted age: 4 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day4/Day4Processed/4_20230310-093354_021.tif
# Extracted age: 4 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day4/Day4Processed/4_20230310-093354_022.tif
# Extracted age: 4 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day4/Day4Processed/4_20230310-093354_023.tif
# Extracted age: 4 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day4/Day4Processed/4_20230310-093523_025.tif
# Extracted age: 4 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day4/Day4Processed/4_20230310-093523_026.tif
# Extracted age: 4 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day4/Day4Processed/4_20230310-093523_027.tif
# Extracted age: 4 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day4/Day4Processed/4_20230310-093523_028.tif
# Extracted age: 4 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day4/Day4Processed/4_20230310-093924_035.tif
# Extracted age: 4 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day4/Day4Processed/4_20230310-094054_047.tif
# Extracted age: 4 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day4/Day4Processed/4_20230310-094550_059.tif
# Extracted age: 4 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day4/Day4Processed/4_20230310-094550_061.tif
# Extracted age: 4 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day4/Day4Processed/4_20230310-095037_069.tif
# Extracted age: 4 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day4/Day4Processed/4_20230310-095037_070.tif
# Extracted age: 4 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day4/Day4Processed/4_20230310-095521_084.tif
# Extracted age: 4 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day4/Day4Processed/4_20230310-095650_096.tif
# Extracted age: 4 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day4/Day4Processed/4_20230310-100014_100.tif
# Extracted age: 4 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day4/Day4Processed/4_20230310-100014_101.tif
# Extracted age: 4 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day4/Day4Processed/4_20230310-100144_105.tif
# Extracted age: 4 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day4/Day4Processed/4_20230310-101302_139.tif
# Extracted age: 4 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day4/Day4Processed/4_20230310-101717_146.tif
# Extracted age: 4 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day4/Day4Processed/4_20230310-101845_155.tif
# Extracted age: 5 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day5/Day5Processed/5_20230311-115053_012.tif
# Extracted age: 5 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day5/Day5Processed/5_20230311-115518_024.tif
# Extracted age: 5 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day5/Day5Processed/5_20230311-115647_025.tif
# Extracted age: 5 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day5/Day5Processed/5_20230311-115647_027.tif
# Extracted age: 5 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day5/Day5Processed/5_20230311-115647_028.tif
# Extracted age: 5 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day5/Day5Processed/5_20230311-115647_031.tif
# Extracted age: 5 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day5/Day5Processed/5_20230311-120054_033.tif
# Extracted age: 5 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day5/Day5Processed/5_20230311-120054_034.tif
# Extracted age: 5 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day5/Day5Processed/5_20230311-120223_041.tif
# Extracted age: 5 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day5/Day5Processed/5_20230311-120726_055.tif
# Extracted age: 5 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day5/Day5Processed/5_20230311-120726_056.tif
# Extracted age: 5 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day5/Day5Processed/5_20230311-120855_057.tif
# Extracted age: 5 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day5/Day5Processed/5_20230311-120855_063.tif
# Extracted age: 5 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day5/Day5Processed/5_20230311-121405_078.tif
# Extracted age: 5 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day5/Day5Processed/5_20230311-121405_080.tif
# Extracted age: 5 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day5/Day5Processed/5_20230311-121720_085.tif
# Extracted age: 5 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day5/Day5Processed/5_20230311-122319_100.tif
# Extracted age: 5 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day5/Day5Processed/5_20230311-122319_101.tif
# Extracted age: 5 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day5/Day5Processed/5_20230311-122319_102.tif
# Extracted age: 5 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day5/Day5Processed/5_20230311-122448_105.tif
# Extracted age: 5 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day5/Day5Processed/5_20230311-122448_107.tif
# Extracted age: 5 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day5/Day5Processed/5_20230311-122448_108.tif
# Extracted age: 5 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day5/Day5Processed/5_20230311-122448_111.tif
# Extracted age: 5 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day5/Day5Processed/5_20230311-122811_113.tif
# Extracted age: 5 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day5/Day5Processed/5_20230311-122940_123.tif
# Extracted age: 5 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day5/Day5Processed/5_20230311-122940_125.tif
# Extracted age: 5 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day5/Day5Processed/5_20230311-123319_129.tif
# Extracted age: 5 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day5/Day5Processed/5_20230311-123319_133.tif
# Extracted age: 5 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day5/Day5Processed/5_20230311-123449_143.tif
# Extracted age: 5 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day5/Day5Processed/5_20230311-123834_146.tif
# Extracted age: 5 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day5/Day5Processed/5_20230311-123834_150.tif
# Extracted age: 5 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day5/Day5Processed/5_20230311-124003_155.tif
# Extracted age: 5 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day5/Day5Processed/5_20230311-124003_156.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-092659_003.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-092659_004.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-092659_005.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-092834_010.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-092834_011.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-092834_012.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-092834_013.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-092834_015.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-092834_016.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-093109_017.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-093109_019.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-093109_020.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-093109_021.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-093109_022.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-093109_023.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-093109_024.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-093238_025.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-093238_026.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-093238_027.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-093238_028.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-093238_029.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-093238_030.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-093238_031.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-093238_032.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-093800_033.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-093800_034.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-093800_036.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-093800_037.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-093800_039.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-093929_041.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-093929_043.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-093929_044.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-093929_046.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-094249_052.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-094249_053.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-094419_057.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-094419_058.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-094419_059.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-094419_063.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-094419_064.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-094711_065.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-094711_066.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-094711_067.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-094711_068.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-094711_069.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-094711_071.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-094711_072.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-094840_077.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-094840_078.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-094840_079.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-094840_080.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-095238_081.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-095238_082.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-095238_083.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-095238_085.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-095238_086.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-095238_087.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-095407_091.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-095407_093.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-095407_094.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-095407_095.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-095407_096.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-095717_098.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-095717_099.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-095717_100.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-095717_101.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-095717_102.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-095717_103.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-095847_105.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-095847_107.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-095847_108.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-095847_109.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-095847_110.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-095847_111.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-095847_112.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-100251_114.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-100251_116.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-100251_117.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-100251_118.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-100251_119.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-100420_123.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-100420_124.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-100420_125.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-100420_126.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-100420_127.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-100420_128.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-100756_129.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-100756_130.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-100756_131.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-100756_132.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-100756_135.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-100925_137.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/ABA_Day7/Day7Processed/7_20230313-100925_138.tif
# ...
# Extracted age: 6 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/IAA_Day6/Day6Processed/6_20230323-092120_139.tif
# Extracted age: 6 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/IAA_Day6/Day6Processed/6_20230323-092120_141.tif
# Extracted age: 6 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/IAA_Day6/Day6Processed/6_20230323-092120_143.tif
# Extracted age: 6 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/IAA_Day6/Day6Processed/6_20230323-092120_144.tif
# Extracted age: 6 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/IAA_Day6/Day6Processed/6_20230323-092446_145.tif
# Extracted age: 6 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/IAA_Day6/Day6Processed/6_20230323-092446_146.tif
# Extracted age: 6 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/IAA_Day6/Day6Processed/6_20230323-092446_150.tif
# Extracted age: 6 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/SLEAP_models_arabidopsis_plates_20250708/SLEAP_models_arabidopsis_plates/tif_files/IAA_Day6/Day6Processed/6_20230323-092446_151.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-091436_007.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-091611_012.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-091611_015.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-091611_016.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-092152_021.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-092152_022.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-092321_025.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-092321_026.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-092321_027.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-092321_030.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-092321_031.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-092937_033.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-092937_035.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-092937_039.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-092937_040.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-093107_041.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-093107_044.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-093107_045.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-093501_051.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-093501_055.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-093630_057.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-093630_058.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-093630_059.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-093630_060.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-093630_061.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-093630_062.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-093630_063.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-093630_064.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-093910_065.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-093910_066.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-093910_067.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-093910_069.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-093910_071.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-093910_072.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-094039_073.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-094039_074.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-094358_081.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-094358_082.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-094358_083.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-094358_084.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-094358_085.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-094358_086.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-094358_087.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-094358_088.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-094527_089.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-094527_091.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-094527_093.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-094527_094.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-094527_095.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-094527_096.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-094825_098.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-094825_101.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-094825_102.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-094954_105.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-094954_106.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-094954_107.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-094954_108.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-094954_109.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-094954_110.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-094954_112.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-095259_115.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-095259_116.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-095259_117.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-095259_119.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-095259_120.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-095428_121.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-095428_122.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-095428_125.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-095810_129.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-095810_130.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-095810_131.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-095810_134.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-095940_138.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-095940_140.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-095940_141.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-095940_143.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-095940_144.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-100224_146.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-100224_149.tif
# Extracted age: 7 from filename: //multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/SLEAP_arabidopsis_plates/IAA_treated_7DAP/Day7Processed/7_20230324-100224_150.tif
# Details saved to \\multilab-na.ad.salk.edu\hpi_dev\users\eberrigan\SLEAP\20250711_plate_arabidopsis_primary_sweep_receptive_field\video_ages.csv
# Number of labeled frames with age found: 606
# Number of labeled frames with age not found: 0

# %%
# Ensure the ages are treated as integers
df['days_old'] = df['days_old'].astype(int)

# Plotting the bar graph
age_counts = df['days_old'].value_counts().sort_index()
plt.figure(figsize=(5, 6), facecolor='white') 
age_counts.plot(kind='bar', color='blue')  # Set color to blue
plt.title('Count of Ages in Labels')
plt.xlabel('Age (Days)')
plt.ylabel('Count')
plt.xticks(rotation=0)  # Rotate the x-axis labels
plt.tight_layout()  # Adjusts the plot to ensure a tight fit

# Save the figure
plot_path = Path(output_path) / 'age_distribution.png'
plt.savefig(plot_path, facecolor='white', bbox_inches='tight')
plt.show()

print(f"Plot saved to {plot_path}")
# Out:
# Plot saved to \\multilab-na.ad.salk.edu\hpi_dev\users\eberrigan\SLEAP\20250711_plate_arabidopsis_primary_sweep_receptive_field\age_distribution.png

# %%
n_train = int(fraction_train*len(user_labels))
print(f"Number of labels for training set should be {n_train}.")
n_val = int((1-fraction_train)*val_test_fraction*len(user_labels))
print(f"Number of labels for validation set should be {n_val}.")
n_test = int((1-fraction_train)*val_test_fraction*len(user_labels))
print(f"Number of labels for validation set should be {n_test}.")
# Out:
# Number of labels for training set should be 424.
# Number of labels for validation set should be 90.
# Number of labels for validation set should be 90.

# %%
# Initialize a list to store information for the CSV file
csv_data = []

for i in range(num_splits):
    # Split the training and validation sets
    labels_train, _, labels_val, _ = sleap.nn.data.training.split_labels_train_val(user_labels, 1-fraction_train) # 1-`fraction_train` allocated for validation and testing
    labels_val, _, labels_test, _ = sleap.nn.data.training.split_labels_train_val(labels_val, val_test_fraction) # `val_test_fraction` of `labels_val` made into a test set

    # Make a directory for this split
    split_dir = Path(output_path) / f"train_test_split.v00{i}"
    os.makedirs(split_dir, exist_ok=True)

    # Save the train, val and test sets
    train_path = Path(split_dir) / "train.pkg.slp"
    val_path = Path(split_dir) / "val.pkg.slp"
    test_path = Path(split_dir) / "test.pkg.slp"
    labels_train.save(train_path, with_images=True)
    labels_val.save(val_path, with_images=True)
    labels_test.save(test_path, with_images=True)

    # Store the information in the list for train, val and test splits
    csv_data.append({'path': train_path, 'version': i, 'labeled_frames': len(labels_train), 'split_type': 'train'})
    csv_data.append({'path': val_path, 'version': i, 'labeled_frames': len(labels_val), 'split_type': 'val'})
    csv_data.append({'path': test_path, 'version': i, 'labeled_frames': len(labels_test), 'split_type': 'test'})

# %%
# Convert the list to a DataFrame and save as CSV
df_new = pd.DataFrame(csv_data)
csv_path = Path(output_path) / 'train_test_splits.csv'
df_new.to_csv(csv_path, index=False)

print(f"Train, val and test splits information saved to {csv_path}")
# Out:
# Train, val and test splits information saved to \\multilab-na.ad.salk.edu\hpi_dev\users\eberrigan\SLEAP\20250711_plate_arabidopsis_primary_sweep_receptive_field\train_test_splits.csv

# %%
df_new
# Out:
#                                                  path  version  \
# 0   \\multilab-na.ad.salk.edu\hpi_dev\users\eberri...        0
# 1   \\multilab-na.ad.salk.edu\hpi_dev\users\eberri...        0
# 2   \\multilab-na.ad.salk.edu\hpi_dev\users\eberri...        0
# 3   \\multilab-na.ad.salk.edu\hpi_dev\users\eberri...        1
# 4   \\multilab-na.ad.salk.edu\hpi_dev\users\eberri...        1
# 5   \\multilab-na.ad.salk.edu\hpi_dev\users\eberri...        1
# 6   \\multilab-na.ad.salk.edu\hpi_dev\users\eberri...        2
# 7   \\multilab-na.ad.salk.edu\hpi_dev\users\eberri...        2
# 8   \\multilab-na.ad.salk.edu\hpi_dev\users\eberri...        2
# 9   \\multilab-na.ad.salk.edu\hpi_dev\users\eberri...        3
# 10  \\multilab-na.ad.salk.edu\hpi_dev\users\eberri...        3
# 11  \\multilab-na.ad.salk.edu\hpi_dev\users\eberri...        3
# 12  \\multilab-na.ad.salk.edu\hpi_dev\users\eberri...        4
# 13  \\multilab-na.ad.salk.edu\hpi_dev\users\eberri...        4
# 14  \\multilab-na.ad.salk.edu\hpi_dev\users\eberri...        4
# 15  \\multilab-na.ad.salk.edu\hpi_dev\users\eberri...        5
# 16  \\multilab-na.ad.salk.edu\hpi_dev\users\eberri...        5
# 17  \\multilab-na.ad.salk.edu\hpi_dev\users\eberri...        5
#
#     labeled_frames split_type
# 0              424      train
# 1               91        val
# 2               91       test
# 3              424      train
# 4               91        val
# 5               91       test
# 6              424      train
# 7               91        val
# 8               91       test
# 9              424      train
# 10              91        val
# 11              91       test
# 12             424      train
# 13              91        val
# 14              91       test
# 15             424      train
# 16              91        val
# 17              91       test
