# %%
import wandb
import sleap_roots_training

from pathlib import Path

from sleap_roots_training.train import main

# %%
# Constants for W&B initialization
ENTITY_NAME = "eberrigan-salk-institute-for-biological-studies"
PROJECT_NAME = "sleap-roots"
REGISTRY = "sleap-roots-models"
JOB_TYPE = "sweep"
EXPERIMENT_NAME = "20250530_younger_rice_seminal_sweep_input_scaling"

# Constants for artifact creation
DESCRIPTION = "rice 3DAG crown roots with 6 nodes with varying input scaling"
TAGS = ["rice", "3DAG", "crown", "6nodes", "rice3DAG", "input_scaling"]
MODEL_TAGS = ["rice3DAG", "crown", "6nodes", "rice"]
COLLECTION_NAME = EXPERIMENT_NAME
CSV_PATH = "D:/SLEAP/20250530_seminal_root_generalist/younger_rice/train_test_splits.csv"

# %%
print(wandb.run)
# Out:
# None

# %%
sleap_roots_training.reset_config()
# Out:
# Configuration updated successfully at e:\repositories\sleap-roots-training\sleap_roots_training\config.yaml.
# Configuration has been reset to default values.

# %%
sleap_roots_training.update_config(entity_name=ENTITY_NAME, project_name=PROJECT_NAME, registry=REGISTRY, job_type=JOB_TYPE, experiment_name=EXPERIMENT_NAME, collection_name=COLLECTION_NAME)
# Out:
# Configuration updated successfully at e:\repositories\sleap-roots-training\sleap_roots_training\config.yaml.
# CONFIG updated to {'project_name': 'sleap-roots', 'entity_name': 'eberrigan-salk-institute-for-biological-studies', 'experiment_name': '20250530_younger_rice_seminal_sweep_input_scaling', 'registry': 'sleap-roots-models', 'collection_name': '20250530_younger_rice_seminal_sweep_input_scaling', 'job_type': 'sweep'}.

# %%
# Define the sweep configuration
sweep_config = {
    "method": "grid",
    "parameters": {
        "data.preprocessing.input_scaling": {"values": [0.5, 0.75, 1.0]}
    }
}

# %%
main(csv_path=CSV_PATH, tags=TAGS, model_tags=MODEL_TAGS, use_sweep=True, sweep_config=sweep_config)
# Out:
# INFO:root:Starting main function with CSV: D:/SLEAP/20250530_seminal_root_generalist/younger_rice/train_test_splits.csv
# INFO:root:Detected 6 train-test splits.
# INFO:root:Processing train-test split version: 0
# INFO:root:Creating W&B sweep for version 0...
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# Create sweep with ID: ke5c8g0s
# Sweep URL: https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/sweeps/ke5c8g0s
# INFO:root:Sweep created for version 0 with ID: ke5c8g0s
# INFO:root:Running W&B grid sweep with 3 experiments for version 0...
# INFO:wandb.agents.pyagent:Starting sweep agent: entity=None, project=None, count=3
# wandb: Agent Starting Run: oi7z7yq3 with config:
# wandb: 	data.preprocessing.input_scaling: 0.5
# INFO:root:Starting training for version 0...
# INFO:root:Directory path for version 0: D:\SLEAP\20250530_seminal_root_generalist\younger_rice\train_test_split.v000
# wandb: Currently logged in as: eberrigan (eberrigan-salk-institute-for-biological-studies). Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# Tracking run with wandb version 0.18.6
# Run data is saved locally in <code>e:\repositories\sleap-roots-training\wandb\run-20250602_102101-oi7z7yq3</code>
# Syncing run <strong><a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/oi7z7yq3' target="_blank">20250530_younger_rice_seminal_sweep_input_scaling_training_v000</a></strong> to <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/sweeps/ke5c8g0s' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/sweeps/ke5c8g0s</a>
#  View project at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a>
#  View sweep at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/sweeps/ke5c8g0s' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/sweeps/ke5c8g0s</a>
#  View run at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/oi7z7yq3' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/oi7z7yq3</a>
# INFO:root:Updating configuration with W&B parameters.
# INFO:root:Original Parameters: {
#     "data": {
#         "labels": {
#             "training_labels": "D:\\SLEAP\\20250530_seminal_root_generalist\\younger_rice\\train_test_split.v000\\train.pkg.slp",
#             "validation_labels": "D:\\SLEAP\\20250530_seminal_root_generalist\\younger_rice\\train_test_split.v000\\val.pkg.slp",
#             "validation_fraction": 0.1,
#             "test_labels": "D:\\SLEAP\\20250530_seminal_root_generalist\\younger_rice\\train_test_split.v000\\test.pkg.slp",
#             "split_by_inds": false,
#             "training_inds": null,
#             "validation_inds": null,
#             "test_inds": null,
#             "search_path_hints": [],
#             "skeletons": []
#         },
#         "preprocessing": {
#             "ensure_rgb": false,
#             "ensure_grayscale": false,
#             "imagenet_mode": null,
#             "input_scaling": 1.0,
#             "pad_to_stride": null,
#             "resize_and_pad_to_target": true,
#             "target_height": null,
#             "target_width": null
#         },
#         "instance_cropping": {
#             "center_on_part": null,
#             "crop_size": null,
#             "crop_size_detection_padding": 16
#         }
#     },
#     "model": {
#         "backbone": {
#             "leap": null,
#             "unet": {
#                 "stem_stride": null,
#                 "max_stride": 64,
#                 "output_stride": 2,
#                 "filters": 24,
#                 "filters_rate": 1.5,
#                 "middle_block": true,
#                 "up_interpolate": true,
#                 "stacks": 1
#             },
#             "hourglass": null,
#             "resnet": null,
#             "pretrained_encoder": null
#         },
#         "heads": {
#             "single_instance": null,
#             "centroid": null,
#             "centered_instance": null,
#             "multi_instance": {
#                 "confmaps": {
#                     "part_names": null,
#                     "sigma": 2.5,
#                     "output_stride": 2,
#                     "loss_weight": 1.0,
#                     "offset_refinement": false
#                 },
#                 "pafs": {
#                     "edges": null,
#                     "sigma": 75.0,
#                     "output_stride": 8,
#                     "loss_weight": 1.0
#                 }
#             }
#         }
#     },
#     "optimization": {
#         "preload_data": true,
#         "augmentation_config": {
#             "rotate": true,
#             "rotation_min_angle": -5.0,
#             "rotation_max_angle": 5.0,
#             "translate": false,
#             "translate_min": -5,
#             "translate_max": 5,
#             "scale": true,
#             "scale_min": 0.5,
#             "scale_max": 1.2,
#             "uniform_noise": false,
#             "uniform_noise_min_val": 0.0,
#             "uniform_noise_max_val": 10.0,
#             "gaussian_noise": false,
#             "gaussian_noise_mean": 5.0,
#             "gaussian_noise_stddev": 1.0,
#             "contrast": true,
#             "contrast_min_gamma": 0.5,
#             "contrast_max_gamma": 2.0,
#             "brightness": false,
#             "brightness_min_val": 0.0,
#             "brightness_max_val": 10.0,
#             "random_crop": false,
#             "random_crop_height": 256,
#             "random_crop_width": 256,
#             "random_flip": false,
#             "flip_horizontal": true
#         },
#         "online_shuffling": true,
#         "shuffle_buffer_size": 128,
#         "prefetch": true,
#         "batch_size": 4,
#         "batches_per_epoch": null,
#         "min_batches_per_epoch": 200,
#         "val_batches_per_epoch": null,
#         "min_val_batches_per_epoch": 10,
#         "epochs": 200,
#         "optimizer": "adam",
#         "initial_learning_rate": 0.0001,
#         "learning_rate_schedule": {
#             "reduce_on_plateau": true,
#             "reduction_factor": 0.5,
#             "plateau_min_delta": 1e-06,
#             "plateau_patience": 5,
#             "plateau_cooldown": 3,
#             "min_learning_rate": 1e-08
#         },
#         "hard_keypoint_mining": {
#             "online_mining": false,
#             "hard_to_easy_ratio": 2.0,
#             "min_hard_keypoints": 2,
#             "max_hard_keypoints": null,
#             "loss_scale": 5.0
#         },
#         "early_stopping": {
#             "stop_training_on_plateau": true,
#             "plateau_min_delta": 1e-06,
#             "plateau_patience": 10
#         }
#     },
#     "outputs": {
#         "save_outputs": true,
#         "run_name": null,
#         "run_name_prefix": "",
#         "run_name_suffix": "",
#         "runs_folder": "D:\\SLEAP\\20250530_seminal_root_generalist\\younger_rice\\train_test_split.v000\\models",
#         "tags": [
#             ""
#         ],
#         "save_visualizations": false,
#         "delete_viz_images": true,
#         "zip_outputs": false,
#         "log_to_csv": true,
#         "checkpointing": {
#             "initial_model": false,
#             "best_model": true,
#             "every_epoch": false,
#             "latest_model": false,
#             "final_model": false
#         },
#         "tensorboard": {
#             "write_logs": false,
#             "loss_frequency": "epoch",
#             "architecture_graph": false,
#             "profile_graph": false,
#             "visualizations": true
#         },
#         "zmq": {
#             "subscribe_to_controller": false,
#             "controller_address": "tcp://127.0.0.1:9000",
#             "controller_polling_timeout": 10,
#             "publish_updates": false,
#             "publish_address": "tcp://127.0.0.1:9001"
#         }
#     },
#     "name": "",
#     "description": "",
#     "sleap_version": "",
#     "filename": "",
#     "data.preprocessing.input_scaling": 0.5,
#     "version": 0,
#     "config_path": "D:/SLEAP/20250530_seminal_root_generalist/younger_rice/train_test_split.v000/initial_config_modified_v000.json"
# }
# INFO:root:Updated parameter: data -> {'labels': {'training_labels': 'D:\\SLEAP\\20250530_seminal_root_generalist\\younger_rice\\train_test_split.v000\\train.pkg.slp', 'validation_labels': 'D:\\SLEAP\\20250530_seminal_root_generalist\\younger_rice\\train_test_split.v000\\val.pkg.slp', 'validation_fraction': 0.1, 'test_labels': 'D:\\SLEAP\\20250530_seminal_root_generalist\\younger_rice\\train_test_split.v000\\test.pkg.slp', 'split_by_inds': False, 'training_inds': None, 'validation_inds': None, 'test_inds': None, 'search_path_hints': [], 'skeletons': []}, 'preprocessing': {'ensure_rgb': False, 'ensure_grayscale': False, 'imagenet_mode': None, 'input_scaling': 1.0, 'pad_to_stride': None, 'resize_and_pad_to_target': True, 'target_height': None, 'target_width': None}, 'instance_cropping': {'center_on_part': None, 'crop_size': None, 'crop_size_detection_padding': 16}}
# INFO:root:Updated parameter: model -> {'backbone': {'leap': None, 'unet': {'stem_stride': None, 'max_stride': 64, 'output_stride': 2, 'filters': 24, 'filters_rate': 1.5, 'middle_block': True, 'up_interpolate': True, 'stacks': 1}, 'hourglass': None, 'resnet': None, 'pretrained_encoder': None}, 'heads': {'single_instance': None, 'centroid': None, 'centered_instance': None, 'multi_instance': {'confmaps': {'part_names': None, 'sigma': 2.5, 'output_stride': 2, 'loss_weight': 1.0, 'offset_refinement': False}, 'pafs': {'edges': None, 'sigma': 75.0, 'output_stride': 8, 'loss_weight': 1.0}}}}
# INFO:root:Updated parameter: optimization -> {'preload_data': True, 'augmentation_config': {'rotate': True, 'rotation_min_angle': -5.0, 'rotation_max_angle': 5.0, 'translate': False, 'translate_min': -5, 'translate_max': 5, 'scale': True, 'scale_min': 0.5, 'scale_max': 1.2, 'uniform_noise': False, 'uniform_noise_min_val': 0.0, 'uniform_noise_max_val': 10.0, 'gaussian_noise': False, 'gaussian_noise_mean': 5.0, 'gaussian_noise_stddev': 1.0, 'contrast': True, 'contrast_min_gamma': 0.5, 'contrast_max_gamma': 2.0, 'brightness': False, 'brightness_min_val': 0.0, 'brightness_max_val': 10.0, 'random_crop': False, 'random_crop_height': 256, 'random_crop_width': 256, 'random_flip': False, 'flip_horizontal': True}, 'online_shuffling': True, 'shuffle_buffer_size': 128, 'prefetch': True, 'batch_size': 4, 'batches_per_epoch': None, 'min_batches_per_epoch': 200, 'val_batches_per_epoch': None, 'min_val_batches_per_epoch': 10, 'epochs': 200, 'optimizer': 'adam', 'initial_learning_rate': 0.0001, 'learning_rate_schedule': {'reduce_on_plateau': True, 'reduction_factor': 0.5, 'plateau_min_delta': 1e-06, 'plateau_patience': 5, 'plateau_cooldown': 3, 'min_learning_rate': 1e-08}, 'hard_keypoint_mining': {'online_mining': False, 'hard_to_easy_ratio': 2.0, 'min_hard_keypoints': 2, 'max_hard_keypoints': None, 'loss_scale': 5.0}, 'early_stopping': {'stop_training_on_plateau': True, 'plateau_min_delta': 1e-06, 'plateau_patience': 10}}
# INFO:root:Updated parameter: outputs -> {'save_outputs': True, 'run_name': None, 'run_name_prefix': '', 'run_name_suffix': '', 'runs_folder': 'D:\\SLEAP\\20250530_seminal_root_generalist\\younger_rice\\train_test_split.v000\\models', 'tags': [''], 'save_visualizations': False, 'delete_viz_images': True, 'zip_outputs': False, 'log_to_csv': True, 'checkpointing': {'initial_model': False, 'best_model': True, 'every_epoch': False, 'latest_model': False, 'final_model': False}, 'tensorboard': {'write_logs': False, 'loss_frequency': 'epoch', 'architecture_graph': False, 'profile_graph': False, 'visualizations': True}, 'zmq': {'subscribe_to_controller': False, 'controller_address': 'tcp://127.0.0.1:9000', 'controller_polling_timeout': 10, 'publish_updates': False, 'publish_address': 'tcp://127.0.0.1:9001'}}
# INFO:root:Updated parameter: name ->
# INFO:root:Updated parameter: description ->
# INFO:root:Updated parameter: sleap_version ->
# INFO:root:Updated parameter: filename ->
# INFO:root:Updated parameter: data.preprocessing.input_scaling -> 0.5
# INFO:root:Updated parameter: version -> 0
# INFO:root:Updated parameter: config_path -> D:/SLEAP/20250530_seminal_root_generalist/younger_rice/train_test_split.v000/initial_config_modified_v000.json
# INFO:root:Final updated configuration:
# {
#     "data": {
#         "labels": {
#             "training_labels": "D:\\SLEAP\\20250530_seminal_root_generalist\\younger_rice\\train_test_split.v000\\train.pkg.slp",
#             "validation_labels": "D:\\SLEAP\\20250530_seminal_root_generalist\\younger_rice\\train_test_split.v000\\val.pkg.slp",
#             "validation_fraction": 0.1,
#             "test_labels": "D:\\SLEAP\\20250530_seminal_root_generalist\\younger_rice\\train_test_split.v000\\test.pkg.slp",
#             "split_by_inds": false,
#             "training_inds": null,
#             "validation_inds": null,
#             "test_inds": null,
#             "search_path_hints": [],
#             "skeletons": []
#         },
#         "preprocessing": {
#             "ensure_rgb": false,
#             "ensure_grayscale": false,
#             "imagenet_mode": null,
#             "input_scaling": 0.5,
#             "pad_to_stride": null,
#             "resize_and_pad_to_target": true,
#             "target_height": null,
#             "target_width": null
#         },
#         "instance_cropping": {
#             "center_on_part": null,
#             "crop_size": null,
#             "crop_size_detection_padding": 16
#         }
#     },
#     "model": {
#         "backbone": {
#             "leap": null,
#             "unet": {
#                 "stem_stride": null,
#                 "max_stride": 64,
#                 "output_stride": 2,
#                 "filters": 24,
#                 "filters_rate": 1.5,
#                 "middle_block": true,
#                 "up_interpolate": true,
#                 "stacks": 1
#             },
#             "hourglass": null,
#             "resnet": null,
#             "pretrained_encoder": null
#         },
#         "heads": {
#             "single_instance": null,
#             "centroid": null,
#             "centered_instance": null,
#             "multi_instance": {
#                 "confmaps": {
#                     "part_names": null,
#                     "sigma": 2.5,
#                     "output_stride": 2,
#                     "loss_weight": 1.0,
#                     "offset_refinement": false
#                 },
#                 "pafs": {
#                     "edges": null,
#                     "sigma": 75.0,
#                     "output_stride": 8,
#                     "loss_weight": 1.0
#                 }
#             }
#         }
#     },
#     "optimization": {
#         "preload_data": true,
#         "augmentation_config": {
#             "rotate": true,
#             "rotation_min_angle": -5.0,
#             "rotation_max_angle": 5.0,
#             "translate": false,
#             "translate_min": -5,
#             "translate_max": 5,
#             "scale": true,
#             "scale_min": 0.5,
#             "scale_max": 1.2,
#             "uniform_noise": false,
#             "uniform_noise_min_val": 0.0,
#             "uniform_noise_max_val": 10.0,
#             "gaussian_noise": false,
#             "gaussian_noise_mean": 5.0,
#             "gaussian_noise_stddev": 1.0,
#             "contrast": true,
#             "contrast_min_gamma": 0.5,
#             "contrast_max_gamma": 2.0,
#             "brightness": false,
#             "brightness_min_val": 0.0,
#             "brightness_max_val": 10.0,
#             "random_crop": false,
#             "random_crop_height": 256,
#             "random_crop_width": 256,
#             "random_flip": false,
#             "flip_horizontal": true
#         },
#         "online_shuffling": true,
#         "shuffle_buffer_size": 128,
#         "prefetch": true,
#         "batch_size": 4,
#         "batches_per_epoch": null,
#         "min_batches_per_epoch": 200,
#         "val_batches_per_epoch": null,
#         "min_val_batches_per_epoch": 10,
#         "epochs": 200,
#         "optimizer": "adam",
#         "initial_learning_rate": 0.0001,
#         "learning_rate_schedule": {
#             "reduce_on_plateau": true,
#             "reduction_factor": 0.5,
#             "plateau_min_delta": 1e-06,
#             "plateau_patience": 5,
#             "plateau_cooldown": 3,
#             "min_learning_rate": 1e-08
#         },
#         "hard_keypoint_mining": {
#             "online_mining": false,
#             "hard_to_easy_ratio": 2.0,
#             "min_hard_keypoints": 2,
#             "max_hard_keypoints": null,
#             "loss_scale": 5.0
#         },
#         "early_stopping": {
#             "stop_training_on_plateau": true,
#             "plateau_min_delta": 1e-06,
#             "plateau_patience": 10
#         }
#     },
#     "outputs": {
#         "save_outputs": true,
#         "run_name": null,
#         "run_name_prefix": "",
#         "run_name_suffix": "",
#         "runs_folder": "D:\\SLEAP\\20250530_seminal_root_generalist\\younger_rice\\train_test_split.v000\\models",
#         "tags": [
#             ""
#         ],
#         "save_visualizations": false,
#         "delete_viz_images": true,
#         "zip_outputs": false,
#         "log_to_csv": true,
#         "checkpointing": {
#             "initial_model": false,
#             "best_model": true,
#             "every_epoch": false,
#             "latest_model": false,
#             "final_model": false
#         },
#         "tensorboard": {
#             "write_logs": false,
#             "loss_frequency": "epoch",
#             "architecture_graph": false,
#             "profile_graph": false,
#             "visualizations": true
#         },
#         "zmq": {
#             "subscribe_to_controller": false,
#             "controller_address": "tcp://127.0.0.1:9000",
#             "controller_polling_timeout": 10,
#             "publish_updates": false,
#             "publish_address": "tcp://127.0.0.1:9001"
#         }
#     },
#     "name": "",
#     "description": "",
#     "sleap_version": "",
#     "filename": "",
#     "version": 0,
#     "config_path": "D:/SLEAP/20250530_seminal_root_generalist/younger_rice/train_test_split.v000/initial_config_modified_v000.json"
# }
# INFO:root:Saved updated configuration to: D:\SLEAP\20250530_seminal_root_generalist\younger_rice\train_test_split.v000\modified_config_v000_20250602_102102.json
# INFO:root:Training with updated config for version 0.
# INFO:root:Executing training command: sleap-train D:/SLEAP/20250530_seminal_root_generalist/younger_rice/train_test_split.v000/modified_config_v000_20250602_102102.json
# Executing: sleap-train D:/SLEAP/20250530_seminal_root_generalist/younger_rice/train_test_split.v000/modified_config_v000_20250602_102102.json
# INFO:sleap.nn.training:Versions:
# SLEAP: 1.3.4
# TensorFlow: 2.7.0
# Numpy: 1.21.6
# Python: 3.7.12
# OS: Windows-10-10.0.26100-SP0
# INFO:sleap.nn.training:Training labels file: None
# INFO:sleap.nn.training:Training profile: D:/SLEAP/20250530_seminal_root_generalist/younger_rice/train_test_split.v000/modified_config_v000_20250602_102102.json
# INFO:sleap.nn.training:
# INFO:sleap.nn.training:Arguments:
# INFO:sleap.nn.training:{
#     "training_job_path": "D:/SLEAP/20250530_seminal_root_generalist/younger_rice/train_test_split.v000/modified_config_v000_20250602_102102.json",
#     "labels_path": null,
#     "video_paths": [
#         ""
#     ],
#     "val_labels": null,
#     "test_labels": null,
#     "base_checkpoint": null,
#     "tensorboard": false,
#     "save_viz": false,
#     "zmq": false,
#     "run_name": "",
#     "prefix": "",
#     "suffix": "",
#     "cpu": false,
#     "first_gpu": false,
#     "last_gpu": false,
#     "gpu": "auto"
# }
# INFO:sleap.nn.training:
# INFO:sleap.nn.training:Training job:
# INFO:sleap.nn.training:{
#     "data": {
#         "labels": {
#             "training_labels": "D:\\SLEAP\\20250530_seminal_root_generalist\\younger_rice\\train_test_split.v000\\train.pkg.slp",
#             "validation_labels": "D:\\SLEAP\\20250530_seminal_root_generalist\\younger_rice\\train_test_split.v000\\val.pkg.slp",
#             "validation_fraction": 0.1,
#             "test_labels": "D:\\SLEAP\\20250530_seminal_root_generalist\\younger_rice\\train_test_split.v000\\test.pkg.slp",
#             "split_by_inds": false,
#             "training_inds": null,
#             "validation_inds": null,
#             "test_inds": null,
#             "search_path_hints": [],
#             "skeletons": []
#         },
#         "preprocessing": {
#             "ensure_rgb": false,
#             "ensure_grayscale": false,
#             "imagenet_mode": null,
#             "input_scaling": 0.5,
#             "pad_to_stride": null,
#             "resize_and_pad_to_target": true,
#             "target_height": null,
#             "target_width": null
#         },
#         "instance_cropping": {
#             "center_on_part": null,
#             "crop_size": null,
#             "crop_size_detection_padding": 16
#         }
#     },
#     "model": {
#         "backbone": {
#             "leap": null,
#             "unet": {
#                 "stem_stride": null,
#                 "max_stride": 64,
#                 "output_stride": 2,
#                 "filters": 24,
#                 "filters_rate": 1.5,
#                 "middle_block": true,
#                 "up_interpolate": true,
#                 "stacks": 1
#             },
#             "hourglass": null,
#             "resnet": null,
#             "pretrained_encoder": null
#         },
#         "heads": {
#             "single_instance": null,
#             "centroid": null,
#             "centered_instance": null,
#             "multi_instance": {
#                 "confmaps": {
#                     "part_names": null,
#                     "sigma": 2.5,
#                     "output_stride": 2,
#                     "loss_weight": 1.0,
#                     "offset_refinement": false
#                 },
#                 "pafs": {
#                     "edges": null,
#                     "sigma": 75.0,
#                     "output_stride": 8,
#                     "loss_weight": 1.0
#                 }
#             },
#             "multi_class_bottomup": null,
#             "multi_class_topdown": null
#         },
#         "base_checkpoint": null
#     },
#     "optimization": {
#         "preload_data": true,
#         "augmentation_config": {
#             "rotate": true,
#             "rotation_min_angle": -5.0,
#             "rotation_max_angle": 5.0,
#             "translate": false,
#             "translate_min": -5,
#             "translate_max": 5,
#             "scale": true,
#             "scale_min": 0.5,
#             "scale_max": 1.2,
#             "uniform_noise": false,
#             "uniform_noise_min_val": 0.0,
#             "uniform_noise_max_val": 10.0,
#             "gaussian_noise": false,
#             "gaussian_noise_mean": 5.0,
#             "gaussian_noise_stddev": 1.0,
#             "contrast": true,
#             "contrast_min_gamma": 0.5,
#             "contrast_max_gamma": 2.0,
#             "brightness": false,
#             "brightness_min_val": 0.0,
#             "brightness_max_val": 10.0,
#             "random_crop": false,
#             "random_crop_height": 256,
#             "random_crop_width": 256,
#             "random_flip": false,
#             "flip_horizontal": true
#         },
#         "online_shuffling": true,
#         "shuffle_buffer_size": 128,
#         "prefetch": true,
#         "batch_size": 4,
#         "batches_per_epoch": null,
#         "min_batches_per_epoch": 200,
#         "val_batches_per_epoch": null,
#         "min_val_batches_per_epoch": 10,
#         "epochs": 200,
#         "optimizer": "adam",
#         "initial_learning_rate": 0.0001,
#         "learning_rate_schedule": {
#             "reduce_on_plateau": true,
#             "reduction_factor": 0.5,
#             "plateau_min_delta": 1e-06,
#             "plateau_patience": 5,
#             "plateau_cooldown": 3,
#             "min_learning_rate": 1e-08
#         },
#         "hard_keypoint_mining": {
#             "online_mining": false,
#             "hard_to_easy_ratio": 2.0,
#             "min_hard_keypoints": 2,
#             "max_hard_keypoints": null,
#             "loss_scale": 5.0
#         },
#         "early_stopping": {
#             "stop_training_on_plateau": true,
#             "plateau_min_delta": 1e-06,
#             "plateau_patience": 10
#         }
#     },
#     "outputs": {
#         "save_outputs": true,
#         "run_name": null,
#         "run_name_prefix": "",
#         "run_name_suffix": "",
#         "runs_folder": "D:\\SLEAP\\20250530_seminal_root_generalist\\younger_rice\\train_test_split.v000\\models",
#         "tags": [
#             ""
#         ],
#         "save_visualizations": false,
#         "delete_viz_images": true,
#         "zip_outputs": false,
#         "log_to_csv": true,
#         "checkpointing": {
#             "initial_model": false,
#             "best_model": true,
#             "every_epoch": false,
#             "latest_model": false,
#             "final_model": false
#         },
#         "tensorboard": {
#             "write_logs": false,
#             "loss_frequency": "epoch",
#             "architecture_graph": false,
#             "profile_graph": false,
#             "visualizations": true
#         },
#         "zmq": {
#             "subscribe_to_controller": false,
#             "controller_address": "tcp://127.0.0.1:9000",
#             "controller_polling_timeout": 10,
#             "publish_updates": false,
#             "publish_address": "tcp://127.0.0.1:9001"
#         }
#     },
#     "name": "",
#     "description": "",
#     "sleap_version": "",
#     "filename": "D:/SLEAP/20250530_seminal_root_generalist/younger_rice/train_test_split.v000/modified_config_v000_20250602_102102.json"
# }
# INFO:sleap.nn.training:
# INFO:sleap.nn.training:Auto-selected GPU 0 with 22952 MiB of free memory.
# INFO:sleap.nn.training:Using GPU 0 for acceleration.
# INFO:sleap.nn.training:Disabled GPU memory pre-allocation.
# INFO:sleap.nn.training:System:
# GPUs: 1/1 available
#   Device: /physical_device:GPU:0
#          Available: True
#         Initalized: False
#      Memory growth: True
# INFO:sleap.nn.training:
# INFO:sleap.nn.training:Initializing trainer...
# INFO:sleap.nn.training:Loading training labels from: D:\SLEAP\20250530_seminal_root_generalist\younger_rice\train_test_split.v000\train.pkg.slp
# INFO:sleap.nn.training:Loading validation labels from: D:\SLEAP\20250530_seminal_root_generalist\younger_rice\train_test_split.v000\val.pkg.slp
# INFO:sleap.nn.training:Loading test labels from: D:\SLEAP\20250530_seminal_root_generalist\younger_rice\train_test_split.v000\test.pkg.slp
# INFO:sleap.nn.training:Setting up for training...
# INFO:sleap.nn.training:Setting up pipeline builders...
# INFO:sleap.nn.training:Setting up model...
# INFO:sleap.nn.training:Building test pipeline...
# INFO:sleap.nn.training:Loaded test example. [2.140s]
# INFO:sleap.nn.training:  Input shape: (576, 1024, 1)
# INFO:sleap.nn.training:Created Keras model.
# INFO:sleap.nn.training:  Backbone: UNet(stacks=1, filters=24, filters_rate=1.5, kernel_size=3, stem_kernel_size=7, convs_per_block=2, stem_blocks=0, down_blocks=6, middle_block=True, up_blocks=5, up_interpolate=True, block_contraction=False)
# INFO:sleap.nn.training:  Max stride: 64
# INFO:sleap.nn.training:  Parameters: 3,848,881
# INFO:sleap.nn.training:  Heads:
# INFO:sleap.nn.training:    [0] = MultiInstanceConfmapsHead(part_names=['r1', 'r2', 'r3', 'r4', 'r5', 'r6'], sigma=2.5, output_stride=2, loss_weight=1.0)
# INFO:sleap.nn.training:    [1] = PartAffinityFieldsHead(edges=[('r1', 'r2'), ('r2', 'r3'), ('r3', 'r4'), ('r4', 'r5'), ('r5', 'r6')], sigma=75.0, output_stride=8, loss_weight=1.0)
# INFO:sleap.nn.training:  Outputs:
# INFO:sleap.nn.training:    [0] = KerasTensor(type_spec=TensorSpec(shape=(None, 288, 512, 6), dtype=tf.float32, name=None), name='MultiInstanceConfmapsHead/BiasAdd:0', description="created by layer 'MultiInstanceConfmapsHead'")
# INFO:sleap.nn.training:    [1] = KerasTensor(type_spec=TensorSpec(shape=(None, 72, 128, 10), dtype=tf.float32, name=None), name='PartAffinityFieldsHead/BiasAdd:0', description="created by layer 'PartAffinityFieldsHead'")
# INFO:sleap.nn.training:Training from scratch
# INFO:sleap.nn.training:Setting up data pipelines...
# INFO:sleap.nn.training:Training set: n = 608
# INFO:sleap.nn.training:Validation set: n = 130
# INFO:sleap.nn.training:Setting up optimization...
# INFO:sleap.nn.training:  Learning rate schedule: LearningRateScheduleConfig(reduce_on_plateau=True, reduction_factor=0.5, plateau_min_delta=1e-06, plateau_patience=5, plateau_cooldown=3, min_learning_rate=1e-08)
# INFO:sleap.nn.training:  Early stopping: EarlyStoppingConfig(stop_training_on_plateau=True, plateau_min_delta=1e-06, plateau_patience=10)
# INFO:sleap.nn.training:Setting up outputs...
# INFO:sleap.nn.training:Created run path: D:\SLEAP\20250530_seminal_root_generalist\younger_rice\train_test_split.v000\models\250602_102111.multi_instance.n=738
# INFO:sleap.nn.training:Setting up visualization...
# INFO:sleap.nn.training:Finished trainer set up. [5.4s]
# INFO:sleap.nn.training:Creating tf.data.Datasets for training data generation...
# INFO:sleap.nn.training:Finished creating training datasets. [13.8s]
# INFO:sleap.nn.training:Starting training loop...
# Epoch 1/200
# 200/200 - 41s - loss: 0.0019 - MultiInstanceConfmapsHead_loss: 3.3447e-04 - PartAffinityFieldsHead_loss: 0.0016 - val_loss: 0.0017 - val_MultiInstanceConfmapsHead_loss: 3.4120e-04 - val_PartAffinityFieldsHead_loss: 0.0014 - lr: 1.0000e-04 - 41s/epoch - 207ms/step
# Epoch 2/200
# 200/200 - 32s - loss: 0.0013 - MultiInstanceConfmapsHead_loss: 2.7690e-04 - PartAffinityFieldsHead_loss: 0.0010 - val_loss: 0.0011 - val_MultiInstanceConfmapsHead_loss: 2.7126e-04 - val_PartAffinityFieldsHead_loss: 8.7615e-04 - lr: 1.0000e-04 - 32s/epoch - 162ms/step
# Epoch 3/200
# 200/200 - 33s - loss: 9.7593e-04 - MultiInstanceConfmapsHead_loss: 2.4074e-04 - PartAffinityFieldsHead_loss: 7.3518e-04 - val_loss: 8.6479e-04 - val_MultiInstanceConfmapsHead_loss: 2.3314e-04 - val_PartAffinityFieldsHead_loss: 6.3165e-04 - lr: 1.0000e-04 - 33s/epoch - 166ms/step
# Epoch 4/200
# 200/200 - 32s - loss: 8.0682e-04 - MultiInstanceConfmapsHead_loss: 2.0913e-04 - PartAffinityFieldsHead_loss: 5.9769e-04 - val_loss: 7.7703e-04 - val_MultiInstanceConfmapsHead_loss: 2.0595e-04 - val_PartAffinityFieldsHead_loss: 5.7107e-04 - lr: 1.0000e-04 - 32s/epoch - 159ms/step
# Epoch 5/200
# 200/200 - 32s - loss: 6.9324e-04 - MultiInstanceConfmapsHead_loss: 1.8594e-04 - PartAffinityFieldsHead_loss: 5.0730e-04 - val_loss: 6.6349e-04 - val_MultiInstanceConfmapsHead_loss: 1.8072e-04 - val_PartAffinityFieldsHead_loss: 4.8277e-04 - lr: 1.0000e-04 - 32s/epoch - 162ms/step
# Epoch 6/200
# 200/200 - 32s - loss: 6.2924e-04 - MultiInstanceConfmapsHead_loss: 1.7222e-04 - PartAffinityFieldsHead_loss: 4.5702e-04 - val_loss: 6.2299e-04 - val_MultiInstanceConfmapsHead_loss: 1.7087e-04 - val_PartAffinityFieldsHead_loss: 4.5212e-04 - lr: 1.0000e-04 - 32s/epoch - 159ms/step
# Epoch 7/200
# 200/200 - 32s - loss: 6.0713e-04 - MultiInstanceConfmapsHead_loss: 1.6465e-04 - PartAffinityFieldsHead_loss: 4.4248e-04 - val_loss: 6.1251e-04 - val_MultiInstanceConfmapsHead_loss: 1.6613e-04 - val_PartAffinityFieldsHead_loss: 4.4638e-04 - lr: 1.0000e-04 - 32s/epoch - 162ms/step
# Epoch 8/200
# 200/200 - 31s - loss: 5.7296e-04 - MultiInstanceConfmapsHead_loss: 1.5812e-04 - PartAffinityFieldsHead_loss: 4.1484e-04 - val_loss: 6.1826e-04 - val_MultiInstanceConfmapsHead_loss: 1.7195e-04 - val_PartAffinityFieldsHead_loss: 4.4631e-04 - lr: 1.0000e-04 - 31s/epoch - 154ms/step
# Epoch 9/200
# 200/200 - 32s - loss: 5.4537e-04 - MultiInstanceConfmapsHead_loss: 1.5153e-04 - PartAffinityFieldsHead_loss: 3.9384e-04 - val_loss: 6.0079e-04 - val_MultiInstanceConfmapsHead_loss: 1.6663e-04 - val_PartAffinityFieldsHead_loss: 4.3416e-04 - lr: 1.0000e-04 - 32s/epoch - 161ms/step
# Epoch 10/200
# 200/200 - 30s - loss: 4.1222e-04 - MultiInstanceConfmapsHead_loss: 1.1836e-04 - PartAffinityFieldsHead_loss: 2.9385e-04 - val_loss: 4.6809e-04 - val_MultiInstanceConfmapsHead_loss: 1.3290e-04 - val_PartAffinityFieldsHead_loss: 3.3518e-04 - lr: 1.0000e-04 - 30s/epoch - 152ms/step
# Epoch 19/200
# 200/200 - 31s - loss: 4.0352e-04 - MultiInstanceConfmapsHead_loss: 1.1604e-04 - PartAffinityFieldsHead_loss: 2.8748e-04 - val_loss: 4.9212e-04 - val_MultiInstanceConfmapsHead_loss: 1.3680e-04 - val_PartAffinityFieldsHead_loss: 3.5532e-04 - lr: 1.0000e-04 - 31s/epoch - 157ms/step
# Epoch 20/200
# 200/200 - 32s - loss: 4.1819e-04 - MultiInstanceConfmapsHead_loss: 1.1830e-04 - PartAffinityFieldsHead_loss: 2.9990e-04 - val_loss: 4.5317e-04 - val_MultiInstanceConfmapsHead_loss: 1.3023e-04 - val_PartAffinityFieldsHead_loss: 3.2293e-04 - lr: 1.0000e-04 - 32s/epoch - 158ms/step
# Epoch 21/200
# 200/200 - 30s - loss: 3.9777e-04 - MultiInstanceConfmapsHead_loss: 1.1402e-04 - PartAffinityFieldsHead_loss: 2.8375e-04 - val_loss: 4.5198e-04 - val_MultiInstanceConfmapsHead_loss: 1.3043e-04 - val_PartAffinityFieldsHead_loss: 3.2154e-04 - lr: 1.0000e-04 - 30s/epoch - 152ms/step
# Epoch 22/200
# 200/200 - 32s - loss: 3.9593e-04 - MultiInstanceConfmapsHead_loss: 1.1322e-04 - PartAffinityFieldsHead_loss: 2.8271e-04 - val_loss: 4.2831e-04 - val_MultiInstanceConfmapsHead_loss: 1.2125e-04 - val_PartAffinityFieldsHead_loss: 3.0706e-04 - lr: 1.0000e-04 - 32s/epoch - 159ms/step
# Epoch 23/200
# 200/200 - 30s - loss: 3.7047e-04 - MultiInstanceConfmapsHead_loss: 1.0657e-04 - PartAffinityFieldsHead_loss: 2.6390e-04 - val_loss: 4.5204e-04 - val_MultiInstanceConfmapsHead_loss: 1.2947e-04 - val_PartAffinityFieldsHead_loss: 3.2256e-04 - lr: 1.0000e-04 - 30s/epoch - 152ms/step
# Epoch 24/200
# 200/200 - 31s - loss: 3.8371e-04 - MultiInstanceConfmapsHead_loss: 1.0864e-04 - PartAffinityFieldsHead_loss: 2.7506e-04 - val_loss: 4.7664e-04 - val_MultiInstanceConfmapsHead_loss: 1.3438e-04 - val_PartAffinityFieldsHead_loss: 3.4226e-04 - lr: 1.0000e-04 - 31s/epoch - 154ms/step
# Epoch 25/200
# 200/200 - 30s - loss: 3.6353e-04 - MultiInstanceConfmapsHead_loss: 1.0501e-04 - PartAffinityFieldsHead_loss: 2.5851e-04 - val_loss: 4.3681e-04 - val_MultiInstanceConfmapsHead_loss: 1.2333e-04 - val_PartAffinityFieldsHead_loss: 3.1348e-04 - lr: 1.0000e-04 - 30s/epoch - 151ms/step
# Epoch 26/200
# 200/200 - 32s - loss: 3.7185e-04 - MultiInstanceConfmapsHead_loss: 1.0770e-04 - PartAffinityFieldsHead_loss: 2.6414e-04 - val_loss: 4.4256e-04 - val_MultiInstanceConfmapsHead_loss: 1.2555e-04 - val_PartAffinityFieldsHead_loss: 3.1701e-04 - lr: 1.0000e-04 - 32s/epoch - 158ms/step
# Epoch 27/200
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 58/200
# 200/200 - 30s - loss: 2.5752e-04 - MultiInstanceConfmapsHead_loss: 7.4656e-05 - PartAffinityFieldsHead_loss: 1.8286e-04 - val_loss: 3.6610e-04 - val_MultiInstanceConfmapsHead_loss: 1.0710e-04 - val_PartAffinityFieldsHead_loss: 2.5900e-04 - lr: 1.2500e-05 - 30s/epoch - 152ms/step
# Epoch 00058: early stopping
# INFO:sleap.nn.training:Finished training loop. [30.4 min]
# INFO:sleap.nn.training:Saving evaluation metrics to model folder...
# Predicting... -------------------------------------- 100% ETA: 0:00:00 47.6 FPS
# INFO:sleap.nn.evals:Saved predictions: D:\SLEAP\20250530_seminal_root_generalist\younger_rice\train_test_split.v000\models\250602_102111.multi_instance.n=738\labels_pr.train.slp
# INFO:sleap.nn.evals:Saved metrics: D:\SLEAP\20250530_seminal_root_generalist\younger_rice\train_test_split.v000\models\250602_102111.multi_instance.n=738\metrics.train.npz
# INFO:sleap.nn.evals:OKS mAP: 0.116882
# Predicting... -------------------------------------- 100% ETA: 0:00:00 23.8 FPS
# INFO:sleap.nn.evals:Saved predictions: D:\SLEAP\20250530_seminal_root_generalist\younger_rice\train_test_split.v000\models\250602_102111.multi_instance.n=738\labels_pr.val.slp
# INFO:sleap.nn.evals:Saved metrics: D:\SLEAP\20250530_seminal_root_generalist\younger_rice\train_test_split.v000\models\250602_102111.multi_instance.n=738\metrics.val.npz
# INFO:sleap.nn.evals:OKS mAP: 0.042720
# Predicting... -------------------------------------- 100% ETA: 0:00:00 26.5 FPS
# INFO:sleap.nn.evals:Saved predictions: D:\SLEAP\20250530_seminal_root_generalist\younger_rice\train_test_split.v000\models\250602_102111.multi_instance.n=738\labels_pr.test.slp
# INFO:sleap.nn.evals:Saved metrics: D:\SLEAP\20250530_seminal_root_generalist\younger_rice\train_test_split.v000\models\250602_102111.multi_instance.n=738\metrics.test.npz
# INFO:sleap.nn.evals:OKS mAP: 0.047450
#
# ...
# 200/200 - 90s - loss: 2.0104e-04 - MultiInstanceConfmapsHead_loss: 4.6848e-05 - PartAffinityFieldsHead_loss: 1.5420e-04 - val_loss: 2.3704e-04 - val_MultiInstanceConfmapsHead_loss: 5.2327e-05 - val_PartAffinityFieldsHead_loss: 1.8471e-04 - lr: 1.0000e-04 - 90s/epoch - 451ms/step
# Epoch 25/200
# 200/200 - 91s - loss: 1.9825e-04 - MultiInstanceConfmapsHead_loss: 4.6506e-05 - PartAffinityFieldsHead_loss: 1.5174e-04 - val_loss: 2.2414e-04 - val_MultiInstanceConfmapsHead_loss: 5.1766e-05 - val_PartAffinityFieldsHead_loss: 1.7237e-04 - lr: 1.0000e-04 - 91s/epoch - 453ms/step
# Epoch 26/200
# 200/200 - 90s - loss: 1.9379e-04 - MultiInstanceConfmapsHead_loss: 4.5681e-05 - PartAffinityFieldsHead_loss: 1.4811e-04 - val_loss: 2.3881e-04 - val_MultiInstanceConfmapsHead_loss: 5.2700e-05 - val_PartAffinityFieldsHead_loss: 1.8611e-04 - lr: 1.0000e-04 - 90s/epoch - 449ms/step
# Epoch 27/200
# 200/200 - 89s - loss: 1.9654e-04 - MultiInstanceConfmapsHead_loss: 4.6346e-05 - PartAffinityFieldsHead_loss: 1.5020e-04 - val_loss: 2.2426e-04 - val_MultiInstanceConfmapsHead_loss: 5.0995e-05 - val_PartAffinityFieldsHead_loss: 1.7326e-04 - lr: 1.0000e-04 - 89s/epoch - 445ms/step
# Epoch 28/200
# 200/200 - 91s - loss: 1.9387e-04 - MultiInstanceConfmapsHead_loss: 4.5799e-05 - PartAffinityFieldsHead_loss: 1.4808e-04 - val_loss: 2.2737e-04 - val_MultiInstanceConfmapsHead_loss: 5.1984e-05 - val_PartAffinityFieldsHead_loss: 1.7539e-04 - lr: 1.0000e-04 - 91s/epoch - 453ms/step
# Epoch 29/200
# Epoch 61/200
# 200/200 - 92s - loss: 1.2609e-04 - MultiInstanceConfmapsHead_loss: 3.2616e-05 - PartAffinityFieldsHead_loss: 9.3478e-05 - val_loss: 2.1423e-04 - val_MultiInstanceConfmapsHead_loss: 5.0295e-05 - val_PartAffinityFieldsHead_loss: 1.6394e-04 - lr: 1.2500e-05 - 92s/epoch - 459ms/step
# Epoch 62/200
# 200/200 - 89s - loss: 1.2758e-04 - MultiInstanceConfmapsHead_loss: 3.3379e-05 - PartAffinityFieldsHead_loss: 9.4201e-05 - val_loss: 2.1588e-04 - val_MultiInstanceConfmapsHead_loss: 4.9918e-05 - val_PartAffinityFieldsHead_loss: 1.6596e-04 - lr: 1.2500e-05 - 89s/epoch - 444ms/step
# Epoch 00062: early stopping
# INFO:sleap.nn.training:Finished training loop. [93.6 min]
# INFO:sleap.nn.training:Saving evaluation metrics to model folder...
# Predicting... -------------------------------------- 100% ETA: 0:00:00 29.6 FPS
# INFO:sleap.nn.evals:Saved predictions: D:\SLEAP\20250530_seminal_root_generalist\younger_rice\train_test_split.v005\models\250603_024145.multi_instance.n=738\labels_pr.train.slp
# INFO:sleap.nn.evals:Saved metrics: D:\SLEAP\20250530_seminal_root_generalist\younger_rice\train_test_split.v005\models\250603_024145.multi_instance.n=738\metrics.train.npz
# INFO:sleap.nn.evals:OKS mAP: 0.176097
# Predicting... --------------------------------------- 100% ETA: 0:00:00 8.5 FPS
# INFO:sleap.nn.evals:Saved predictions: D:\SLEAP\20250530_seminal_root_generalist\younger_rice\train_test_split.v005\models\250603_024145.multi_instance.n=738\labels_pr.val.slp
# INFO:sleap.nn.evals:Saved metrics: D:\SLEAP\20250530_seminal_root_generalist\younger_rice\train_test_split.v005\models\250603_024145.multi_instance.n=738\metrics.val.npz
# INFO:sleap.nn.evals:OKS mAP: 0.053958
# Predicting... -------------------------------------- 100% ETA: 0:00:00 18.3 FPS
# INFO:sleap.nn.evals:Saved predictions: D:\SLEAP\20250530_seminal_root_generalist\younger_rice\train_test_split.v005\models\250603_024145.multi_instance.n=738\labels_pr.test.slp
# INFO:sleap.nn.evals:Saved metrics: D:\SLEAP\20250530_seminal_root_generalist\younger_rice\train_test_split.v005\models\250603_024145.multi_instance.n=738\metrics.test.npz
# INFO:sleap.nn.evals:OKS mAP: 0.069673
#
# INFO:root:Latest run directory: D:\SLEAP\20250530_seminal_root_generalist\younger_rice\train_test_split.v005\models\250603_024145.multi_instance.n=738
# wandb: Adding directory to artifact (D:\SLEAP\20250530_seminal_root_generalist\younger_rice\train_test_split.v005\models\250603_024145.multi_instance.n=738)...
# W&B run configuration updated with training configuration.
# Done. 0.2s
# Model path: D:/SLEAP/20250530_seminal_root_generalist/younger_rice/train_test_split.v005/models/250603_024145.multi_instance.n=738
# Metrics loaded from model directory: D:/SLEAP/20250530_seminal_root_generalist/younger_rice/train_test_split.v005/models/250603_024145.multi_instance.n=738
# Model artifact '20250530_younger_rice_seminal_sweep_input_scaling_v005' logged to W&B with evaluations.
# VBox(children=(Label(value='3.650 MB of 61.630 MB uploaded\r'), FloatProgress(value=0.0592322624304685, max=1.…
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>dist_avg</td><td>0.72338</td></tr><tr><td>dist_p50</td><td>0.29138</td></tr><tr><td>dist_p90</td><td>1.43051</td></tr><tr><td>dist_p95</td><td>2.20945</td></tr><tr><td>dist_p99</td><td>6.36942</td></tr><tr><td>dist_std</td><td>2.00256</td></tr><tr><td>model_name</td><td>250603_024145.multi_...</td></tr><tr><td>model_path</td><td>D:/SLEAP/20250530_se...</td></tr><tr><td>oks_map</td><td>0.06967</td></tr><tr><td>oks_mar</td><td>0.16474</td></tr><tr><td>vis_prec</td><td>0.99552</td></tr><tr><td>vis_recall</td><td>0.92258</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">20250530_younger_rice_seminal_sweep_input_scaling_training_v005</strong> at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/cu9g3nje' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/cu9g3nje</a><br/> View project at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a><br/>Synced 6 W&B file(s), 0 media file(s), 19 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250603_024135-cu9g3nje\logs</code>
# INFO:root:W&B run for version 5 finished.
# INFO:root:Completed training for version 5.
# INFO:root:Finished sweep for version 5.
# INFO:root:All versions processed successfully.
