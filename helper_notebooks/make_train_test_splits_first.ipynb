# %%
import os
import pandas as pd
import sleap
import numpy as np
import random
import re
import matplotlib.pyplot as plt

from pathlib import Path

# %% [markdown]
# # Step 1
#
# This notebook processes labeled data to extract video age information and prepare datasets for model development. It outputs a CSV file summarizing video ages, a CSV detailing train-test splits, and a bar plot visualizing the age distribution.
#
# ### User-Defined Inputs
# - **Labels Path**: Path to the input labeled data (`user_labels`), which must be specified before running the notebook.
# - **Fractions for Data Splitting**:
#   - `fraction_train`: Proportion of data to be allocated to the training set.
#   - `val_test_fraction`: Proportion of the remaining data to be allocated to the test set.
#
# ### Key Functionalities
# 1. **Extracting Video Age Information**:
#    - Extracts the age (in days) from video filenames of labeled data.
#    - Saves the results to a CSV file (`video_ages.csv`).
#    - Generates a bar plot visualizing the age distribution.
#
# 2. **Splitting Data for Training**:
#    - Divides the labeled data into training, validation, and test sets using specified fractions.
#    - Repeats the split three times, saving datasets to directories (`train.pkg.slp`, `val.pkg.slp`, `test.pkg.slp`) with associated images.
#    - Records metadata for each split, including file path, version, labeled frames, and split type, in a CSV file (`train_test_splits_info.csv`).
#
# ### Outputs
# - A CSV file (`video_ages.csv`) with video filenames and corresponding age information.
# - A CSV file (`train_test_splits_info.csv`) summarizing train-test splits.
# - A bar plot visualizing the age distribution.

# %%
# labels path
labels_path = "D:/SLEAP/20250530_seminal_root_generalist/younger_rice/labels_rice_3do_main_6nodes.v029.slp"

# train, val and test fractions
fraction_train = 0.7 # fraction of total user labels to be used for training
val_test_fraction = 0.5 # 1-`fraction_train` allocated for validation and testing

# Number of train-test splits
num_splits = 6

# Directory output path
output_path = "D:/SLEAP/20250530_seminal_root_generalist/younger_rice"

# %%
# Function to extract the age from the filename (for younger rice)
# D:/SLEAP/SLEAP_Rice/Hydroponic/5DAG_primary/h5_files/hg-1x-r8.h5S
# D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/F22HK4M.h5
def extract_age(filename):
    match = re.search(r'(\d+)DAG', filename)
    match2 = re.search(r'(\d+)_do', filename)
    if match:
        print(f"Extracted age: {match.group(1)} from filename: {filename}")
        return int(match.group(1))
    elif match2:
        print(f"Extracted age: {match2.group(1)} from filename: {filename}")
        return int(match2.group(1))
    else:
        print(f"Age not found in filename: {filename}")
        return 'NA'

# %%
# # Function to extract the age from the filename (for sorghum, wheat datasets)
# # Day14_2-7-2025FastScanner
# def extract_age(filename):
#     match = re.search(r'Day(\d+)_', filename)
#     if match:
#         print(f"Match found: {match.group(1)}")
#         return match.group(1)
#     else:
#         print(f"Match not found for {filename}")
#         return 'NA'

# %%
# Function to extract the age from the filename (for soybean dataset)
# h5_files_blue_6_do_1.17.22
# def extract_age(filename):
#     match = re.search(r'_(\d+)_do', filename)
#     if match:
#         print(f"Match found: {match.group(1)}")
#         return match.group(1)
#     else:
#         print(f"Match not found for {filename}")
#         return 'NA'

# %%
# Function to extract the age from the filename (for canola dataset)

# 'D:/SLEAP/SLEAP_Canola_Pennycress/primary_root/h5_files_for_PR_sleap_project/9_do/33PFABDMTW.h5'
# Z:/Experiments/Canola/CYL_Canola_Diversity_Screen/Downstream_Data_Extraction_and_Analysis/4-19-23_data_v000_not_qc_not_proofread/H5_w_SLEAP_predictions_preqc_preproofread/W22/2do/HMDQXXWRSQ.h5
# D:\SLEAP\SLEAP_Canola_Pennycress\primary_root\h5_files_for_PR_sleap_project\pennycress\14_do
# def extract_age(filename):
#     match = re.search(r'(\d+)_do', filename)
#     match2 = re.search(r'(\d+)do', filename)
#     if match:
#         print(f"Match found: {match.group(1)}")
#         # Check to see if it is pennycress
#         if 'pennycress' in filename:
#             return f"pennycress_{match.group(1)}"
#         return match.group(1)
#     elif match2:
#         print(f"Match found: {match2.group(1)}")
#         return match2.group(1)
#     else:
#         print(f"Match not found for {filename}")
#         return 'NA'

# %%
# Function to extract the age from the filename (for pennycress dataset)
# D:\SLEAP\SLEAP_Canola_Pennycress\primary_root\h5_files_for_PR_sleap_project\pennycress\14_do
# D:/SLEAP/SLEAP_Canola_Pennycress/lateral_3_nodes/h5_files_for_LR_sleap_project/pennycress_round2/7P2M34R81D.h5
# def extract_age(filename):
#     match = re.search(r'(\d+)_do', filename)
#     match2 = re.search('pennycress_round2', filename)
#     if match:
#         print(f"Match found: {match.group(1)}")
#         return match.group(1)
#     elif match2:
#         print(f"Match found: {match2.group(0)}")
#         return 14
#     else:
#         print(f"Match not found for {filename}")
#         return 'NA'

# %%
# Function to extract the age from the filename (for arabidopsis dataset)
# D:/SLEAP/SLEAP_arabidopsis/h5_files_7dap_041522/1027_E_R1.h5
# D:/SLEAP/SLEAP_arabidopsis/h5_files_reorganized/11_days/DMSO/1002_1.h5
# def extract_age(filename):
#     match = re.search(r'_(\d+)dap', filename)
#     match2 = re.search(r'(\d+)_days', filename)
#     if match:
#         print(f"Match found: {match.group(1)}")
#         return match.group(1)
#     elif match2:
#         print(f"Match found: {match2.group(1)}")
#         return match2.group(1)
#     else:
#         print(f"Match not found for {filename}")
#         return 'NA'

# %%
# arabidopsis, pennycress and canola
# def extract_age(filename):
#     match_pennycress = re.search(r'pennycress', filename)
#     match_arabodopsis = re.search(r'arabidopsis', filename)
#     # match_canola1 =  re.search(r'(\d+)_do', filename)
#     # match_canola2 = re.search(r'(\d+)do', filename)
#     if match_pennycress:
#         return 'pennycress'
#     elif match_arabodopsis:
#         print(f"Match found for {filename}")
#         return 'arabidopsis'
#     else:
#         print(f"Match not found for {filename}")
#         return 'NA'

# %%
base_labels = sleap.load_file(Path(labels_path).as_posix()) # load labels file
user_labels = base_labels.with_user_labels_only() # user instances only

# %%
# Make the output directory if it doesn't exist
Path(output_path).mkdir(parents=True, exist_ok=True)

# %%
# Print the first few items to check their structure
for label in user_labels[:5]:
    print(label)
# Out:
# LabeledFrame(video=HDF5Video('D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0GYVRBO.h5'), frame_idx=0, instances=5)
# LabeledFrame(video=HDF5Video('D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/3LIAGQX.h5'), frame_idx=57, instances=4)
# LabeledFrame(video=HDF5Video('D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/4XMOTDX.h5'), frame_idx=57, instances=4)
# LabeledFrame(video=HDF5Video('D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0S5UOG4.h5'), frame_idx=3, instances=6)
# LabeledFrame(video=HDF5Video('D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/3LIAGQX.h5'), frame_idx=15, instances=4)

# %%
print(f"There are {len(user_labels)} labels total.")

# Variables to keep count of matches and non-matches
match_count = 0
no_match_count = 0

# Create a DataFrame from the canola labels
data = []
for label in user_labels:
    age = extract_age(label.video.filename)
    if age != 'NA':
        match_count += 1
    else:
        no_match_count += 1
    data.append({'video_filename': label.video.filename, 'days_old': age})

df = pd.DataFrame(data)

# Save the DataFrame to a CSV file
csv_file = Path(output_path) / 'video_ages.csv'
df.to_csv(csv_file, index=False)

print(f"Details saved to {csv_file}")
print(f"Number of labeled frames with age found: {match_count}")
print(f"Number of labeled frames with age not found: {no_match_count}")
# Out:
# There are 868 labels total.
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0GYVRBO.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/3LIAGQX.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/4XMOTDX.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0S5UOG4.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/3LIAGQX.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/3LIAGQX.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/3LIAGQX.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/4Y8KDC0.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/5DF4U1D.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/5DF4U1D.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/5FMRDSA.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/5FMRDSA.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/8E4KG77.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/9FPQ3WR.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/9FPQ3WR.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/11KRJS1.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/22VX7PD.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/22VX7PD.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/25UUY5L.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/25UUY5L.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/27Q6KRQ.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/27Q6KRQ.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/39N151W.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/39N151W.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/56TMR7T.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/56TMR7T.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/060A8AP.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/060A8AP.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/60S80RL.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/62LVJ0H.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/A1DNMU3.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0GYVRBO.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0GYVRBO.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0Q7DV3E.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/71AE2FQ.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/71AE2FQ.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/71XUN1B.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/73CUFI3.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/73CUFI3.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/513TTTO.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/513TTTO.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/513TTTO.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/571KAZD.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/571KAZD.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/4016D73.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/4016D73.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/A1DNMU3.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/A1DNMU3.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/A3WKL39.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/A21R3I7.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/ACCFKGT.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/AEZ18IH.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/AEZ18IH.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/AT6XX0T.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/B43X0GN.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/BC3WWKS.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/BC3WWKS.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/BC3WWKS.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/BEVT3B1.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/BEVT3B1.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/BEVT3B1.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/BEVT3B1.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/BEVT3B1.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/BRIHROW.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/BRIHROW.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/BRIHROW.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/BS0TCEV.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/BS0TCEV.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/BSYIM6E.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/BSYIM6E.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/BURKNEK.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/BURKNEK.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/BW9U68R.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/C613R7G.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/C613R7G.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/C613R7G.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/CD80SRX.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/71AE2FQ.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/73CUFI3.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/73CUFI3.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/73CUFI3.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/73CUFI3.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/513TTTO.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/513TTTO.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/571KAZD.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/571KAZD.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/571KAZD.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/A1DNMU3.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/A1DNMU3.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/A1DNMU3.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/ACCFKGT.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/ACCFKGT.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/ACCFKGT.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/AEZ18IH.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/AEZ18IH.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/AEZ18IH.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/AXDCT5H.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/AXDCT5H.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/AXDCT5H.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/B43X0GN.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/B43X0GN.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/BC3WWKS.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/5R32HX4.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/6XR60ED.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/6XR60ED.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/6Z2NR7Q.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/6Z2NR7Q.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/7BWX1JK.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/7BWX1JK.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/8KVVEUI.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/8KVVEUI.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/8R0B4QY.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/8R0B4QY.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/8TJAAEL.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/8TJAAEL.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/8XP941O.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/8XP941O.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/71XUN1B.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/A3WKL39.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/AT6XX0T.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/BURKNEK.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/BVO9ARQ.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/BVO9ARQ.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/BVO9ARQ.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/BVO9ARQ.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/BW9U68R.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/BW9U68R.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/BYIHMUR.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/BYIHMUR.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/C1HPY7X.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/C1HPY7X.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/C1HPY7X.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/C8LWYPG.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/C8LWYPG.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/C8LWYPG.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/C84L7LU.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/C84L7LU.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/C84L7LU.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/C84L7LU.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/C84L7LU.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/C84L7LU.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/C84L7LU.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/C84L7LU.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/C84L7LU.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/C84L7LU.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/C84L7LU.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/C84L7LU.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/C84L7LU.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/C84L7LU.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/C613R7G.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/CD80SRX.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/CD80SRX.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/CG80XIB.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/CG80XIB.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/CG98PS6.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/CG98PS6.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/CG98PS6.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/CG98PS6.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/CJGYY98.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/CJGYY98.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/CJGYY98.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/CVLY013.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/D0BKBV2.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/D0BKBV2.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/D0BKBV2.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/D7EFLP2.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/D7EFLP2.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/D7EFLP2.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/DDF0ZEE.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/DDF0ZEE.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/DDF0ZEE.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/DMT9VG4.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/DMT9VG4.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/DMT9VG4.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/DMT9VG4.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/DWYI6FP.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/DWYI6FP.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/DWYI6FP.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/EC2POBM.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/EC2POBM.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/EC2POBM.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/EC2POBM.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/EE2TXK7.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/EE2TXK7.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/EGQPQ3C.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/EGQPQ3C.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/EGQPQ3C.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/EJ0SLNG.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/EJ0SLNG.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/EQG8SRQ.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/EQG8SRQ.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/EQG8SRQ.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/ETDJ64P.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/ETDJ64P.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/ETDJ64P.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/ETDJ64P.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/F5BA44S.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/F5BA44S.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/F5BA44S.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/F8Q9IFS.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/F8Q9IFS.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/F8Q9IFS.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/F8Q9IFS.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/F9E5ZTF.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/F9E5ZTF.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/F9E5ZTF.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/F9E5ZTF.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/F22HK4M.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/F22HK4M.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/F22HK4M.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/F22HK4M.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/FA3EMTM.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/FA3EMTM.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/FC3IHRY.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/FC3IHRY.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/FC3IHRY.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/FOF0CJJ.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/FOF0CJJ.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/FOF0CJJ.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/FOF0CJJ.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/FSLK95F.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/FSLK95F.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/FTKWRJT.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/FTKWRJT.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/FVHW4OW.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/FVHW4OW.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/G5TYIT0.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/G5TYIT0.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/G5TYIT0.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/G55YVUB.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/G55YVUB.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/G55YVUB.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/GO9OZDT.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/GO9OZDT.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/GO9OZDT.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/GQZ9WPD.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/GQZ9WPD.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/GVWTJH6.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/GVWTJH6.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/H1ELA6H.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/H1ELA6H.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/HAE9PTW.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/HAE9PTW.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/HN73R60.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/HN73R60.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/HQ7YPL2.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/HQ7YPL2.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/HUY4ZND.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/HUY4ZND.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/HUY4ZND.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/HW2V9GM.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/HW2V9GM.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/HW2V9GM.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/HW2V9GM.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/HYQHJRX.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/HYQHJRX.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/HYQHJRX.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/I03F2HY.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/I03F2HY.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/I8K07FX.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/I8K07FX.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/I8K07FX.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/I70VSBH.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/I70VSBH.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/I70VSBH.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/I80Y74W.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/I80Y74W.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/I80Y74W.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/IIRBRBW.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/IIRBRBW.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/IIRBRBW.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/IM9I86F.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/IM9I86F.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/IM9I86F.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/IQ2M5MO.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/IQ2M5MO.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/IQ2M5MO.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/IYJ3WT1.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/IYJ3WT1.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/JCXSLSG.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/JCXSLSG.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/JCXSLSG.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/JID89YX.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/JID89YX.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/JID89YX.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/JID89YX.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/JNI2026.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/JNI2026.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/JNI2026.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/K2JR03P.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/K2JR03P.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/K2JR03P.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/K6G8QIS.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/K6G8QIS.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/KFEAKIV.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/KFEAKIV.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/KFEAKIV.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/KGHUBAH.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/KGHUBAH.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/KGHUBAH.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/KGHUBAH.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/KM434Q6.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/KM434Q6.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/KM434Q6.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/KQNNGWP.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/KQNNGWP.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/KQNNGWP.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/KWGWCZF.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/KWGWCZF.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/KWSI4V5.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/KWSI4V5.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/KWSI4V5.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/KWYPOY9.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/KYRAP63.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/KYRAP63.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/LDULSVG.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/LDULSVG.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/LDULSVG.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/LDULSVG.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/LDULSVG.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/LFRPSQF.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/LFRPSQF.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/LFRPSQF.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/LFRPSQF.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/LGMKTYC.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/LGMKTYC.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/LK4BTJ5.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/VMIQBJ3.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/VMIQBJ3.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/VMIQBJ3.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/VMIQBJ3.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/VMIQBJ3.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/VMIQBJ3.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0K9E8BI.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0OTKRUH.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0Q7DV3E.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0S5UOG4.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0T1JVVK.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0VKBP5C.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/1DSR7T9.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/1ESMOKK.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/1HK9E28.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/1IT28H1.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/1L9IDR4.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/1QL685D.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/1S4UA7C.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/1TWI6T3.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0GYVRBO.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0K9E8BI.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0OTKRUH.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0Q7DV3E.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0S5UOG4.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0T1JVVK.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0VKBP5C.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/1DSR7T9.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/1ESMOKK.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/1HK9E28.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/1IT28H1.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/1L9IDR4.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/1QL685D.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/1S4UA7C.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/1TWI6T3.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/2LR30A9.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/3M81DAH.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0GYVRBO.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0K9E8BI.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0K9E8BI.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0K9E8BI.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0K9E8BI.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0K9E8BI.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0K9E8BI.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0K9E8BI.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0K9E8BI.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0K9E8BI.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0K9E8BI.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0OTKRUH.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/2LR30A9.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/2OXIBYE.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/2OXIBYE.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/03LSBKX.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/03LSBKX.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/3EROJVR.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/3NZ5VHN.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/3PGOE0V.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/3R3XEXW.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/4FCYLI7.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/4RETAZ7.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/4Y8KDC0.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/2LR30A9.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/2Z86SO1.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/3GAN648.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/3M81DAH.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/3R3XEXW.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/4RETAZ7.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/4UNPKCV.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0OTKRUH.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0OTKRUH.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0OTKRUH.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0Q7DV3E.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0Q7DV3E.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0Q7DV3E.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0Q7DV3E.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0T1JVVK.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0T1JVVK.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0T1JVVK.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0T1JVVK.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0T1JVVK.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0T1JVVK.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0VKBP5C.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/1DSR7T9.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/1DSR7T9.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/1ESMOKK.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/1HK9E28.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/CVLY013.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0S5UOG4.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/1DSR7T9.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/2OXIBYE.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/2OXIBYE.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/03LSBKX.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/3EROJVR.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/3GAN648.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/3GAN648.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/3M81DAH.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/3NZ5VHN.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/3PGOE0V.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/4A4URF6.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/4A4URF6.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/4FCYLI7.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/4UNPKCV.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/4UNPKCV.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/4XMOTDX.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/4XMOTDX.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/4Y8KDC0.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/4Y8KDC0.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/5IZOP2Y.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/5IZOP2Y.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/5JGSFDD.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/5JGSFDD.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/5PEFY2G.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/5PEFY2G.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/5SWTI4Q.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/5SWTI4Q.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/6RUAQ3V.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/6RUAQ3V.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/7HAHB8L.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/7HAHB8L.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/8FXG8UA.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/8FXG8UA.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/CVLY013.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/CVLY013.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/4FCYLI7.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/4FCYLI7.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/4FCYLI7.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/4FCYLI7.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/4FCYLI7.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/4FCYLI7.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/4FCYLI7.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/4FCYLI7.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/4FCYLI7.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/4FCYLI7.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/4FCYLI7.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/4FCYLI7.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/4FCYLI7.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0OTKRUH.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0OTKRUH.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0T1JVVK.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/1TWI6T3.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/5PEFY2G.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/5R32HX4.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/7OM5AZN.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/7OM5AZN.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/8E4KG77.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/8V5R0R6.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/8V5R0R6.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/11KRJS1.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/60S80RL.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/62LVJ0H.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0OTKRUH.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0OTKRUH.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0OTKRUH.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0OTKRUH.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0VKBP5C.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0GYVRBO.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0GYVRBO.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0GYVRBO.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0GYVRBO.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0GYVRBO.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0GYVRBO.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0GYVRBO.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0GYVRBO.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0GYVRBO.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0GYVRBO.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0GYVRBO.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0K9E8BI.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0K9E8BI.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0K9E8BI.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0K9E8BI.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0K9E8BI.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0K9E8BI.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0OTKRUH.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0Q7DV3E.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0S5UOG4.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0T1JVVK.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0T1JVVK.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/FTKWRJT.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0K9E8BI.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0K9E8BI.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/71AE2FQ.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/71AE2FQ.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/A21R3I7.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/A21R3I7.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/A21R3I7.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/A21R3I7.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/A21R3I7.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/AGAMDNF.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/AGAMDNF.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/AGAMDNF.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/AGAMDNF.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/AGAMDNF.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/AGAMDNF.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/AGAMDNF.h5
# ...
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/6CCq37nGHc.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/6CCq37nGHc.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/6CCq37nGHc.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/6CCq37nGHc.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/6CCq37nGHc.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/6CCq37nGHc.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/6CCq37nGHc.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/75neOOL0qD.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/75neOOL0qD.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/75neOOL0qD.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/75neOOL0qD.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/75neOOL0qD.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/75neOOL0qD.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/75neOOL0qD.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/75neOOL0qD.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/75neOOL0qD.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/75neOOL0qD.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/jvwrJ9wtZG.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/jvwrJ9wtZG.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/jvwrJ9wtZG.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/jvwrJ9wtZG.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/jvwrJ9wtZG.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/jvwrJ9wtZG.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/jvwrJ9wtZG.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/jvwrJ9wtZG.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/jvwrJ9wtZG.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/jvwrJ9wtZG.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/jvwrJ9wtZG.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/mWV9ga7Qgj.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/mWV9ga7Qgj.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/mWV9ga7Qgj.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/mWV9ga7Qgj.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/mWV9ga7Qgj.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/mWV9ga7Qgj.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/mWV9ga7Qgj.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/mWV9ga7Qgj.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/mWV9ga7Qgj.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/mWV9ga7Qgj.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/Pr20pGACxC.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/Pr20pGACxC.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/Pr20pGACxC.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/Pr20pGACxC.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/Pr20pGACxC.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/Pr20pGACxC.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/Pr20pGACxC.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/Pr20pGACxC.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/Pr20pGACxC.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/Pr20pGACxC.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/raUR0rYAFf.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/raUR0rYAFf.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/raUR0rYAFf.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/raUR0rYAFf.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/raUR0rYAFf.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/raUR0rYAFf.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/raUR0rYAFf.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/raUR0rYAFf.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/raUR0rYAFf.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/raUR0rYAFf.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/raUR0rYAFf.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/raUR0rYAFf.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/raUR0rYAFf.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/raUR0rYAFf.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/raUR0rYAFf.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/wC3a33BFft.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/wC3a33BFft.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/wC3a33BFft.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/wC3a33BFft.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/wC3a33BFft.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/wC3a33BFft.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/wC3a33BFft.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/wC3a33BFft.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/wC3a33BFft.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/wC3a33BFft.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/wC3a33BFft.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/ZCxW58dxo9.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/ZCxW58dxo9.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/ZCxW58dxo9.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/ZCxW58dxo9.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/ZCxW58dxo9.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/ZCxW58dxo9.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/ZCxW58dxo9.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/ZCxW58dxo9.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/ZCxW58dxo9.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/ZCxW58dxo9.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/ZCxW58dxo9.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 3/4yXP8Nu73M.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 3/4yXP8Nu73M.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 3/4yXP8Nu73M.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 3/4yXP8Nu73M.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 3/4yXP8Nu73M.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 3/4yXP8Nu73M.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 3/4yXP8Nu73M.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 3/4yXP8Nu73M.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 3/4yXP8Nu73M.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 3/4yXP8Nu73M.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 3/4yXP8Nu73M.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 3/4yXP8Nu73M.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 3/DsKwzoRFsn.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 3/DsKwzoRFsn.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 3/DsKwzoRFsn.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 3/DsKwzoRFsn.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 3/DsKwzoRFsn.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 3/DsKwzoRFsn.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 3/DsKwzoRFsn.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 3/DsKwzoRFsn.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 3/DsKwzoRFsn.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 3/DsKwzoRFsn.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 3/DsKwzoRFsn.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 3/DsKwzoRFsn.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 3/DsKwzoRFsn.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 3/DsKwzoRFsn.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 3/DsKwzoRFsn.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 3/ZMHNYMx6AY.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0K9E8BI.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0K9E8BI.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0K9E8BI.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0K9E8BI.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0K9E8BI.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0K9E8BI.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0K9E8BI.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0OTKRUH.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0OTKRUH.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0Q7DV3E.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0Q7DV3E.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0Q7DV3E.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0Q7DV3E.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0VKBP5C.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0VKBP5C.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0VKBP5C.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/1ESMOKK.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/1ESMOKK.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/1ESMOKK.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/1HK9E28.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/3NZ5VHN.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/3PGOE0V.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/4A4URF6.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 1/9LXUejqYWF.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/raUR0rYAFf.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/FN_2021NEW/new pt 2/wC3a33BFft.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0GYVRBO.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0K9E8BI.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0K9E8BI.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0K9E8BI.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0K9E8BI.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0K9E8BI.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0K9E8BI.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0Q7DV3E.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0Q7DV3E.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0Q7DV3E.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0Q7DV3E.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0Q7DV3E.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/0VKBP5C.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/1QL685D.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/3EROJVR.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/3R3XEXW.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/3R3XEXW.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/4A4URF6.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/5DF4U1D.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/5FMRDSA.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/5JGSFDD.h5
# Extracted age: 3 from filename: D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/DMT9VG4.h5
# Details saved to D:\SLEAP\20250530_seminal_root_generalist\younger_rice\video_ages.csv
# Number of labeled frames with age found: 868
# Number of labeled frames with age not found: 0

# %%
# Ensure the ages are treated as integers
df['days_old'] = df['days_old'].astype(int)

# Plotting the bar graph
age_counts = df['days_old'].value_counts().sort_index()
plt.figure(figsize=(5, 6), facecolor='white') 
age_counts.plot(kind='bar', color='blue')  # Set color to blue
plt.title('Count of Ages in Labels')
plt.xlabel('Age (Days)')
plt.ylabel('Count')
plt.xticks(rotation=0)  # Rotate the x-axis labels
plt.tight_layout()  # Adjusts the plot to ensure a tight fit

# Save the figure
plot_path = Path(output_path) / 'age_distribution.png'
plt.savefig(plot_path, facecolor='white', bbox_inches='tight')
plt.show()

print(f"Plot saved to {plot_path}")
# Out:
# Plot saved to D:\SLEAP\20250530_seminal_root_generalist\younger_rice\age_distribution.png

# %%
n_train = int(fraction_train*len(user_labels))
print(f"Number of labels for training set should be {n_train}.")
n_val = int((1-fraction_train)*val_test_fraction*len(user_labels))
print(f"Number of labels for validation set should be {n_val}.")
n_test = int((1-fraction_train)*val_test_fraction*len(user_labels))
print(f"Number of labels for validation set should be {n_test}.")
# Out:
# Number of labels for training set should be 607.
# Number of labels for validation set should be 130.
# Number of labels for validation set should be 130.

# %%
# Initialize a list to store information for the CSV file
csv_data = []

for i in range(num_splits):
    # Split the training and validation sets
    labels_train, _, labels_val, _ = sleap.nn.data.training.split_labels_train_val(user_labels, 1-fraction_train) # 1-`fraction_train` allocated for validation and testing
    labels_val, _, labels_test, _ = sleap.nn.data.training.split_labels_train_val(labels_val, val_test_fraction) # `val_test_fraction` of `labels_val` made into a test set

    # Make a directory for this split
    split_dir = Path(output_path) / f"train_test_split.v00{i}"
    os.makedirs(split_dir, exist_ok=True)

    # Save the train, val and test sets
    train_path = Path(split_dir) / "train.pkg.slp"
    val_path = Path(split_dir) / "val.pkg.slp"
    test_path = Path(split_dir) / "test.pkg.slp"
    labels_train.save(train_path, with_images=True)
    labels_val.save(val_path, with_images=True)
    labels_test.save(test_path, with_images=True)

    # Store the information in the list for train, val and test splits
    csv_data.append({'path': train_path, 'version': i, 'labeled_frames': len(labels_train), 'split_type': 'train'})
    csv_data.append({'path': val_path, 'version': i, 'labeled_frames': len(labels_val), 'split_type': 'val'})
    csv_data.append({'path': test_path, 'version': i, 'labeled_frames': len(labels_test), 'split_type': 'test'})

# %%
# Convert the list to a DataFrame and save as CSV
df_new = pd.DataFrame(csv_data)
csv_path = Path(output_path) / 'train_test_splits.csv'
df_new.to_csv(csv_path, index=False)

print(f"Train, val and test splits information saved to {csv_path}")
# Out:
# Train, val and test splits information saved to D:\SLEAP\20250530_seminal_root_generalist\younger_rice\train_test_splits.csv

# %%
df_new
# Out:
#                                                 path  version  labeled_frames  \
# 0  D:\SLEAP\20250530_seminal_root_generalist\youn...        0             608
# 1  D:\SLEAP\20250530_seminal_root_generalist\youn...        0             130
# 2  D:\SLEAP\20250530_seminal_root_generalist\youn...        0             130
# 3  D:\SLEAP\20250530_seminal_root_generalist\youn...        1             608
# 4  D:\SLEAP\20250530_seminal_root_generalist\youn...        1             130
# 5  D:\SLEAP\20250530_seminal_root_generalist\youn...        1             130
# 6  D:\SLEAP\20250530_seminal_root_generalist\youn...        2             608
# 7  D:\SLEAP\20250530_seminal_root_generalist\youn...        2             130
# 8  D:\SLEAP\20250530_seminal_root_generalist\youn...        2             130
#
#   split_type
# 0      train
# 1        val
# 2       test
# 3      train
# 4        val
# 5       test
# 6      train
# 7        val
# 8       test
