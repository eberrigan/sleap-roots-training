# %%
import wandb
import sleap_roots_training

from pathlib import Path

from sleap_roots_training.train import main

# %%
# Constants for W&B initialization
ENTITY_NAME = "eberrigan-salk-institute-for-biological-studies"
PROJECT_NAME = "sleap-roots"
REGISTRY = "sleap-roots-models"
JOB_TYPE = "sweep"
EXPERIMENT_NAME = "20250530_wheat_seminal_sweep"

# Constants for artifact creation
DESCRIPTION = "wheat 5-14 DAG seminal roots with 6 nodes with varying input scaling"
TAGS = ["wheat5-14DAG", "seminal", "6nodes", "wheat", "input_scaling"]
MODEL_TAGS = ["wheat5-14DAG", "seminal", "6nodes", "wheat"]
COLLECTION_NAME = EXPERIMENT_NAME
CSV_PATH = "D:/SLEAP/20250530_seminal_root_generalist/wheat/train_test_splits.csv"

# %%
print(wandb.run)
# Out:
# None

# %%
sleap_roots_training.reset_config()
# Out:
# Configuration updated successfully at e:\repositories\sleap-roots-training\sleap_roots_training\config.yaml.
# Configuration has been reset to default values.

# %%
sleap_roots_training.update_config(entity_name=ENTITY_NAME, project_name=PROJECT_NAME, registry=REGISTRY, job_type=JOB_TYPE, experiment_name=EXPERIMENT_NAME, collection_name=COLLECTION_NAME)
# Out:
# Configuration updated successfully at e:\repositories\sleap-roots-training\sleap_roots_training\config.yaml.
# CONFIG updated to {'project_name': 'sleap-roots', 'entity_name': 'eberrigan-salk-institute-for-biological-studies', 'experiment_name': '20250530_wheat_seminal_sweep', 'registry': 'sleap-roots-models', 'collection_name': '20250530_wheat_seminal_sweep', 'job_type': 'sweep'}.

# %%
# Define the sweep configuration
sweep_config = {
    "method": "grid",
    "parameters": {
        "data.preprocessing.input_scaling": {"values": [0.5, 0.75, 1.0]}
    }
}

# %%
main(csv_path=CSV_PATH, tags=TAGS, model_tags=MODEL_TAGS, use_sweep=True, sweep_config=sweep_config)
# Out:
# INFO:root:Starting main function with CSV: D:/SLEAP/20250530_seminal_root_generalist/wheat/train_test_splits.csv
# INFO:root:Detected 6 train-test splits.
# INFO:root:Processing train-test split version: 0
# INFO:root:Creating W&B sweep for version 0...
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# Create sweep with ID: 8tv8mpjm
# Sweep URL: https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/sweeps/8tv8mpjm
# INFO:root:Sweep created for version 0 with ID: 8tv8mpjm
# INFO:root:Running W&B grid sweep with 3 experiments for version 0...
# INFO:wandb.agents.pyagent:Starting sweep agent: entity=None, project=None, count=3
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 8lq35ozd with config:
# wandb: 	data.preprocessing.input_scaling: 0.5
# INFO:root:Starting training for version 0...
# INFO:root:Directory path for version 0: D:\SLEAP\20250530_seminal_root_generalist\wheat\train_test_split.v000
# wandb: Currently logged in as: eberrigan (eberrigan-salk-institute-for-biological-studies). Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# Tracking run with wandb version 0.18.6
# Run data is saved locally in <code>e:\repositories\sleap-roots-training\wandb\run-20250530_213037-8lq35ozd</code>
# Syncing run <strong><a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/8lq35ozd' target="_blank">20250530_wheat_seminal_sweep_training_v000</a></strong> to <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/sweeps/8tv8mpjm' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/sweeps/8tv8mpjm</a>
#  View project at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a>
#  View sweep at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/sweeps/8tv8mpjm' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/sweeps/8tv8mpjm</a>
#  View run at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/8lq35ozd' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/8lq35ozd</a>
# INFO:root:Updating configuration with W&B parameters.
# INFO:root:Original Parameters: {
#     "data": {
#         "labels": {
#             "training_labels": "D:\\SLEAP\\20250530_seminal_root_generalist\\wheat\\train_test_split.v000\\train.pkg.slp",
#             "validation_labels": "D:\\SLEAP\\20250530_seminal_root_generalist\\wheat\\train_test_split.v000\\val.pkg.slp",
#             "validation_fraction": 0.1,
#             "test_labels": "D:\\SLEAP\\20250530_seminal_root_generalist\\wheat\\train_test_split.v000\\test.pkg.slp",
#             "split_by_inds": false,
#             "training_inds": null,
#             "validation_inds": null,
#             "test_inds": null,
#             "search_path_hints": [],
#             "skeletons": []
#         },
#         "preprocessing": {
#             "ensure_rgb": false,
#             "ensure_grayscale": false,
#             "imagenet_mode": null,
#             "input_scaling": 1.0,
#             "pad_to_stride": null,
#             "resize_and_pad_to_target": true,
#             "target_height": null,
#             "target_width": null
#         },
#         "instance_cropping": {
#             "center_on_part": null,
#             "crop_size": null,
#             "crop_size_detection_padding": 16
#         }
#     },
#     "model": {
#         "backbone": {
#             "leap": null,
#             "unet": {
#                 "stem_stride": null,
#                 "max_stride": 64,
#                 "output_stride": 2,
#                 "filters": 24,
#                 "filters_rate": 1.5,
#                 "middle_block": true,
#                 "up_interpolate": true,
#                 "stacks": 1
#             },
#             "hourglass": null,
#             "resnet": null,
#             "pretrained_encoder": null
#         },
#         "heads": {
#             "single_instance": null,
#             "centroid": null,
#             "centered_instance": null,
#             "multi_instance": {
#                 "confmaps": {
#                     "part_names": null,
#                     "sigma": 2.5,
#                     "output_stride": 2,
#                     "loss_weight": 1.0,
#                     "offset_refinement": false
#                 },
#                 "pafs": {
#                     "edges": null,
#                     "sigma": 75.0,
#                     "output_stride": 8,
#                     "loss_weight": 1.0
#                 }
#             }
#         }
#     },
#     "optimization": {
#         "preload_data": true,
#         "augmentation_config": {
#             "rotate": true,
#             "rotation_min_angle": -5.0,
#             "rotation_max_angle": 5.0,
#             "translate": false,
#             "translate_min": -5,
#             "translate_max": 5,
#             "scale": true,
#             "scale_min": 0.5,
#             "scale_max": 1.2,
#             "uniform_noise": false,
#             "uniform_noise_min_val": 0.0,
#             "uniform_noise_max_val": 10.0,
#             "gaussian_noise": false,
#             "gaussian_noise_mean": 5.0,
#             "gaussian_noise_stddev": 1.0,
#             "contrast": true,
#             "contrast_min_gamma": 0.5,
#             "contrast_max_gamma": 2.0,
#             "brightness": false,
#             "brightness_min_val": 0.0,
#             "brightness_max_val": 10.0,
#             "random_crop": false,
#             "random_crop_height": 256,
#             "random_crop_width": 256,
#             "random_flip": false,
#             "flip_horizontal": true
#         },
#         "online_shuffling": true,
#         "shuffle_buffer_size": 128,
#         "prefetch": true,
#         "batch_size": 4,
#         "batches_per_epoch": null,
#         "min_batches_per_epoch": 200,
#         "val_batches_per_epoch": null,
#         "min_val_batches_per_epoch": 10,
#         "epochs": 200,
#         "optimizer": "adam",
#         "initial_learning_rate": 0.0001,
#         "learning_rate_schedule": {
#             "reduce_on_plateau": true,
#             "reduction_factor": 0.5,
#             "plateau_min_delta": 1e-06,
#             "plateau_patience": 5,
#             "plateau_cooldown": 3,
#             "min_learning_rate": 1e-08
#         },
#         "hard_keypoint_mining": {
#             "online_mining": false,
#             "hard_to_easy_ratio": 2.0,
#             "min_hard_keypoints": 2,
#             "max_hard_keypoints": null,
#             "loss_scale": 5.0
#         },
#         "early_stopping": {
#             "stop_training_on_plateau": true,
#             "plateau_min_delta": 1e-06,
#             "plateau_patience": 10
#         }
#     },
#     "outputs": {
#         "save_outputs": true,
#         "run_name": null,
#         "run_name_prefix": "",
#         "run_name_suffix": "",
#         "runs_folder": "D:\\SLEAP\\20250530_seminal_root_generalist\\wheat\\train_test_split.v000\\models",
#         "tags": [
#             ""
#         ],
#         "save_visualizations": false,
#         "delete_viz_images": true,
#         "zip_outputs": false,
#         "log_to_csv": true,
#         "checkpointing": {
#             "initial_model": false,
#             "best_model": true,
#             "every_epoch": false,
#             "latest_model": false,
#             "final_model": false
#         },
#         "tensorboard": {
#             "write_logs": false,
#             "loss_frequency": "epoch",
#             "architecture_graph": false,
#             "profile_graph": false,
#             "visualizations": true
#         },
#         "zmq": {
#             "subscribe_to_controller": false,
#             "controller_address": "tcp://127.0.0.1:9000",
#             "controller_polling_timeout": 10,
#             "publish_updates": false,
#             "publish_address": "tcp://127.0.0.1:9001"
#         }
#     },
#     "name": "",
#     "description": "",
#     "sleap_version": "",
#     "filename": "",
#     "data.preprocessing.input_scaling": 0.5,
#     "version": 0,
#     "config_path": "D:/SLEAP/20250530_seminal_root_generalist/wheat/train_test_split.v000/initial_config_modified_v000.json"
# }
# INFO:root:Updated parameter: data -> {'labels': {'training_labels': 'D:\\SLEAP\\20250530_seminal_root_generalist\\wheat\\train_test_split.v000\\train.pkg.slp', 'validation_labels': 'D:\\SLEAP\\20250530_seminal_root_generalist\\wheat\\train_test_split.v000\\val.pkg.slp', 'validation_fraction': 0.1, 'test_labels': 'D:\\SLEAP\\20250530_seminal_root_generalist\\wheat\\train_test_split.v000\\test.pkg.slp', 'split_by_inds': False, 'training_inds': None, 'validation_inds': None, 'test_inds': None, 'search_path_hints': [], 'skeletons': []}, 'preprocessing': {'ensure_rgb': False, 'ensure_grayscale': False, 'imagenet_mode': None, 'input_scaling': 1.0, 'pad_to_stride': None, 'resize_and_pad_to_target': True, 'target_height': None, 'target_width': None}, 'instance_cropping': {'center_on_part': None, 'crop_size': None, 'crop_size_detection_padding': 16}}
# INFO:root:Updated parameter: model -> {'backbone': {'leap': None, 'unet': {'stem_stride': None, 'max_stride': 64, 'output_stride': 2, 'filters': 24, 'filters_rate': 1.5, 'middle_block': True, 'up_interpolate': True, 'stacks': 1}, 'hourglass': None, 'resnet': None, 'pretrained_encoder': None}, 'heads': {'single_instance': None, 'centroid': None, 'centered_instance': None, 'multi_instance': {'confmaps': {'part_names': None, 'sigma': 2.5, 'output_stride': 2, 'loss_weight': 1.0, 'offset_refinement': False}, 'pafs': {'edges': None, 'sigma': 75.0, 'output_stride': 8, 'loss_weight': 1.0}}}}
# INFO:root:Updated parameter: optimization -> {'preload_data': True, 'augmentation_config': {'rotate': True, 'rotation_min_angle': -5.0, 'rotation_max_angle': 5.0, 'translate': False, 'translate_min': -5, 'translate_max': 5, 'scale': True, 'scale_min': 0.5, 'scale_max': 1.2, 'uniform_noise': False, 'uniform_noise_min_val': 0.0, 'uniform_noise_max_val': 10.0, 'gaussian_noise': False, 'gaussian_noise_mean': 5.0, 'gaussian_noise_stddev': 1.0, 'contrast': True, 'contrast_min_gamma': 0.5, 'contrast_max_gamma': 2.0, 'brightness': False, 'brightness_min_val': 0.0, 'brightness_max_val': 10.0, 'random_crop': False, 'random_crop_height': 256, 'random_crop_width': 256, 'random_flip': False, 'flip_horizontal': True}, 'online_shuffling': True, 'shuffle_buffer_size': 128, 'prefetch': True, 'batch_size': 4, 'batches_per_epoch': None, 'min_batches_per_epoch': 200, 'val_batches_per_epoch': None, 'min_val_batches_per_epoch': 10, 'epochs': 200, 'optimizer': 'adam', 'initial_learning_rate': 0.0001, 'learning_rate_schedule': {'reduce_on_plateau': True, 'reduction_factor': 0.5, 'plateau_min_delta': 1e-06, 'plateau_patience': 5, 'plateau_cooldown': 3, 'min_learning_rate': 1e-08}, 'hard_keypoint_mining': {'online_mining': False, 'hard_to_easy_ratio': 2.0, 'min_hard_keypoints': 2, 'max_hard_keypoints': None, 'loss_scale': 5.0}, 'early_stopping': {'stop_training_on_plateau': True, 'plateau_min_delta': 1e-06, 'plateau_patience': 10}}
# INFO:root:Updated parameter: outputs -> {'save_outputs': True, 'run_name': None, 'run_name_prefix': '', 'run_name_suffix': '', 'runs_folder': 'D:\\SLEAP\\20250530_seminal_root_generalist\\wheat\\train_test_split.v000\\models', 'tags': [''], 'save_visualizations': False, 'delete_viz_images': True, 'zip_outputs': False, 'log_to_csv': True, 'checkpointing': {'initial_model': False, 'best_model': True, 'every_epoch': False, 'latest_model': False, 'final_model': False}, 'tensorboard': {'write_logs': False, 'loss_frequency': 'epoch', 'architecture_graph': False, 'profile_graph': False, 'visualizations': True}, 'zmq': {'subscribe_to_controller': False, 'controller_address': 'tcp://127.0.0.1:9000', 'controller_polling_timeout': 10, 'publish_updates': False, 'publish_address': 'tcp://127.0.0.1:9001'}}
# INFO:root:Updated parameter: name ->
# INFO:root:Updated parameter: description ->
# INFO:root:Updated parameter: sleap_version ->
# INFO:root:Updated parameter: filename ->
# INFO:root:Updated parameter: data.preprocessing.input_scaling -> 0.5
# INFO:root:Updated parameter: version -> 0
# INFO:root:Updated parameter: config_path -> D:/SLEAP/20250530_seminal_root_generalist/wheat/train_test_split.v000/initial_config_modified_v000.json
# INFO:root:Final updated configuration:
# {
#     "data": {
#         "labels": {
#             "training_labels": "D:\\SLEAP\\20250530_seminal_root_generalist\\wheat\\train_test_split.v000\\train.pkg.slp",
#             "validation_labels": "D:\\SLEAP\\20250530_seminal_root_generalist\\wheat\\train_test_split.v000\\val.pkg.slp",
#             "validation_fraction": 0.1,
#             "test_labels": "D:\\SLEAP\\20250530_seminal_root_generalist\\wheat\\train_test_split.v000\\test.pkg.slp",
#             "split_by_inds": false,
#             "training_inds": null,
#             "validation_inds": null,
#             "test_inds": null,
#             "search_path_hints": [],
#             "skeletons": []
#         },
#         "preprocessing": {
#             "ensure_rgb": false,
#             "ensure_grayscale": false,
#             "imagenet_mode": null,
#             "input_scaling": 0.5,
#             "pad_to_stride": null,
#             "resize_and_pad_to_target": true,
#             "target_height": null,
#             "target_width": null
#         },
#         "instance_cropping": {
#             "center_on_part": null,
#             "crop_size": null,
#             "crop_size_detection_padding": 16
#         }
#     },
#     "model": {
#         "backbone": {
#             "leap": null,
#             "unet": {
#                 "stem_stride": null,
#                 "max_stride": 64,
#                 "output_stride": 2,
#                 "filters": 24,
#                 "filters_rate": 1.5,
#                 "middle_block": true,
#                 "up_interpolate": true,
#                 "stacks": 1
#             },
#             "hourglass": null,
#             "resnet": null,
#             "pretrained_encoder": null
#         },
#         "heads": {
#             "single_instance": null,
#             "centroid": null,
#             "centered_instance": null,
#             "multi_instance": {
#                 "confmaps": {
#                     "part_names": null,
#                     "sigma": 2.5,
#                     "output_stride": 2,
#                     "loss_weight": 1.0,
#                     "offset_refinement": false
#                 },
#                 "pafs": {
#                     "edges": null,
#                     "sigma": 75.0,
#                     "output_stride": 8,
#                     "loss_weight": 1.0
#                 }
#             }
#         }
#     },
#     "optimization": {
#         "preload_data": true,
#         "augmentation_config": {
#             "rotate": true,
#             "rotation_min_angle": -5.0,
#             "rotation_max_angle": 5.0,
#             "translate": false,
#             "translate_min": -5,
#             "translate_max": 5,
#             "scale": true,
#             "scale_min": 0.5,
#             "scale_max": 1.2,
#             "uniform_noise": false,
#             "uniform_noise_min_val": 0.0,
#             "uniform_noise_max_val": 10.0,
#             "gaussian_noise": false,
#             "gaussian_noise_mean": 5.0,
#             "gaussian_noise_stddev": 1.0,
#             "contrast": true,
#             "contrast_min_gamma": 0.5,
#             "contrast_max_gamma": 2.0,
#             "brightness": false,
#             "brightness_min_val": 0.0,
#             "brightness_max_val": 10.0,
#             "random_crop": false,
#             "random_crop_height": 256,
#             "random_crop_width": 256,
#             "random_flip": false,
#             "flip_horizontal": true
#         },
#         "online_shuffling": true,
#         "shuffle_buffer_size": 128,
#         "prefetch": true,
#         "batch_size": 4,
#         "batches_per_epoch": null,
#         "min_batches_per_epoch": 200,
#         "val_batches_per_epoch": null,
#         "min_val_batches_per_epoch": 10,
#         "epochs": 200,
#         "optimizer": "adam",
#         "initial_learning_rate": 0.0001,
#         "learning_rate_schedule": {
#             "reduce_on_plateau": true,
#             "reduction_factor": 0.5,
#             "plateau_min_delta": 1e-06,
#             "plateau_patience": 5,
#             "plateau_cooldown": 3,
#             "min_learning_rate": 1e-08
#         },
#         "hard_keypoint_mining": {
#             "online_mining": false,
#             "hard_to_easy_ratio": 2.0,
#             "min_hard_keypoints": 2,
#             "max_hard_keypoints": null,
#             "loss_scale": 5.0
#         },
#         "early_stopping": {
#             "stop_training_on_plateau": true,
#             "plateau_min_delta": 1e-06,
#             "plateau_patience": 10
#         }
#     },
#     "outputs": {
#         "save_outputs": true,
#         "run_name": null,
#         "run_name_prefix": "",
#         "run_name_suffix": "",
#         "runs_folder": "D:\\SLEAP\\20250530_seminal_root_generalist\\wheat\\train_test_split.v000\\models",
#         "tags": [
#             ""
#         ],
#         "save_visualizations": false,
#         "delete_viz_images": true,
#         "zip_outputs": false,
#         "log_to_csv": true,
#         "checkpointing": {
#             "initial_model": false,
#             "best_model": true,
#             "every_epoch": false,
#             "latest_model": false,
#             "final_model": false
#         },
#         "tensorboard": {
#             "write_logs": false,
#             "loss_frequency": "epoch",
#             "architecture_graph": false,
#             "profile_graph": false,
#             "visualizations": true
#         },
#         "zmq": {
#             "subscribe_to_controller": false,
#             "controller_address": "tcp://127.0.0.1:9000",
#             "controller_polling_timeout": 10,
#             "publish_updates": false,
#             "publish_address": "tcp://127.0.0.1:9001"
#         }
#     },
#     "name": "",
#     "description": "",
#     "sleap_version": "",
#     "filename": "",
#     "version": 0,
#     "config_path": "D:/SLEAP/20250530_seminal_root_generalist/wheat/train_test_split.v000/initial_config_modified_v000.json"
# }
# INFO:root:Saved updated configuration to: D:\SLEAP\20250530_seminal_root_generalist\wheat\train_test_split.v000\modified_config_v000_20250530_213037.json
# INFO:root:Training with updated config for version 0.
# INFO:root:Executing training command: sleap-train D:/SLEAP/20250530_seminal_root_generalist/wheat/train_test_split.v000/modified_config_v000_20250530_213037.json
# Executing: sleap-train D:/SLEAP/20250530_seminal_root_generalist/wheat/train_test_split.v000/modified_config_v000_20250530_213037.json
# INFO:sleap.nn.training:Versions:
# SLEAP: 1.3.4
# TensorFlow: 2.7.0
# Numpy: 1.21.6
# Python: 3.7.12
# OS: Windows-10-10.0.26100-SP0
# INFO:sleap.nn.training:Training labels file: None
# INFO:sleap.nn.training:Training profile: D:/SLEAP/20250530_seminal_root_generalist/wheat/train_test_split.v000/modified_config_v000_20250530_213037.json
# INFO:sleap.nn.training:
# INFO:sleap.nn.training:Arguments:
# INFO:sleap.nn.training:{
#     "training_job_path": "D:/SLEAP/20250530_seminal_root_generalist/wheat/train_test_split.v000/modified_config_v000_20250530_213037.json",
#     "labels_path": null,
#     "video_paths": [
#         ""
#     ],
#     "val_labels": null,
#     "test_labels": null,
#     "base_checkpoint": null,
#     "tensorboard": false,
#     "save_viz": false,
#     "zmq": false,
#     "run_name": "",
#     "prefix": "",
#     "suffix": "",
#     "cpu": false,
#     "first_gpu": false,
#     "last_gpu": false,
#     "gpu": "auto"
# }
# INFO:sleap.nn.training:
# INFO:sleap.nn.training:Training job:
# INFO:sleap.nn.training:{
#     "data": {
#         "labels": {
#             "training_labels": "D:\\SLEAP\\20250530_seminal_root_generalist\\wheat\\train_test_split.v000\\train.pkg.slp",
#             "validation_labels": "D:\\SLEAP\\20250530_seminal_root_generalist\\wheat\\train_test_split.v000\\val.pkg.slp",
#             "validation_fraction": 0.1,
#             "test_labels": "D:\\SLEAP\\20250530_seminal_root_generalist\\wheat\\train_test_split.v000\\test.pkg.slp",
#             "split_by_inds": false,
#             "training_inds": null,
#             "validation_inds": null,
#             "test_inds": null,
#             "search_path_hints": [],
#             "skeletons": []
#         },
#         "preprocessing": {
#             "ensure_rgb": false,
#             "ensure_grayscale": false,
#             "imagenet_mode": null,
#             "input_scaling": 0.5,
#             "pad_to_stride": null,
#             "resize_and_pad_to_target": true,
#             "target_height": null,
#             "target_width": null
#         },
#         "instance_cropping": {
#             "center_on_part": null,
#             "crop_size": null,
#             "crop_size_detection_padding": 16
#         }
#     },
#     "model": {
#         "backbone": {
#             "leap": null,
#             "unet": {
#                 "stem_stride": null,
#                 "max_stride": 64,
#                 "output_stride": 2,
#                 "filters": 24,
#                 "filters_rate": 1.5,
#                 "middle_block": true,
#                 "up_interpolate": true,
#                 "stacks": 1
#             },
#             "hourglass": null,
#             "resnet": null,
#             "pretrained_encoder": null
#         },
#         "heads": {
#             "single_instance": null,
#             "centroid": null,
#             "centered_instance": null,
#             "multi_instance": {
#                 "confmaps": {
#                     "part_names": null,
#                     "sigma": 2.5,
#                     "output_stride": 2,
#                     "loss_weight": 1.0,
#                     "offset_refinement": false
#                 },
#                 "pafs": {
#                     "edges": null,
#                     "sigma": 75.0,
#                     "output_stride": 8,
#                     "loss_weight": 1.0
#                 }
#             },
#             "multi_class_bottomup": null,
#             "multi_class_topdown": null
#         },
#         "base_checkpoint": null
#     },
#     "optimization": {
#         "preload_data": true,
#         "augmentation_config": {
#             "rotate": true,
#             "rotation_min_angle": -5.0,
#             "rotation_max_angle": 5.0,
#             "translate": false,
#             "translate_min": -5,
#             "translate_max": 5,
#             "scale": true,
#             "scale_min": 0.5,
#             "scale_max": 1.2,
#             "uniform_noise": false,
#             "uniform_noise_min_val": 0.0,
#             "uniform_noise_max_val": 10.0,
#             "gaussian_noise": false,
#             "gaussian_noise_mean": 5.0,
#             "gaussian_noise_stddev": 1.0,
#             "contrast": true,
#             "contrast_min_gamma": 0.5,
#             "contrast_max_gamma": 2.0,
#             "brightness": false,
#             "brightness_min_val": 0.0,
#             "brightness_max_val": 10.0,
#             "random_crop": false,
#             "random_crop_height": 256,
#             "random_crop_width": 256,
#             "random_flip": false,
#             "flip_horizontal": true
#         },
#         "online_shuffling": true,
#         "shuffle_buffer_size": 128,
#         "prefetch": true,
#         "batch_size": 4,
#         "batches_per_epoch": null,
#         "min_batches_per_epoch": 200,
#         "val_batches_per_epoch": null,
#         "min_val_batches_per_epoch": 10,
#         "epochs": 200,
#         "optimizer": "adam",
#         "initial_learning_rate": 0.0001,
#         "learning_rate_schedule": {
#             "reduce_on_plateau": true,
#             "reduction_factor": 0.5,
#             "plateau_min_delta": 1e-06,
#             "plateau_patience": 5,
#             "plateau_cooldown": 3,
#             "min_learning_rate": 1e-08
#         },
#         "hard_keypoint_mining": {
#             "online_mining": false,
#             "hard_to_easy_ratio": 2.0,
#             "min_hard_keypoints": 2,
#             "max_hard_keypoints": null,
#             "loss_scale": 5.0
#         },
#         "early_stopping": {
#             "stop_training_on_plateau": true,
#             "plateau_min_delta": 1e-06,
#             "plateau_patience": 10
#         }
#     },
#     "outputs": {
#         "save_outputs": true,
#         "run_name": null,
#         "run_name_prefix": "",
#         "run_name_suffix": "",
#         "runs_folder": "D:\\SLEAP\\20250530_seminal_root_generalist\\wheat\\train_test_split.v000\\models",
#         "tags": [
#             ""
#         ],
#         "save_visualizations": false,
#         "delete_viz_images": true,
#         "zip_outputs": false,
#         "log_to_csv": true,
#         "checkpointing": {
#             "initial_model": false,
#             "best_model": true,
#             "every_epoch": false,
#             "latest_model": false,
#             "final_model": false
#         },
#         "tensorboard": {
#             "write_logs": false,
#             "loss_frequency": "epoch",
#             "architecture_graph": false,
#             "profile_graph": false,
#             "visualizations": true
#         },
#         "zmq": {
#             "subscribe_to_controller": false,
#             "controller_address": "tcp://127.0.0.1:9000",
#             "controller_polling_timeout": 10,
#             "publish_updates": false,
#             "publish_address": "tcp://127.0.0.1:9001"
#         }
#     },
#     "name": "",
#     "description": "",
#     "sleap_version": "",
#     "filename": "D:/SLEAP/20250530_seminal_root_generalist/wheat/train_test_split.v000/modified_config_v000_20250530_213037.json"
# }
# INFO:sleap.nn.training:
# INFO:sleap.nn.training:Auto-selected GPU 0 with 22756 MiB of free memory.
# INFO:sleap.nn.training:Using GPU 0 for acceleration.
# INFO:sleap.nn.training:Disabled GPU memory pre-allocation.
# INFO:sleap.nn.training:System:
# GPUs: 1/1 available
#   Device: /physical_device:GPU:0
#          Available: True
#         Initalized: False
#      Memory growth: True
# INFO:sleap.nn.training:
# INFO:sleap.nn.training:Initializing trainer...
# INFO:sleap.nn.training:Loading training labels from: D:\SLEAP\20250530_seminal_root_generalist\wheat\train_test_split.v000\train.pkg.slp
# INFO:sleap.nn.training:Loading validation labels from: D:\SLEAP\20250530_seminal_root_generalist\wheat\train_test_split.v000\val.pkg.slp
# INFO:sleap.nn.training:Loading test labels from: D:\SLEAP\20250530_seminal_root_generalist\wheat\train_test_split.v000\test.pkg.slp
# INFO:sleap.nn.training:Setting up for training...
# INFO:sleap.nn.training:Setting up pipeline builders...
# INFO:sleap.nn.training:Setting up model...
# INFO:sleap.nn.training:Building test pipeline...
# INFO:sleap.nn.training:Loaded test example. [2.004s]
# INFO:sleap.nn.training:  Input shape: (576, 1024, 1)
# INFO:sleap.nn.training:Created Keras model.
# INFO:sleap.nn.training:  Backbone: UNet(stacks=1, filters=24, filters_rate=1.5, kernel_size=3, stem_kernel_size=7, convs_per_block=2, stem_blocks=0, down_blocks=6, middle_block=True, up_blocks=5, up_interpolate=True, block_contraction=False)
# INFO:sleap.nn.training:  Max stride: 64
# INFO:sleap.nn.training:  Parameters: 3,848,881
# INFO:sleap.nn.training:  Heads:
# INFO:sleap.nn.training:    [0] = MultiInstanceConfmapsHead(part_names=['r1', 'r2', 'r3', 'r4', 'r5', 'r6'], sigma=2.5, output_stride=2, loss_weight=1.0)
# INFO:sleap.nn.training:    [1] = PartAffinityFieldsHead(edges=[('r1', 'r2'), ('r2', 'r3'), ('r3', 'r4'), ('r4', 'r5'), ('r5', 'r6')], sigma=75.0, output_stride=8, loss_weight=1.0)
# INFO:sleap.nn.training:  Outputs:
# INFO:sleap.nn.training:    [0] = KerasTensor(type_spec=TensorSpec(shape=(None, 288, 512, 6), dtype=tf.float32, name=None), name='MultiInstanceConfmapsHead/BiasAdd:0', description="created by layer 'MultiInstanceConfmapsHead'")
# INFO:sleap.nn.training:    [1] = KerasTensor(type_spec=TensorSpec(shape=(None, 72, 128, 10), dtype=tf.float32, name=None), name='PartAffinityFieldsHead/BiasAdd:0', description="created by layer 'PartAffinityFieldsHead'")
# INFO:sleap.nn.training:Training from scratch
# INFO:sleap.nn.training:Setting up data pipelines...
# INFO:sleap.nn.training:Training set: n = 143
# INFO:sleap.nn.training:Validation set: n = 31
# INFO:sleap.nn.training:Setting up optimization...
# INFO:sleap.nn.training:  Learning rate schedule: LearningRateScheduleConfig(reduce_on_plateau=True, reduction_factor=0.5, plateau_min_delta=1e-06, plateau_patience=5, plateau_cooldown=3, min_learning_rate=1e-08)
# INFO:sleap.nn.training:  Early stopping: EarlyStoppingConfig(stop_training_on_plateau=True, plateau_min_delta=1e-06, plateau_patience=10)
# INFO:sleap.nn.training:Setting up outputs...
# INFO:sleap.nn.training:Created run path: D:\SLEAP\20250530_seminal_root_generalist\wheat\train_test_split.v000\models\250530_213047.multi_instance.n=174
# INFO:sleap.nn.training:Setting up visualization...
# INFO:sleap.nn.training:Finished trainer set up. [4.8s]
# INFO:sleap.nn.training:Creating tf.data.Datasets for training data generation...
# INFO:sleap.nn.training:Finished creating training datasets. [5.5s]
# INFO:sleap.nn.training:Starting training loop...
# Epoch 1/200
# 200/200 - 40s - loss: 0.0038 - MultiInstanceConfmapsHead_loss: 5.0744e-04 - PartAffinityFieldsHead_loss: 0.0033 - val_loss: 0.0029 - val_MultiInstanceConfmapsHead_loss: 4.8905e-04 - val_PartAffinityFieldsHead_loss: 0.0025 - lr: 1.0000e-04 - 40s/epoch - 199ms/step
# Epoch 2/200
# 200/200 - 35s - loss: 0.0026 - MultiInstanceConfmapsHead_loss: 4.4050e-04 - PartAffinityFieldsHead_loss: 0.0021 - val_loss: 0.0024 - val_MultiInstanceConfmapsHead_loss: 4.4663e-04 - val_PartAffinityFieldsHead_loss: 0.0020 - lr: 1.0000e-04 - 35s/epoch - 175ms/step
# Epoch 3/200
# 200/200 - 33s - loss: 0.0021 - MultiInstanceConfmapsHead_loss: 3.8910e-04 - PartAffinityFieldsHead_loss: 0.0017 - val_loss: 0.0021 - val_MultiInstanceConfmapsHead_loss: 3.9231e-04 - val_PartAffinityFieldsHead_loss: 0.0017 - lr: 1.0000e-04 - 33s/epoch - 167ms/step
# Epoch 4/200
# 200/200 - 32s - loss: 0.0018 - MultiInstanceConfmapsHead_loss: 3.5467e-04 - PartAffinityFieldsHead_loss: 0.0015 - val_loss: 0.0022 - val_MultiInstanceConfmapsHead_loss: 3.9815e-04 - val_PartAffinityFieldsHead_loss: 0.0018 - lr: 1.0000e-04 - 32s/epoch - 160ms/step
# Epoch 5/200
# 200/200 - 33s - loss: 0.0017 - MultiInstanceConfmapsHead_loss: 3.3742e-04 - PartAffinityFieldsHead_loss: 0.0014 - val_loss: 0.0019 - val_MultiInstanceConfmapsHead_loss: 3.6236e-04 - val_PartAffinityFieldsHead_loss: 0.0016 - lr: 1.0000e-04 - 33s/epoch - 166ms/step
# Epoch 6/200
# 200/200 - 33s - loss: 0.0016 - MultiInstanceConfmapsHead_loss: 3.2497e-04 - PartAffinityFieldsHead_loss: 0.0013 - val_loss: 0.0018 - val_MultiInstanceConfmapsHead_loss: 3.5355e-04 - val_PartAffinityFieldsHead_loss: 0.0015 - lr: 1.0000e-04 - 33s/epoch - 163ms/step
# Epoch 7/200
# 200/200 - 33s - loss: 0.0015 - MultiInstanceConfmapsHead_loss: 3.0366e-04 - PartAffinityFieldsHead_loss: 0.0012 - val_loss: 0.0018 - val_MultiInstanceConfmapsHead_loss: 3.5009e-04 - val_PartAffinityFieldsHead_loss: 0.0015 - lr: 1.0000e-04 - 33s/epoch - 163ms/step
# Epoch 8/200
# 200/200 - 33s - loss: 0.0014 - MultiInstanceConfmapsHead_loss: 2.9582e-04 - PartAffinityFieldsHead_loss: 0.0011 - val_loss: 0.0018 - val_MultiInstanceConfmapsHead_loss: 3.5240e-04 - val_PartAffinityFieldsHead_loss: 0.0015 - lr: 1.0000e-04 - 33s/epoch - 166ms/step
# Epoch 9/200
# 200/200 - 32s - loss: 0.0014 - MultiInstanceConfmapsHead_loss: 2.8914e-04 - PartAffinityFieldsHead_loss: 0.0011 - val_loss: 0.0018 - val_MultiInstanceConfmapsHead_loss: 3.4620e-04 - val_PartAffinityFieldsHead_loss: 0.0015 - lr: 1.0000e-04 - 32s/epoch - 160ms/step
# Epoch 10/200
# 200/200 - 34s - loss: 0.0013 - MultiInstanceConfmapsHead_loss: 2.7802e-04 - PartAffinityFieldsHead_loss: 0.0011 - val_loss: 0.0018 - val_MultiInstanceConfmapsHead_loss: 3.4680e-04 - val_PartAffinityFieldsHead_loss: 0.0014 - lr: 1.0000e-04 - 34s/epoch - 168ms/step
# Epoch 11/200
# 200/200 - 32s - loss: 0.0012 - MultiInstanceConfmapsHead_loss: 2.6085e-04 - PartAffinityFieldsHead_loss: 9.4366e-04 - val_loss: 0.0019 - val_MultiInstanceConfmapsHead_loss: 3.6946e-04 - val_PartAffinityFieldsHead_loss: 0.0015 - lr: 1.0000e-04 - 32s/epoch - 160ms/step
# Epoch 12/200
# 200/200 - 33s - loss: 0.0012 - MultiInstanceConfmapsHead_loss: 2.5745e-04 - PartAffinityFieldsHead_loss: 9.3398e-04 - val_loss: 0.0017 - val_MultiInstanceConfmapsHead_loss: 3.3085e-04 - val_PartAffinityFieldsHead_loss: 0.0014 - lr: 1.0000e-04 - 33s/epoch - 167ms/step
# Epoch 13/200
# 200/200 - 32s - loss: 0.0012 - MultiInstanceConfmapsHead_loss: 2.5235e-04 - PartAffinityFieldsHead_loss: 9.0390e-04 - val_loss: 0.0018 - val_MultiInstanceConfmapsHead_loss: 3.4606e-04 - val_PartAffinityFieldsHead_loss: 0.0015 - lr: 1.0000e-04 - 32s/epoch - 160ms/step
# Epoch 14/200
# 200/200 - 33s - loss: 0.0011 - MultiInstanceConfmapsHead_loss: 2.4397e-04 - PartAffinityFieldsHead_loss: 8.6404e-04 - val_loss: 0.0018 - val_MultiInstanceConfmapsHead_loss: 3.4151e-04 - val_PartAffinityFieldsHead_loss: 0.0015 - lr: 1.0000e-04 - 33s/epoch - 163ms/step
# Epoch 15/200
# 200/200 - 33s - loss: 0.0011 - MultiInstanceConfmapsHead_loss: 2.3622e-04 - PartAffinityFieldsHead_loss: 8.3082e-04 - val_loss: 0.0017 - val_MultiInstanceConfmapsHead_loss: 3.3532e-04 - val_PartAffinityFieldsHead_loss: 0.0014 - lr: 1.0000e-04 - 33s/epoch - 166ms/step
# Epoch 16/200
# 200/200 - 33s - loss: 9.9487e-04 - MultiInstanceConfmapsHead_loss: 2.2643e-04 - PartAffinityFieldsHead_loss: 7.6844e-04 - val_loss: 0.0016 - val_MultiInstanceConfmapsHead_loss: 3.2723e-04 - val_PartAffinityFieldsHead_loss: 0.0013 - lr: 1.0000e-04 - 33s/epoch - 163ms/step
# Epoch 17/200
# 200/200 - 32s - loss: 9.9470e-04 - MultiInstanceConfmapsHead_loss: 2.2456e-04 - PartAffinityFieldsHead_loss: 7.7014e-04 - val_loss: 0.0017 - val_MultiInstanceConfmapsHead_loss: 3.3353e-04 - val_PartAffinityFieldsHead_loss: 0.0013 - lr: 1.0000e-04 - 32s/epoch - 159ms/step
# Epoch 18/200
# 200/200 - 33s - loss: 9.5765e-04 - MultiInstanceConfmapsHead_loss: 2.1839e-04 - PartAffinityFieldsHead_loss: 7.3926e-04 - val_loss: 0.0017 - val_MultiInstanceConfmapsHead_loss: 3.3369e-04 - val_PartAffinityFieldsHead_loss: 0.0013 - lr: 1.0000e-04 - 33s/epoch - 163ms/step
# Epoch 19/200
# 200/200 - 32s - loss: 8.5811e-04 - MultiInstanceConfmapsHead_loss: 2.0101e-04 - PartAffinityFieldsHead_loss: 6.5710e-04 - val_loss: 0.0017 - val_MultiInstanceConfmapsHead_loss: 3.4191e-04 - val_PartAffinityFieldsHead_loss: 0.0013 - lr: 1.0000e-04 - 32s/epoch - 162ms/step
# Epoch 20/200
# 200/200 - 33s - loss: 8.5434e-04 - MultiInstanceConfmapsHead_loss: 2.0084e-04 - PartAffinityFieldsHead_loss: 6.5350e-04 - val_loss: 0.0016 - val_MultiInstanceConfmapsHead_loss: 3.3183e-04 - val_PartAffinityFieldsHead_loss: 0.0013 - lr: 1.0000e-04 - 33s/epoch - 166ms/step
# Epoch 21/200
# 200/200 - 33s - loss: 8.1048e-04 - MultiInstanceConfmapsHead_loss: 1.9262e-04 - PartAffinityFieldsHead_loss: 6.1786e-04 - val_loss: 0.0016 - val_MultiInstanceConfmapsHead_loss: 3.3729e-04 - val_PartAffinityFieldsHead_loss: 0.0013 - lr: 1.0000e-04 - 33s/epoch - 164ms/step
# Epoch 22/200
# 200/200 - 33s - loss: 8.1978e-04 - MultiInstanceConfmapsHead_loss: 1.9402e-04 - PartAffinityFieldsHead_loss: 6.2576e-04 - val_loss: 0.0016 - val_MultiInstanceConfmapsHead_loss: 3.1522e-04 - val_PartAffinityFieldsHead_loss: 0.0013 - lr: 1.0000e-04 - 33s/epoch - 163ms/step
# Epoch 23/200
# 200/200 - 33s - loss: 7.8421e-04 - MultiInstanceConfmapsHead_loss: 1.8670e-04 - PartAffinityFieldsHead_loss: 5.9751e-04 - val_loss: 0.0016 - val_MultiInstanceConfmapsHead_loss: 3.2975e-04 - val_PartAffinityFieldsHead_loss: 0.0012 - lr: 1.0000e-04 - 33s/epoch - 163ms/step
# Epoch 24/200
# 200/200 - 32s - loss: 7.6582e-04 - MultiInstanceConfmapsHead_loss: 1.8232e-04 - PartAffinityFieldsHead_loss: 5.8350e-04 - val_loss: 0.0018 - val_MultiInstanceConfmapsHead_loss: 3.6637e-04 - val_PartAffinityFieldsHead_loss: 0.0014 - lr: 1.0000e-04 - 32s/epoch - 160ms/step
# Epoch 25/200
# 200/200 - 33s - loss: 7.0198e-04 - MultiInstanceConfmapsHead_loss: 1.7014e-04 - PartAffinityFieldsHead_loss: 5.3183e-04 - val_loss: 0.0015 - val_MultiInstanceConfmapsHead_loss: 3.1126e-04 - val_PartAffinityFieldsHead_loss: 0.0012 - lr: 1.0000e-04 - 33s/epoch - 166ms/step
# Epoch 26/200
# 200/200 - 32s - loss: 6.9643e-04 - MultiInstanceConfmapsHead_loss: 1.6932e-04 - PartAffinityFieldsHead_loss: 5.2711e-04 - val_loss: 0.0018 - val_MultiInstanceConfmapsHead_loss: 3.5099e-04 - val_PartAffinityFieldsHead_loss: 0.0014 - lr: 1.0000e-04 - 32s/epoch - 160ms/step
# Epoch 27/200
# 200/200 - 33s - loss: 6.7464e-04 - MultiInstanceConfmapsHead_loss: 1.6494e-04 - PartAffinityFieldsHead_loss: 5.0970e-04 - val_loss: 0.0015 - val_MultiInstanceConfmapsHead_loss: 3.3573e-04 - val_PartAffinityFieldsHead_loss: 0.0012 - lr: 1.0000e-04 - 33s/epoch - 163ms/step
# Epoch 28/200
# 200/200 - 33s - loss: 6.5010e-04 - MultiInstanceConfmapsHead_loss: 1.5885e-04 - PartAffinityFieldsHead_loss: 4.9125e-04 - val_loss: 0.0018 - val_MultiInstanceConfmapsHead_loss: 3.6202e-04 - val_PartAffinityFieldsHead_loss: 0.0015 - lr: 1.0000e-04 - 33s/epoch - 163ms/step
# Epoch 29/200
# 200/200 - 32s - loss: 6.1765e-04 - MultiInstanceConfmapsHead_loss: 1.5197e-04 - PartAffinityFieldsHead_loss: 4.6568e-04 - val_loss: 0.0017 - val_MultiInstanceConfmapsHead_loss: 3.4888e-04 - val_PartAffinityFieldsHead_loss: 0.0013 - lr: 1.0000e-04 - 32s/epoch - 162ms/step
# Epoch 30/200
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 200/200 - 33s - loss: 6.2353e-04 - MultiInstanceConfmapsHead_loss: 1.5371e-04 - PartAffinityFieldsHead_loss: 4.6982e-04 - val_loss: 0.0017 - val_MultiInstanceConfmapsHead_loss: 3.6135e-04 - val_PartAffinityFieldsHead_loss: 0.0014 - lr: 1.0000e-04 - 33s/epoch - 164ms/step
# Epoch 31/200
# 200/200 - 32s - loss: 5.3179e-04 - MultiInstanceConfmapsHead_loss: 1.2918e-04 - PartAffinityFieldsHead_loss: 4.0261e-04 - val_loss: 0.0016 - val_MultiInstanceConfmapsHead_loss: 3.3326e-04 - val_PartAffinityFieldsHead_loss: 0.0012 - lr: 5.0000e-05 - 32s/epoch - 162ms/step
# Epoch 32/200
# 200/200 - 32s - loss: 5.2033e-04 - MultiInstanceConfmapsHead_loss: 1.2637e-04 - PartAffinityFieldsHead_loss: 3.9396e-04 - val_loss: 0.0016 - val_MultiInstanceConfmapsHead_loss: 3.5091e-04 - val_PartAffinityFieldsHead_loss: 0.0012 - lr: 5.0000e-05 - 32s/epoch - 162ms/step
# Epoch 33/200
# 200/200 - 33s - loss: 4.8934e-04 - MultiInstanceConfmapsHead_loss: 1.1893e-04 - PartAffinityFieldsHead_loss: 3.7041e-04 - val_loss: 0.0016 - val_MultiInstanceConfmapsHead_loss: 3.5210e-04 - val_PartAffinityFieldsHead_loss: 0.0013 - lr: 5.0000e-05 - 33s/epoch - 163ms/step
# Epoch 34/200
# 200/200 - 33s - loss: 4.9073e-04 - MultiInstanceConfmapsHead_loss: 1.1967e-04 - PartAffinityFieldsHead_loss: 3.7107e-04 - val_loss: 0.0017 - val_MultiInstanceConfmapsHead_loss: 3.5968e-04 - val_PartAffinityFieldsHead_loss: 0.0013 - lr: 5.0000e-05 - 33s/epoch - 163ms/step
# Epoch 35/200
# 200/200 - 33s - loss: 4.9889e-04 - MultiInstanceConfmapsHead_loss: 1.2095e-04 - PartAffinityFieldsHead_loss: 3.7794e-04 - val_loss: 0.0017 - val_MultiInstanceConfmapsHead_loss: 3.7408e-04 - val_PartAffinityFieldsHead_loss: 0.0014 - lr: 5.0000e-05 - 33s/epoch - 163ms/step
# Epoch 00035: early stopping
# INFO:sleap.nn.training:Finished training loop. [19.2 min]
# INFO:sleap.nn.training:Saving evaluation metrics to model folder...
# Predicting... -------------------------------------- 100% ETA: 0:00:00 20.0 FPS
# INFO:sleap.nn.evals:Saved predictions: D:\SLEAP\20250530_seminal_root_generalist\wheat\train_test_split.v000\models\250530_213047.multi_instance.n=174\labels_pr.train.slp
# INFO:sleap.nn.evals:Saved metrics: D:\SLEAP\20250530_seminal_root_generalist\wheat\train_test_split.v000\models\250530_213047.multi_instance.n=174\metrics.train.npz
# INFO:sleap.nn.evals:OKS mAP: 0.359266
# Predicting... -------------------------------------- 100% ETA: 0:00:00 11.5 FPS
# INFO:sleap.nn.evals:Saved predictions: D:\SLEAP\20250530_seminal_root_generalist\wheat\train_test_split.v000\models\250530_213047.multi_instance.n=174\labels_pr.val.slp
# INFO:sleap.nn.evals:Saved metrics: D:\SLEAP\20250530_seminal_root_generalist\wheat\train_test_split.v000\models\250530_213047.multi_instance.n=174\metrics.val.npz
# INFO:sleap.nn.evals:OKS mAP: 0.046595
# WARNING:tensorflow:5 out of the last 45 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000023A2D267D38> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Predicting... --------------------------------------- 100% ETA: 0:00:00 7.7 FPS
# INFO:sleap.nn.evals:Saved predictions: D:\SLEAP\20250530_seminal_root_generalist\wheat\train_test_split.v000\models\250530_213047.multi_instance.n=174\labels_pr.test.slp
# INFO:sleap.nn.evals:Saved metrics: D:\SLEAP\20250530_seminal_root_generalist\wheat\train_test_split.v000\models\250530_213047.multi_instance.n=174\metrics.test.npz
# INFO:sleap.nn.evals:OKS mAP: 0.067452
#
# INFO:root:Latest run directory: D:\SLEAP\20250530_seminal_root_generalist\wheat\train_test_split.v000\models\250530_213047.multi_instance.n=174
# wandb: Adding directory to artifact (D:\SLEAP\20250530_seminal_root_generalist\wheat\train_test_split.v000\models\250530_213047.multi_instance.n=174)...
# W&B run configuration updated with training configuration.
# Done. 0.2s
# Model path: D:/SLEAP/20250530_seminal_root_generalist/wheat/train_test_split.v000/models/250530_213047.multi_instance.n=174
# Metrics loaded from model directory: D:/SLEAP/20250530_seminal_root_generalist/wheat/train_test_split.v000/models/250530_213047.multi_instance.n=174
# Model artifact '20250530_wheat_seminal_sweep_v000' logged to W&B with evaluations.
# VBox(children=(Label(value='8.113 MB of 60.702 MB uploaded\r'), FloatProgress(value=0.13365659892296092, max=1…
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>dist_avg</td><td>1.97477</td></tr><tr><td>dist_p50</td><td>0.78359</td></tr><tr><td>dist_p90</td><td>4.45364</td></tr><tr><td>dist_p95</td><td>7.47679</td></tr><tr><td>dist_p99</td><td>19.13207</td></tr><tr><td>dist_std</td><td>3.4741</td></tr><tr><td>model_name</td><td>250530_213047.multi_...</td></tr><tr><td>model_path</td><td>D:/SLEAP/20250530_se...</td></tr><tr><td>oks_map</td><td>0.06745</td></tr><tr><td>oks_mar</td><td>0.1496</td></tr><tr><td>vis_prec</td><td>0.99522</td></tr><tr><td>vis_recall</td><td>0.86546</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">20250530_wheat_seminal_sweep_training_v000</strong> at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/8lq35ozd' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/8lq35ozd</a><br/> View project at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a><br/>Synced 4 W&B file(s), 0 media file(s), 24 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250530_213037-8lq35ozd\logs</code>
# INFO:root:W&B run for version 0 finished.
# INFO:root:Completed training for version 0.
# wandb: Agent Starting Run: 1dwo131x with config:
# wandb: 	data.preprocessing.input_scaling: 0.75
# INFO:root:Starting training for version 0...
# INFO:root:Directory path for version 0: D:\SLEAP\20250530_seminal_root_generalist\wheat\train_test_split.v000
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# Tracking run with wandb version 0.18.6
# Run data is saved locally in <code>e:\repositories\sleap-roots-training\wandb\run-20250530_215043-1dwo131x</code>
# Syncing run <strong><a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/1dwo131x' target="_blank">20250530_wheat_seminal_sweep_training_v000</a></strong> to <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/sweeps/8tv8mpjm' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/sweeps/8tv8mpjm</a>
#  View project at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a>
#  View sweep at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/sweeps/8tv8mpjm' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/sweeps/8tv8mpjm</a>
#  View run at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/1dwo131x' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/1dwo131x</a>
# INFO:root:Updating configuration with W&B parameters.
# INFO:root:Original Parameters: {
#     "data": {
#         "labels": {
#             "training_labels": "D:\\SLEAP\\20250530_seminal_root_generalist\\wheat\\train_test_split.v000\\train.pkg.slp",
#             "validation_labels": "D:\\SLEAP\\20250530_seminal_root_generalist\\wheat\\train_test_split.v000\\val.pkg.slp",
#             "validation_fraction": 0.1,
#             "test_labels": "D:\\SLEAP\\20250530_seminal_root_generalist\\wheat\\train_test_split.v000\\test.pkg.slp",
#             "split_by_inds": false,
#             "training_inds": null,
#             "validation_inds": null,
#             "test_inds": null,
#             "search_path_hints": [],
#             "skeletons": []
#         },
#         "preprocessing": {
#             "ensure_rgb": false,
#             "ensure_grayscale": false,
#             "imagenet_mode": null,
#             "input_scaling": 1.0,
#             "pad_to_stride": null,
#             "resize_and_pad_to_target": true,
#             "target_height": null,
#             "target_width": null
#         },
#         "instance_cropping": {
#             "center_on_part": null,
#             "crop_size": null,
#             "crop_size_detection_padding": 16
#         }
#     },
#     "model": {
#         "backbone": {
#             "leap": null,
#             "unet": {
#                 "stem_stride": null,
#                 "max_stride": 64,
#                 "output_stride": 2,
#                 "filters": 24,
#                 "filters_rate": 1.5,
#                 "middle_block": true,
#                 "up_interpolate": true,
#                 "stacks": 1
#             },
#             "hourglass": null,
#             "resnet": null,
#             "pretrained_encoder": null
#         },
#         "heads": {
#             "single_instance": null,
#             "centroid": null,
#             "centered_instance": null,
#             "multi_instance": {
#                 "confmaps": {
#                     "part_names": null,
#                     "sigma": 2.5,
#                     "output_stride": 2,
#                     "loss_weight": 1.0,
#                     "offset_refinement": false
#                 },
#                 "pafs": {
#                     "edges": null,
#                     "sigma": 75.0,
#                     "output_stride": 8,
# ...
# INFO:sleap.nn.training:Training set: n = 143
# INFO:sleap.nn.training:Validation set: n = 31
# INFO:sleap.nn.training:Setting up optimization...
# INFO:sleap.nn.training:  Learning rate schedule: LearningRateScheduleConfig(reduce_on_plateau=True, reduction_factor=0.5, plateau_min_delta=1e-06, plateau_patience=5, plateau_cooldown=3, min_learning_rate=1e-08)
# INFO:sleap.nn.training:  Early stopping: EarlyStoppingConfig(stop_training_on_plateau=True, plateau_min_delta=1e-06, plateau_patience=10)
# INFO:sleap.nn.training:Setting up outputs...
# INFO:sleap.nn.training:Created run path: D:\SLEAP\20250530_seminal_root_generalist\wheat\train_test_split.v005\models\250531_065825.multi_instance.n=174
# INFO:sleap.nn.training:Setting up visualization...
# INFO:sleap.nn.training:Finished trainer set up. [4.5s]
# INFO:sleap.nn.training:Creating tf.data.Datasets for training data generation...
# INFO:sleap.nn.training:Finished creating training datasets. [5.6s]
# INFO:sleap.nn.training:Starting training loop...
# Epoch 1/200
# 200/200 - 107s - loss: 0.0018 - MultiInstanceConfmapsHead_loss: 1.5902e-04 - PartAffinityFieldsHead_loss: 0.0017 - val_loss: 0.0015 - val_MultiInstanceConfmapsHead_loss: 1.4404e-04 - val_PartAffinityFieldsHead_loss: 0.0013 - lr: 1.0000e-04 - 107s/epoch - 537ms/step
# Epoch 2/200
# 200/200 - 101s - loss: 0.0014 - MultiInstanceConfmapsHead_loss: 1.3954e-04 - PartAffinityFieldsHead_loss: 0.0012 - val_loss: 0.0013 - val_MultiInstanceConfmapsHead_loss: 1.4147e-04 - val_PartAffinityFieldsHead_loss: 0.0012 - lr: 1.0000e-04 - 101s/epoch - 504ms/step
# Epoch 3/200
# 200/200 - 101s - loss: 0.0012 - MultiInstanceConfmapsHead_loss: 1.3378e-04 - PartAffinityFieldsHead_loss: 0.0010 - val_loss: 0.0012 - val_MultiInstanceConfmapsHead_loss: 1.3413e-04 - val_PartAffinityFieldsHead_loss: 0.0011 - lr: 1.0000e-04 - 101s/epoch - 507ms/step
# Epoch 4/200
# 200/200 - 99s - loss: 0.0011 - MultiInstanceConfmapsHead_loss: 1.2880e-04 - PartAffinityFieldsHead_loss: 9.3223e-04 - val_loss: 0.0011 - val_MultiInstanceConfmapsHead_loss: 1.2952e-04 - val_PartAffinityFieldsHead_loss: 9.9615e-04 - lr: 1.0000e-04 - 99s/epoch - 495ms/step
# Epoch 5/200
# 200/200 - 100s - loss: 9.8211e-04 - MultiInstanceConfmapsHead_loss: 1.2393e-04 - PartAffinityFieldsHead_loss: 8.5818e-04 - val_loss: 0.0010 - val_MultiInstanceConfmapsHead_loss: 1.2367e-04 - val_PartAffinityFieldsHead_loss: 9.0290e-04 - lr: 1.0000e-04 - 100s/epoch - 499ms/step
# Epoch 6/200
# 200/200 - 99s - loss: 9.1650e-04 - MultiInstanceConfmapsHead_loss: 1.1986e-04 - PartAffinityFieldsHead_loss: 7.9664e-04 - val_loss: 9.2482e-04 - val_MultiInstanceConfmapsHead_loss: 1.1656e-04 - val_PartAffinityFieldsHead_loss: 8.0826e-04 - lr: 1.0000e-04 - 99s/epoch - 496ms/step
# Epoch 7/200
# 200/200 - 98s - loss: 8.7762e-04 - MultiInstanceConfmapsHead_loss: 1.1608e-04 - PartAffinityFieldsHead_loss: 7.6154e-04 - val_loss: 9.2929e-04 - val_MultiInstanceConfmapsHead_loss: 1.1823e-04 - val_PartAffinityFieldsHead_loss: 8.1106e-04 - lr: 1.0000e-04 - 98s/epoch - 490ms/step
# Epoch 8/200
# 200/200 - 99s - loss: 8.2448e-04 - MultiInstanceConfmapsHead_loss: 1.1183e-04 - PartAffinityFieldsHead_loss: 7.1266e-04 - val_loss: 9.3917e-04 - val_MultiInstanceConfmapsHead_loss: 1.1235e-04 - val_PartAffinityFieldsHead_loss: 8.2682e-04 - lr: 1.0000e-04 - 99s/epoch - 496ms/step
# Epoch 9/200
# 200/200 - 101s - loss: 8.1593e-04 - MultiInstanceConfmapsHead_loss: 1.0896e-04 - PartAffinityFieldsHead_loss: 7.0697e-04 - val_loss: 9.0634e-04 - val_MultiInstanceConfmapsHead_loss: 1.0855e-04 - val_PartAffinityFieldsHead_loss: 7.9779e-04 - lr: 1.0000e-04 - 101s/epoch - 503ms/step
# Epoch 10/200
# 200/200 - 100s - loss: 7.6238e-04 - MultiInstanceConfmapsHead_loss: 1.0559e-04 - PartAffinityFieldsHead_loss: 6.5679e-04 - val_loss: 8.6941e-04 - val_MultiInstanceConfmapsHead_loss: 1.0951e-04 - val_PartAffinityFieldsHead_loss: 7.5990e-04 - lr: 1.0000e-04 - 100s/epoch - 499ms/step
# Epoch 11/200
# 200/200 - 98s - loss: 7.4156e-04 - MultiInstanceConfmapsHead_loss: 1.0388e-04 - PartAffinityFieldsHead_loss: 6.3768e-04 - val_loss: 8.9864e-04 - val_MultiInstanceConfmapsHead_loss: 1.1545e-04 - val_PartAffinityFieldsHead_loss: 7.8319e-04 - lr: 1.0000e-04 - 98s/epoch - 489ms/step
# Epoch 12/200
# 200/200 - 101s - loss: 6.8903e-04 - MultiInstanceConfmapsHead_loss: 9.9319e-05 - PartAffinityFieldsHead_loss: 5.8971e-04 - val_loss: 8.5148e-04 - val_MultiInstanceConfmapsHead_loss: 1.0658e-04 - val_PartAffinityFieldsHead_loss: 7.4490e-04 - lr: 1.0000e-04 - 101s/epoch - 503ms/step
# Epoch 13/200
# 200/200 - 99s - loss: 6.7839e-04 - MultiInstanceConfmapsHead_loss: 9.8463e-05 - PartAffinityFieldsHead_loss: 5.7993e-04 - val_loss: 9.2692e-04 - val_MultiInstanceConfmapsHead_loss: 1.1129e-04 - val_PartAffinityFieldsHead_loss: 8.1564e-04 - lr: 1.0000e-04 - 99s/epoch - 497ms/step
# Epoch 14/200
# 200/200 - 100s - loss: 6.5566e-04 - MultiInstanceConfmapsHead_loss: 9.6510e-05 - PartAffinityFieldsHead_loss: 5.5915e-04 - val_loss: 8.1862e-04 - val_MultiInstanceConfmapsHead_loss: 1.0418e-04 - val_PartAffinityFieldsHead_loss: 7.1445e-04 - lr: 1.0000e-04 - 100s/epoch - 502ms/step
# Epoch 15/200
# 200/200 - 98s - loss: 6.1675e-04 - MultiInstanceConfmapsHead_loss: 9.3290e-05 - PartAffinityFieldsHead_loss: 5.2346e-04 - val_loss: 8.7751e-04 - val_MultiInstanceConfmapsHead_loss: 1.0981e-04 - val_PartAffinityFieldsHead_loss: 7.6770e-04 - lr: 1.0000e-04 - 98s/epoch - 490ms/step
# Epoch 16/200
# 200/200 - 100s - loss: 6.0394e-04 - MultiInstanceConfmapsHead_loss: 9.2251e-05 - PartAffinityFieldsHead_loss: 5.1169e-04 - val_loss: 8.1663e-04 - val_MultiInstanceConfmapsHead_loss: 1.0720e-04 - val_PartAffinityFieldsHead_loss: 7.0942e-04 - lr: 1.0000e-04 - 100s/epoch - 499ms/step
# Epoch 17/200
# 200/200 - 100s - loss: 5.7281e-04 - MultiInstanceConfmapsHead_loss: 8.9716e-05 - PartAffinityFieldsHead_loss: 4.8309e-04 - val_loss: 7.8299e-04 - val_MultiInstanceConfmapsHead_loss: 1.0124e-04 - val_PartAffinityFieldsHead_loss: 6.8175e-04 - lr: 1.0000e-04 - 100s/epoch - 500ms/step
# Epoch 18/200
# 200/200 - 96s - loss: 5.4258e-04 - MultiInstanceConfmapsHead_loss: 8.7414e-05 - PartAffinityFieldsHead_loss: 4.5517e-04 - val_loss: 8.3634e-04 - val_MultiInstanceConfmapsHead_loss: 1.0416e-04 - val_PartAffinityFieldsHead_loss: 7.3218e-04 - lr: 1.0000e-04 - 96s/epoch - 478ms/step
# Epoch 19/200
# 200/200 - 99s - loss: 5.3871e-04 - MultiInstanceConfmapsHead_loss: 8.6448e-05 - PartAffinityFieldsHead_loss: 4.5226e-04 - val_loss: 7.9855e-04 - val_MultiInstanceConfmapsHead_loss: 1.0318e-04 - val_PartAffinityFieldsHead_loss: 6.9537e-04 - lr: 1.0000e-04 - 99s/epoch - 495ms/step
# Epoch 20/200
# 200/200 - 100s - loss: 5.1000e-04 - MultiInstanceConfmapsHead_loss: 8.4229e-05 - PartAffinityFieldsHead_loss: 4.2577e-04 - val_loss: 8.5715e-04 - val_MultiInstanceConfmapsHead_loss: 1.0513e-04 - val_PartAffinityFieldsHead_loss: 7.5202e-04 - lr: 1.0000e-04 - 100s/epoch - 499ms/step
# Epoch 21/200
# 200/200 - 99s - loss: 4.7568e-04 - MultiInstanceConfmapsHead_loss: 8.1214e-05 - PartAffinityFieldsHead_loss: 3.9447e-04 - val_loss: 7.5047e-04 - val_MultiInstanceConfmapsHead_loss: 1.0040e-04 - val_PartAffinityFieldsHead_loss: 6.5008e-04 - lr: 1.0000e-04 - 99s/epoch - 496ms/step
# Epoch 22/200
# 200/200 - 98s - loss: 4.8005e-04 - MultiInstanceConfmapsHead_loss: 8.1541e-05 - PartAffinityFieldsHead_loss: 3.9851e-04 - val_loss: 8.0398e-04 - val_MultiInstanceConfmapsHead_loss: 1.0248e-04 - val_PartAffinityFieldsHead_loss: 7.0150e-04 - lr: 1.0000e-04 - 98s/epoch - 490ms/step
# Epoch 23/200
# 200/200 - 99s - loss: 4.5546e-04 - MultiInstanceConfmapsHead_loss: 7.9581e-05 - PartAffinityFieldsHead_loss: 3.7588e-04 - val_loss: 9.8136e-04 - val_MultiInstanceConfmapsHead_loss: 1.1089e-04 - val_PartAffinityFieldsHead_loss: 8.7047e-04 - lr: 1.0000e-04 - 99s/epoch - 493ms/step
# Epoch 24/200
# 200/200 - 101s - loss: 4.2660e-04 - MultiInstanceConfmapsHead_loss: 7.6717e-05 - PartAffinityFieldsHead_loss: 3.4988e-04 - val_loss: 6.6660e-04 - val_MultiInstanceConfmapsHead_loss: 9.4903e-05 - val_PartAffinityFieldsHead_loss: 5.7170e-04 - lr: 1.0000e-04 - 101s/epoch - 503ms/step
# Epoch 25/200
# 200/200 - 97s - loss: 4.2867e-04 - MultiInstanceConfmapsHead_loss: 7.5859e-05 - PartAffinityFieldsHead_loss: 3.5281e-04 - val_loss: 9.2780e-04 - val_MultiInstanceConfmapsHead_loss: 1.0639e-04 - val_PartAffinityFieldsHead_loss: 8.2142e-04 - lr: 1.0000e-04 - 97s/epoch - 486ms/step
# Epoch 26/200
# 200/200 - 100s - loss: 4.0108e-04 - MultiInstanceConfmapsHead_loss: 7.3105e-05 - PartAffinityFieldsHead_loss: 3.2797e-04 - val_loss: 7.9475e-04 - val_MultiInstanceConfmapsHead_loss: 9.9756e-05 - val_PartAffinityFieldsHead_loss: 6.9499e-04 - lr: 1.0000e-04 - 100s/epoch - 498ms/step
# Epoch 27/200
# 200/200 - 99s - loss: 3.8618e-04 - MultiInstanceConfmapsHead_loss: 7.2109e-05 - PartAffinityFieldsHead_loss: 3.1407e-04 - val_loss: 8.2472e-04 - val_MultiInstanceConfmapsHead_loss: 1.0930e-04 - val_PartAffinityFieldsHead_loss: 7.1542e-04 - lr: 1.0000e-04 - 99s/epoch - 497ms/step
# Epoch 28/200
# 200/200 - 98s - loss: 3.7181e-04 - MultiInstanceConfmapsHead_loss: 7.0746e-05 - PartAffinityFieldsHead_loss: 3.0106e-04 - val_loss: 9.0794e-04 - val_MultiInstanceConfmapsHead_loss: 1.0342e-04 - val_PartAffinityFieldsHead_loss: 8.0451e-04 - lr: 1.0000e-04 - 98s/epoch - 491ms/step
# Epoch 29/200
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 200/200 - 99s - loss: 3.5331e-04 - MultiInstanceConfmapsHead_loss: 6.8481e-05 - PartAffinityFieldsHead_loss: 2.8483e-04 - val_loss: 9.3413e-04 - val_MultiInstanceConfmapsHead_loss: 1.1102e-04 - val_PartAffinityFieldsHead_loss: 8.2311e-04 - lr: 1.0000e-04 - 99s/epoch - 497ms/step
# Epoch 30/200
# 200/200 - 99s - loss: 3.1450e-04 - MultiInstanceConfmapsHead_loss: 6.2236e-05 - PartAffinityFieldsHead_loss: 2.5226e-04 - val_loss: 8.4904e-04 - val_MultiInstanceConfmapsHead_loss: 1.0757e-04 - val_PartAffinityFieldsHead_loss: 7.4147e-04 - lr: 5.0000e-05 - 99s/epoch - 495ms/step
# Epoch 31/200
# 200/200 - 99s - loss: 2.9955e-04 - MultiInstanceConfmapsHead_loss: 5.9279e-05 - PartAffinityFieldsHead_loss: 2.4027e-04 - val_loss: 8.0160e-04 - val_MultiInstanceConfmapsHead_loss: 1.0812e-04 - val_PartAffinityFieldsHead_loss: 6.9348e-04 - lr: 5.0000e-05 - 99s/epoch - 495ms/step
# Epoch 32/200
# 200/200 - 98s - loss: 2.8746e-04 - MultiInstanceConfmapsHead_loss: 5.7795e-05 - PartAffinityFieldsHead_loss: 2.2966e-04 - val_loss: 9.8751e-04 - val_MultiInstanceConfmapsHead_loss: 1.1333e-04 - val_PartAffinityFieldsHead_loss: 8.7418e-04 - lr: 5.0000e-05 - 98s/epoch - 488ms/step
# Epoch 33/200
# 200/200 - 100s - loss: 2.8598e-04 - MultiInstanceConfmapsHead_loss: 5.7211e-05 - PartAffinityFieldsHead_loss: 2.2877e-04 - val_loss: 8.9321e-04 - val_MultiInstanceConfmapsHead_loss: 1.0963e-04 - val_PartAffinityFieldsHead_loss: 7.8358e-04 - lr: 5.0000e-05 - 100s/epoch - 499ms/step
# Epoch 34/200
# 200/200 - 99s - loss: 2.7187e-04 - MultiInstanceConfmapsHead_loss: 5.5223e-05 - PartAffinityFieldsHead_loss: 2.1665e-04 - val_loss: 7.5923e-04 - val_MultiInstanceConfmapsHead_loss: 1.1164e-04 - val_PartAffinityFieldsHead_loss: 6.4758e-04 - lr: 5.0000e-05 - 99s/epoch - 495ms/step
# Epoch 00034: early stopping
# INFO:sleap.nn.training:Finished training loop. [56.4 min]
# INFO:sleap.nn.training:Saving evaluation metrics to model folder...
# Predicting... --------------------------------------- 100% ETA: 0:00:00 7.0 FPS
# INFO:sleap.nn.evals:Saved predictions: D:\SLEAP\20250530_seminal_root_generalist\wheat\train_test_split.v005\models\250531_065825.multi_instance.n=174\labels_pr.train.slp
# INFO:sleap.nn.evals:Saved metrics: D:\SLEAP\20250530_seminal_root_generalist\wheat\train_test_split.v005\models\250531_065825.multi_instance.n=174\metrics.train.npz
# INFO:sleap.nn.evals:OKS mAP: 0.558972
# Predicting... -------------------------------------- 100% ETA: 0:00:00 10.7 FPS
# INFO:sleap.nn.evals:Saved predictions: D:\SLEAP\20250530_seminal_root_generalist\wheat\train_test_split.v005\models\250531_065825.multi_instance.n=174\labels_pr.val.slp
# INFO:sleap.nn.evals:Saved metrics: D:\SLEAP\20250530_seminal_root_generalist\wheat\train_test_split.v005\models\250531_065825.multi_instance.n=174\metrics.val.npz
# INFO:sleap.nn.evals:OKS mAP: 0.071580
# WARNING:tensorflow:5 out of the last 45 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000019E9FF3AA68> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Predicting... --------------------------------------- 100% ETA: 0:00:00 5.7 FPS
# INFO:sleap.nn.evals:Saved predictions: D:\SLEAP\20250530_seminal_root_generalist\wheat\train_test_split.v005\models\250531_065825.multi_instance.n=174\labels_pr.test.slp
# INFO:sleap.nn.evals:Saved metrics: D:\SLEAP\20250530_seminal_root_generalist\wheat\train_test_split.v005\models\250531_065825.multi_instance.n=174\metrics.test.npz
# INFO:sleap.nn.evals:OKS mAP: 0.082097
#
# INFO:root:Latest run directory: D:\SLEAP\20250530_seminal_root_generalist\wheat\train_test_split.v005\models\250531_065825.multi_instance.n=174
# wandb: Adding directory to artifact (D:\SLEAP\20250530_seminal_root_generalist\wheat\train_test_split.v005\models\250531_065825.multi_instance.n=174)...
# W&B run configuration updated with training configuration.
# Done. 0.2s
# Model path: D:/SLEAP/20250530_seminal_root_generalist/wheat/train_test_split.v005/models/250531_065825.multi_instance.n=174
# Metrics loaded from model directory: D:/SLEAP/20250530_seminal_root_generalist/wheat/train_test_split.v005/models/250531_065825.multi_instance.n=174
# Model artifact '20250530_wheat_seminal_sweep_v005' logged to W&B with evaluations.
# VBox(children=(Label(value='7.217 MB of 60.680 MB uploaded\r'), FloatProgress(value=0.11893228064596399, max=1…
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>dist_avg</td><td>1.99172</td></tr><tr><td>dist_p50</td><td>0.80253</td></tr><tr><td>dist_p90</td><td>4.69692</td></tr><tr><td>dist_p95</td><td>8.27275</td></tr><tr><td>dist_p99</td><td>19.03297</td></tr><tr><td>dist_std</td><td>3.30205</td></tr><tr><td>model_name</td><td>250531_065825.multi_...</td></tr><tr><td>model_path</td><td>D:/SLEAP/20250530_se...</td></tr><tr><td>oks_map</td><td>0.0821</td></tr><tr><td>oks_mar</td><td>0.13588</td></tr><tr><td>vis_prec</td><td>0.99535</td></tr><tr><td>vis_recall</td><td>0.84031</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">20250530_wheat_seminal_sweep_training_v005</strong> at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/imdvenry' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/imdvenry</a><br/> View project at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a><br/>Synced 6 W&B file(s), 0 media file(s), 19 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250531_065816-imdvenry\logs</code>
# INFO:root:W&B run for version 5 finished.
# INFO:root:Completed training for version 5.
# INFO:root:Finished sweep for version 5.
# INFO:root:All versions processed successfully.
