# %%
import wandb
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sleap
import numpy as np
import datetime

from matplotlib.patches import ConnectionPatch
from pathlib import Path

# %%
import sleap_roots_training

from sleap_roots_training.evaluate import main, predictions_viz_from_sleap_files, visualize_predictions_from_artifacts

# %%
# Constants for W&B initialization
ENTITY_NAME = "eberrigan-salk-institute-for-biological-studies"
PROJECT_NAME = "sleap-roots"
REGISTRY = "sleap-roots-models"
EXPERIMENT_NAME = "2025-06-02-visualize-generalist-model"

# %%
# Model and group configuration
GROUPS = ["soybean-primary-2025-01-05", "rice-primary-2025-01-19", "canola-primary-2025-01-19", "pennycress-primary-2025-01-19", "arabidopsis-primary-2025-01-19", "sorghum-primary-2025-01-06"]
VERSIONS = ["000", "001", "002"]
MODEL_GROUP = "sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20"

# %%
# Constants for artifacts
# TAGS = ["rice3-5DAG", "soybean6-8DAG", "sorghum5-12DAG", "soybean", "sorghum", "canola2-13DAG", "canola", "pennycress", "arabidopsis", "pennycress14DAG", "arabidopsis7-11DAG", "primary", "2025-04-14", "rice"]
# ARTIFACT_NAME = "primary-root-model-metrics"

# %%
LABEL_COUNTS_CSV_PATH = "D:/SLEAP/20250102_generalizability_experiment/primary/sorghum_soybean_canola_pennycress_rice_arabidopsis/train_test_splits.csv"

# %%
sleap_roots_training.reset_config()
# Out:
# Configuration updated successfully at e:\repositories\sleap-roots-training\sleap_roots_training\config.yaml.
# Configuration has been reset to default values.

# %%
sleap_roots_training.update_config(entity_name=ENTITY_NAME, project_name=PROJECT_NAME, registry=REGISTRY, experiment_name=EXPERIMENT_NAME)
# Out:
# Configuration updated successfully at e:\repositories\sleap-roots-training\sleap_roots_training\config.yaml.
# CONFIG updated to {'project_name': 'sleap-roots', 'entity_name': 'eberrigan-salk-institute-for-biological-studies', 'experiment_name': '2025-06-02-visualize-generalist-model', 'registry': 'sleap-roots-models', 'collection_name': None, 'job_type': None}.

# %%
# Make directory for experiment
Path(EXPERIMENT_NAME).mkdir(exist_ok=True, parents=True)

# %%
datetime_str = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

# %%
# # Visualize model on test set for a given version
# version="001"
# model_name = f"{MODEL_GROUP}_v{version}"
# group="sorghum-primary-2025-01-06"
# group_name = f"{group}_v{version}"
# visualize_predictions_from_artifacts(
#     model_artifact_name=model_name,
#     test_artifact_name=group_name,
#     output_dir=Path(EXPERIMENT_NAME) / f"{model_name}_{group_name}_{datetime_str}",
#     num_frames=5,
#     overwrite=False,
# )

# %%
# Iterate through all groups and versions to visualize predictions
for group in GROUPS:
    for version in VERSIONS:
        model_name = f"{MODEL_GROUP}_v{version}"
        group_name = f"{group}_v{version}"
        output_dir = Path(EXPERIMENT_NAME) / f"{model_name}_on_{group_name}"
        
        visualize_predictions_from_artifacts(
            model_artifact_name=model_name,
            test_artifact_name=group_name,
            output_dir=output_dir,
            num_frames=5,
            overwrite=False,
        )
# Out:
# Tracking run with wandb version 0.18.6
# Run data is saved locally in <code>e:\repositories\sleap-roots-training\wandb\run-20250602_143749-o2yjte9b</code>
# Syncing run <strong><a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/o2yjte9b' target="_blank">viz_sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_soybean-primary-2025-01-05_v000</a></strong> to <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a>
#  View run at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/o2yjte9b' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/o2yjte9b</a>
# wandb: WARNING Registries can be linked/fetched using a shorthand form without specifying the organization name. Try using shorthand path format: <my_registry_name>/<artifact_name> or just <my_registry_name> if fetching just the project.
# Fetching artifact: eberrigan-salk-institute-for-biological-studies-org/wandb-registry-sleap-roots-models/sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000:latest
# wandb: WARNING Registries can be linked/fetched using a shorthand form without specifying the organization name. Try using shorthand path format: <my_registry_name>/<artifact_name> or just <my_registry_name> if fetching just the project.
# Fetching artifact: eberrigan-salk-institute-for-biological-studies-org/wandb-registry-sleap-roots-models/soybean-primary-2025-01-05_v000:latest
# wandb: Downloading large artifact sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000:latest, 282.33MB. 212 files...
# Loaded test data from D:\SLEAP\20250102_generalizability_experiment\primary\soybean\train_test_split.v000\test.pkg.slp.
# wandb:   212 of 212 files downloaded.
# Done. 0:0:0.8
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# INFO:sleap.nn.evals:OKS mAP: 0.125015
# Saved predictions to 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_soybean-primary-2025-01-05_v000\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_soybean-primary-2025-01-05_v000_test_predictions.slp
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_soybean-primary-2025-01-05_v000\test.pkg_frame_39_idx_0.png
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_soybean-primary-2025-01-05_v000\test.pkg_frame_39_idx_1.png
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_soybean-primary-2025-01-05_v000\test.pkg_frame_30_idx_2.png
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_soybean-primary-2025-01-05_v000\test.pkg_frame_21_idx_3.png
# wandb: Adding directory to artifact (.\2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_soybean-primary-2025-01-05_v000)... Done. 0.1s
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_soybean-primary-2025-01-05_v000\test.pkg_frame_51_idx_4.png
# Logged outputs as artifact: sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_soybean-primary-2025-01-05_v000_viz_outputs
#  View run <strong style="color:#cdcd00">viz_sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_soybean-primary-2025-01-05_v000</strong> at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/o2yjte9b' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/o2yjte9b</a><br/> View project at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a><br/>Synced 6 W&B file(s), 0 media file(s), 5 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250602_143749-o2yjte9b\logs</code>
# Tracking run with wandb version 0.18.6
# Run data is saved locally in <code>e:\repositories\sleap-roots-training\wandb\run-20250602_143854-x5ol304o</code>
# Syncing run <strong><a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/x5ol304o' target="_blank">viz_sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001_on_soybean-primary-2025-01-05_v001</a></strong> to <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a>
#  View run at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/x5ol304o' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/x5ol304o</a>
# wandb: WARNING Registries can be linked/fetched using a shorthand form without specifying the organization name. Try using shorthand path format: <my_registry_name>/<artifact_name> or just <my_registry_name> if fetching just the project.
# Fetching artifact: eberrigan-salk-institute-for-biological-studies-org/wandb-registry-sleap-roots-models/sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001:latest
# wandb: WARNING Registries can be linked/fetched using a shorthand form without specifying the organization name. Try using shorthand path format: <my_registry_name>/<artifact_name> or just <my_registry_name> if fetching just the project.
# Fetching artifact: eberrigan-salk-institute-for-biological-studies-org/wandb-registry-sleap-roots-models/soybean-primary-2025-01-05_v001:latest
# wandb: Downloading large artifact sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001:latest, 322.95MB. 252 files...
# Loaded test data from D:\SLEAP\20250102_generalizability_experiment\primary\soybean\train_test_split.v001\test.pkg.slp.
# wandb:   252 of 252 files downloaded.
# Done. 0:0:0.9
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# INFO:sleap.nn.evals:OKS mAP: 0.241127
# Saved predictions to 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001_on_soybean-primary-2025-01-05_v001\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001_on_soybean-primary-2025-01-05_v001_test_predictions.slp
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001_on_soybean-primary-2025-01-05_v001\test.pkg_frame_30_idx_0.png
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001_on_soybean-primary-2025-01-05_v001\test.pkg_frame_27_idx_1.png
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001_on_soybean-primary-2025-01-05_v001\test.pkg_frame_45_idx_2.png
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001_on_soybean-primary-2025-01-05_v001\test.pkg_frame_0_idx_3.png
# wandb: Adding directory to artifact (.\2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001_on_soybean-primary-2025-01-05_v001)... Done. 0.1s
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001_on_soybean-primary-2025-01-05_v001\test.pkg_frame_39_idx_4.png
# Logged outputs as artifact: sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001_on_soybean-primary-2025-01-05_v001_viz_outputs
#  View run <strong style="color:#cdcd00">viz_sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001_on_soybean-primary-2025-01-05_v001</strong> at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/x5ol304o' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/x5ol304o</a><br/> View project at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a><br/>Synced 6 W&B file(s), 0 media file(s), 4 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250602_143854-x5ol304o\logs</code>
# Tracking run with wandb version 0.18.6
# Run data is saved locally in <code>e:\repositories\sleap-roots-training\wandb\run-20250602_143949-a2sjw251</code>
# Syncing run <strong><a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/a2sjw251' target="_blank">viz_sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_soybean-primary-2025-01-05_v002</a></strong> to <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a>
#  View run at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/a2sjw251' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/a2sjw251</a>
# wandb: WARNING Registries can be linked/fetched using a shorthand form without specifying the organization name. Try using shorthand path format: <my_registry_name>/<artifact_name> or just <my_registry_name> if fetching just the project.
# Fetching artifact: eberrigan-salk-institute-for-biological-studies-org/wandb-registry-sleap-roots-models/sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002:latest
# wandb: WARNING Registries can be linked/fetched using a shorthand form without specifying the organization name. Try using shorthand path format: <my_registry_name>/<artifact_name> or just <my_registry_name> if fetching just the project.
# Fetching artifact: eberrigan-salk-institute-for-biological-studies-org/wandb-registry-sleap-roots-models/soybean-primary-2025-01-05_v002:latest
# wandb: Downloading large artifact sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002:latest, 331.10MB. 260 files...
# Loaded test data from D:\SLEAP\20250102_generalizability_experiment\primary\soybean\train_test_split.v002\test.pkg.slp.
# wandb:   260 of 260 files downloaded.
# Done. 0:0:0.9
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# INFO:sleap.nn.evals:OKS mAP: 0.219019
# Saved predictions to 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_soybean-primary-2025-01-05_v002\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_soybean-primary-2025-01-05_v002_test_predictions.slp
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_soybean-primary-2025-01-05_v002\test.pkg_frame_30_idx_0.png
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_soybean-primary-2025-01-05_v002\test.pkg_frame_48_idx_1.png
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_soybean-primary-2025-01-05_v002\test.pkg_frame_18_idx_2.png
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_soybean-primary-2025-01-05_v002\test.pkg_frame_24_idx_3.png
# wandb: Adding directory to artifact (.\2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_soybean-primary-2025-01-05_v002)... Done. 0.1s
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_soybean-primary-2025-01-05_v002\test.pkg_frame_57_idx_4.png
# Logged outputs as artifact: sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_soybean-primary-2025-01-05_v002_viz_outputs
#  View run <strong style="color:#cdcd00">viz_sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_soybean-primary-2025-01-05_v002</strong> at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/a2sjw251' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/a2sjw251</a><br/> View project at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a><br/>Synced 6 W&B file(s), 0 media file(s), 4 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250602_143949-a2sjw251\logs</code>
# Tracking run with wandb version 0.18.6
# Run data is saved locally in <code>e:\repositories\sleap-roots-training\wandb\run-20250602_144041-rwaxptq1</code>
# Syncing run <strong><a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/rwaxptq1' target="_blank">viz_sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_rice-primary-2025-01-19_v000</a></strong> to <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a>
#  View run at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/rwaxptq1' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/rwaxptq1</a>
# wandb: WARNING Registries can be linked/fetched using a shorthand form without specifying the organization name. Try using shorthand path format: <my_registry_name>/<artifact_name> or just <my_registry_name> if fetching just the project.
# Fetching artifact: eberrigan-salk-institute-for-biological-studies-org/wandb-registry-sleap-roots-models/sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000:latest
# Fetching artifact: eberrigan-salk-institute-for-biological-studies-org/wandb-registry-sleap-roots-models/rice-primary-2025-01-19_v000:latest
# wandb: WARNING Registries can be linked/fetched using a shorthand form without specifying the organization name. Try using shorthand path format: <my_registry_name>/<artifact_name> or just <my_registry_name> if fetching just the project.
# wandb: Downloading large artifact sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000:latest, 282.33MB. 212 files...
# Loaded test data from D:\SLEAP\20250102_generalizability_experiment\primary\younger_rice\train_test_split.v000\test.pkg.slp.
# wandb:   212 of 212 files downloaded.
# Done. 0:0:0.8
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# INFO:sleap.nn.evals:OKS mAP: 0.194268
# Saved predictions to 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_rice-primary-2025-01-19_v000\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_rice-primary-2025-01-19_v000_test_predictions.slp
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_rice-primary-2025-01-19_v000\test.pkg_frame_22_idx_0.png
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_rice-primary-2025-01-19_v000\test.pkg_frame_0_idx_1.png
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_rice-primary-2025-01-19_v000\test.pkg_frame_16_idx_2.png
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_rice-primary-2025-01-19_v000\test.pkg_frame_68_idx_3.png
# wandb: Adding directory to artifact (.\2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_rice-primary-2025-01-19_v000)... Done. 0.1s
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_rice-primary-2025-01-19_v000\test.pkg_frame_0_idx_4.png
# Logged outputs as artifact: sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_rice-primary-2025-01-19_v000_viz_outputs
#  View run <strong style="color:#cdcd00">viz_sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_rice-primary-2025-01-19_v000</strong> at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/rwaxptq1' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/rwaxptq1</a><br/> View project at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a><br/>Synced 6 W&B file(s), 0 media file(s), 4 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250602_144041-rwaxptq1\logs</code>
# Tracking run with wandb version 0.18.6
# Run data is saved locally in <code>e:\repositories\sleap-roots-training\wandb\run-20250602_144148-akpxfflp</code>
# Syncing run <strong><a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/akpxfflp' target="_blank">viz_sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001_on_rice-primary-2025-01-19_v001</a></strong> to <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a>
#  View run at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/akpxfflp' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/akpxfflp</a>
# wandb: WARNING Registries can be linked/fetched using a shorthand form without specifying the organization name. Try using shorthand path format: <my_registry_name>/<artifact_name> or just <my_registry_name> if fetching just the project.
# Fetching artifact: eberrigan-salk-institute-for-biological-studies-org/wandb-registry-sleap-roots-models/sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001:latest
# wandb: WARNING Registries can be linked/fetched using a shorthand form without specifying the organization name. Try using shorthand path format: <my_registry_name>/<artifact_name> or just <my_registry_name> if fetching just the project.
# Fetching artifact: eberrigan-salk-institute-for-biological-studies-org/wandb-registry-sleap-roots-models/rice-primary-2025-01-19_v001:latest
# wandb: Downloading large artifact sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001:latest, 322.95MB. 252 files...
# Loaded test data from D:\SLEAP\20250102_generalizability_experiment\primary\younger_rice\train_test_split.v001\test.pkg.slp.
# wandb:   252 of 252 files downloaded.
# Done. 0:0:0.9
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# INFO:sleap.nn.evals:OKS mAP: 0.180218
# Saved predictions to 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001_on_rice-primary-2025-01-19_v001\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001_on_rice-primary-2025-01-19_v001_test_predictions.slp
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001_on_rice-primary-2025-01-19_v001\test.pkg_frame_24_idx_0.png
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001_on_rice-primary-2025-01-19_v001\test.pkg_frame_29_idx_1.png
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001_on_rice-primary-2025-01-19_v001\test.pkg_frame_55_idx_2.png
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001_on_rice-primary-2025-01-19_v001\test.pkg_frame_45_idx_3.png
# wandb: Adding directory to artifact (.\2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001_on_rice-primary-2025-01-19_v001)... Done. 0.1s
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001_on_rice-primary-2025-01-19_v001\test.pkg_frame_42_idx_4.png
# Logged outputs as artifact: sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001_on_rice-primary-2025-01-19_v001_viz_outputs
# VBox(children=(Label(value='0.340 MB of 0.340 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
#  View run <strong style="color:#cdcd00">viz_sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001_on_rice-primary-2025-01-19_v001</strong> at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/akpxfflp' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/akpxfflp</a><br/> View project at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a><br/>Synced 6 W&B file(s), 0 media file(s), 5 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250602_144148-akpxfflp\logs</code>
# Tracking run with wandb version 0.18.6
# Run data is saved locally in <code>e:\repositories\sleap-roots-training\wandb\run-20250602_144307-r2icv7qw</code>
# Syncing run <strong><a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/r2icv7qw' target="_blank">viz_sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_rice-primary-2025-01-19_v002</a></strong> to <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a>
#  View run at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/r2icv7qw' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/r2icv7qw</a>
# wandb: WARNING Registries can be linked/fetched using a shorthand form without specifying the organization name. Try using shorthand path format: <my_registry_name>/<artifact_name> or just <my_registry_name> if fetching just the project.
# Fetching artifact: eberrigan-salk-institute-for-biological-studies-org/wandb-registry-sleap-roots-models/sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002:latest
# wandb: WARNING Registries can be linked/fetched using a shorthand form without specifying the organization name. Try using shorthand path format: <my_registry_name>/<artifact_name> or just <my_registry_name> if fetching just the project.
# Fetching artifact: eberrigan-salk-institute-for-biological-studies-org/wandb-registry-sleap-roots-models/rice-primary-2025-01-19_v002:latest
# wandb: Downloading large artifact sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002:latest, 331.10MB. 260 files...
# Loaded test data from D:\SLEAP\20250102_generalizability_experiment\primary\younger_rice\train_test_split.v002\test.pkg.slp.
# wandb:   260 of 260 files downloaded.
# Done. 0:0:1.2
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# INFO:sleap.nn.evals:OKS mAP: 0.180338
# c:\Users\pbiobgh\.conda\envs\sleap_v1.3.4\lib\site-packages\sleap\nn\evals.py:128: RuntimeWarning: All-NaN slice encountered
#   min_pt = np.nanmin(points, axis=-2)
# c:\Users\pbiobgh\.conda\envs\sleap_v1.3.4\lib\site-packages\sleap\nn\evals.py:129: RuntimeWarning: All-NaN slice encountered
#   max_pt = np.nanmax(points, axis=-2)
# c:\Users\pbiobgh\.conda\envs\sleap_v1.3.4\lib\site-packages\sleap\nn\evals.py:247: RuntimeWarning: invalid value encountered in true_divide
#   oks = np.sum(ks, axis=-1) / n_visible_gt
# Saved predictions to 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_rice-primary-2025-01-19_v002\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_rice-primary-2025-01-19_v002_test_predictions.slp
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_rice-primary-2025-01-19_v002\test.pkg_frame_37_idx_0.png
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_rice-primary-2025-01-19_v002\test.pkg_frame_39_idx_1.png
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_rice-primary-2025-01-19_v002\test.pkg_frame_5_idx_2.png
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_rice-primary-2025-01-19_v002\test.pkg_frame_26_idx_3.png
# wandb: Adding directory to artifact (.\2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_rice-primary-2025-01-19_v002)... Done. 0.1s
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_rice-primary-2025-01-19_v002\test.pkg_frame_70_idx_4.png
# Logged outputs as artifact: sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_rice-primary-2025-01-19_v002_viz_outputs
#  View run <strong style="color:#cdcd00">viz_sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_rice-primary-2025-01-19_v002</strong> at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/r2icv7qw' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/r2icv7qw</a><br/> View project at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a><br/>Synced 6 W&B file(s), 0 media file(s), 4 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250602_144307-r2icv7qw\logs</code>
# Tracking run with wandb version 0.18.6
# Run data is saved locally in <code>e:\repositories\sleap-roots-training\wandb\run-20250602_144431-llob5oz0</code>
# Syncing run <strong><a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/llob5oz0' target="_blank">viz_sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_canola-primary-2025-01-19_v000</a></strong> to <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a>
#  View run at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/llob5oz0' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/llob5oz0</a>
# wandb: WARNING Registries can be linked/fetched using a shorthand form without specifying the organization name. Try using shorthand path format: <my_registry_name>/<artifact_name> or just <my_registry_name> if fetching just the project.
# Fetching artifact: eberrigan-salk-institute-for-biological-studies-org/wandb-registry-sleap-roots-models/sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000:latest
# Fetching artifact: eberrigan-salk-institute-for-biological-studies-org/wandb-registry-sleap-roots-models/canola-primary-2025-01-19_v000:latest
# wandb: WARNING Registries can be linked/fetched using a shorthand form without specifying the organization name. Try using shorthand path format: <my_registry_name>/<artifact_name> or just <my_registry_name> if fetching just the project.
# wandb: Downloading large artifact sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000:latest, 282.33MB. 212 files...
# Loaded test data from D:\SLEAP\20250102_generalizability_experiment\primary\canola\train_test_split.v000\test.pkg.slp.
# wandb:   212 of 212 files downloaded.
# Done. 0:0:1.5
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# INFO:sleap.nn.evals:OKS mAP: 0.166392
# Saved predictions to 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_canola-primary-2025-01-19_v000\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_canola-primary-2025-01-19_v000_test_predictions.slp
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_canola-primary-2025-01-19_v000\test.pkg_frame_13_idx_0.png
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_canola-primary-2025-01-19_v000\test.pkg_frame_36_idx_1.png
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_canola-primary-2025-01-19_v000\test.pkg_frame_19_idx_2.png
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_canola-primary-2025-01-19_v000\test.pkg_frame_6_idx_3.png
# wandb: Adding directory to artifact (.\2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_canola-primary-2025-01-19_v000)...
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_canola-primary-2025-01-19_v000\test.pkg_frame_11_idx_4.png
# Done. 0.2s
# Logged outputs as artifact: sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_canola-primary-2025-01-19_v000_viz_outputs
#  View run <strong style="color:#cdcd00">viz_sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_canola-primary-2025-01-19_v000</strong> at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/llob5oz0' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/llob5oz0</a><br/> View project at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a><br/>Synced 6 W&B file(s), 0 media file(s), 4 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250602_144431-llob5oz0\logs</code>
# Tracking run with wandb version 0.18.6
# Run data is saved locally in <code>e:\repositories\sleap-roots-training\wandb\run-20250602_144459-f8njceo7</code>
# Syncing run <strong><a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/f8njceo7' target="_blank">viz_sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001_on_canola-primary-2025-01-19_v001</a></strong> to <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a>
#  View run at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/f8njceo7' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/f8njceo7</a>
# Fetching artifact: eberrigan-salk-institute-for-biological-studies-org/wandb-registry-sleap-roots-models/sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001:latest
# wandb: WARNING Registries can be linked/fetched using a shorthand form without specifying the organization name. Try using shorthand path format: <my_registry_name>/<artifact_name> or just <my_registry_name> if fetching just the project.
# wandb: WARNING Registries can be linked/fetched using a shorthand form without specifying the organization name. Try using shorthand path format: <my_registry_name>/<artifact_name> or just <my_registry_name> if fetching just the project.
# Fetching artifact: eberrigan-salk-institute-for-biological-studies-org/wandb-registry-sleap-roots-models/canola-primary-2025-01-19_v001:latest
# wandb: Downloading large artifact sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001:latest, 322.95MB. 252 files...
# Loaded test data from D:\SLEAP\20250102_generalizability_experiment\primary\canola\train_test_split.v001\test.pkg.slp.
# wandb:   252 of 252 files downloaded.
# Done. 0:0:1.2
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# INFO:sleap.nn.evals:OKS mAP: 0.353154
# Saved predictions to 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001_on_canola-primary-2025-01-19_v001\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001_on_canola-primary-2025-01-19_v001_test_predictions.slp
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001_on_canola-primary-2025-01-19_v001\test.pkg_frame_5_idx_0.png
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001_on_canola-primary-2025-01-19_v001\test.pkg_frame_31_idx_1.png
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001_on_canola-primary-2025-01-19_v001\test.pkg_frame_58_idx_2.png
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001_on_canola-primary-2025-01-19_v001\test.pkg_frame_27_idx_3.png
# wandb: Adding directory to artifact (.\2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001_on_canola-primary-2025-01-19_v001)... Done. 0.1s
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001_on_canola-primary-2025-01-19_v001\test.pkg_frame_57_idx_4.png
# Logged outputs as artifact: sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001_on_canola-primary-2025-01-19_v001_viz_outputs
#  View run <strong style="color:#cdcd00">viz_sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001_on_canola-primary-2025-01-19_v001</strong> at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/f8njceo7' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/f8njceo7</a><br/> View project at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a><br/>Synced 6 W&B file(s), 0 media file(s), 4 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250602_144459-f8njceo7\logs</code>
# Tracking run with wandb version 0.18.6
# Run data is saved locally in <code>e:\repositories\sleap-roots-training\wandb\run-20250602_144541-tjf4pxnh</code>
# Syncing run <strong><a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/tjf4pxnh' target="_blank">viz_sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_canola-primary-2025-01-19_v002</a></strong> to <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a>
#  View run at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/tjf4pxnh' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/tjf4pxnh</a>
# wandb: WARNING Registries can be linked/fetched using a shorthand form without specifying the organization name. Try using shorthand path format: <my_registry_name>/<artifact_name> or just <my_registry_name> if fetching just the project.
# Fetching artifact: eberrigan-salk-institute-for-biological-studies-org/wandb-registry-sleap-roots-models/sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002:latest
# wandb: WARNING Registries can be linked/fetched using a shorthand form without specifying the organization name. Try using shorthand path format: <my_registry_name>/<artifact_name> or just <my_registry_name> if fetching just the project.
# Fetching artifact: eberrigan-salk-institute-for-biological-studies-org/wandb-registry-sleap-roots-models/canola-primary-2025-01-19_v002:latest
# wandb: Downloading large artifact sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002:latest, 331.10MB. 260 files...
# Loaded test data from D:\SLEAP\20250102_generalizability_experiment\primary\canola\train_test_split.v002\test.pkg.slp.
# wandb:   260 of 260 files downloaded.
# Done. 0:0:0.9
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# INFO:sleap.nn.evals:OKS mAP: 0.244671
# Saved predictions to 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_canola-primary-2025-01-19_v002\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_canola-primary-2025-01-19_v002_test_predictions.slp
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_canola-primary-2025-01-19_v002\test.pkg_frame_15_idx_0.png
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_canola-primary-2025-01-19_v002\test.pkg_frame_45_idx_1.png
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_canola-primary-2025-01-19_v002\test.pkg_frame_33_idx_2.png
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_canola-primary-2025-01-19_v002\test.pkg_frame_66_idx_3.png
# wandb: Adding directory to artifact (.\2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_canola-primary-2025-01-19_v002)... Done. 0.1s
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_canola-primary-2025-01-19_v002\test.pkg_frame_0_idx_4.png
# Logged outputs as artifact: sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_canola-primary-2025-01-19_v002_viz_outputs
# VBox(children=(Label(value='0.242 MB of 0.242 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
#  View run <strong style="color:#cdcd00">viz_sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_canola-primary-2025-01-19_v002</strong> at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/tjf4pxnh' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/tjf4pxnh</a><br/> View project at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a><br/>Synced 6 W&B file(s), 0 media file(s), 4 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250602_144541-tjf4pxnh\logs</code>
# Tracking run with wandb version 0.18.6
# Run data is saved locally in <code>e:\repositories\sleap-roots-training\wandb\run-20250602_144623-n2aln69i</code>
# Syncing run <strong><a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/n2aln69i' target="_blank">viz_sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_pennycress-primary-2025-01-19_v000</a></strong> to <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a>
#  View run at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/n2aln69i' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/n2aln69i</a>
# wandb: WARNING Registries can be linked/fetched using a shorthand form without specifying the organization name. Try using shorthand path format: <my_registry_name>/<artifact_name> or just <my_registry_name> if fetching just the project.
# Fetching artifact: eberrigan-salk-institute-for-biological-studies-org/wandb-registry-sleap-roots-models/sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000:latest
# wandb: WARNING Registries can be linked/fetched using a shorthand form without specifying the organization name. Try using shorthand path format: <my_registry_name>/<artifact_name> or just <my_registry_name> if fetching just the project.
# Fetching artifact: eberrigan-salk-institute-for-biological-studies-org/wandb-registry-sleap-roots-models/pennycress-primary-2025-01-19_v000:latest
# wandb: Downloading large artifact sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000:latest, 282.33MB. 212 files...
# Loaded test data from D:\SLEAP\20250102_generalizability_experiment\primary\pennycress\train_test_split.v000\test.pkg.slp.
# wandb:   212 of 212 files downloaded.
# Done. 0:0:0.7
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# INFO:sleap.nn.evals:OKS mAP: 0.045633
# Saved predictions to 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_pennycress-primary-2025-01-19_v000\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_pennycress-primary-2025-01-19_v000_test_predictions.slp
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_pennycress-primary-2025-01-19_v000\test.pkg_frame_0_idx_0.png
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_pennycress-primary-2025-01-19_v000\test.pkg_frame_0_idx_1.png
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_pennycress-primary-2025-01-19_v000\test.pkg_frame_0_idx_2.png
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_pennycress-primary-2025-01-19_v000\test.pkg_frame_0_idx_3.png
# wandb: Adding directory to artifact (.\2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_pennycress-primary-2025-01-19_v000)... Done. 0.1s
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_pennycress-primary-2025-01-19_v000\test.pkg_frame_0_idx_4.png
# Logged outputs as artifact: sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_pennycress-primary-2025-01-19_v000_viz_outputs
#  View run <strong style="color:#cdcd00">viz_sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_pennycress-primary-2025-01-19_v000</strong> at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/n2aln69i' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/n2aln69i</a><br/> View project at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a><br/>Synced 6 W&B file(s), 0 media file(s), 4 artifact file(s) and 0 other file(s)
# ...
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_arabidopsis-primary-2025-01-19_v002\test.pkg_frame_12_idx_3.png
# wandb: Adding directory to artifact (.\2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_arabidopsis-primary-2025-01-19_v002)... Done. 0.1s
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_arabidopsis-primary-2025-01-19_v002\test.pkg_frame_57_idx_4.png
# Logged outputs as artifact: sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_arabidopsis-primary-2025-01-19_v002_viz_outputs
# VBox(children=(Label(value='0.059 MB of 0.059 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
#  View run <strong style="color:#cdcd00">viz_sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_arabidopsis-primary-2025-01-19_v002</strong> at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/3654bszc' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/3654bszc</a><br/> View project at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a><br/>Synced 6 W&B file(s), 0 media file(s), 4 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250602_144847-3654bszc\logs</code>
# Tracking run with wandb version 0.18.6
# Run data is saved locally in <code>e:\repositories\sleap-roots-training\wandb\run-20250602_144922-di9xszpg</code>
# Syncing run <strong><a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/di9xszpg' target="_blank">viz_sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_sorghum-primary-2025-01-06_v000</a></strong> to <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a>
#  View run at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/di9xszpg' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/di9xszpg</a>
# wandb: WARNING Registries can be linked/fetched using a shorthand form without specifying the organization name. Try using shorthand path format: <my_registry_name>/<artifact_name> or just <my_registry_name> if fetching just the project.
# Fetching artifact: eberrigan-salk-institute-for-biological-studies-org/wandb-registry-sleap-roots-models/sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000:latest
# wandb: WARNING Registries can be linked/fetched using a shorthand form without specifying the organization name. Try using shorthand path format: <my_registry_name>/<artifact_name> or just <my_registry_name> if fetching just the project.
# Fetching artifact: eberrigan-salk-institute-for-biological-studies-org/wandb-registry-sleap-roots-models/sorghum-primary-2025-01-06_v000:latest
# wandb: Downloading large artifact sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000:latest, 282.33MB. 212 files...
# Loaded test data from D:\SLEAP\20250102_generalizability_experiment\primary\sorghum\train_test_split.v000\test.pkg.slp.
# wandb:   212 of 212 files downloaded.
# Done. 0:0:1.2
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# INFO:sleap.nn.evals:OKS mAP: 0.061786
# Saved predictions to 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_sorghum-primary-2025-01-06_v000\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_sorghum-primary-2025-01-06_v000_test_predictions.slp
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_sorghum-primary-2025-01-06_v000\test.pkg_frame_17_idx_0.png
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_sorghum-primary-2025-01-06_v000\test.pkg_frame_17_idx_1.png
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_sorghum-primary-2025-01-06_v000\test.pkg_frame_0_idx_2.png
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_sorghum-primary-2025-01-06_v000\test.pkg_frame_0_idx_3.png
# wandb: Adding directory to artifact (.\2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_sorghum-primary-2025-01-06_v000)... Done. 0.1s
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_sorghum-primary-2025-01-06_v000\test.pkg_frame_48_idx_4.png
# Logged outputs as artifact: sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_sorghum-primary-2025-01-06_v000_viz_outputs
#  View run <strong style="color:#cdcd00">viz_sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v000_on_sorghum-primary-2025-01-06_v000</strong> at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/di9xszpg' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/di9xszpg</a><br/> View project at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a><br/>Synced 6 W&B file(s), 0 media file(s), 4 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250602_144922-di9xszpg\logs</code>
# Tracking run with wandb version 0.18.6
# Run data is saved locally in <code>e:\repositories\sleap-roots-training\wandb\run-20250602_145030-qurfbv1v</code>
# Syncing run <strong><a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/qurfbv1v' target="_blank">viz_sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001_on_sorghum-primary-2025-01-06_v001</a></strong> to <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a>
#  View run at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/qurfbv1v' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/qurfbv1v</a>
# wandb: WARNING Registries can be linked/fetched using a shorthand form without specifying the organization name. Try using shorthand path format: <my_registry_name>/<artifact_name> or just <my_registry_name> if fetching just the project.
# Fetching artifact: eberrigan-salk-institute-for-biological-studies-org/wandb-registry-sleap-roots-models/sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001:latest
# wandb: WARNING Registries can be linked/fetched using a shorthand form without specifying the organization name. Try using shorthand path format: <my_registry_name>/<artifact_name> or just <my_registry_name> if fetching just the project.
# Fetching artifact: eberrigan-salk-institute-for-biological-studies-org/wandb-registry-sleap-roots-models/sorghum-primary-2025-01-06_v001:latest
# wandb: Downloading large artifact sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001:latest, 322.95MB. 252 files...
# Loaded test data from D:\SLEAP\20250102_generalizability_experiment\primary\sorghum\train_test_split.v001\test.pkg.slp.
# wandb:   252 of 252 files downloaded.
# Done. 0:0:1.0
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# INFO:sleap.nn.evals:OKS mAP: 0.085403
# Saved predictions to 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001_on_sorghum-primary-2025-01-06_v001\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001_on_sorghum-primary-2025-01-06_v001_test_predictions.slp
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001_on_sorghum-primary-2025-01-06_v001\test.pkg_frame_39_idx_0.png
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001_on_sorghum-primary-2025-01-06_v001\test.pkg_frame_18_idx_1.png
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001_on_sorghum-primary-2025-01-06_v001\test.pkg_frame_48_idx_2.png
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001_on_sorghum-primary-2025-01-06_v001\test.pkg_frame_43_idx_3.png
# wandb: Adding directory to artifact (.\2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001_on_sorghum-primary-2025-01-06_v001)... Done. 0.1s
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001_on_sorghum-primary-2025-01-06_v001\test.pkg_frame_43_idx_4.png
# Logged outputs as artifact: sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001_on_sorghum-primary-2025-01-06_v001_viz_outputs
#  View run <strong style="color:#cdcd00">viz_sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v001_on_sorghum-primary-2025-01-06_v001</strong> at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/qurfbv1v' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/qurfbv1v</a><br/> View project at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a><br/>Synced 6 W&B file(s), 0 media file(s), 4 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250602_145030-qurfbv1v\logs</code>
# Tracking run with wandb version 0.18.6
# Run data is saved locally in <code>e:\repositories\sleap-roots-training\wandb\run-20250602_145100-lmazcu1z</code>
# Syncing run <strong><a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/lmazcu1z' target="_blank">viz_sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_sorghum-primary-2025-01-06_v002</a></strong> to <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a>
#  View run at <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/lmazcu1z' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/lmazcu1z</a>
# wandb: WARNING Registries can be linked/fetched using a shorthand form without specifying the organization name. Try using shorthand path format: <my_registry_name>/<artifact_name> or just <my_registry_name> if fetching just the project.
# Fetching artifact: eberrigan-salk-institute-for-biological-studies-org/wandb-registry-sleap-roots-models/sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002:latest
# wandb: WARNING Registries can be linked/fetched using a shorthand form without specifying the organization name. Try using shorthand path format: <my_registry_name>/<artifact_name> or just <my_registry_name> if fetching just the project.
# Fetching artifact: eberrigan-salk-institute-for-biological-studies-org/wandb-registry-sleap-roots-models/sorghum-primary-2025-01-06_v002:latest
# wandb: Downloading large artifact sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002:latest, 331.10MB. 260 files...
# Loaded test data from D:\SLEAP\20250102_generalizability_experiment\primary\sorghum\train_test_split.v002\test.pkg.slp.
# wandb:   260 of 260 files downloaded.
# Done. 0:0:0.8
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# INFO:sleap.nn.evals:OKS mAP: 0.062050
# Saved predictions to 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_sorghum-primary-2025-01-06_v002\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_sorghum-primary-2025-01-06_v002_test_predictions.slp
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_sorghum-primary-2025-01-06_v002\test.pkg_frame_45_idx_0.png
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_sorghum-primary-2025-01-06_v002\test.pkg_frame_38_idx_1.png
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_sorghum-primary-2025-01-06_v002\test.pkg_frame_0_idx_2.png
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_sorghum-primary-2025-01-06_v002\test.pkg_frame_27_idx_3.png
# wandb: Adding directory to artifact (.\2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_sorghum-primary-2025-01-06_v002)... Done. 0.1s
# Saved prediction image: 2025-06-02-visualize-generalist-model\sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_sorghum-primary-2025-01-06_v002\test.pkg_frame_4_idx_4.png
# Logged outputs as artifact: sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_sorghum-primary-2025-01-06_v002_viz_outputs
#  View run <strong style="color:#cdcd00">viz_sorghum-soybean-canola-pennycress-rice-arabidopsis-primary-2025-01-20_v002_on_sorghum-primary-2025-01-06_v002</strong> at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/lmazcu1z' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/lmazcu1z</a><br/> View project at: <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots</a><br/>Synced 6 W&B file(s), 0 media file(s), 4 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250602_145100-lmazcu1z\logs</code>
