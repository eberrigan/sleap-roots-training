# %%
import wandb

from pathlib import Path

from sleap_roots_training import config, datasets

# %%
# Constants for W&B initialization
ENTITY_NAME = "eberrigan-salk-institute-for-biological-studies"
PROJECT_NAME = "sleap-roots"
REGISTRY = "sleap-roots-labels"
JOB_TYPE = "build_dataset"
EXPERIMENT_NAME = "20250717_plate_medicago_primary_sweep_receptive_field"

# Constants for dataset creation
ARTIFACT_NAME = "plate_medicago_14DAG_primary_8nodes_labels"
DESCRIPTION = "14 DAG medicago labels for primary root with 8 nodes on plates"
TAGS = ["plate", "medicago", "14DAG", "primary", "8nodes", "medicago14DAG", "2025-07-17"]
COLLECTION_NAME = "plate_medicago_14DAG_primary_8nodes_labels"
DATASET_PATH = "//multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/SLEAP/20250717_plate_medicago_primary_sweep_receptive_field/primary_root_MK22_Day14_labels.v003.slp"

# %%
print(wandb.run)
# Out:
# None

# %%
config.reset_config()
# Out:
# Configuration updated successfully at c:\repos\sleap-roots-training\sleap_roots_training\config.yaml.
# Configuration has been reset to default values.

# %%
config.update_config(entity_name=ENTITY_NAME, project_name=PROJECT_NAME, registry=REGISTRY, job_type=JOB_TYPE, experiment_name=EXPERIMENT_NAME, collection_name=COLLECTION_NAME)
# Out:
# Configuration updated successfully at c:\repos\sleap-roots-training\sleap_roots_training\config.yaml.
# CONFIG updated to {'project_name': 'sleap-roots', 'entity_name': 'eberrigan-salk-institute-for-biological-studies', 'experiment_name': '20250717_plate_medicago_primary_sweep_receptive_field', 'registry': 'sleap-roots-labels', 'collection_name': 'plate_medicago_14DAG_primary_8nodes_labels', 'job_type': 'build_dataset'}.

# %%
datasets.make_dataset_artifact(artifact_name=ARTIFACT_NAME, dataset_path=DATASET_PATH, link_to_registry=True, description=DESCRIPTION, tags=TAGS)
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: eberrigan (eberrigan-salk-institute-for-biological-studies). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>c:\repos\sleap-roots-training\wandb\run-20250717_204758-n3h6svli</code>
# Syncing run <strong><a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots/runs/n3h6svli' target="_blank">20250717_plate_medicago_primary_sweep_receptive_field</a></strong> to <a href='https://wandb.ai/eberrigan-salk-institute-for-biological-studies/sleap-roots' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
# ...
