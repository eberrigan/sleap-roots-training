# %%
import os
import pandas as pd
import sleap
import numpy as np
import random
import re
import matplotlib.pyplot as plt

from pathlib import Path

# %% [markdown]
# # Step 1
#
# This notebook processes labeled data to extract video age information and prepare datasets for model development. It outputs a CSV file summarizing video ages, a CSV detailing train-test splits, and a bar plot visualizing the age distribution.
#
# ### User-Defined Inputs
# - **Labels Path**: Path to the input labeled data (`user_labels`), which must be specified before running the notebook.
# - **Fractions for Data Splitting**:
#   - `fraction_train`: Proportion of data to be allocated to the training set.
#   - `val_test_fraction`: Proportion of the remaining data to be allocated to the test set.
#
# ### Key Functionalities
# 1. **Extracting Video Age Information**:
#    - Extracts the age (in days) from video filenames of labeled data.
#    - Saves the results to a CSV file (`video_ages.csv`).
#    - Generates a bar plot visualizing the age distribution.
#
# 2. **Splitting Data for Training**:
#    - Divides the labeled data into training, validation, and test sets using specified fractions.
#    - Repeats the split three times, saving datasets to directories (`train.pkg.slp`, `val.pkg.slp`, `test.pkg.slp`) with associated images.
#    - Records metadata for each split, including file path, version, labeled frames, and split type, in a CSV file (`train_test_splits_info.csv`).
#
# ### Outputs
# - A CSV file (`video_ages.csv`) with video filenames and corresponding age information.
# - A CSV file (`train_test_splits_info.csv`) summarizing train-test splits.
# - A bar plot visualizing the age distribution.

# %%
# labels path
labels_path = "D:/SLEAP/20250530_seminal_root_generalist/older_rice/labels_rice_10do_6nodes.v018.slp"

# train, val and test fractions
fraction_train = 0.7 # fraction of total user labels to be used for training
val_test_fraction = 0.5 # 1-`fraction_train` allocated for validation and testing

# Number of train-test splits
num_splits = 6

# Directory output path
output_path = "D:/SLEAP/20250530_seminal_root_generalist/older_rice"

# %%
# Function to extract the age from the filename (for rice)
# D:/SLEAP/SLEAP_Rice/Hydroponic/5DAG_primary/h5_files/hg-1x-r8.h5S
# D:/SLEAP/SLEAP_Rice/3_do/h5_files/Day3_4-18-2022/F22HK4M.h5
def extract_age(filename):
    match = re.search(r'(\d+)DAG', filename)
    match2 = re.search(r'(\d+)_do', filename)
    if match:
        print(f"Extracted age: {match.group(1)} from filename: {filename}")
        return int(match.group(1))
    elif match2:
        print(f"Extracted age: {match2.group(1)} from filename: {filename}")
        return int(match2.group(1))
    else:
        print(f"Age not found in filename: {filename}")
        return 'NA'

# %%
# # Function to extract the age from the filename (for sorghum, wheat datasets)
# # Day14_2-7-2025FastScanner
# def extract_age(filename):
#     match = re.search(r'Day(\d+)_', filename)
#     if match:
#         print(f"Match found: {match.group(1)}")
#         return match.group(1)
#     else:
#         print(f"Match not found for {filename}")
#         return 'NA'

# %%
# Function to extract the age from the filename (for soybean dataset)
# h5_files_blue_6_do_1.17.22
# def extract_age(filename):
#     match = re.search(r'_(\d+)_do', filename)
#     if match:
#         print(f"Match found: {match.group(1)}")
#         return match.group(1)
#     else:
#         print(f"Match not found for {filename}")
#         return 'NA'

# %%
# Function to extract the age from the filename (for canola dataset)

# 'D:/SLEAP/SLEAP_Canola_Pennycress/primary_root/h5_files_for_PR_sleap_project/9_do/33PFABDMTW.h5'
# Z:/Experiments/Canola/CYL_Canola_Diversity_Screen/Downstream_Data_Extraction_and_Analysis/4-19-23_data_v000_not_qc_not_proofread/H5_w_SLEAP_predictions_preqc_preproofread/W22/2do/HMDQXXWRSQ.h5
# D:\SLEAP\SLEAP_Canola_Pennycress\primary_root\h5_files_for_PR_sleap_project\pennycress\14_do
# def extract_age(filename):
#     match = re.search(r'(\d+)_do', filename)
#     match2 = re.search(r'(\d+)do', filename)
#     if match:
#         print(f"Match found: {match.group(1)}")
#         # Check to see if it is pennycress
#         if 'pennycress' in filename:
#             return f"pennycress_{match.group(1)}"
#         return match.group(1)
#     elif match2:
#         print(f"Match found: {match2.group(1)}")
#         return match2.group(1)
#     else:
#         print(f"Match not found for {filename}")
#         return 'NA'

# %%
# Function to extract the age from the filename (for pennycress dataset)
# D:\SLEAP\SLEAP_Canola_Pennycress\primary_root\h5_files_for_PR_sleap_project\pennycress\14_do
# D:/SLEAP/SLEAP_Canola_Pennycress/lateral_3_nodes/h5_files_for_LR_sleap_project/pennycress_round2/7P2M34R81D.h5
# def extract_age(filename):
#     match = re.search(r'(\d+)_do', filename)
#     match2 = re.search('pennycress_round2', filename)
#     if match:
#         print(f"Match found: {match.group(1)}")
#         return match.group(1)
#     elif match2:
#         print(f"Match found: {match2.group(0)}")
#         return 14
#     else:
#         print(f"Match not found for {filename}")
#         return 'NA'

# %%
# Function to extract the age from the filename (for arabidopsis dataset)
# D:/SLEAP/SLEAP_arabidopsis/h5_files_7dap_041522/1027_E_R1.h5
# D:/SLEAP/SLEAP_arabidopsis/h5_files_reorganized/11_days/DMSO/1002_1.h5
# def extract_age(filename):
#     match = re.search(r'_(\d+)dap', filename)
#     match2 = re.search(r'(\d+)_days', filename)
#     if match:
#         print(f"Match found: {match.group(1)}")
#         return match.group(1)
#     elif match2:
#         print(f"Match found: {match2.group(1)}")
#         return match2.group(1)
#     else:
#         print(f"Match not found for {filename}")
#         return 'NA'

# %%
# arabidopsis, pennycress and canola
# def extract_age(filename):
#     match_pennycress = re.search(r'pennycress', filename)
#     match_arabodopsis = re.search(r'arabidopsis', filename)
#     # match_canola1 =  re.search(r'(\d+)_do', filename)
#     # match_canola2 = re.search(r'(\d+)do', filename)
#     if match_pennycress:
#         return 'pennycress'
#     elif match_arabodopsis:
#         print(f"Match found for {filename}")
#         return 'arabidopsis'
#     else:
#         print(f"Match not found for {filename}")
#         return 'NA'

# %%
base_labels = sleap.load_file(Path(labels_path).as_posix()) # load labels file
user_labels = base_labels.with_user_labels_only() # user instances only

# %%
# Make the output directory if it doesn't exist
Path(output_path).mkdir(parents=True, exist_ok=True)

# %%
# Print the first few items to check their structure
for label in user_labels[:5]:
    print(label)
# Out:
# LabeledFrame(video=HDF5Video('D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/6Z2NR7Q.h5'), frame_idx=0, instances=6)
# LabeledFrame(video=HDF5Video('D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/6Z2NR7Q.h5'), frame_idx=3, instances=6)
# LabeledFrame(video=HDF5Video('D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/0GYVRBO.h5'), frame_idx=0, instances=9)
# LabeledFrame(video=HDF5Video('D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/0GYVRBO.h5'), frame_idx=3, instances=8)
# LabeledFrame(video=HDF5Video('D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/0K9E8BI.h5'), frame_idx=0, instances=3)

# %%
print(f"There are {len(user_labels)} labels total.")

# Variables to keep count of matches and non-matches
match_count = 0
no_match_count = 0

# Create a DataFrame from the canola labels
data = []
for label in user_labels:
    age = extract_age(label.video.filename)
    if age != 'NA':
        match_count += 1
    else:
        no_match_count += 1
    data.append({'video_filename': label.video.filename, 'days_old': age})

df = pd.DataFrame(data)

# Save the DataFrame to a CSV file
csv_file = Path(output_path) / 'video_ages.csv'
df.to_csv(csv_file, index=False)

print(f"Details saved to {csv_file}")
print(f"Number of labeled frames with age found: {match_count}")
print(f"Number of labeled frames with age not found: {no_match_count}")
# Out:
# There are 586 labels total.
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/6Z2NR7Q.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/6Z2NR7Q.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/0GYVRBO.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/0GYVRBO.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/0K9E8BI.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/0K9E8BI.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/0OTKRUH.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/0OTKRUH.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/0Q7DV3E.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/0Q7DV3E.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/0S5UOG4.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/0S5UOG4.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/0T1JVVK.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/0T1JVVK.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/0VKBP5C.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/0VKBP5C.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/1DSR7T9.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/1DSR7T9.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/1ESMOKK.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/1HK9E28.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/1HK9E28.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/1IT28H1.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/1IT28H1.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/1L9IDR4.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/1QL685D.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/1QL685D.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/1S4UA7C.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/1S4UA7C.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/1TWI6T3.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/1TWI6T3.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/1ESMOKK.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/1ESMOKK.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/1L9IDR4.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/1L9IDR4.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/1QL685D.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/2LR30A9.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/2LR30A9.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/2OXIBYE.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/2OXIBYE.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/2Z86SO1.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/2Z86SO1.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/NGVI8V2.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/XFL3QZL.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/Z5JXSRD.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/03LSBKX.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/03LSBKX.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/3EROJVR.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/3EROJVR.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/3EROJVR.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/3GAN648.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/3GAN648.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/3LIAGQX.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/3LIAGQX.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/3LIAGQX.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/3M81DAH.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/3M81DAH.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/3M81DAH.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/3NZ5VHN.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/3NZ5VHN.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/K2JR03P.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/0GYVRBO.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/0K9E8BI.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/3VVBTJY.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/5FMRDSA.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/5FMRDSA.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/5JGSFDD.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/CG80XIB.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/CG80XIB.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/K2JR03P.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/N0QVV38.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/N0QVV38.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/NGVI8V2.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/S0F7SA1.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/S0F7SA1.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/UMVAAYD.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/XFL3QZL.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/Z5JXSRD.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/UMVAAYD.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/5JGSFDD.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/3PGOE0V.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/3R3XEXW.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/4A4URF6.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/4FCYLI7.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/4RETAZ7.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/4UNPKCV.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/4XMOTDX.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/4Y8KDC0.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/5DF4U1D.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/5IZOP2Y.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/5JGSFDD.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/5PEFY2G.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/5R32HX4.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/5SWTI4Q.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/6RUAQ3V.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/6XR60ED.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/7BWX1JK.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/7HAHB8L.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/7NC6XM4.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/7OM5AZN.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/8E4KG77.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/8FXG8UA.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/8KVVEUI.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/8R0B4QY.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/8TJAAEL.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/8V5R0R6.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/8XP941O.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/9FPQ3WR.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/9YTQ5LP.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/11KRJS1.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/22VX7PD.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/25UUY5L.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/27Q6KRQ.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/39N151W.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/56TMR7T.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/060A8AP.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/60S80RL.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/62LVJ0H.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/71AE2FQ.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/71XUN1B.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/73CUFI3.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/513TTTO.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/571KAZD.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/768R0BG.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/4016D73.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/A1DNMU3.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/A3WKL39.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/A21R3I7.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/4KPK15A.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/4KPK15A.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/4JGS40I.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/4JGS40I.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/4HXTZYQ.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/0EOWT9X.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/0EOWT9X.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/4HXTZYQ.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/3XGI2OS.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/3XGI2OS.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/3ULCFGZ.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/3ULCFGZ.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/3RN34FM.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/3RN34FM.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/3MN894M.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/3MN894M.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/3GX3K3I.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/3GX3K3I.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/3C1B3H0.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/3C1B3H0.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/2ZLIKDY.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/2ZLIKDY.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/2PWE1LK.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/2PWE1LK.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/2GJPZR9.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/2GJPZR9.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/2MQWVKI.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/2MQWVKI.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/2N6G1OT.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/2N6G1OT.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/2P8UPAP.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/2P8UPAP.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/0FSD6LN.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/0FSD6LN.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/0RFZ6F3.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/0RFZ6F3.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/0SHJAQH.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/0SHJAQH.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/1CIRQFX.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/1CIRQFX.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/1SMV84T.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/1SMV84T.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/1UR80QH.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/1UR80QH.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/4NDSTR6.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/4NDSTR6.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/4UHTCNN.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/4UHTCNN.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/4XK8EA1.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/4XK8EA1.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/5DM84R8.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/5DM84R8.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/5DR5RUZ.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/5DR5RUZ.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/5MRFG84.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/5MRFG84.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/5OJBT89.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/5OJBT89.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/5R540BR.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/5R540BR.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/5WZQUOE.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/5WZQUOE.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/06XC2PR.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/06XC2PR.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/6G4WFIW.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/6G4WFIW.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/6GTZS83.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/6GTZS83.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/6M1KSCY.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/6M1KSCY.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/6Q2M9D6.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/6Q2M9D6.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/6Q5DNRP.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/6Q5DNRP.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/6QES4PP.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/6QES4PP.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/6R65VGL.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/6R65VGL.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/6S6Q6FN.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/6S6Q6FN.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/6VT3YA6.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/6VT3YA6.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/6X4CEZD.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/6X4CEZD.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/7GV3LVQ.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/7GV3LVQ.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/7JBIPA2.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/7JBIPA2.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/7K5S86Y.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/avery_main_root_rice_10do_FN_week3_5-9-22/7K5S86Y.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/0CPQJ1R.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/0CPQJ1R.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/0FHOBV7.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/0FHOBV7.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/0ML45XM.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/0ML45XM.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/0NK1R70.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/0NK1R70.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/0QMZ91L.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/0QMZ91L.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/0X1855H.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/0X1855H.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/1HFSYPK.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/1HFSYPK.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/1QKUCG5.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/1QKUCG5.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/1X027XU.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/1X027XU.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/1XUVTQC.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/2CXQ777.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/2CXQ777.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/2GU3CS5.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/2GU3CS5.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/2H53DRN.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/2H53DRN.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/2K2AJLY.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/2K2AJLY.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/2OHXTVT.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/2OHXTVT.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/2PN576K.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/2PN576K.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/2R7J25J.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/2R7J25J.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/2RB2F19.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/2RB2F19.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/2SIBCNV.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/2SIBCNV.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/3ACHKKM.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/3ACHKKM.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/3C38WES.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/3C38WES.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/3GC9NFZ.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/3GC9NFZ.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/3HXF7XU.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/3HXF7XU.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/3JJW38W.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/3JJW38W.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/3KH9OIY.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/3KH9OIY.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/3WO0WF5.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/3WO0WF5.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/3XNLCLP.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/3XNLCLP.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/4BWO9HV.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/4BWO9HV.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/4ECDRP1.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/4ECDRP1.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/4IYZ6WX.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/4IYZ6WX.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/4R758T5.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/4R758T5.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/4RTPA69.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/4RTPA69.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/4YORSMB.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/4YORSMB.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/4YY2V8H.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/4YY2V8H.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/05MX009.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/05MX009.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/5E05I7Z.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/5E05I7Z.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/5JJAKPB.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/5JJAKPB.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/5PNBYR3.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/5PNBYR3.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/5TUISHC.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/5TUISHC.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/5VWQBUH.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/5VWQBUH.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/5X0I9EK.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/5X0I9EK.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/5Y7XHQT.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/5Y7XHQT.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/5Z4MU99.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/5Z4MU99.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/5ZYSP3X.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/5ZYSP3X.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/6E0SRQK.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/6E0SRQK.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/6N82OR6.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/6N82OR6.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/6R6XY4X.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/6R6XY4X.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/6VCBU2R.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/6VCBU2R.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/6VJBTUY.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/6VJBTUY.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/6XMTRQ1.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/6XMTRQ1.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/7CCB81F.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/7CCB81F.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/7IQ17MY.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/7IQ17MY.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/7KR4PQC.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/7KR4PQC.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/7PX8571.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/7PX8571.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/7T2WV21.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/7T2WV21.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/7Y4XLX6.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/7Y4XLX6.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/8G6CTL1.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/8G6CTL1.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/8OIA86D.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/8OIA86D.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/8TSWDSA.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/8TSWDSA.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/8VNWEBT.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/8VNWEBT.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/9ANMM1Q.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/9ANMM1Q.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/9BOTTZK.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/9BOTTZK.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/9EX65X9.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/9EX65X9.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/15M3KGP.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/15M3KGP.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/21WK4VJ.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/21WK4VJ.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/25NAT7V.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/25NAT7V.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/33E11T2.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/33E11T2.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/38HY8Y3.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/38HY8Y3.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/54CPYU0.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/54CPYU0.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/88QPFSW.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/88QPFSW.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/089TE5E.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/089TE5E.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/0203BC6.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/0203BC6.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/612K6PX.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/612K6PX.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/698BJ07.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/698BJ07.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/844Q65Q.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/844Q65Q.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/854IL8S.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/854IL8S.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/926PP1Q.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/926PP1Q.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/5987UN7.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/5987UN7.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/A2J1FLC.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/A2J1FLC.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/A9E8MIQ.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/A9E8MIQ.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/A9EL4GX.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/A9EL4GX.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/A97O8Q1.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/A97O8Q1.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/A864X22.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/A864X22.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/ACCDAI9.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/ACCDAI9.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/AGXOOPD.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/AGXOOPD.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/AL223EA.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/AL223EA.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/APZD0GH.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/APZD0GH.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/AS6RTFG.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/AS6RTFG.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/ASGT5EB.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/ASGT5EB.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/AUMWHCG.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/AUMWHCG.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/BAZY6OM.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/BAZY6OM.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/BKOBY21.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/BKOBY21.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/BRV2EZ9.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/BRV2EZ9.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/BWCL9E0.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/BWCL9E0.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/C0UW33G.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/C0UW33G.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/C3O97A5.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/C3O97A5.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/CO5C7IY.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/CO5C7IY.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/CPLU3UD.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/CPLU3UD.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/CPNZRVG.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/CPNZRVG.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/CQ9IPBC.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/CQ9IPBC.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/D2H1KES.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/D2H1KES.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/D2SNWCM.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/D2SNWCM.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/D4W48CI.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/D4W48CI.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/D7K5G48.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/D7K5G48.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/DEBM0AB.h5
# ...
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/F8OT8UJ.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/F8OT8UJ.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/F9GVR6K.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/F9GVR6K.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/F9RA38X.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/F9RA38X.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/F42VEQ1.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/F42VEQ1.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/F241Y3A.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/F241Y3A.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/F484L5E.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/F484L5E.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/FF26MWL.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/FF26MWL.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/FU6THMW.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/FU6THMW.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/FUFVNS3.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/FUFVNS3.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/FVUFFRB.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/FVUFFRB.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/FX3O4OF.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/FX3O4OF.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/G3WEN10.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/G3WEN10.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/G30XI6O.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/G30XI6O.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/GE87FLV.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/GE87FLV.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/GKSJZQE.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/GKSJZQE.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/GLJLEWT.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/GLJLEWT.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/GLL6TKG.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/GLL6TKG.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/H2GHFBB.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/H2GHFBB.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/H9BHZEI.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/H9BHZEI.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/HC8OY17.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/HC8OY17.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/HDFXZ7T.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/HDFXZ7T.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/HMNQNHZ.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/HMNQNHZ.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/HSSPSKX.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/HSSPSKX.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/HYVORMJ.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/HYVORMJ.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/IEWFHRY.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/IEWFHRY.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/IF2C88A.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/IF2C88A.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/IHFJ69C.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/IHFJ69C.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/IJLN7X3.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/IJLN7X3.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/INGFAIP.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/INGFAIP.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/INMFZWO.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/INMFZWO.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/IP4JLAJ.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/IP4JLAJ.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/IQ9HL8H.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/IQ9HL8H.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/IXTS6UU.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/IXTS6UU.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/IXYI87N.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/IXYI87N.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/J1EQWVZ.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/J1EQWVZ.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/JAYQ4S8.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/JAYQ4S8.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/JBLR8CF.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/JBLR8CF.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/JD6MA0D.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/JD6MA0D.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/JNEMA8U.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/JNEMA8U.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/JP4OCL3.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/JP4OCL3.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/JUCV9K8.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/JUCV9K8.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/JX2G82F.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/JX2G82F.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/JZMMQIX.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/JZMMQIX.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/K0L2FPY.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/K0L2FPY.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/K2L4LW0.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/K2L4LW0.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/K4XFXLW.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/K4XFXLW.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/KA5CUOS.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/KA5CUOS.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/KEBNC4X.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/KEBNC4X.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/KEMG91Z.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/KEMG91Z.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/KP1N8V2.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/KP1N8V2.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/KQRDCSN.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/KQRDCSN.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/KXVQVR2.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/KXVQVR2.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/KY3M54Q.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/KY3M54Q.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/LDIEWB0.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/LDIEWB0.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/LMK7BQ6.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/LMK7BQ6.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/LOLV00T.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/LOLV00T.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/LOZ134Z.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/LOZ134Z.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/LTMESVZ.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/LTMESVZ.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/LTPQCVT.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/LTPQCVT.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/M1P1ZCA.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/M1P1ZCA.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/MA3WIL0.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/dawn_main_root_rice_10do_FN_week2_5-2-22/MA3WIL0.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/AGAMDNF.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/AGAMDNF.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/AEZ18IH.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/AXDCT5H.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/AXDCT5H.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/AT6XX0T.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/ACCFKGT.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/AEZ18IH.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/ACCFKGT.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/AM2LY2W.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/AM2LY2W.h5
# Extracted age: 10 from filename: D:/SLEAP/SLEAP_Rice/10_do/h5_files/Day10_4-25-2022/AT6XX0T.h5
# Details saved to D:\SLEAP\20250530_seminal_root_generalist\older_rice\video_ages.csv
# Number of labeled frames with age found: 586
# Number of labeled frames with age not found: 0

# %%
# Ensure the ages are treated as integers
df['days_old'] = df['days_old'].astype(int)

# Plotting the bar graph
age_counts = df['days_old'].value_counts().sort_index()
plt.figure(figsize=(5, 6), facecolor='white') 
age_counts.plot(kind='bar', color='blue')  # Set color to blue
plt.title('Count of Ages in Labels')
plt.xlabel('Age (Days)')
plt.ylabel('Count')
plt.xticks(rotation=0)  # Rotate the x-axis labels
plt.tight_layout()  # Adjusts the plot to ensure a tight fit

# Save the figure
plot_path = Path(output_path) / 'age_distribution.png'
plt.savefig(plot_path, facecolor='white', bbox_inches='tight')
plt.show()

print(f"Plot saved to {plot_path}")
# Out:
# Plot saved to D:\SLEAP\20250530_seminal_root_generalist\older_rice\age_distribution.png

# %%
n_train = int(fraction_train*len(user_labels))
print(f"Number of labels for training set should be {n_train}.")
n_val = int((1-fraction_train)*val_test_fraction*len(user_labels))
print(f"Number of labels for validation set should be {n_val}.")
n_test = int((1-fraction_train)*val_test_fraction*len(user_labels))
print(f"Number of labels for validation set should be {n_test}.")
# Out:
# Number of labels for training set should be 410.
# Number of labels for validation set should be 87.
# Number of labels for validation set should be 87.

# %%
# Initialize a list to store information for the CSV file
csv_data = []

for i in range(num_splits):
    # Split the training and validation sets
    labels_train, _, labels_val, _ = sleap.nn.data.training.split_labels_train_val(user_labels, 1-fraction_train) # 1-`fraction_train` allocated for validation and testing
    labels_val, _, labels_test, _ = sleap.nn.data.training.split_labels_train_val(labels_val, val_test_fraction) # `val_test_fraction` of `labels_val` made into a test set

    # Make a directory for this split
    split_dir = Path(output_path) / f"train_test_split.v00{i}"
    os.makedirs(split_dir, exist_ok=True)

    # Save the train, val and test sets
    train_path = Path(split_dir) / "train.pkg.slp"
    val_path = Path(split_dir) / "val.pkg.slp"
    test_path = Path(split_dir) / "test.pkg.slp"
    labels_train.save(train_path, with_images=True)
    labels_val.save(val_path, with_images=True)
    labels_test.save(test_path, with_images=True)

    # Store the information in the list for train, val and test splits
    csv_data.append({'path': train_path, 'version': i, 'labeled_frames': len(labels_train), 'split_type': 'train'})
    csv_data.append({'path': val_path, 'version': i, 'labeled_frames': len(labels_val), 'split_type': 'val'})
    csv_data.append({'path': test_path, 'version': i, 'labeled_frames': len(labels_test), 'split_type': 'test'})

# %%
# Convert the list to a DataFrame and save as CSV
df_new = pd.DataFrame(csv_data)
csv_path = Path(output_path) / 'train_test_splits.csv'
df_new.to_csv(csv_path, index=False)

print(f"Train, val and test splits information saved to {csv_path}")
# Out:
# Train, val and test splits information saved to D:\SLEAP\20250530_seminal_root_generalist\older_rice\train_test_splits.csv

# %%
df_new
# Out:
#                                                  path  version  \
# 0   D:\SLEAP\20250530_seminal_root_generalist\olde...        0
# 1   D:\SLEAP\20250530_seminal_root_generalist\olde...        0
# 2   D:\SLEAP\20250530_seminal_root_generalist\olde...        0
# 3   D:\SLEAP\20250530_seminal_root_generalist\olde...        1
# 4   D:\SLEAP\20250530_seminal_root_generalist\olde...        1
# 5   D:\SLEAP\20250530_seminal_root_generalist\olde...        1
# 6   D:\SLEAP\20250530_seminal_root_generalist\olde...        2
# 7   D:\SLEAP\20250530_seminal_root_generalist\olde...        2
# 8   D:\SLEAP\20250530_seminal_root_generalist\olde...        2
# 9   D:\SLEAP\20250530_seminal_root_generalist\olde...        3
# 10  D:\SLEAP\20250530_seminal_root_generalist\olde...        3
# 11  D:\SLEAP\20250530_seminal_root_generalist\olde...        3
# 12  D:\SLEAP\20250530_seminal_root_generalist\olde...        4
# 13  D:\SLEAP\20250530_seminal_root_generalist\olde...        4
# 14  D:\SLEAP\20250530_seminal_root_generalist\olde...        4
# 15  D:\SLEAP\20250530_seminal_root_generalist\olde...        5
# 16  D:\SLEAP\20250530_seminal_root_generalist\olde...        5
# 17  D:\SLEAP\20250530_seminal_root_generalist\olde...        5
#
#     labeled_frames split_type
# 0              410      train
# 1               88        val
# 2               88       test
# 3              410      train
# 4               88        val
# 5               88       test
# 6              410      train
# 7               88        val
# 8               88       test
# 9              410      train
# 10              88        val
# 11              88       test
# 12             410      train
# 13              88        val
# 14              88       test
# 15             410      train
# 16              88        val
# 17              88       test
